# %%
import os
import glob
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras import layers, models, Input, mixed_precision
from sklearn.model_selection import train_test_split
import cv2
import keras
print("library loaded successfully")
# Out:
# library loaded successfully

# %%
IMG_SIZE = 256  # Standardized input resolution for both phases
BATCH_SIZE = 4 # Batch size
EPOCHS_PHASE1 = 120  # Semantic Segmentation Focus, for Segmentation 
EPOCHS_PHASE2 = 100   # Segmentation-Based Classification Focus for classification Polyp and Non-Polyp

# %% [markdown]
# #### Declaring dataset path for segmentation and classification

# %%
# Directory and Artifact Paths
DATA_PATH = '/mnt/c/development/Thesis/PolypSegmentationBasedClassification/DataSets/PolypGen2021_MultiCenterData_v2'
POSITIVE_DIR = os.path.join(DATA_PATH, 'imagesAll_positive') # For Polyp classification
NEGATIVE_DIR = os.path.join(DATA_PATH, 'sequenceData/negativeOnly')  # For non polyp classification
MODEL_SAVE_PATH = "/mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_26_5_04.keras"

# %% [markdown]
# #### mixed_precision
# Activate mixed precision training for efficiency and memory optimization
# It is a performance optimization for GPU. It utilize half of the GPU Memory,
# increases the the model training speed 3 times without effecting on accuracy.
# mixed_float16, 16 bits helps to get speedy calculation when need, Flawless accuracy performed by 32-bits

# %%
mixed_precision.set_global_policy('mixed_float16')

# %% [markdown]
# #### Image Augmentation
# As we have limited datasources we have to augment images. If we train with limited datasets Model can memorize
# instead of learning which causes overfitting. An overfitted model cannot predict other image except training dataset. Even it cannot predict on validation dataset as well.The **overfitting occurs** when The Training Loss going down but the validation loss increases at a time

# %%
def augment(img, mask):
    """Applies shape-preserving geometric and radiometric transformations."""
    if tf.random.uniform(()) > 0.5:
        img = tf.image.flip_left_right(img)
        mask = tf.image.flip_left_right(mask)
    if tf.random.uniform(()) > 0.5:
        img = tf.image.flip_up_down(img)
        mask = tf.image.flip_up_down(mask)
    
    img = tf.image.random_brightness(img, max_delta=0.15)
    img = tf.image.random_contrast(img, lower=0.85, upper=1.15)
    img = tf.clip_by_value(img, 0.0, 1.0)
    
    img.set_shape([IMG_SIZE, IMG_SIZE, 3])
    mask.set_shape([IMG_SIZE, IMG_SIZE, 1])
    return img, mask

# %% [markdown]
# #### Data / Image pre-processing pipeline for segmentation
# This functions primary task is to load raw images corresponding its mask image from the file storage, clean them up, standardizing the image size finally convert them into clean tensor ( or a 2D matrix) suitable for the model to be trained.

# %%
# def process_path_segmentation(img_path, mask_path):
#     """
#     Advanced Preprocessing Wrapper for Dataset B.
#     Applies CLAHE and Mild Sharpening via OpenCV with strict EagerTensor handles.
#     """
#     def _read_and_process(img_p, mask_p):
#         img_p_str = img_p.numpy().decode('utf-8') if hasattr(img_p, 'numpy') else img_p.decode('utf-8')
#         mask_p_str = mask_p.numpy().decode('utf-8') if hasattr(mask_p, 'numpy') else mask_p.decode('utf-8')
        
#         img = cv2.imread(img_p_str)
#         img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#         img = cv2.resize(img, (IMG_SIZE, IMG_SIZE))
        
#         mask = cv2.imread(mask_p_str, cv2.IMREAD_GRAYSCALE)
#         mask = cv2.resize(mask, (IMG_SIZE, IMG_SIZE))
        

#         lab = cv2.cvtColor(img, cv2.COLOR_RGB2LAB)
#         l_channel, a_channel, b_channel = cv2.split(lab)
        
#         clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
#         cl = clahe.apply(l_channel)
        
#         limg = cv2.merge((cl, a_channel, b_channel))
#         enhanced_img = cv2.cvtColor(limg, cv2.COLOR_LAB2RGB)
        

#         gaussian_blur = cv2.GaussianBlur(enhanced_img, (5, 5), 1.0)
#         sharpened = cv2.addWeighted(enhanced_img, 1.5, gaussian_blur, -0.5, 0)
        
#         normalized_img = sharpened / 255.0
#         normalized_mask = mask / 255.0
#         normalized_mask = np.where(normalized_mask > 0.5, 1.0, 0.0)
        
#         normalized_mask = np.expand_dims(normalized_mask, axis=-1)
        
#         return normalized_img.astype(np.float32), normalized_mask.astype(np.float32)


#     [img_tensor, mask_tensor] = tf.py_function(
#         _read_and_process, 
#         [img_path, mask_path], 
#         [tf.float32, tf.float32]
#     )
    

#     img_tensor.set_shape([IMG_SIZE, IMG_SIZE, 3])
#     mask_tensor.set_shape([IMG_SIZE, IMG_SIZE, 1])
    
#     return img_tensor, mask_tensor
def process_path_segmentation(img_path, mask_path):
    """
    Advanced Preprocessing Wrapper for Dataset B.
    Applies CLAHE and Mild Sharpening via OpenCV with Median Blur (Edge-Preserving).
    """
    def _read_and_process(img_p, mask_p):
        img_p_str = img_p.numpy().decode('utf-8') if hasattr(img_p, 'numpy') else img_p.decode('utf-8')
        mask_p_str = mask_p.numpy().decode('utf-8') if hasattr(mask_p, 'numpy') else mask_p.decode('utf-8')
        
        img = cv2.imread(img_p_str)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        img = cv2.resize(img, (IMG_SIZE, IMG_SIZE))
        
        mask = cv2.imread(mask_p_str, cv2.IMREAD_GRAYSCALE)
        mask = cv2.resize(mask, (IMG_SIZE, IMG_SIZE))
        
        # ─── STEP 1: CONTRAST ENHANCEMENT (CLAHE) ───
        lab = cv2.cvtColor(img, cv2.COLOR_RGB2LAB)
        l_channel, a_channel, b_channel = cv2.split(lab)
        
        clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
        cl = clahe.apply(l_channel)
        
        limg = cv2.merge((cl, a_channel, b_channel))
        enhanced_img = cv2.cvtColor(limg, cv2.COLOR_LAB2RGB)
        
        # ─── STEP 2: EDGE-PRESERVING NOISE REDUCTION (MEDIAN BLUR) ───
        # 🎯 GaussianBlur এর জায়গায় Median Blur যোগ করা হলো (Kernel size 5)
        median_blur = cv2.medianBlur(enhanced_img, 5)
        
        # ─── STEP 3: MILD SHARPENING ───
        # এখন মিডিয়ান ব্লারকে সাবট্র্যাক্ট করে বর্ডার আরও নিখুঁতভাবে শার্প করা হবে
        sharpened = cv2.addWeighted(enhanced_img, 1.5, median_blur, -0.5, 0)
        
        # ─── STEP 4: NORMALIZATION ───
        normalized_img = sharpened / 255.0
        normalized_mask = mask / 255.0
        normalized_mask = np.where(normalized_mask > 0.5, 1.0, 0.0)
        
        normalized_mask = np.expand_dims(normalized_mask, axis=-1)
        
        return normalized_img.astype(np.float32), normalized_mask.astype(np.float32)

    [img_tensor, mask_tensor] = tf.py_function(
        _read_and_process, 
        [img_path, mask_path], 
        [tf.float32, tf.float32]
    )
    
    img_tensor.set_shape([IMG_SIZE, IMG_SIZE, 3])
    mask_tensor.set_shape([IMG_SIZE, IMG_SIZE, 1])
    
    return img_tensor, mask_tensor

# %% [markdown]
# #### Data / Image Pre-processing for classification
# getting the image and label wheather it is polyp or not, also converting the image for standardization

# %%
def process_path_classification(img_path, label):
    """Preprocesses input tensors and categorical targets for Dataset A."""
    img = tf.io.read_file(img_path)
    img = tf.image.decode_image(img, channels=3, expand_animations=False)
    img = tf.image.resize(img, [IMG_SIZE, IMG_SIZE])
    img = tf.cast(img, tf.float32) / 255.0
    img.set_shape([IMG_SIZE, IMG_SIZE, 3])
    return img, label

# %% [markdown]
# #### Load Segmentation data path
# Instead of loading the actual images into memory, it loads the images path dynamically,
# The image is only collected for segmentation training, it it's exact mask match in the dataset directory.

# %%
def load_segmentation_paths(base_path):
    """Extracts paired image and mask absolute paths from multi-center repositories."""
    all_images, all_masks = [], []
    for i in range(1, 7):
        center_id = f"C{i}"
        img_dir = os.path.join(base_path, f"data_{center_id}", f"images_{center_id}")
        mask_dir = os.path.join(base_path, f"data_{center_id}", f"masks_{center_id}")
        if os.path.exists(img_dir) and os.path.exists(mask_dir):
            img_paths = (glob.glob(os.path.join(img_dir, "*.jpg")) + glob.glob(os.path.join(img_dir, "*.JPG")) +
                         glob.glob(os.path.join(img_dir, "*.png")) + glob.glob(os.path.join(img_dir, "*.jpeg")))
            for img_p in img_paths:
                filename = os.path.basename(img_p)
                name_without_ext, ext = os.path.splitext(filename)
                expected_mask_name = f"{name_without_ext}_mask{ext}"
                mask_p = os.path.join(mask_dir, expected_mask_name)
                if os.path.exists(mask_p):
                    all_images.append(img_p)
                    all_masks.append(mask_p)
    return all_images, all_masks

# %% [markdown]
# #### Load Classification data path
# this function labels the images into two classes -0 for Negative image or Non-Polyp and 1 for Positive image or Polyp
# **Note:** When your dataset has 90% negative and 10% positive, highly imbalance dataset it creates a cheat code to get high accuracy. thus it causes a Accuracy Paradox, and for this reason it misclassify the image.

# %%
def load_classification_paths():
    """Compiles absolute paths for global positive and artifact-heavy negative sequences."""
    valid_exts = ('*.png', '*.jpg', '*.jpeg', '*.bmp', '*.tif', '*.PNG', '*.JPG', '*.JPEG')
    pos_files, neg_files = [], []
    for ext in valid_exts:
        pos_files.extend(glob.glob(os.path.join(POSITIVE_DIR, "**", ext), recursive=True))
    for i in range(1, 14):
        target_folder = os.path.join(NEGATIVE_DIR, f"seq{i}_neg")
        if os.path.exists(target_folder):
            for ext in valid_exts:
                neg_files.extend(glob.glob(os.path.join(target_folder, "**", ext), recursive=True))
    pos_files = [f for f in pos_files if os.path.isfile(f)]
    neg_files = [f for f in neg_files if os.path.isfile(f)]
    
    file_paths = pos_files + neg_files
    labels = [1.0] * len(pos_files) + [0.0] * len(neg_files)
    return np.array(file_paths), np.array(labels, dtype=np.float32)

# %% [markdown]
# #### Squeeze-and-Excitation Block
# To get channel-wise attention it is very much powerful for CNN. An SE_Block dynamically learns which channel/features are the most important for a specific image and scale up the specific features with dimming down the noise with irrelevent ones.
# Standard CNN only looks at the small neighbour of the pixel at a time, But GlobalAveragePooling2D gets the average value of pixels.  from the total height and weight of a channel.
# __How Squeeze works:__
# We can consider an image with a 3D feature map, as it has three distinct geometric dimentions: Height, Width and Depth (Channels).
# Image Height (H) : Vertical Pixels (256 pixels height)
# Image Width (W) : Horizontal Pixels (256 pixels width)
# Channels (C): The depth layer, this is 3 (RGB)
# So an image has a 3D block dimentions = 256x256x3.
# When an image passes through convolutional layers, the spatial dimentions (H and W) usually shrink, but the number of channels (C) expands dramatically, Deep in your network you might have a feature map of size 16x16x512 that is a literal 3D cube made of 131,072 numarial values.
# ** The Sqeeze Turns 3D into 1D** ```layers.GlobalAveragePooling2D()(input_tensor)``` this sentence takes the 3D Cube and flattens its spatial dimentions.
#
# ```sh
# 3D CUBE[16x16x512] -----Global Average Pooling------> 1D vector [512]
#
# Before Squeeze (3D Cube):
#        _______
#       /      /|
#      /______/ |  <- 512 separate 16x16 slices stacked deep
#     |       | |
#     |_______|/
#   16x16 spatial grid
#
# After Squeeze (1D Array/Vector):
#     [ 0.78,  0.12,  0.91,  0.03, ... , 0.55 ]  <- Exactly 512 numbers long
# ```
# __How Excitation Works:__
# Excitation works with 3 steps.
# 1. (512-->32) Make the flatten array smaller from 512 to 32 by removing the noices and connecting the relation between hidden relations.
# 2. Employee ReLU filter: negative or week features are converted to 0
# 3. (32-->512) Revert the process.

# %%
def se_block(input_tensor, ratio=16):
    """Channel-wise Squeeze-and-Excitation Attention Layer."""
    channels = input_tensor.shape[-1]
    squeeze = layers.GlobalAveragePooling2D()(input_tensor)
    excitation = layers.Dense(channels // ratio, activation='relu', use_bias=False)(squeeze)
    excitation = layers.Dense(channels, activation='sigmoid', use_bias=False)(excitation)
    excitation = layers.Reshape((1, 1, channels))(excitation)
    return layers.multiply([input_tensor, excitation])

# %% [markdown]
# #### depthwise_separable_conv_block
# Instead of using Conv2D block, we integrated Depthwise Separable for optimizing the operation.

# %%
def depthwise_seperable_conv_block(x, filters, dropout_rate=0.0, name_prefix=""):
    """Multi-Scale Parallel Kernels (3x3, 5x5, 7x7, 1x1) with Depthwise Separable Convolutions."""
    f4 = filters // 4
    b3 = layers.SeparableConv2D(f4, 3, padding='same', use_bias=False, name=f"{name_prefix}_3x3")(x)
    b3 = layers.BatchNormalization()(b3); b3 = layers.Activation('relu')(b3)
    
    b5 = layers.SeparableConv2D(f4, 5, padding='same', use_bias=False, name=f"{name_prefix}_5x5")(x)
    b5 = layers.BatchNormalization()(b5); b5 = layers.Activation('relu')(b5)
    
    b7 = layers.SeparableConv2D(f4, 7, padding='same', use_bias=False, name=f"{name_prefix}_7x7")(x)
    b7 = layers.BatchNormalization()(b7); b7 = layers.Activation('relu')(b7)
    
    b1 = layers.SeparableConv2D(f4, 1, padding='same', use_bias=False, name=f"{name_prefix}_1x1")(x)
    b1 = layers.BatchNormalization()(b1); b1 = layers.Activation('relu')(b1)
    
    merged = layers.Concatenate(name=f"{name_prefix}_concat")([b3, b5, b7, b1])
    x_se = se_block(merged, ratio=16) 
    
    if x.shape[-1] == filters:
        x_se = layers.add([x, x_se], name=f"{name_prefix}_residual")
    if dropout_rate > 0:
        x_se = layers.SpatialDropout2D(dropout_rate, name=f"{name_prefix}_dropout")(x_se)
    return x_se

# %% [markdown]
# #### Pearson Corelation Coefficient
# As Global Average Pooling returns 1D feature vector, the relation can be found by employing PCC on this feature.
# The first and formost condition is to standardize the feature before employing PCC on 1D feature vector.

# %%
@tf.keras.utils.register_keras_serializable()
class KerasPCCLayer(layers.Layer):
    """Natively computes spatial Pearson Correlation Coefficients within the network graph."""
    def __init__(self, **kwargs):
        super(KerasPCCLayer, self).__init__(**kwargs)

    def call(self, inputs):
        # We used epsilon sothat standard deviation value cannot be zero, otherwise code will crash
        epsilon = 1e-8
        # finds the average standard deviaiton
        mean = tf.reduce_mean(inputs, axis=-1, keepdims=True)
        std = tf.math.reduce_std(inputs, axis=-1, keepdims=True) + epsilon
        # data normalization or (Z-Score)
        norm_inputs = (inputs - mean) / std
        pcc_matrix = tf.matmul(tf.expand_dims(norm_inputs, -1), tf.expand_dims(norm_inputs, 1))
        return layers.Flatten()(pcc_matrix)

# %% [markdown]
# #### Build Unified Segmentation based Model
# A multi-task Y-Net model building for both segmentation and classification for Colorectal Polyp.

# %%
def build_unified_segmentation_based_model(input_shape=(256, 256, 3)):
    """
    Constructs a dual-headed multi-task Y-Net architecture.
    Shares a deeply regularized, multi-scale latent space to simultaneously
    perform semantic image segmentation and unified scene classification.
    """
    # [Input Layer]: Defines the input tensor shape holding the raw 3-channel RGB medical images.
    inputs = Input(shape=input_shape, name="shared_input_image")

    # ── Shared Custom Multi-Scale Encoder ─────────────────────────────────────
    # Extracts multi-scale localized features down the spatial hierarchy while compressing parameters.
    
    # [Enc Block 1]: Processes raw input into 32 multi-scale feature channels. Output dim: (256, 256, 32)
    c1 = depthwise_seperable_conv_block(inputs, 32, name_prefix="enc_c1")
    # [Max Pooling 1]: Downsamples spatial dimensions by a factor of 2 via neighborhood max selection. Dim: (128, 128, 32)
    p1 = layers.MaxPooling2D(2, name="enc_p1")(c1)

    # [Enc Block 2]: Extracts deeper geometric abstractions into 64 semantic channels. Output dim: (128, 128, 64)
    c2 = depthwise_seperable_conv_block(p1, 64, name_prefix="enc_c2")
    # [Max Pooling 2]: Downsamples spatial dimensions further to compress representation. Dim: (64, 64, 64)
    p2 = layers.MaxPooling2D(2, name="enc_p2")(c2)

    # [Enc Block 3]: Scales representation to 128 channels; introduces 10% spatial dropout to avoid co-adaptation. Dim: (64, 64, 128)
    c3 = depthwise_seperable_conv_block(p2, 128, dropout_rate=0.1, name_prefix="enc_c3")
    # [Max Pooling 3]: Reduces resolution further, forcing the model to learn translation invariance. Dim: (32, 32, 128)
    p3 = layers.MaxPooling2D(2, name="enc_p3")(c3)

    # [Enc Block 4]: Captures high-level contextual abstracts across 256 channels with 20% spatial dropout. Dim: (32, 32, 256)
    c4 = depthwise_seperable_conv_block(p3, 256, dropout_rate=0.2, name_prefix="enc_c4")
    # [Max Pooling 4]: Compresses spatial grid to its lowest native encoder resolution. Dim: (16, 16, 256)
    p4 = layers.MaxPooling2D(2, name="enc_p4")(c4)
    
    # ── Shared Representation Latent Bottleneck ───────────────────────────────
    # The lowest spatial resolution holding the densest and most global abstract features.
    
    # [Shared Bottleneck]: Maps the compressed grid into a highly dense 512-channel latent feature space. Dim: (16, 16, 512)
    b = depthwise_seperable_conv_block(p4, 512, dropout_rate=0.3, name_prefix="shared_bottleneck")

    # ── Output Branch A: Semantic Segmentation Decoder ────────────────────────
    # Reconstructs spatial resolution progressively, using skip connections to retain fine edge details.
    
    # [Upsampling 4]: Uses learned transpose convolution filters to upscale the latent grid. Dim: (32, 32, 256)
    u4 = layers.Conv2DTranspose(256, 2, strides=2, padding='same', name="dec_u4")(b)
    # [Skip Connection 4]: Concatenates low-level encoder features (c4) along the channel axis. Total channels: 256 + 256 = 512
    u4 = layers.concatenate([u4, c4], name="dec_concat_4")
    # [Dec Block 5]: Regularizes concatenated representation back to 256 optimized multi-scale features. Dim: (32, 32, 256)
    c5 = depthwise_seperable_conv_block(u4, 256, dropout_rate=0.2, name_prefix="dec_c5")

    # [Upsampling 3]: Expands spatial dimensions by a factor of 2 using fractionally strided convolutions. Dim: (64, 64, 128)
    u3 = layers.Conv2DTranspose(128, 2, strides=2, padding='same', name="dec_u3")(c5)
    # [Skip Connection 3]: Merges encoder's mid-level spatial structural details (c3). Total channels: 128 + 128 = 256
    u3 = layers.concatenate([u3, c3], name="dec_concat_3")
    # [Dec Block 6]: Consolidates features and applies 10% dropout to eliminate localization noise. Dim: (64, 64, 128)
    c6 = depthwise_seperable_conv_block(u3, 128, dropout_rate=0.1, name_prefix="dec_c6")

    # [Upsampling 2]: Inverts the pooling operation of the encoder stage p2. Output dim: (128, 128, 64)
    u2 = layers.Conv2DTranspose(64, 2, strides=2, padding='same', name="dec_u2")(c6)
    # [Skip Connection 2]: Re-introduces high-resolution textures directly from encoder block c2. Total channels: 64 + 64 = 128
    u2 = layers.concatenate([u2, c2], name="dec_concat_2")
    # [Dec Block 7]: Harmonizes concatenated maps into 64 optimized spatial-channel streams. Dim: (128, 128, 64)
    c7 = depthwise_seperable_conv_block(u2, 64, name_prefix="dec_c7")

    # [Upsampling 1]: Restores feature maps back to the original input spatial size. Output dim: (256, 256, 32)
    u1 = layers.Conv2DTranspose(32, 2, strides=2, padding='same', name="dec_u1")(c7)
    # [Skip Connection 1]: Concat-links raw spatial coordinates and fine boundaries directly from c1. Total channels: 32 + 32 = 64
    u1 = layers.concatenate([u1, c1], name="dec_concat_1")
    # [Dec Block 8]: Refines final decoded features prior to pixel-level threshold mapping. Dim: (256, 256, 32)
    c8 = depthwise_seperable_conv_block(u1, 32, name_prefix="dec_c8")

    # [Segmentation Mask Output]: Maps 32 channels to a 1-channel binary pixel map via a 1x1 Conv with Sigmoid. Dim: (256, 256, 1)
    segmentation_output = layers.Conv2D(1, 1, activation='sigmoid', dtype='float32', name='seg_output')(c8)

    # ── Output Branch B: Segmentation-Guided Classification Head ──────────────
    # Re-purposes the rich latent space to predict global clinical states (e.g., normal vs abnormal).
    
    # [Classification CNN]: Performs light 3x3 depthwise separable convolution to filter classification cues. Dim: (16, 16, 128)
    pd_cnn = layers.SeparableConv2D(32, (3, 3), padding='same', activation='relu', name="clf_pd_cnn")(b)
    # [Max Pooling]: Downsamples classification maps spatially to distill localized signals. Output dim: (8, 8, 128)
    p_pool = layers.MaxPooling2D((2, 2), name="clf_maxpool")(pd_cnn)
    
    # [Global Average Pooling (GAP)]: Collapses spatial dimensions (8x8) into a single 128-dimensional global vector.
    flat_features = layers.GlobalAveragePooling2D(name="clf_gap")(p_pool)
    # [Keras PCC Layer]: Computes an all-to-all Pearson Correlation Matrix tracking linear statistical dependency between features.
    pcc_features = KerasPCCLayer(name="clf_pcc_layer")(flat_features)
    # [Z-Score Normalization]: Shifts feature distribution to a mean of 0 and variance of 1 to stabilize dense convergence.
    standardized = layers.BatchNormalization(name="clf_zscore_bn")(pcc_features)
    
    # [Fully Connected Dense]: Learns non-linear inter-feature correlation states over 64 hidden nodes.
    d1 = layers.Dense(64, activation='relu', name="clf_dense1")(standardized)
    # [Dropout]: Randomly zeros out 30% of connections during training iterations to deter neural memorization.
    d1 = layers.Dropout(0.3, name="clf_dropout")(d1)
    # [Classification Score Output]: Yields a singular scalar value (0 to 1) indicating global disease probability.
    classification_output = layers.Dense(1, activation='sigmoid', dtype='float32', name='clf_output')(d1)

    # [Model Compilation Graph]: Maps the input node to both parallel output tensors, finalizing the multi-task network.
    return models.Model(inputs=inputs, outputs=[segmentation_output, classification_output], name="Thesis_Unified_YNet")

# %% [markdown]
# #### Mathematical Criteria and Performance Metrics

# %% [markdown]
# #### Dice Coefficient
# The most popular performance matrix for segmentation. the more close to 100% means the better performance.
# Excellent dice Coef score between 0.8 to 0.9
# Good Score 0.70 to 0.80

# %%
@keras.saving.register_keras_serializable()
def dice_coef(y_true, y_pred, smooth=1.0):
    y_true_f = tf.cast(tf.reshape(y_true, [-1]), tf.float32)
    y_pred_f = tf.cast(tf.reshape(y_pred, [-1]), tf.float32)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return (2.0 * intersection + smooth) / (tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + smooth)

# %%
def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

# %%
def bce_dice_loss(y_true, y_pred):
    bce = tf.reduce_mean(tf.keras.losses.binary_crossentropy(y_true, y_pred))
    return bce + dice_loss(y_true, y_pred)

# %%
def focal_tversky_loss(y_true, y_pred, alpha=0.7, beta=0.3, gamma=0.75):
    """
    Focal Tversky Loss for imbalanced medical image segmentation.
    alpha: controls penalty for False Negatives (FN) -> keeping it higher (0.7) focuses on small polyps.
    beta: controls penalty for False Positives (FP).
    """
    y_true_f = tf.cast(tf.reshape(y_true, [-1]), tf.float32)
    y_pred_f = tf.cast(tf.reshape(y_pred, [-1]), tf.float32)
    
    # Calculate True Positives, False Negatives, and False Positives
    tp = tf.reduce_sum(y_true_f * y_pred_f)
    fn = tf.reduce_sum(y_true_f * (1.0 - y_pred_f))
    fp = tf.reduce_sum((1.0 - y_true_f) * y_pred_f)
    
    # Tversky Index
    smooth = 1e-6
    tversky_index = (tp + smooth) / (tp + alpha * fn + beta * fp + smooth)
    
    # Focal Tversky Loss
    return tf.math.pow((1.0 - tversky_index), gamma)

# %%
@keras.saving.register_keras_serializable()
def iou_metric(y_true, y_pred):
    y_true_f = tf.cast(y_true, tf.float32)
    y_pred_f = tf.cast(y_pred > 0.5, tf.float32)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    union = tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) - intersection
    return (intersection + 1.0) / (union + 1.0)

# %%
@keras.saving.register_keras_serializable()
def tnr_metric(y_true, y_pred):
    y_true_f = tf.cast(tf.reshape(y_true, [-1]), tf.float32)
    y_pred_f = tf.cast(tf.reshape(y_pred, [-1]), tf.float32)

    true_negatives = tf.reduce_sum(tf.cast((1.0 - y_true_f) * (1.0 - y_pred_f), tf.float32))
    false_positives = tf.reduce_sum(tf.cast((1.0 - y_true_f) * y_pred_f, tf.float32))
    
    # TNR = TN / (TN + FP)
    return (true_negatives + 1e-7) / (true_negatives + false_positives + 1e-7)

# %% [markdown]
# ### Master Pipeline Controller

# %%
# Initialize allocation strategy for physical compute hardware by scanning for available GPU units.
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus: tf.config.experimental.set_memory_growth(gpu, True)
        print("✓ Tensor Graph Allocation Locked over available GPU nodes.")
    except RuntimeError as e: print(e)

# 1. PARSE PIPELINE DIRECTORIES
print("\n[Data Ingestion] Parsing Multi-Center Localization Data (Dataset B)...")
seg_imgs, seg_masks = load_segmentation_paths(DATA_PATH)
s_train_x, s_val_x, s_train_y, s_val_y = train_test_split(seg_imgs, seg_masks, test_size=0.2, random_state=42)

print("[Data Ingestion] Parsing Balanced Sequence Arrays (Dataset A)...")
clf_imgs, clf_labels = load_classification_paths()
indices = np.arange(len(clf_imgs))
np.random.seed(42); np.random.shuffle(indices)
clf_imgs, clf_labels = clf_imgs[indices], clf_labels[indices]
c_split = int(0.8 * len(clf_imgs))

# 2. GENERATE HIGH-THROUGHPUT ITERATORS
print("\n⚡ Initializing Multi-Threaded High-Throughput Iterators via AUTOTUNE...")

# --- Segmentation Datasets ---
train_seg_ds = tf.data.Dataset.from_tensor_slices((s_train_x, s_train_y)) \
    .shuffle(len(s_train_x)) \
    .map(process_path_segmentation, num_parallel_calls=tf.data.AUTOTUNE) \
    .map(augment, num_parallel_calls=tf.data.AUTOTUNE) \
    .batch(BATCH_SIZE) \
    .prefetch(tf.data.AUTOTUNE)

val_seg_ds = tf.data.Dataset.from_tensor_slices((s_val_x, s_val_y)) \
    .map(process_path_segmentation, num_parallel_calls=tf.data.AUTOTUNE) \
    .batch(BATCH_SIZE) \
    .prefetch(tf.data.AUTOTUNE)


train_clf_ds = tf.data.Dataset.from_tensor_slices((clf_imgs[:c_split], clf_labels[:c_split])) \
    .shuffle(1024) \
    .map(process_path_classification, num_parallel_calls=tf.data.AUTOTUNE) \
    .batch(BATCH_SIZE) \
    .prefetch(tf.data.AUTOTUNE)

val_clf_ds = tf.data.Dataset.from_tensor_slices((clf_imgs[c_split:], clf_labels[c_split:])) \
    .map(process_path_classification, num_parallel_calls=tf.data.AUTOTUNE) \
    .batch(BATCH_SIZE) \
    .prefetch(tf.data.AUTOTUNE)

# 3. GRAPH INSTANTIATION
print("\n🏗️ Compiling Dual-Head Computation Topology...")
model = build_unified_segmentation_based_model()

# 🌟 STAGE 1: SEMANTIC SEGMENTATION MAXIMIZATION (Dataset B Only)
print("\n=======================================================")
print("[PHASE 1] Optimizing Localization Ensembles & Structural Layers")
print("=======================================================")

# Freeze classification branch entirely to avoid uninitialized variable gradients
for layer in model.layers:
    if "clf_" in layer.name:
        layer.trainable = False
    else:
        layer.trainable = True

model.compile(
    optimizer=mixed_precision.LossScaleOptimizer(tf.keras.optimizers.Adam(learning_rate=1e-3)),
    loss=[focal_tversky_loss, None],
    #metrics=[[dice_coef, iou_metric, 'accuracy'], []]
    metrics = {
        'seg_output': [
            'accuracy',                                      
            tf.keras.metrics.Recall(name='recall'),          
            tnr_metric,
            dice_coef,
            iou_metric
        ]
    }
)

# ── FIXED CALLBACKS FOR PHASE 1 ──────────────────────────────────────────
phase1_callbacks = [
    tf.keras.callbacks.ModelCheckpoint(MODEL_SAVE_PATH, monitor='val_seg_output_dice_coef', save_best_only=True, mode='max', verbose=1),
    tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=6, min_lr=1e-4, verbose=1)
]

# PHASE 1 Training started ...
history_p1 = model.fit(train_seg_ds, validation_data=val_seg_ds, epochs=EPOCHS_PHASE1, callbacks=phase1_callbacks, verbose=1)
print("[PHASE 1 COMPLETE] Spatial boundaries locked successfully.")

#  STAGE 2: SEGMENTATION-BASED CLASSIFICATION FINE-TUNING (Dataset A Only)
print("\n =======================================================")
print(" [PHASE 2] Initializing Classification Head over Locked Feature Embeddings")
print(" =======================================================")

# Reload historical weights to secure maximum localization properties
print(f"🔄 Fetching peak localization weights from storage: {MODEL_SAVE_PATH}")
model = tf.keras.models.load_model(MODEL_SAVE_PATH, custom_objects={
    'KerasPCCLayer': KerasPCCLayer, 
    'dice_coef': dice_coef, 
    'iou_metric': iou_metric, 
    'bce_dice_loss': bce_dice_loss,
    'focal_tversky_loss': focal_tversky_loss
})

# CRITICAL FIX: Explicitly freeze layers on the freshly reloaded model object 
print("🔒 Enforcing Strict Structural Freeze on the Shared Features Sub-Graph...")
for layer in model.layers:
    if "clf_" in layer.name:
        layer.trainable = True  # Unlock only the classification head
    else:
        layer.trainable = False # Permanently lock Encoder and Decoder paths to stop Catastrophic Forgetting

# Compile targeting classification targets mapped to Output Index 1
# model.compile(
#     optimizer=mixed_precision.LossScaleOptimizer(tf.keras.optimizers.Adam(learning_rate=1e-4)),
#     loss=[None, 'binary_crossentropy'],
#     metrics=[[], ['accuracy', tf.keras.metrics.AUC(name='auc')]]
# )

model.compile(
    optimizer=mixed_precision.LossScaleOptimizer(tf.keras.optimizers.Adam(learning_rate=1e-4)),
    loss=[None, 'binary_crossentropy'],
    metrics={
        'clf_output': ['accuracy', tf.keras.metrics.AUC(name='auc')] 
    }
)

phase2_callbacks = [
    tf.keras.callbacks.ModelCheckpoint(MODEL_SAVE_PATH, monitor='val_loss', save_best_only=True, mode='min', verbose=1),
    tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=25, restore_best_weights=True, mode='min', verbose=1)
]
history_p2 = model.fit(train_clf_ds, validation_data=val_clf_ds, epochs=EPOCHS_PHASE2, callbacks=phase2_callbacks, verbose=1)
print(f"🏆 [TRAINING COMPLETE] Unified Graph successfully archived at: {MODEL_SAVE_PATH}")
# Out:
# ✓ Tensor Graph Allocation Locked over available GPU nodes.
#
# [Data Ingestion] Parsing Multi-Center Localization Data (Dataset B)...
# [Data Ingestion] Parsing Balanced Sequence Arrays (Dataset A)...
#
# ⚡ Initializing Multi-Threaded High-Throughput Iterators via AUTOTUNE...
#
# 🏗️ Compiling Dual-Head Computation Topology...
#
# =======================================================
# [PHASE 1] Optimizing Localization Ensembles & Structural Layers
# =======================================================
# Epoch 1/120
# I0000 00:00:1779805945.644378    4547 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_2235119__.484
# I0000 00:00:1779805967.379277    4547 subprocess_compilation.cc:348] ptxas warning : Registers are spilled to local memory in function 'input_reduce_fusion_214', 44 bytes spill stores, 44 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'input_reduce_fusion_178', 56 bytes spill stores, 56 bytes spill loads
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.7494 - seg_output_accuracy: 0.6662 - seg_output_dice_coef: 0.2400 - seg_output_iou_metric: 0.1661 - seg_output_recall: 0.7713 - seg_output_tnr_metric: 0.6269
# I0000 00:00:1779806006.636795    4550 subprocess_compilation.cc:348] ptxas warning : Registers are spilled to local memory in function 'input_reduce_fusion_4', 56 bytes spill stores, 56 bytes spill loads
# Epoch 1: val_seg_output_dice_coef improved from None to 0.07239, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_26_5_04.keras
#
# Epoch 1: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_26_5_04.keras
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 102s 105ms/step - loss: 0.7208 - seg_output_accuracy: 0.7178 - seg_output_dice_coef: 0.2710 - seg_output_iou_metric: 0.1838 - seg_output_recall: 0.7672 - seg_output_tnr_metric: 0.6923 - val_loss: 0.9501 - val_seg_output_accuracy: 0.9197 - val_seg_output_dice_coef: 0.0724 - val_seg_output_iou_metric: 8.6287e-05 - val_seg_output_recall: 0.0000e+00 - val_seg_output_tnr_metric: 0.9584 - learning_rate: 0.0010
# Epoch 2/120
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.6564 - seg_output_accuracy: 0.7957 - seg_output_dice_coef: 0.3458 - seg_output_iou_metric: 0.2255 - seg_output_recall: 0.7318 - seg_output_tnr_metric: 0.8009
# Epoch 2: val_seg_output_dice_coef improved from 0.07239 to 0.34819, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_26_5_04.keras
#
# Epoch 2: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_26_5_04.keras
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 22s 70ms/step - loss: 0.6552 - seg_output_accuracy: 0.8054 - seg_output_dice_coef: 0.3502 - seg_output_iou_metric: 0.2269 - seg_output_recall: 0.6987 - seg_output_tnr_metric: 0.8151 - val_loss: 0.6748 - val_seg_output_accuracy: 0.8429 - val_seg_output_dice_coef: 0.3482 - val_seg_output_iou_metric: 0.2268 - val_seg_output_recall: 0.6069 - val_seg_output_tnr_metric: 0.8681 - learning_rate: 0.0010
# Epoch 3/120
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.6264 - seg_output_accuracy: 0.8386 - seg_output_dice_coef: 0.3880 - seg_output_iou_metric: 0.2553 - seg_output_recall: 0.6846 - seg_output_tnr_metric: 0.8531
# Epoch 3: val_seg_output_dice_coef did not improve from 0.34819
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 21s 68ms/step - loss: 0.6364 - seg_output_accuracy: 0.8354 - seg_output_dice_coef: 0.3782 - seg_output_iou_metric: 0.2473 - seg_output_recall: 0.6647 - seg_output_tnr_metric: 0.8515 - val_loss: 0.6619 - val_seg_output_accuracy: 0.7837 - val_seg_output_dice_coef: 0.3369 - val_seg_output_iou_metric: 0.2145 - val_seg_output_recall: 0.7580 - val_seg_output_tnr_metric: 0.7910 - learning_rate: 0.0010
# Epoch 4/120
# 306/307 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.6213 - seg_output_accuracy: 0.8488 - seg_output_dice_coef: 0.3931 - seg_output_iou_metric: 0.2579 - seg_output_recall: 0.6829 - seg_output_tnr_metric: 0.8639
# Epoch 4: val_seg_output_dice_coef did not improve from 0.34819
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 21s 68ms/step - loss: 0.6176 - seg_output_accuracy: 0.8544 - seg_output_dice_coef: 0.4029 - seg_output_iou_metric: 0.2659 - seg_output_recall: 0.6532 - seg_output_tnr_metric: 0.8731 - val_loss: 0.6489 - val_seg_output_accuracy: 0.7845 - val_seg_output_dice_coef: 0.3469 - val_seg_output_iou_metric: 0.2219 - val_seg_output_recall: 0.7847 - val_seg_output_tnr_metric: 0.7851 - learning_rate: 0.0010
# Epoch 5/120
# 306/307 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.6161 - seg_output_accuracy: 0.8590 - seg_output_dice_coef: 0.4056 - seg_output_iou_metric: 0.2679 - seg_output_recall: 0.6535 - seg_output_tnr_metric: 0.8780
# Epoch 5: val_seg_output_dice_coef improved from 0.34819 to 0.37760, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_26_5_04.keras
#
# Epoch 5: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_26_5_04.keras
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 23s 75ms/step - loss: 0.6049 - seg_output_accuracy: 0.8640 - seg_output_dice_coef: 0.4199 - seg_output_iou_metric: 0.2811 - seg_output_recall: 0.6555 - seg_output_tnr_metric: 0.8834 - val_loss: 0.6258 - val_seg_output_accuracy: 0.8209 - val_seg_output_dice_coef: 0.3776 - val_seg_output_iou_metric: 0.2468 - val_seg_output_recall: 0.7572 - val_seg_output_tnr_metric: 0.8270 - learning_rate: 0.0010
# Epoch 6/120
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.6217 - seg_output_accuracy: 0.8481 - seg_output_dice_coef: 0.4005 - seg_output_iou_metric: 0.2660 - seg_output_recall: 0.6538 - seg_output_tnr_metric: 0.8682
# Epoch 6: val_seg_output_dice_coef improved from 0.37760 to 0.43331, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_26_5_04.keras
#
# Epoch 6: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_26_5_04.keras
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 23s 73ms/step - loss: 0.6069 - seg_output_accuracy: 0.8604 - seg_output_dice_coef: 0.4165 - seg_output_iou_metric: 0.2791 - seg_output_recall: 0.6640 - seg_output_tnr_metric: 0.8792 - val_loss: 0.6264 - val_seg_output_accuracy: 0.9073 - val_seg_output_dice_coef: 0.4333 - val_seg_output_iou_metric: 0.2954 - val_seg_output_recall: 0.5206 - val_seg_output_tnr_metric: 0.9408 - learning_rate: 0.0010
# Epoch 7/120
# 306/307 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.6044 - seg_output_accuracy: 0.8741 - seg_output_dice_coef: 0.4280 - seg_output_iou_metric: 0.2892 - seg_output_recall: 0.6237 - seg_output_tnr_metric: 0.8979
# Epoch 7: val_seg_output_dice_coef improved from 0.43331 to 0.44443, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_26_5_04.keras
#
# Epoch 7: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_26_5_04.keras
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 23s 75ms/step - loss: 0.5969 - seg_output_accuracy: 0.8783 - seg_output_dice_coef: 0.4350 - seg_output_iou_metric: 0.2951 - seg_output_recall: 0.6305 - seg_output_tnr_metric: 0.9008 - val_loss: 0.5838 - val_seg_output_accuracy: 0.8810 - val_seg_output_dice_coef: 0.4444 - val_seg_output_iou_metric: 0.3024 - val_seg_output_recall: 0.6748 - val_seg_output_tnr_metric: 0.8996 - learning_rate: 0.0010
# Epoch 8/120
# 306/307 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.5700 - seg_output_accuracy: 0.8810 - seg_output_dice_coef: 0.4647 - seg_output_iou_metric: 0.3207 - seg_output_recall: 0.6594 - seg_output_tnr_metric: 0.9026
# Epoch 8: val_seg_output_dice_coef did not improve from 0.44443
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 22s 70ms/step - loss: 0.5863 - seg_output_accuracy: 0.8820 - seg_output_dice_coef: 0.4474 - seg_output_iou_metric: 0.3059 - seg_output_recall: 0.6337 - seg_output_tnr_metric: 0.9048 - val_loss: 0.5911 - val_seg_output_accuracy: 0.8806 - val_seg_output_dice_coef: 0.4363 - val_seg_output_iou_metric: 0.2972 - val_seg_output_recall: 0.6656 - val_seg_output_tnr_metric: 0.8994 - learning_rate: 0.0010
# Epoch 9/120
# 306/307 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.5815 - seg_output_accuracy: 0.8772 - seg_output_dice_coef: 0.4511 - seg_output_iou_metric: 0.3087 - seg_output_recall: 0.6649 - seg_output_tnr_metric: 0.8979
# Epoch 9: val_seg_output_dice_coef did not improve from 0.44443
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 22s 71ms/step - loss: 0.5772 - seg_output_accuracy: 0.8832 - seg_output_dice_coef: 0.4572 - seg_output_iou_metric: 0.3130 - seg_output_recall: 0.6549 - seg_output_tnr_metric: 0.9042 - val_loss: 0.6113 - val_seg_output_accuracy: 0.8690 - val_seg_output_dice_coef: 0.4123 - val_seg_output_iou_metric: 0.2767 - val_seg_output_recall: 0.6641 - val_seg_output_tnr_metric: 0.8865 - learning_rate: 0.0010
# Epoch 10/120
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.5891 - seg_output_accuracy: 0.8827 - seg_output_dice_coef: 0.4400 - seg_output_iou_metric: 0.3024 - seg_output_recall: 0.6529 - seg_output_tnr_metric: 0.9033
# Epoch 10: val_seg_output_dice_coef did not improve from 0.44443
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 22s 71ms/step - loss: 0.5774 - seg_output_accuracy: 0.8843 - seg_output_dice_coef: 0.4562 - seg_output_iou_metric: 0.3135 - seg_output_recall: 0.6497 - seg_output_tnr_metric: 0.9061 - val_loss: 0.6826 - val_seg_output_accuracy: 0.9298 - val_seg_output_dice_coef: 0.4129 - val_seg_output_iou_metric: 0.2839 - val_seg_output_recall: 0.3507 - val_seg_output_tnr_metric: 0.9801 - learning_rate: 0.0010
# Epoch 11/120
# 306/307 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.5605 - seg_output_accuracy: 0.9027 - seg_output_dice_coef: 0.4901 - seg_output_iou_metric: 0.3438 - seg_output_recall: 0.6137 - seg_output_tnr_metric: 0.9289
# Epoch 11: val_seg_output_dice_coef improved from 0.44443 to 0.48265, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_26_5_04.keras
#
# Epoch 11: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_26_5_04.keras
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 23s 74ms/step - loss: 0.5621 - seg_output_accuracy: 0.8996 - seg_output_dice_coef: 0.4835 - seg_output_iou_metric: 0.3390 - seg_output_recall: 0.6230 - seg_output_tnr_metric: 0.9246 - val_loss: 0.5821 - val_seg_output_accuracy: 0.9202 - val_seg_output_dice_coef: 0.4826 - val_seg_output_iou_metric: 0.3432 - val_seg_output_recall: 0.5650 - val_seg_output_tnr_metric: 0.9514 - learning_rate: 0.0010
# Epoch 12/120
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.5617 - seg_output_accuracy: 0.8889 - seg_output_dice_coef: 0.4771 - seg_output_iou_metric: 0.3324 - seg_output_recall: 0.6438 - seg_output_tnr_metric: 0.9130
# Epoch 12: val_seg_output_dice_coef did not improve from 0.48265
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 22s 70ms/step - loss: 0.5638 - seg_output_accuracy: 0.8914 - seg_output_dice_coef: 0.4740 - seg_output_iou_metric: 0.3312 - seg_output_recall: 0.6551 - seg_output_tnr_metric: 0.9133 - val_loss: 0.5782 - val_seg_output_accuracy: 0.8875 - val_seg_output_dice_coef: 0.4532 - val_seg_output_iou_metric: 0.3124 - val_seg_output_recall: 0.6805 - val_seg_output_tnr_metric: 0.9058 - learning_rate: 0.0010
# Epoch 13/120
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.5545 - seg_output_accuracy: 0.9021 - seg_output_dice_coef: 0.4945 - seg_output_iou_metric: 0.3497 - seg_output_recall: 0.6306 - seg_output_tnr_metric: 0.9275
# Epoch 13: val_seg_output_dice_coef improved from 0.48265 to 0.48991, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_26_5_04.keras
#
# Epoch 13: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_26_5_04.keras
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 26s 86ms/step - loss: 0.5596 - seg_output_accuracy: 0.8976 - seg_output_dice_coef: 0.4840 - seg_output_iou_metric: 0.3405 - seg_output_recall: 0.6377 - seg_output_tnr_metric: 0.9213 - val_loss: 0.5636 - val_seg_output_accuracy: 0.9107 - val_seg_output_dice_coef: 0.4899 - val_seg_output_iou_metric: 0.3474 - val_seg_output_recall: 0.6294 - val_seg_output_tnr_metric: 0.9352 - learning_rate: 0.0010
# Epoch 14/120
# 306/307 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.5506 - seg_output_accuracy: 0.8968 - seg_output_dice_coef: 0.4896 - seg_output_iou_metric: 0.3441 - seg_output_recall: 0.6645 - seg_output_tnr_metric: 0.9175
# Epoch 14: val_seg_output_dice_coef did not improve from 0.48991
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 24s 78ms/step - loss: 0.5488 - seg_output_accuracy: 0.8969 - seg_output_dice_coef: 0.4916 - seg_output_iou_metric: 0.3468 - seg_output_recall: 0.6611 - seg_output_tnr_metric: 0.9185 - val_loss: 0.6716 - val_seg_output_accuracy: 0.9349 - val_seg_output_dice_coef: 0.4308 - val_seg_output_iou_metric: 0.3029 - val_seg_output_recall: 0.3599 - val_seg_output_tnr_metric: 0.9848 - learning_rate: 0.0010
# Epoch 15/120
# 306/307 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.5545 - seg_output_accuracy: 0.9070 - seg_output_dice_coef: 0.4931 - seg_output_iou_metric: 0.3497 - seg_output_recall: 0.6256 - seg_output_tnr_metric: 0.9311
# Epoch 15: val_seg_output_dice_coef improved from 0.48991 to 0.52851, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_26_5_04.keras
#
# Epoch 15: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_26_5_04.keras
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 24s 76ms/step - loss: 0.5514 - seg_output_accuracy: 0.9000 - seg_output_dice_coef: 0.4920 - seg_output_iou_metric: 0.3463 - seg_output_recall: 0.6432 - seg_output_tnr_metric: 0.9234 - val_loss: 0.5434 - val_seg_output_accuracy: 0.9281 - val_seg_output_dice_coef: 0.5285 - val_seg_output_iou_metric: 0.3824 - val_seg_output_recall: 0.5838 - val_seg_output_tnr_metric: 0.9582 - learning_rate: 0.0010
# Epoch 16/120
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.5301 - seg_output_accuracy: 0.9100 - seg_output_dice_coef: 0.5163 - seg_output_iou_metric: 0.3706 - seg_output_recall: 0.6644 - seg_output_tnr_metric: 0.9322
# Epoch 16: val_seg_output_dice_coef did not improve from 0.52851
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 22s 71ms/step - loss: 0.5466 - seg_output_accuracy: 0.9022 - seg_output_dice_coef: 0.4971 - seg_output_iou_metric: 0.3530 - seg_output_recall: 0.6503 - seg_output_tnr_metric: 0.9254 - val_loss: 0.5730 - val_seg_output_accuracy: 0.9175 - val_seg_output_dice_coef: 0.4861 - val_seg_output_iou_metric: 0.3446 - val_seg_output_recall: 0.5734 - val_seg_output_tnr_metric: 0.9475 - learning_rate: 0.0010
# Epoch 17/120
# 306/307 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.5577 - seg_output_accuracy: 0.9012 - seg_output_dice_coef: 0.4864 - seg_output_iou_metric: 0.3445 - seg_output_recall: 0.6435 - seg_output_tnr_metric: 0.9249
# Epoch 17: val_seg_output_dice_coef did not improve from 0.52851
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 22s 71ms/step - loss: 0.5516 - seg_output_accuracy: 0.9010 - seg_output_dice_coef: 0.4918 - seg_output_iou_metric: 0.3492 - seg_output_recall: 0.6531 - seg_output_tnr_metric: 0.9239 - val_loss: 0.5421 - val_seg_output_accuracy: 0.9043 - val_seg_output_dice_coef: 0.4967 - val_seg_output_iou_metric: 0.3521 - val_seg_output_recall: 0.6902 - val_seg_output_tnr_metric: 0.9229 - learning_rate: 0.0010
# Epoch 18/120
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.5340 - seg_output_accuracy: 0.9048 - seg_output_dice_coef: 0.5083 - seg_output_iou_metric: 0.3599 - seg_output_recall: 0.6737 - seg_output_tnr_metric: 0.9255
# Epoch 18: val_seg_output_dice_coef did not improve from 0.52851
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 22s 73ms/step - loss: 0.5351 - seg_output_accuracy: 0.9036 - seg_output_dice_coef: 0.5092 - seg_output_iou_metric: 0.3619 - seg_output_recall: 0.6656 - seg_output_tnr_metric: 0.9254 - val_loss: 0.5784 - val_seg_output_accuracy: 0.9257 - val_seg_output_dice_coef: 0.4951 - val_seg_output_iou_metric: 0.3545 - val_seg_output_recall: 0.5358 - val_seg_output_tnr_metric: 0.9595 - learning_rate: 0.0010
# Epoch 19/120
# 306/307 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.5295 - seg_output_accuracy: 0.9028 - seg_output_dice_coef: 0.5176 - seg_output_iou_metric: 0.3670 - seg_output_recall: 0.6628 - seg_output_tnr_metric: 0.9261
# Epoch 19: val_seg_output_dice_coef did not improve from 0.52851
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 22s 70ms/step - loss: 0.5343 - seg_output_accuracy: 0.9063 - seg_output_dice_coef: 0.5118 - seg_output_iou_metric: 0.3643 - seg_output_recall: 0.6551 - seg_output_tnr_metric: 0.9293 - val_loss: 0.5542 - val_seg_output_accuracy: 0.9234 - val_seg_output_dice_coef: 0.5090 - val_seg_output_iou_metric: 0.3665 - val_seg_output_recall: 0.6012 - val_seg_output_tnr_metric: 0.9515 - learning_rate: 0.0010
# Epoch 20/120
# 306/307 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.5245 - seg_output_accuracy: 0.9169 - seg_output_dice_coef: 0.5265 - seg_output_iou_metric: 0.3808 - seg_output_recall: 0.6575 - seg_output_tnr_metric: 0.9393
# Epoch 20: val_seg_output_dice_coef did not improve from 0.52851
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 22s 71ms/step - loss: 0.5260 - seg_output_accuracy: 0.9118 - seg_output_dice_coef: 0.5251 - seg_output_iou_metric: 0.3777 - seg_output_recall: 0.6501 - seg_output_tnr_metric: 0.9356 - val_loss: 0.5511 - val_seg_output_accuracy: 0.9028 - val_seg_output_dice_coef: 0.4886 - val_seg_output_iou_metric: 0.3438 - val_seg_output_recall: 0.6818 - val_seg_output_tnr_metric: 0.9225 - learning_rate: 0.0010
# Epoch 21/120
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.5267 - seg_output_accuracy: 0.9119 - seg_output_dice_coef: 0.5207 - seg_output_iou_metric: 0.3745 - seg_output_recall: 0.6593 - seg_output_tnr_metric: 0.9347
# Epoch 21: val_seg_output_dice_coef did not improve from 0.52851
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 22s 70ms/step - loss: 0.5321 - seg_output_accuracy: 0.9072 - seg_output_dice_coef: 0.5143 - seg_output_iou_metric: 0.3693 - seg_output_recall: 0.6650 - seg_output_tnr_metric: 0.9296 - val_loss: 0.5327 - val_seg_output_accuracy: 0.9073 - val_seg_output_dice_coef: 0.5085 - val_seg_output_iou_metric: 0.3607 - val_seg_output_recall: 0.6861 - val_seg_output_tnr_metric: 0.9266 - learning_rate: 0.0010
# Epoch 22/120
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.5189 - seg_output_accuracy: 0.9118 - seg_output_dice_coef: 0.5275 - seg_output_iou_metric: 0.3809 - seg_output_recall: 0.6809 - seg_output_tnr_metric: 0.9326
# Epoch 22: val_seg_output_dice_coef improved from 0.52851 to 0.54342, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_26_5_04.keras
#
# Epoch 22: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_26_5_04.keras
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 23s 74ms/step - loss: 0.5194 - seg_output_accuracy: 0.9113 - seg_output_dice_coef: 0.5287 - seg_output_iou_metric: 0.3822 - seg_output_recall: 0.6610 - seg_output_tnr_metric: 0.9342 - val_loss: 0.5090 - val_seg_output_accuracy: 0.9215 - val_seg_output_dice_coef: 0.5434 - val_seg_output_iou_metric: 0.3953 - val_seg_output_recall: 0.6739 - val_seg_output_tnr_metric: 0.9432 - learning_rate: 0.0010
# Epoch 23/120
# 306/307 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.5112 - seg_output_accuracy: 0.9170 - seg_output_dice_coef: 0.5394 - seg_output_iou_metric: 0.3898 - seg_output_recall: 0.6568 - seg_output_tnr_metric: 0.9408
# Epoch 23: val_seg_output_dice_coef did not improve from 0.54342
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 22s 71ms/step - loss: 0.5125 - seg_output_accuracy: 0.9172 - seg_output_dice_coef: 0.5395 - seg_output_iou_metric: 0.3921 - seg_output_recall: 0.6543 - seg_output_tnr_metric: 0.9412 - val_loss: 0.5792 - val_seg_output_accuracy: 0.9340 - val_seg_output_dice_coef: 0.5120 - val_seg_output_iou_metric: 0.3697 - val_seg_output_recall: 0.4918 - val_seg_output_tnr_metric: 0.9727 - learning_rate: 0.0010
# Epoch 24/120
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.5297 - seg_output_accuracy: 0.9148 - seg_output_dice_coef: 0.5249 - seg_output_iou_metric: 0.3767 - seg_output_recall: 0.6377 - seg_output_tnr_metric: 0.9397
# Epoch 24: val_seg_output_dice_coef improved from 0.54342 to 0.55132, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_26_5_04.keras
#
# Epoch 24: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_26_5_04.keras
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 23s 74ms/step - loss: 0.5173 - seg_output_accuracy: 0.9174 - seg_output_dice_coef: 0.5386 - seg_output_iou_metric: 0.3906 - seg_output_recall: 0.6464 - seg_output_tnr_metric: 0.9423 - val_loss: 0.5291 - val_seg_output_accuracy: 0.9373 - val_seg_output_dice_coef: 0.5513 - val_seg_output_iou_metric: 0.4090 - val_seg_output_recall: 0.5894 - val_seg_output_tnr_metric: 0.9676 - learning_rate: 0.0010
# Epoch 25/120
# 306/307 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.5048 - seg_output_accuracy: 0.9198 - seg_output_dice_coef: 0.5532 - seg_output_iou_metric: 0.4073 - seg_output_recall: 0.6430 - seg_output_tnr_metric: 0.9458
# Epoch 25: val_seg_output_dice_coef did not improve from 0.55132
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 22s 70ms/step - loss: 0.4983 - seg_output_accuracy: 0.9209 - seg_output_dice_coef: 0.5570 - seg_output_iou_metric: 0.4095 - seg_output_recall: 0.6655 - seg_output_tnr_metric: 0.9442 - val_loss: 0.5834 - val_seg_output_accuracy: 0.9430 - val_seg_output_dice_coef: 0.5208 - val_seg_output_iou_metric: 0.3851 - val_seg_output_recall: 0.4579 - val_seg_output_tnr_metric: 0.9853 - learning_rate: 0.0010
# Epoch 26/120
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.5103 - seg_output_accuracy: 0.9181 - seg_output_dice_coef: 0.5421 - seg_output_iou_metric: 0.3954 - seg_output_recall: 0.6635 - seg_output_tnr_metric: 0.9410
# Epoch 26: val_seg_output_dice_coef improved from 0.55132 to 0.56087, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_26_5_04.keras
#
# Epoch 26: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_26_5_04.keras
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 23s 74ms/step - loss: 0.4960 - seg_output_accuracy: 0.9212 - seg_output_dice_coef: 0.5592 - seg_output_iou_metric: 0.4114 - seg_output_recall: 0.6649 - seg_output_tnr_metric: 0.9446 - val_loss: 0.5293 - val_seg_output_accuracy: 0.9402 - val_seg_output_dice_coef: 0.5609 - val_seg_output_iou_metric: 0.4167 - val_seg_output_recall: 0.5737 - val_seg_output_tnr_metric: 0.9721 - learning_rate: 0.0010
# Epoch 27/120
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.4966 - seg_output_accuracy: 0.9238 - seg_output_dice_coef: 0.5640 - seg_output_iou_metric: 0.4199 - seg_output_recall: 0.6605 - seg_output_tnr_metric: 0.9484
# Epoch 27: val_seg_output_dice_coef did not improve from 0.56087
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 22s 71ms/step - loss: 0.4923 - seg_output_accuracy: 0.9222 - seg_output_dice_coef: 0.5627 - seg_output_iou_metric: 0.4176 - seg_output_recall: 0.6786 - seg_output_tnr_metric: 0.9445 - val_loss: 0.5015 - val_seg_output_accuracy: 0.9144 - val_seg_output_dice_coef: 0.5386 - val_seg_output_iou_metric: 0.3903 - val_seg_output_recall: 0.7354 - val_seg_output_tnr_metric: 0.9301 - learning_rate: 0.0010
# Epoch 28/120
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.4975 - seg_output_accuracy: 0.9236 - seg_output_dice_coef: 0.5576 - seg_output_iou_metric: 0.4124 - seg_output_recall: 0.6591 - seg_output_tnr_metric: 0.9475
# Epoch 28: val_seg_output_dice_coef improved from 0.56087 to 0.58028, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_26_5_04.keras
#
# Epoch 28: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_26_5_04.keras
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 23s 74ms/step - loss: 0.4889 - seg_output_accuracy: 0.9241 - seg_output_dice_coef: 0.5668 - seg_output_iou_metric: 0.4213 - seg_output_recall: 0.6641 - seg_output_tnr_metric: 0.9479 - val_loss: 0.4726 - val_seg_output_accuracy: 0.9302 - val_seg_output_dice_coef: 0.5803 - val_seg_output_iou_metric: 0.4341 - val_seg_output_recall: 0.7268 - val_seg_output_tnr_metric: 0.9481 - learning_rate: 0.0010
# Epoch 29/120
# 306/307 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.4814 - seg_output_accuracy: 0.9262 - seg_output_dice_coef: 0.5815 - seg_output_iou_metric: 0.4328 - seg_output_recall: 0.6638 - seg_output_tnr_metric: 0.9511
# Epoch 29: val_seg_output_dice_coef improved from 0.58028 to 0.58891, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_26_5_04.keras
#
# Epoch 29: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_26_5_04.keras
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 23s 75ms/step - loss: 0.4863 - seg_output_accuracy: 0.9269 - seg_output_dice_coef: 0.5730 - seg_output_iou_metric: 0.4280 - seg_output_recall: 0.6663 - seg_output_tnr_metric: 0.9507 - val_loss: 0.4853 - val_seg_output_accuracy: 0.9400 - val_seg_output_dice_coef: 0.5889 - val_seg_output_iou_metric: 0.4443 - val_seg_output_recall: 0.6533 - val_seg_output_tnr_metric: 0.9650 - learning_rate: 0.0010
# Epoch 30/120
# 306/307 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.4872 - seg_output_accuracy: 0.9272 - seg_output_dice_coef: 0.5746 - seg_output_iou_metric: 0.4282 - seg_output_recall: 0.6570 - seg_output_tnr_metric: 0.9521
# Epoch 30: val_seg_output_dice_coef improved from 0.58891 to 0.58986, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_26_5_04.keras
#
# Epoch 30: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_26_5_04.keras
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 23s 74ms/step - loss: 0.4781 - seg_output_accuracy: 0.9273 - seg_output_dice_coef: 0.5807 - seg_output_iou_metric: 0.4344 - seg_output_recall: 0.6758 - seg_output_tnr_metric: 0.9502 - val_loss: 0.4892 - val_seg_output_accuracy: 0.9428 - val_seg_output_dice_coef: 0.5899 - val_seg_output_iou_metric: 0.4489 - val_seg_output_recall: 0.6249 - val_seg_output_tnr_metric: 0.9705 - learning_rate: 0.0010
# Epoch 31/120
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.4807 - seg_output_accuracy: 0.9235 - seg_output_dice_coef: 0.5804 - seg_output_iou_metric: 0.4328 - seg_output_recall: 0.6760 - seg_output_tnr_metric: 0.9478
# Epoch 31: val_seg_output_dice_coef did not improve from 0.58986
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 22s 71ms/step - loss: 0.4741 - seg_output_accuracy: 0.9286 - seg_output_dice_coef: 0.5862 - seg_output_iou_metric: 0.4387 - seg_output_recall: 0.6745 - seg_output_tnr_metric: 0.9518 - val_loss: 0.5330 - val_seg_output_accuracy: 0.9486 - val_seg_output_dice_coef: 0.5745 - val_seg_output_iou_metric: 0.4374 - val_seg_output_recall: 0.5223 - val_seg_output_tnr_metric: 0.9857 - learning_rate: 0.0010
# Epoch 32/120
# 306/307 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.4516 - seg_output_accuracy: 0.9322 - seg_output_dice_coef: 0.6112 - seg_output_iou_metric: 0.4707 - seg_output_recall: 0.7014 - seg_output_tnr_metric: 0.9541
# Epoch 32: val_seg_output_dice_coef did not improve from 0.58986
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 22s 71ms/step - loss: 0.4616 - seg_output_accuracy: 0.9305 - seg_output_dice_coef: 0.5977 - seg_output_iou_metric: 0.4539 - seg_output_recall: 0.7011 - seg_output_tnr_metric: 0.9515 - val_loss: 0.4823 - val_seg_output_accuracy: 0.9260 - val_seg_output_dice_coef: 0.5674 - val_seg_output_iou_metric: 0.4224 - val_seg_output_recall: 0.7300 - val_seg_output_tnr_metric: 0.9433 - learning_rate: 0.0010
# Epoch 33/120
# 306/307 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.4482 - seg_output_accuracy: 0.9380 - seg_output_dice_coef: 0.6141 - seg_output_iou_metric: 0.4699 - seg_output_recall: 0.6979 - seg_output_tnr_metric: 0.9591
# Epoch 33: val_seg_output_dice_coef did not improve from 0.58986
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 22s 71ms/step - loss: 0.4544 - seg_output_accuracy: 0.9356 - seg_output_dice_coef: 0.6112 - seg_output_iou_metric: 0.4642 - seg_output_recall: 0.6749 - seg_output_tnr_metric: 0.9592 - val_loss: 0.4858 - val_seg_output_accuracy: 0.9293 - val_seg_output_dice_coef: 0.5702 - val_seg_output_iou_metric: 0.4220 - val_seg_output_recall: 0.7054 - val_seg_output_tnr_metric: 0.9486 - learning_rate: 0.0010
# Epoch 34/120
# 306/307 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.4753 - seg_output_accuracy: 0.9352 - seg_output_dice_coef: 0.5886 - seg_output_iou_metric: 0.4466 - seg_output_recall: 0.6716 - seg_output_tnr_metric: 0.9580
# Epoch 34: val_seg_output_dice_coef did not improve from 0.58986
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 22s 71ms/step - loss: 0.4661 - seg_output_accuracy: 0.9321 - seg_output_dice_coef: 0.5974 - seg_output_iou_metric: 0.4539 - seg_output_recall: 0.6813 - seg_output_tnr_metric: 0.9549 - val_loss: 0.5406 - val_seg_output_accuracy: 0.9489 - val_seg_output_dice_coef: 0.5714 - val_seg_output_iou_metric: 0.4338 - val_seg_output_recall: 0.4938 - val_seg_output_tnr_metric: 0.9885 - learning_rate: 0.0010
# Epoch 35/120
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.4596 - seg_output_accuracy: 0.9383 - seg_output_dice_coef: 0.6091 - seg_output_iou_metric: 0.4645 - seg_output_recall: 0.6639 - seg_output_tnr_metric: 0.9625
# Epoch 35: val_seg_output_dice_coef improved from 0.58986 to 0.62929, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_26_5_04.keras
#
# Epoch 35: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_26_5_04.keras
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 23s 73ms/step - loss: 0.4469 - seg_output_accuracy: 0.9382 - seg_output_dice_coef: 0.6190 - seg_output_iou_metric: 0.4739 - seg_output_recall: 0.6864 - seg_output_tnr_metric: 0.9611 - val_loss: 0.4670 - val_seg_output_accuracy: 0.9521 - val_seg_output_dice_coef: 0.6293 - val_seg_output_iou_metric: 0.4904 - val_seg_output_recall: 0.6206 - val_seg_output_tnr_metric: 0.9810 - learning_rate: 5.0000e-04
# Epoch 36/120
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.4427 - seg_output_accuracy: 0.9358 - seg_output_dice_coef: 0.6257 - seg_output_iou_metric: 0.4784 - seg_output_recall: 0.6689 - seg_output_tnr_metric: 0.9611
# Epoch 36: val_seg_output_dice_coef improved from 0.62929 to 0.64773, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_26_5_04.keras
#
# Epoch 36: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_26_5_04.keras
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 23s 75ms/step - loss: 0.4319 - seg_output_accuracy: 0.9400 - seg_output_dice_coef: 0.6333 - seg_output_iou_metric: 0.4878 - seg_output_recall: 0.7004 - seg_output_tnr_metric: 0.9617 - val_loss: 0.4375 - val_seg_output_accuracy: 0.9501 - val_seg_output_dice_coef: 0.6477 - val_seg_output_iou_metric: 0.5033 - val_seg_output_recall: 0.6832 - val_seg_output_tnr_metric: 0.9734 - learning_rate: 5.0000e-04
# Epoch 37/120
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.4519 - seg_output_accuracy: 0.9335 - seg_output_dice_coef: 0.6135 - seg_output_iou_metric: 0.4693 - seg_output_recall: 0.6926 - seg_output_tnr_metric: 0.9570
# Epoch 37: val_seg_output_dice_coef did not improve from 0.64773
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 24s 79ms/step - loss: 0.4336 - seg_output_accuracy: 0.9403 - seg_output_dice_coef: 0.6317 - seg_output_iou_metric: 0.4896 - seg_output_recall: 0.7030 - seg_output_tnr_metric: 0.9617 - val_loss: 0.4526 - val_seg_output_accuracy: 0.9529 - val_seg_output_dice_coef: 0.6409 - val_seg_output_iou_metric: 0.5048 - val_seg_output_recall: 0.6363 - val_seg_output_tnr_metric: 0.9805 - learning_rate: 5.0000e-04
# Epoch 38/120
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.4181 - seg_output_accuracy: 0.9423 - seg_output_dice_coef: 0.6526 - seg_output_iou_metric: 0.5100 - seg_output_recall: 0.6904 - seg_output_tnr_metric: 0.9667
# Epoch 38: val_seg_output_dice_coef did not improve from 0.64773
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 25s 80ms/step - loss: 0.4189 - seg_output_accuracy: 0.9425 - seg_output_dice_coef: 0.6465 - seg_output_iou_metric: 0.5041 - seg_output_recall: 0.7107 - seg_output_tnr_metric: 0.9635 - val_loss: 0.4605 - val_seg_output_accuracy: 0.9547 - val_seg_output_dice_coef: 0.6446 - val_seg_output_iou_metric: 0.5063 - val_seg_output_recall: 0.6123 - val_seg_output_tnr_metric: 0.9845 - learning_rate: 5.0000e-04
# Epoch 39/120
# 306/307 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.4339 - seg_output_accuracy: 0.9437 - seg_output_dice_coef: 0.6323 - seg_output_iou_metric: 0.4888 - seg_output_recall: 0.6834 - seg_output_tnr_metric: 0.9663
# Epoch 39: val_seg_output_dice_coef improved from 0.64773 to 0.66423, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_26_5_04.keras
#
# Epoch 39: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_26_5_04.keras
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 23s 75ms/step - loss: 0.4269 - seg_output_accuracy: 0.9423 - seg_output_dice_coef: 0.6406 - seg_output_iou_metric: 0.4974 - seg_output_recall: 0.6955 - seg_output_tnr_metric: 0.9646 - val_loss: 0.4418 - val_seg_output_accuracy: 0.9560 - val_seg_output_dice_coef: 0.6642 - val_seg_output_iou_metric: 0.5247 - val_seg_output_recall: 0.6239 - val_seg_output_tnr_metric: 0.9849 - learning_rate: 5.0000e-04
# Epoch 40/120
# 306/307 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.4158 - seg_output_accuracy: 0.9453 - seg_output_dice_coef: 0.6517 - seg_output_iou_metric: 0.5106 - seg_output_recall: 0.7220 - seg_output_tnr_metric: 0.9664
# Epoch 40: val_seg_output_dice_coef did not improve from 0.66423
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 22s 70ms/step - loss: 0.4236 - seg_output_accuracy: 0.9438 - seg_output_dice_coef: 0.6439 - seg_output_iou_metric: 0.4998 - seg_output_recall: 0.7050 - seg_output_tnr_metric: 0.9654 - val_loss: 0.4533 - val_seg_output_accuracy: 0.9531 - val_seg_output_dice_coef: 0.6438 - val_seg_output_iou_metric: 0.5040 - val_seg_output_recall: 0.6392 - val_seg_output_tnr_metric: 0.9804 - learning_rate: 5.0000e-04
# Epoch 41/120
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.4268 - seg_output_accuracy: 0.9426 - seg_output_dice_coef: 0.6457 - seg_output_iou_metric: 0.4998 - seg_output_recall: 0.6801 - seg_output_tnr_metric: 0.9677
# Epoch 41: val_seg_output_dice_coef improved from 0.66423 to 0.67361, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_26_5_04.keras
#
# Epoch 41: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_26_5_04.keras
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 23s 74ms/step - loss: 0.4179 - seg_output_accuracy: 0.9455 - seg_output_dice_coef: 0.6532 - seg_output_iou_metric: 0.5101 - seg_output_recall: 0.6975 - seg_output_tnr_metric: 0.9680 - val_loss: 0.4081 - val_seg_output_accuracy: 0.9537 - val_seg_output_dice_coef: 0.6736 - val_seg_output_iou_metric: 0.5315 - val_seg_output_recall: 0.7219 - val_seg_output_tnr_metric: 0.9739 - learning_rate: 5.0000e-04
# Epoch 42/120
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.4195 - seg_output_accuracy: 0.9396 - seg_output_dice_coef: 0.6412 - seg_output_iou_metric: 0.5048 - seg_output_recall: 0.7387 - seg_output_tnr_metric: 0.9587
# Epoch 42: val_seg_output_dice_coef did not improve from 0.67361
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 22s 70ms/step - loss: 0.4144 - seg_output_accuracy: 0.9416 - seg_output_dice_coef: 0.6480 - seg_output_iou_metric: 0.5073 - seg_output_recall: 0.7281 - seg_output_tnr_metric: 0.9609 - val_loss: 0.4149 - val_seg_output_accuracy: 0.9541 - val_seg_output_dice_coef: 0.6716 - val_seg_output_iou_metric: 0.5307 - val_seg_output_recall: 0.6948 - val_seg_output_tnr_metric: 0.9767 - learning_rate: 5.0000e-04
# Epoch 43/120
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.4170 - seg_output_accuracy: 0.9452 - seg_output_dice_coef: 0.6518 - seg_output_iou_metric: 0.5094 - seg_output_recall: 0.6959 - seg_output_tnr_metric: 0.9677
# Epoch 43: val_seg_output_dice_coef did not improve from 0.67361
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 21s 69ms/step - loss: 0.4104 - seg_output_accuracy: 0.9466 - seg_output_dice_coef: 0.6603 - seg_output_iou_metric: 0.5193 - seg_output_recall: 0.7034 - seg_output_tnr_metric: 0.9687 - val_loss: 0.4656 - val_seg_output_accuracy: 0.9572 - val_seg_output_dice_coef: 0.6477 - val_seg_output_iou_metric: 0.5139 - val_seg_output_recall: 0.5808 - val_seg_output_tnr_metric: 0.9899 - learning_rate: 5.0000e-04
# Epoch 44/120
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.4145 - seg_output_accuracy: 0.9485 - seg_output_dice_coef: 0.6556 - seg_output_iou_metric: 0.5144 - seg_output_recall: 0.7233 - seg_output_tnr_metric: 0.9679
# Epoch 44: val_seg_output_dice_coef improved from 0.67361 to 0.67819, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_26_5_04.keras
#
# Epoch 44: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_26_5_04.keras
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 22s 73ms/step - loss: 0.4046 - seg_output_accuracy: 0.9479 - seg_output_dice_coef: 0.6679 - seg_output_iou_metric: 0.5237 - seg_output_recall: 0.7136 - seg_output_tnr_metric: 0.9690 - val_loss: 0.4096 - val_seg_output_accuracy: 0.9556 - val_seg_output_dice_coef: 0.6782 - val_seg_output_iou_metric: 0.5396 - val_seg_output_recall: 0.6991 - val_seg_output_tnr_metric: 0.9779 - learning_rate: 5.0000e-04
# Epoch 45/120
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.3950 - seg_output_accuracy: 0.9507 - seg_output_dice_coef: 0.6757 - seg_output_iou_metric: 0.5342 - seg_output_recall: 0.7312 - seg_output_tnr_metric: 0.9695
# Epoch 45: val_seg_output_dice_coef did not improve from 0.67819
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 22s 71ms/step - loss: 0.4003 - seg_output_accuracy: 0.9487 - seg_output_dice_coef: 0.6731 - seg_output_iou_metric: 0.5304 - seg_output_recall: 0.7080 - seg_output_tnr_metric: 0.9704 - val_loss: 0.4154 - val_seg_output_accuracy: 0.9517 - val_seg_output_dice_coef: 0.6640 - val_seg_output_iou_metric: 0.5219 - val_seg_output_recall: 0.7211 - val_seg_output_tnr_metric: 0.9717 - learning_rate: 5.0000e-04
# Epoch 46/120
# 306/307 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.4163 - seg_output_accuracy: 0.9453 - seg_output_dice_coef: 0.6528 - seg_output_iou_metric: 0.5155 - seg_output_recall: 0.7235 - seg_output_tnr_metric: 0.9658
# Epoch 46: val_seg_output_dice_coef improved from 0.67819 to 0.68282, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_26_5_04.keras
#
# Epoch 46: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_26_5_04.keras
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 23s 74ms/step - loss: 0.4055 - seg_output_accuracy: 0.9482 - seg_output_dice_coef: 0.6656 - seg_output_iou_metric: 0.5273 - seg_output_recall: 0.7186 - seg_output_tnr_metric: 0.9690 - val_loss: 0.4343 - val_seg_output_accuracy: 0.9595 - val_seg_output_dice_coef: 0.6828 - val_seg_output_iou_metric: 0.5434 - val_seg_output_recall: 0.6219 - val_seg_output_tnr_metric: 0.9889 - learning_rate: 5.0000e-04
# Epoch 47/120
# 306/307 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.3946 - seg_output_accuracy: 0.9499 - seg_output_dice_coef: 0.6800 - seg_output_iou_metric: 0.5424 - seg_output_recall: 0.7218 - seg_output_tnr_metric: 0.9709
# Epoch 47: val_seg_output_dice_coef did not improve from 0.68282
#
# Epoch 47: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 22s 70ms/step - loss: 0.3989 - seg_output_accuracy: 0.9485 - seg_output_dice_coef: 0.6724 - seg_output_iou_metric: 0.5322 - seg_output_recall: 0.7199 - seg_output_tnr_metric: 0.9691 - val_loss: 0.4486 - val_seg_output_accuracy: 0.9588 - val_seg_output_dice_coef: 0.6626 - val_seg_output_iou_metric: 0.5290 - val_seg_output_recall: 0.6113 - val_seg_output_tnr_metric: 0.9890 - learning_rate: 5.0000e-04
# Epoch 48/120
# 306/307 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.3743 - seg_output_accuracy: 0.9553 - seg_output_dice_coef: 0.7031 - seg_output_iou_metric: 0.5672 - seg_output_recall: 0.7064 - seg_output_tnr_metric: 0.9776
# Epoch 48: val_seg_output_dice_coef improved from 0.68282 to 0.69352, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_26_5_04.keras
#
# Epoch 48: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_26_5_04.keras
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 22s 72ms/step - loss: 0.3822 - seg_output_accuracy: 0.9539 - seg_output_dice_coef: 0.6949 - seg_output_iou_metric: 0.5569 - seg_output_recall: 0.7072 - seg_output_tnr_metric: 0.9760 - val_loss: 0.4007 - val_seg_output_accuracy: 0.9589 - val_seg_output_dice_coef: 0.6935 - val_seg_output_iou_metric: 0.5565 - val_seg_output_recall: 0.6912 - val_seg_output_tnr_metric: 0.9822 - learning_rate: 2.5000e-04
# Epoch 49/120
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.3906 - seg_output_accuracy: 0.9526 - seg_output_dice_coef: 0.6891 - seg_output_iou_metric: 0.5478 - seg_output_recall: 0.7047 - seg_output_tnr_metric: 0.9752
# Epoch 49: val_seg_output_dice_coef did not improve from 0.69352
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 23s 73ms/step - loss: 0.3849 - seg_output_accuracy: 0.9539 - seg_output_dice_coef: 0.6926 - seg_output_iou_metric: 0.5518 - seg_output_recall: 0.7191 - seg_output_tnr_metric: 0.9750 - val_loss: 0.4032 - val_seg_output_accuracy: 0.9567 - val_seg_output_dice_coef: 0.6851 - val_seg_output_iou_metric: 0.5455 - val_seg_output_recall: 0.7093 - val_seg_output_tnr_metric: 0.9783 - learning_rate: 2.5000e-04
# Epoch 50/120
# 306/307 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.3647 - seg_output_accuracy: 0.9568 - seg_output_dice_coef: 0.7113 - seg_output_iou_metric: 0.5758 - seg_output_recall: 0.7409 - seg_output_tnr_metric: 0.9758
# Epoch 50: val_seg_output_dice_coef improved from 0.69352 to 0.70447, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_26_5_04.keras
#
# Epoch 50: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_26_5_04.keras
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 23s 75ms/step - loss: 0.3719 - seg_output_accuracy: 0.9541 - seg_output_dice_coef: 0.7020 - seg_output_iou_metric: 0.5639 - seg_output_recall: 0.7350 - seg_output_tnr_metric: 0.9737 - val_loss: 0.3832 - val_seg_output_accuracy: 0.9592 - val_seg_output_dice_coef: 0.7045 - val_seg_output_iou_metric: 0.5690 - val_seg_output_recall: 0.7277 - val_seg_output_tnr_metric: 0.9792 - learning_rate: 2.5000e-04
# Epoch 51/120
# 306/307 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.3846 - seg_output_accuracy: 0.9513 - seg_output_dice_coef: 0.6913 - seg_output_iou_metric: 0.5503 - seg_output_recall: 0.7249 - seg_output_tnr_metric: 0.9727
# Epoch 51: val_seg_output_dice_coef did not improve from 0.70447
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 22s 70ms/step - loss: 0.3789 - seg_output_accuracy: 0.9527 - seg_output_dice_coef: 0.6926 - seg_output_iou_metric: 0.5549 - seg_output_recall: 0.7396 - seg_output_tnr_metric: 0.9719 - val_loss: 0.4100 - val_seg_output_accuracy: 0.9604 - val_seg_output_dice_coef: 0.6955 - val_seg_output_iou_metric: 0.5573 - val_seg_output_recall: 0.6787 - val_seg_output_tnr_metric: 0.9849 - learning_rate: 2.5000e-04
# Epoch 52/120
# 306/307 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.3861 - seg_output_accuracy: 0.9524 - seg_output_dice_coef: 0.6898 - seg_output_iou_metric: 0.5540 - seg_output_recall: 0.7164 - seg_output_tnr_metric: 0.9738
# Epoch 52: val_seg_output_dice_coef did not improve from 0.70447
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 22s 70ms/step - loss: 0.3780 - seg_output_accuracy: 0.9533 - seg_output_dice_coef: 0.6946 - seg_output_iou_metric: 0.5582 - seg_output_recall: 0.7317 - seg_output_tnr_metric: 0.9732 - val_loss: 0.3903 - val_seg_output_accuracy: 0.9590 - val_seg_output_dice_coef: 0.7014 - val_seg_output_iou_metric: 0.5647 - val_seg_output_recall: 0.7207 - val_seg_output_tnr_metric: 0.9797 - learning_rate: 2.5000e-04
# Epoch 53/120
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.3680 - seg_output_accuracy: 0.9563 - seg_output_dice_coef: 0.7007 - seg_output_iou_metric: 0.5687 - seg_output_recall: 0.7588 - seg_output_tnr_metric: 0.9736
# Epoch 53: val_seg_output_dice_coef improved from 0.70447 to 0.70925, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_26_5_04.keras
#
# Epoch 53: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_26_5_04.keras
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 23s 73ms/step - loss: 0.3686 - seg_output_accuracy: 0.9548 - seg_output_dice_coef: 0.7044 - seg_output_iou_metric: 0.5690 - seg_output_recall: 0.7439 - seg_output_tnr_metric: 0.9737 - val_loss: 0.3861 - val_seg_output_accuracy: 0.9610 - val_seg_output_dice_coef: 0.7093 - val_seg_output_iou_metric: 0.5751 - val_seg_output_recall: 0.7174 - val_seg_output_tnr_metric: 0.9822 - learning_rate: 2.5000e-04
# Epoch 54/120
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.3640 - seg_output_accuracy: 0.9538 - seg_output_dice_coef: 0.7092 - seg_output_iou_metric: 0.5764 - seg_output_recall: 0.7303 - seg_output_tnr_metric: 0.9748
# Epoch 54: val_seg_output_dice_coef did not improve from 0.70925
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 22s 71ms/step - loss: 0.3723 - seg_output_accuracy: 0.9543 - seg_output_dice_coef: 0.6994 - seg_output_iou_metric: 0.5656 - seg_output_recall: 0.7403 - seg_output_tnr_metric: 0.9735 - val_loss: 0.3755 - val_seg_output_accuracy: 0.9535 - val_seg_output_dice_coef: 0.6879 - val_seg_output_iou_metric: 0.5508 - val_seg_output_recall: 0.8004 - val_seg_output_tnr_metric: 0.9666 - learning_rate: 2.5000e-04
# Epoch 55/120
# 306/307 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.3484 - seg_output_accuracy: 0.9567 - seg_output_dice_coef: 0.7240 - seg_output_iou_metric: 0.5905 - seg_output_recall: 0.7690 - seg_output_tnr_metric: 0.9737
# Epoch 55: val_seg_output_dice_coef improved from 0.70925 to 0.70973, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_26_5_04.keras
#
# Epoch 55: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_26_5_04.keras
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 24s 77ms/step - loss: 0.3672 - seg_output_accuracy: 0.9546 - seg_output_dice_coef: 0.7057 - seg_output_iou_metric: 0.5702 - seg_output_recall: 0.7506 - seg_output_tnr_metric: 0.9728 - val_loss: 0.3729 - val_seg_output_accuracy: 0.9601 - val_seg_output_dice_coef: 0.7097 - val_seg_output_iou_metric: 0.5763 - val_seg_output_recall: 0.7622 - val_seg_output_tnr_metric: 0.9773 - learning_rate: 2.5000e-04
# Epoch 56/120
# ...
# Epoch 104: val_seg_output_dice_coef did not improve from 0.74759
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 24s 76ms/step - loss: 0.3114 - seg_output_accuracy: 0.9643 - seg_output_dice_coef: 0.7580 - seg_output_iou_metric: 0.6343 - seg_output_recall: 0.8076 - seg_output_tnr_metric: 0.9783 - val_loss: 0.3278 - val_seg_output_accuracy: 0.9646 - val_seg_output_dice_coef: 0.7443 - val_seg_output_iou_metric: 0.6201 - val_seg_output_recall: 0.8187 - val_seg_output_tnr_metric: 0.9770 - learning_rate: 1.0000e-04
# Epoch 105/120
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.3193 - seg_output_accuracy: 0.9629 - seg_output_dice_coef: 0.7520 - seg_output_iou_metric: 0.6255 - seg_output_recall: 0.7964 - seg_output_tnr_metric: 0.9776
# Epoch 105: val_seg_output_dice_coef did not improve from 0.74759
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 22s 72ms/step - loss: 0.3239 - seg_output_accuracy: 0.9626 - seg_output_dice_coef: 0.7483 - seg_output_iou_metric: 0.6225 - seg_output_recall: 0.7912 - seg_output_tnr_metric: 0.9778 - val_loss: 0.3316 - val_seg_output_accuracy: 0.9600 - val_seg_output_dice_coef: 0.7269 - val_seg_output_iou_metric: 0.6020 - val_seg_output_recall: 0.8393 - val_seg_output_tnr_metric: 0.9703 - learning_rate: 1.0000e-04
# Epoch 106/120
# 306/307 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.3042 - seg_output_accuracy: 0.9654 - seg_output_dice_coef: 0.7674 - seg_output_iou_metric: 0.6466 - seg_output_recall: 0.8097 - seg_output_tnr_metric: 0.9797
# Epoch 106: val_seg_output_dice_coef improved from 0.74759 to 0.75110, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_26_5_04.keras
#
# Epoch 106: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_26_5_04.keras
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 23s 75ms/step - loss: 0.3180 - seg_output_accuracy: 0.9644 - seg_output_dice_coef: 0.7537 - seg_output_iou_metric: 0.6303 - seg_output_recall: 0.7945 - seg_output_tnr_metric: 0.9795 - val_loss: 0.3276 - val_seg_output_accuracy: 0.9660 - val_seg_output_dice_coef: 0.7511 - val_seg_output_iou_metric: 0.6281 - val_seg_output_recall: 0.8065 - val_seg_output_tnr_metric: 0.9797 - learning_rate: 1.0000e-04
# Epoch 107/120
# 306/307 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.3107 - seg_output_accuracy: 0.9665 - seg_output_dice_coef: 0.7613 - seg_output_iou_metric: 0.6379 - seg_output_recall: 0.8030 - seg_output_tnr_metric: 0.9806
# Epoch 107: val_seg_output_dice_coef did not improve from 0.75110
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 22s 73ms/step - loss: 0.3155 - seg_output_accuracy: 0.9654 - seg_output_dice_coef: 0.7588 - seg_output_iou_metric: 0.6343 - seg_output_recall: 0.7947 - seg_output_tnr_metric: 0.9805 - val_loss: 0.3267 - val_seg_output_accuracy: 0.9622 - val_seg_output_dice_coef: 0.7356 - val_seg_output_iou_metric: 0.6114 - val_seg_output_recall: 0.8388 - val_seg_output_tnr_metric: 0.9726 - learning_rate: 1.0000e-04
# Epoch 108/120
# 306/307 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.3134 - seg_output_accuracy: 0.9610 - seg_output_dice_coef: 0.7560 - seg_output_iou_metric: 0.6288 - seg_output_recall: 0.8135 - seg_output_tnr_metric: 0.9747
# Epoch 108: val_seg_output_dice_coef did not improve from 0.75110
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 23s 73ms/step - loss: 0.3093 - seg_output_accuracy: 0.9639 - seg_output_dice_coef: 0.7611 - seg_output_iou_metric: 0.6343 - seg_output_recall: 0.8076 - seg_output_tnr_metric: 0.9777 - val_loss: 0.3270 - val_seg_output_accuracy: 0.9660 - val_seg_output_dice_coef: 0.7491 - val_seg_output_iou_metric: 0.6280 - val_seg_output_recall: 0.8141 - val_seg_output_tnr_metric: 0.9789 - learning_rate: 1.0000e-04
# Epoch 109/120
# 306/307 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.3102 - seg_output_accuracy: 0.9631 - seg_output_dice_coef: 0.7645 - seg_output_iou_metric: 0.6404 - seg_output_recall: 0.7891 - seg_output_tnr_metric: 0.9793
# Epoch 109: val_seg_output_dice_coef improved from 0.75110 to 0.75580, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_26_5_04.keras
#
# Epoch 109: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_26_5_04.keras
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 24s 78ms/step - loss: 0.3158 - seg_output_accuracy: 0.9641 - seg_output_dice_coef: 0.7567 - seg_output_iou_metric: 0.6316 - seg_output_recall: 0.7941 - seg_output_tnr_metric: 0.9791 - val_loss: 0.3294 - val_seg_output_accuracy: 0.9673 - val_seg_output_dice_coef: 0.7558 - val_seg_output_iou_metric: 0.6348 - val_seg_output_recall: 0.7964 - val_seg_output_tnr_metric: 0.9819 - learning_rate: 1.0000e-04
# Epoch 110/120
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.3146 - seg_output_accuracy: 0.9640 - seg_output_dice_coef: 0.7644 - seg_output_iou_metric: 0.6409 - seg_output_recall: 0.7735 - seg_output_tnr_metric: 0.9812
# Epoch 110: val_seg_output_dice_coef did not improve from 0.75580
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 22s 72ms/step - loss: 0.3121 - seg_output_accuracy: 0.9655 - seg_output_dice_coef: 0.7637 - seg_output_iou_metric: 0.6390 - seg_output_recall: 0.7951 - seg_output_tnr_metric: 0.9806 - val_loss: 0.3335 - val_seg_output_accuracy: 0.9670 - val_seg_output_dice_coef: 0.7525 - val_seg_output_iou_metric: 0.6295 - val_seg_output_recall: 0.7918 - val_seg_output_tnr_metric: 0.9819 - learning_rate: 1.0000e-04
# Epoch 111/120
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.3032 - seg_output_accuracy: 0.9683 - seg_output_dice_coef: 0.7694 - seg_output_iou_metric: 0.6468 - seg_output_recall: 0.8067 - seg_output_tnr_metric: 0.9813
# Epoch 111: val_seg_output_dice_coef did not improve from 0.75580
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 22s 72ms/step - loss: 0.3092 - seg_output_accuracy: 0.9652 - seg_output_dice_coef: 0.7665 - seg_output_iou_metric: 0.6429 - seg_output_recall: 0.7895 - seg_output_tnr_metric: 0.9807 - val_loss: 0.3286 - val_seg_output_accuracy: 0.9633 - val_seg_output_dice_coef: 0.7376 - val_seg_output_iou_metric: 0.6130 - val_seg_output_recall: 0.8282 - val_seg_output_tnr_metric: 0.9748 - learning_rate: 1.0000e-04
# Epoch 112/120
# 306/307 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.3174 - seg_output_accuracy: 0.9635 - seg_output_dice_coef: 0.7486 - seg_output_iou_metric: 0.6218 - seg_output_recall: 0.8137 - seg_output_tnr_metric: 0.9763
# Epoch 112: val_seg_output_dice_coef did not improve from 0.75580
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 23s 73ms/step - loss: 0.3144 - seg_output_accuracy: 0.9642 - seg_output_dice_coef: 0.7570 - seg_output_iou_metric: 0.6322 - seg_output_recall: 0.8021 - seg_output_tnr_metric: 0.9785 - val_loss: 0.3226 - val_seg_output_accuracy: 0.9647 - val_seg_output_dice_coef: 0.7462 - val_seg_output_iou_metric: 0.6231 - val_seg_output_recall: 0.8258 - val_seg_output_tnr_metric: 0.9766 - learning_rate: 1.0000e-04
# Epoch 113/120
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.3142 - seg_output_accuracy: 0.9642 - seg_output_dice_coef: 0.7531 - seg_output_iou_metric: 0.6284 - seg_output_recall: 0.8181 - seg_output_tnr_metric: 0.9774
# Epoch 113: val_seg_output_dice_coef did not improve from 0.75580
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 23s 74ms/step - loss: 0.3116 - seg_output_accuracy: 0.9648 - seg_output_dice_coef: 0.7588 - seg_output_iou_metric: 0.6348 - seg_output_recall: 0.8087 - seg_output_tnr_metric: 0.9787 - val_loss: 0.3345 - val_seg_output_accuracy: 0.9665 - val_seg_output_dice_coef: 0.7501 - val_seg_output_iou_metric: 0.6262 - val_seg_output_recall: 0.7910 - val_seg_output_tnr_metric: 0.9816 - learning_rate: 1.0000e-04
# Epoch 114/120
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.3089 - seg_output_accuracy: 0.9665 - seg_output_dice_coef: 0.7668 - seg_output_iou_metric: 0.6468 - seg_output_recall: 0.8065 - seg_output_tnr_metric: 0.9808
# Epoch 114: val_seg_output_dice_coef did not improve from 0.75580
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 23s 73ms/step - loss: 0.3087 - seg_output_accuracy: 0.9651 - seg_output_dice_coef: 0.7641 - seg_output_iou_metric: 0.6425 - seg_output_recall: 0.8049 - seg_output_tnr_metric: 0.9790 - val_loss: 0.3346 - val_seg_output_accuracy: 0.9658 - val_seg_output_dice_coef: 0.7449 - val_seg_output_iou_metric: 0.6233 - val_seg_output_recall: 0.8008 - val_seg_output_tnr_metric: 0.9799 - learning_rate: 1.0000e-04
# Epoch 115/120
# 306/307 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.3072 - seg_output_accuracy: 0.9657 - seg_output_dice_coef: 0.7674 - seg_output_iou_metric: 0.6452 - seg_output_recall: 0.8030 - seg_output_tnr_metric: 0.9805
# Epoch 115: val_seg_output_dice_coef did not improve from 0.75580
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 23s 73ms/step - loss: 0.3168 - seg_output_accuracy: 0.9647 - seg_output_dice_coef: 0.7553 - seg_output_iou_metric: 0.6321 - seg_output_recall: 0.8015 - seg_output_tnr_metric: 0.9792 - val_loss: 0.3426 - val_seg_output_accuracy: 0.9669 - val_seg_output_dice_coef: 0.7453 - val_seg_output_iou_metric: 0.6226 - val_seg_output_recall: 0.7768 - val_seg_output_tnr_metric: 0.9833 - learning_rate: 1.0000e-04
# Epoch 116/120
# 306/307 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.3029 - seg_output_accuracy: 0.9636 - seg_output_dice_coef: 0.7690 - seg_output_iou_metric: 0.6458 - seg_output_recall: 0.8122 - seg_output_tnr_metric: 0.9778
# Epoch 116: val_seg_output_dice_coef did not improve from 0.75580
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 23s 73ms/step - loss: 0.3006 - seg_output_accuracy: 0.9653 - seg_output_dice_coef: 0.7703 - seg_output_iou_metric: 0.6463 - seg_output_recall: 0.8120 - seg_output_tnr_metric: 0.9788 - val_loss: 0.3397 - val_seg_output_accuracy: 0.9669 - val_seg_output_dice_coef: 0.7476 - val_seg_output_iou_metric: 0.6265 - val_seg_output_recall: 0.7821 - val_seg_output_tnr_metric: 0.9826 - learning_rate: 1.0000e-04
# Epoch 117/120
# 306/307 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.3011 - seg_output_accuracy: 0.9662 - seg_output_dice_coef: 0.7770 - seg_output_iou_metric: 0.6530 - seg_output_recall: 0.7922 - seg_output_tnr_metric: 0.9815
# Epoch 117: val_seg_output_dice_coef did not improve from 0.75580
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 22s 73ms/step - loss: 0.3001 - seg_output_accuracy: 0.9664 - seg_output_dice_coef: 0.7748 - seg_output_iou_metric: 0.6527 - seg_output_recall: 0.8012 - seg_output_tnr_metric: 0.9809 - val_loss: 0.3345 - val_seg_output_accuracy: 0.9666 - val_seg_output_dice_coef: 0.7504 - val_seg_output_iou_metric: 0.6281 - val_seg_output_recall: 0.7892 - val_seg_output_tnr_metric: 0.9818 - learning_rate: 1.0000e-04
# Epoch 118/120
# 306/307 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.3213 - seg_output_accuracy: 0.9647 - seg_output_dice_coef: 0.7536 - seg_output_iou_metric: 0.6313 - seg_output_recall: 0.7980 - seg_output_tnr_metric: 0.9795
# Epoch 118: val_seg_output_dice_coef did not improve from 0.75580
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 23s 75ms/step - loss: 0.3128 - seg_output_accuracy: 0.9646 - seg_output_dice_coef: 0.7589 - seg_output_iou_metric: 0.6349 - seg_output_recall: 0.8069 - seg_output_tnr_metric: 0.9786 - val_loss: 0.3330 - val_seg_output_accuracy: 0.9630 - val_seg_output_dice_coef: 0.7353 - val_seg_output_iou_metric: 0.6129 - val_seg_output_recall: 0.8239 - val_seg_output_tnr_metric: 0.9748 - learning_rate: 1.0000e-04
# Epoch 119/120
# 306/307 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.3003 - seg_output_accuracy: 0.9669 - seg_output_dice_coef: 0.7670 - seg_output_iou_metric: 0.6447 - seg_output_recall: 0.8248 - seg_output_tnr_metric: 0.9789
# Epoch 119: val_seg_output_dice_coef did not improve from 0.75580
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 23s 73ms/step - loss: 0.3141 - seg_output_accuracy: 0.9637 - seg_output_dice_coef: 0.7574 - seg_output_iou_metric: 0.6331 - seg_output_recall: 0.7969 - seg_output_tnr_metric: 0.9783 - val_loss: 0.3257 - val_seg_output_accuracy: 0.9634 - val_seg_output_dice_coef: 0.7401 - val_seg_output_iou_metric: 0.6171 - val_seg_output_recall: 0.8328 - val_seg_output_tnr_metric: 0.9743 - learning_rate: 1.0000e-04
# Epoch 120/120
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.3170 - seg_output_accuracy: 0.9667 - seg_output_dice_coef: 0.7503 - seg_output_iou_metric: 0.6268 - seg_output_recall: 0.8128 - seg_output_tnr_metric: 0.9791
# Epoch 120: val_seg_output_dice_coef did not improve from 0.75580
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 23s 75ms/step - loss: 0.3066 - seg_output_accuracy: 0.9657 - seg_output_dice_coef: 0.7642 - seg_output_iou_metric: 0.6422 - seg_output_recall: 0.8088 - seg_output_tnr_metric: 0.9796 - val_loss: 0.3318 - val_seg_output_accuracy: 0.9667 - val_seg_output_dice_coef: 0.7514 - val_seg_output_iou_metric: 0.6299 - val_seg_output_recall: 0.7960 - val_seg_output_tnr_metric: 0.9813 - learning_rate: 1.0000e-04
# [PHASE 1 COMPLETE] Spatial boundaries locked successfully.
#
#  =======================================================
#  [PHASE 2] Initializing Classification Head over Locked Feature Embeddings
#  =======================================================
# 🔄 Fetching peak localization weights from storage: /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_26_5_04.keras
# 🔒 Enforcing Strict Structural Freeze on the Shared Features Sub-Graph...
# Epoch 1/100
# I0000 00:00:1779808723.622071    4548 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_3808297__.138
# I0000 00:00:1779808728.471342    4548 subprocess_compilation.cc:348] ptxas warning : Registers are spilled to local memory in function 'input_reduce_fusion_5', 56 bytes spill stores, 56 bytes spill loads
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.7911
# I0000 00:00:1779808763.475011    4549 subprocess_compilation.cc:348] ptxas warning : Registers are spilled to local memory in function 'input_reduce_fusion_1', 56 bytes spill stores, 56 bytes spill loads
# Epoch 1: val_loss improved from None to 0.51222, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_26_5_04.keras
#
# Epoch 1: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_26_5_04.keras
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 58s 36ms/step - loss: 0.7484 - val_loss: 0.5122
# Epoch 2/100
# 1255/1257 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.6445
# Epoch 2: val_loss improved from 0.51222 to 0.34098, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_26_5_04.keras
#
# Epoch 2: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_26_5_04.keras
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.6253 - val_loss: 0.3410
# Epoch 3/100
# 1256/1257 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5678
# Epoch 3: val_loss improved from 0.34098 to 0.26417, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_26_5_04.keras
#
# Epoch 3: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_26_5_04.keras
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.5387 - val_loss: 0.2642
# Epoch 4/100
# 1253/1257 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4795
# Epoch 4: val_loss improved from 0.26417 to 0.25771, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_26_5_04.keras
#
# Epoch 4: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_26_5_04.keras
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4772 - val_loss: 0.2577
# Epoch 5/100
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4356
# Epoch 5: val_loss did not improve from 0.25771
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.4204 - val_loss: 0.3047
# Epoch 6/100
#  315/1257 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - loss: 0.3923

# %% [markdown]
# ### Evaluation Matrix

# %% [markdown]
# ### 📈 PHASE 1: SEGMENTATION LEARNING CURVES (TRAIN VS VALIDATION)

# %%
# ─────────────────────────────────────────────────────────────────────────────
# 📈 PHASE 1: SEGMENTATION LEARNING CURVES (TRAIN VS VALIDATION) - DYNAMIC FIX
# ─────────────────────────────────────────────────────────────────────────────
print("\n📈 [Visuals] Plotting Phase-1 Segmentation History (Train vs Val)...")
history_dict = history_p1.history 
epochs_range = range(1, len(history_dict['loss']) + 1)

dice_key = [k for k in history_dict.keys() if 'dice' in k and 'val' not in k][0]
val_dice_key = [k for k in history_dict.keys() if 'dice' in k and 'val' in k][0]

iou_key = [k for k in history_dict.keys() if 'iou' in k and 'val' not in k][0]
val_iou_key = [k for k in history_dict.keys() if 'iou' in k and 'val' in k][0]


acc_key = [k for k in history_dict.keys() if ('acc' in k or 'accuracy' in k) and 'val' not in k and 'dice' not in k and 'iou' not in k][0]
val_acc_key = [k for k in history_dict.keys() if ('acc' in k or 'accuracy' in k) and 'val' in k and 'dice' not in k and 'iou' not in k][0]

print(f"📊 Mapping Keys Automatically -> Dice: '{dice_key}', IoU: '{iou_key}', Accuracy: '{acc_key}'")

fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(18, 5), dpi=150)

# 1. Dice Coefficient Curve (Train vs Val)
axes[0].plot(epochs_range, history_dict[dice_key], color='teal', lw=2, label='Training Dice')
axes[0].plot(epochs_range, history_dict[val_dice_key], color='darkorange', lw=2, linestyle='--', label='Validation Dice')
axes[0].grid(True, linestyle=':', alpha=0.6)
axes[0].set_title('Segmentation Dice Coefficient', fontsize=12, fontweight='bold')
axes[0].set_xlabel('Epochs', fontsize=10)
axes[0].set_ylabel('Dice Score', fontsize=10)
axes[0].legend(loc='lower right')

# 2. IoU Metric Curve (Train vs Val)
axes[1].plot(epochs_range, history_dict[iou_key], color='purple', lw=2, label='Training IoU')
axes[1].plot(epochs_range, history_dict[val_iou_key], color='crimson', lw=2, linestyle='--', label='Validation IoU')
axes[1].grid(True, linestyle=':', alpha=0.6)
axes[1].set_title('Intersection over Union (IoU)', fontsize=12, fontweight='bold')
axes[1].set_xlabel('Epochs', fontsize=10)
axes[1].set_ylabel('IoU Score', fontsize=10)
axes[1].legend(loc='lower right')

# 3. Pixel Accuracy Curve (Train vs Val)
axes[2].plot(epochs_range, history_dict[acc_key], color='forestgreen', lw=2, label='Training Accuracy')
axes[2].plot(epochs_range, history_dict[val_acc_key], color='royalblue', lw=2, linestyle='--', label='Validation Accuracy')
axes[2].grid(True, linestyle=':', alpha=0.6)
axes[2].set_title('Segmentation Pixel Accuracy', fontsize=12, fontweight='bold')
axes[2].set_xlabel('Epochs', fontsize=10)
axes[2].set_ylabel('Accuracy Score', fontsize=10)
axes[2].legend(loc='lower right')

plt.tight_layout()
plt.show()
print("💾 Saved: segmentation_train_val_metrics04.png")
# Out:
# 📈 [Visuals] Plotting Phase-1 Segmentation History (Train vs Val)...
# 📊 Mapping Keys Automatically -> Dice: 'seg_output_dice_coef', IoU: 'seg_output_iou_metric', Accuracy: 'seg_output_accuracy'
# 💾 Saved: segmentation_train_val_metrics04.png

# %%
import matplotlib.pyplot as plt

print("\n📈 [Visuals] Plotting Phase-2 Classification Loss (Train vs Val)...")
h2_dict = history_p2.history
epochs_p2 = range(1, len(h2_dict['loss']) + 1)

p2_loss = [k for k in h2_dict.keys() if 'loss' in k and 'val' not in k][0]
p2_val_loss = [k for k in h2_dict.keys() if 'loss' in k and 'val' in k][0]


plt.figure(figsize=(8, 5), dpi=100)
plt.plot(epochs_p2, h2_dict[p2_loss], color='crimson', lw=2.5, label='Training Loss')
plt.plot(epochs_p2, h2_dict[p2_val_loss], color='midnightblue', lw=2.5, linestyle='--', label='Validation Loss')


plt.title('Classification Cross-Entropy Loss Learning Curve', fontsize=12, fontweight='bold', pad=12)
plt.xlabel('Epochs', fontsize=10)
plt.ylabel('Loss Value', fontsize=10)
plt.grid(True, linestyle=':', alpha=0.6)
plt.legend(loc='upper right', fontsize=10)

plt.tight_layout()
plt.show()

print("💾 Saved: classification_train_val_loss.png")
# Out:
# 📈 [Visuals] Plotting Phase-2 Classification Loss (Train vs Val)...
# 💾 Saved: classification_train_val_loss.png

# %%
print(list(history_p2.history.keys()))
# Out:
# ['loss', 'seg_output_accuracy', 'val_loss', 'val_seg_output_accuracy']

# %% [markdown]
# ### Testing the Model Phase 1 + Phase 2

# %%
# %matplotlib inline

import os
import cv2
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# ─────────────────────────────────────────────────────────────────────────────
# ⚙️ GLOBAL INFERENCE CONFIGURATIONS
# ─────────────────────────────────────────────────────────────────────────────
IMG_SIZE = 256

# Define your exact paths here
MODEL_PATH = "/mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_26_5_02.keras"
TEST_POSITIVE_IMAGE_PATH = "/mnt/c/development/Thesis/PolypSegmentationBasedClassification/DataSets/PolypGen2021_MultiCenterData_v2/data_C4/images_C4/16_endocv2021_positive_557.jpg"
TEST_NEG_IMAGE_PATH = "/mnt/c/development/Thesis/PolypSegmentationBasedClassification/DataSets/PolypGen2021_MultiCenterData_v2/sequenceData/negativeOnly/seq10_neg/EndoCV2021_seq10_neg_40_endocv2021_negative_754.jpg"
TEST_POSITIVE_IMAGE_PATH_2 = "/mnt/c/development/Thesis/PolypSegmentationBasedClassification/DataSets/PolypGen2021_MultiCenterData_v2/imagesAll_positive/176OLCV1_100H0890.jpg"
TEST_NEG2_IMAGE_PATH = "/mnt/c/development/Thesis/PolypSegmentationBasedClassification/DataSets/PolypGen2021_MultiCenterData_v2/sequenceData/negativeOnly/seq13_neg/EndoCV2021_C5_seq3_246.jpg"
# ─────────────────────────────────────────────────────────────────────────────
# 🎨 REFINED IMAGE LABELED LOCALIZATION ENGINE
# ─────────────────────────────────────────────────────────────────────────────
def draw_bounding_box(image, mask):
    """
    Draws a clean bounding box around the predicted polyp region with 
    high-contrast paper-grade typography and dimension mapping.
    """
    res_img = image.copy()
    mask_uint8 = (mask > 0.5).astype(np.uint8) * 255
    contours, _ = cv2.findContours(mask_uint8, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    
    # Calibration ratio: mapping image pixels to physical centimeters
    pixel_to_cm_ratio = 50 
    
    for cnt in contours:
        # Filter out minor noise elements or artifacts
        if cv2.contourArea(cnt) < 10:
            continue
            
        x, y, w, h = cv2.boundingRect(cnt)
        
        # Calculate real-world scale approximations
        width_cm = w / pixel_to_cm_ratio
        height_cm = h / pixel_to_cm_ratio
        size_text = f"Polyp: {width_cm:.1f}cm x {height_cm:.1f}cm"
        
        # 1. Draw High-Visibility Bounding Box (Green)
        cv2.rectangle(res_img, (x, y), (x + w, y + h), (0, 255, 0), 2)
        
        # 2. Advanced Typography: Dynamic Text Positioning with Background Shadow
        text_y = y - 10 if y - 10 > 20 else y + h + 20
        
        # Draw a clean black backdrop shadow for ultra-clear readability in papers
        cv2.putText(res_img, size_text, (x + 1, text_y + 1), 
                    cv2.FONT_HERSHEY_SIMPLEX, 0.45, (0, 0, 0), 2, cv2.LINE_AA)
        # Draw the primary text layer
        cv2.putText(res_img, size_text, (x, text_y), 
                    cv2.FONT_HERSHEY_SIMPLEX, 0.45, (0, 255, 0), 1, cv2.LINE_AA)
        
    return res_img

# ─────────────────────────────────────────────────────────────────────────────
# 🔮 MULTI-TASK INFERENCE CORE PIPELINE (SEGMENTATION + CLASSIFICATION)
# ─────────────────────────────────────────────────────────────────────────────
def test_and_display(model, image_path, output_filename='result.png'):
    """
    Executes a joint multi-task prediction, extracting both pixel-level 
    segmentation masks and categorical classification diagnostic boundaries.
    """
    # 1. Read and pre-process target frame
    img = cv2.imread(image_path)
    if img is None:
        raise FileNotFoundError(f"❌ Target frame could not be loaded at: {image_path}")
        
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img_res = cv2.resize(img_rgb, (IMG_SIZE, IMG_SIZE))
    inp = np.expand_dims(img_res / 255.0, axis=0).astype(np.float32)

    # 2. Target forward pass prediction (Extracting multi-head lists)
    pred_outputs = model.predict(inp, verbose=0)
    
    # Check if the model returns a multi-head list [seg_output, clf_output]
    if isinstance(pred_outputs, list) and len(pred_outputs) >= 2:
        pred_mask_spatial = pred_outputs[0][0]  # Output Index 0: Segmentation Mask [256, 256, 1]
        clf_prediction = pred_outputs[1][0][0]  # Output Index 1: Classification Score (Scalar)
        has_classification = True
    else:
        # Fallback if model architecture is only predicting masks in this state
        pred_mask_spatial = pred_outputs[0] if isinstance(pred_outputs, list) else pred_outputs[0]
        clf_prediction = 0.0
        has_classification = False

    # 3. Geometric extraction mappings
    mask_bin = (pred_mask_spatial > 0.5).astype(np.uint8)
    mask_3d = np.concatenate([mask_bin] * 3, axis=-1)
    extracted = (img_res * mask_3d).astype(np.uint8)
    detected_img = draw_bounding_box(img_res, pred_mask_spatial)

    # 4. Generate Dynamically Labeled Classification Title
    if has_classification:
        if clf_prediction >= 0.5:
            diagnostic_text = f"DIAGNOSIS: POLYP DETECTED ({clf_prediction * 100:.2f}% Confidence)"
            title_color = '#1faa00' # Vibrant Green
        else:
            diagnostic_text = f"DIAGNOSIS: NON-POLYP ({(1.0 - clf_prediction) * 100:.2f}% Confidence)"
            title_color = '#dd0000' # Deep Red
    else:
        diagnostic_text = "DIAGNOSIS: Segmentation Mode Active (No Classification Head Found)"
        title_color = 'orange'

    # 5. Generate Professional 4-Column Presentation Graph
    titles = ['(a) Original Frame', '(b) Predicted Mask', '(c) Extracted Region', '(d) Localization View']
    display_images = [img_res, pred_mask_spatial.squeeze(), extracted, detected_img]
    
    fig, axes = plt.subplots(1, 4, figsize=(20, 5))
    
    for i in range(4):
        axes[i].imshow(display_images[i], cmap='gray' if i == 1 else None)
        axes[i].set_title(titles[i], fontsize=13, fontweight='bold', pad=12)
        axes[i].axis('off')
    
    # High-level overview structural description super-title with live diagnosis
    plt.suptitle(diagnostic_text, fontsize=16, fontweight='bold', color=title_color, y=1.04)
    
    plt.tight_layout()
    
    # Save the polished output image to disk
    plt.savefig(output_filename, dpi=300, bbox_inches='tight')
    print(f"🏆 Qualitative evaluation plot successfully saved to: {output_filename}")
    plt.show()

# ─────────────────────────────────────────────────────────────────────────────
# 🏃‍♂️ EXECUTION STEP
# ─────────────────────────────────────────────────────────────────────────────
if __name__ == '__main__':
    print("⏳ Loading Keras Architecture Graph into Memory (Shared Nodes)...")
    # Load model once outside the function to optimize execution loop
    shared_model = tf.keras.models.load_model(MODEL_PATH, compile=False)
    print("✅ Multi-Task Graph successfully initialized.\n")
    
    print("🎬 Processing Positive Dataset Specimen...")
    test_and_display(shared_model, TEST_POSITIVE_IMAGE_PATH, 'thesis_positive_result.png')
    
    print("\n🎬 Processing Negative Dataset Specimen...")
    test_and_display(shared_model, TEST_NEG_IMAGE_PATH, 'thesis_negative_result.png')

    print("\n🎬 Processing Negative Dataset Specimen...")
    test_and_display(shared_model, TEST_POSITIVE_IMAGE_PATH_2,'Neg3.png')

    print("\n🎬 Processing Negative Dataset Specimen...")
    test_and_display(shared_model, TEST_NEG2_IMAGE_PATH,'Neg4.png')
# Out:
# ⏳ Loading Keras Architecture Graph into Memory (Shared Nodes)...
# ✅ Multi-Task Graph successfully initialized.
#
# 🎬 Processing Positive Dataset Specimen...
# 🏆 Qualitative evaluation plot successfully saved to: thesis_positive_result.png
# 🎬 Processing Negative Dataset Specimen...
# 🏆 Qualitative evaluation plot successfully saved to: thesis_negative_result.png
# 🎬 Processing Negative Dataset Specimen...
# 🏆 Qualitative evaluation plot successfully saved to: Neg3.png
# 🎬 Processing Negative Dataset Specimen...
# 🏆 Qualitative evaluation plot successfully saved to: Neg4.png

# %% [markdown]
# #### Performance Matrix

# %%
# =============================================================================
# 📊 PRINT PEAK PERFORMANCE METRICS FOR THESIS REPORT
# =============================================================================
print("=====================================================================")
print("🏆 Unified Model: Peak Performance Metrics (Phase 1 & Phase 2)")
print("=====================================================================")

# 🧠 1. PHASE 1: SEMANTIC SEGMENTATION PERFORMANCE
h1 = history_p1.history


dice_key = [k for k in h1.keys() if 'dice' in k and 'val' not in k][0]
val_dice_key = [k for k in h1.keys() if 'dice' in k and 'val' in k][0]
iou_key = [k for k in h1.keys() if 'iou' in k and 'val' not in k][0]
val_iou_key = [k for k in h1.keys() if 'iou' in k and 'val' in k][0]


acc_key = [k for k in h1.keys() if ('acc' in k or 'accuracy' in k) and 'val' not in k][0]
val_acc_key = [k for k in h1.keys() if ('acc' in k or 'accuracy' in k) and 'val' in k][0]
rec_key = [k for k in h1.keys() if 'recall' in k and 'val' not in k][0]
val_rec_key = [k for k in h1.keys() if 'recall' in k and 'val' in k][0]
tnr_key = [k for k in h1.keys() if 'tnr' in k and 'val' not in k][0]
val_tnr_key = [k for k in h1.keys() if 'tnr' in k and 'val' in k][0]


best_p1_idx = np.argmax(h1[val_dice_key])

print(f"\n📍 [PHASE 1: SEGMENTATION (Best Epoch: {best_p1_idx + 1})]")
print(f"   • Best Training Dice Score    : {h1[dice_key][best_p1_idx]:.4f}")
print(f"   • Best Validation Dice Score  : {h1[val_dice_key][best_p1_idx]:.4f} 🌟")
print(f"   • Associated Training IoU     : {h1[iou_key][best_p1_idx]:.4f}")
print(f"   • Associated Validation IoU   : {h1[val_iou_key][best_p1_idx]:.4f}")

print(f"   • Associated Training Acc     : {h1[acc_key][best_p1_idx]:.4f}")
print(f"   • Associated Validation Acc   : {h1[val_acc_key][best_p1_idx]:.4f}")
print(f"   • Associated Training Recall  : {h1[rec_key][best_p1_idx]:.4f}")
print(f"   • Associated Validation Recall: {h1[val_rec_key][best_p1_idx]:.4f}")
print(f"   • Associated Training TNR     : {h1[tnr_key][best_p1_idx]:.4f}")
print(f"   • Associated Validation TNR   : {h1[val_tnr_key][best_p1_idx]:.4f}")


# 🧠 2. PHASE 2: CLASSIFICATION PERFORMANCE
h2 = history_p2.history
best_p2_idx = np.argmin(h2['val_loss'])

print(f"\n📍 [PHASE 2: CLASSIFICATION (Best Epoch: {best_p2_idx + 1})]")
print(f"   • Minimum Training Loss       : {h2['loss'][best_p2_idx]:.4f}")
print(f"   • Minimum Validation Loss     : {h2['val_loss'][best_p2_idx]:.4f} 🌟")

p2_acc_keys = [k for k in h2.keys() if 'acc' in k or 'accuracy' in k]
if p2_acc_keys:
    acc_k = [k for k in p2_acc_keys if 'val' not in k][0]
    val_acc_k = [k for k in p2_acc_keys if 'val' in k][0]
    print(f"   • Peak Training Accuracy      : {h2[acc_k][best_p2_idx]:.4f}")
    print(f"   • Peak Validation Accuracy    : {h2[val_acc_k][best_p2_idx]:.4f}")
else:
    print("   • Note: Accuracy metrics were dropped in Phase 2 compile for this run.")

print("=====================================================================")
# Out:
# =====================================================================
# 🏆 Unified Model: Peak Performance Metrics (Phase 1 & Phase 2)
# =====================================================================
#
# 📍 [PHASE 1: SEGMENTATION (Best Epoch: 118)]
#    • Best Training Dice Score    : 0.8087
#    • Best Validation Dice Score  : 0.7849 🌟
#    • Associated Training IoU     : 0.6987
#    • Associated Validation IoU   : 0.6749
#    • Associated Training Acc     : 0.9720
#    • Associated Validation Acc   : 0.9711
#    • Associated Training Recall  : 0.8394
#    • Associated Validation Recall: 0.8318
#    • Associated Training TNR     : 0.9837
#    • Associated Validation TNR   : 0.9831
#
# 📍 [PHASE 2: CLASSIFICATION (Best Epoch: 62)]
#    • Minimum Training Loss       : 0.0743
#    • Minimum Validation Loss     : 0.0290 🌟
#    • Peak Training Accuracy      : 0.4101
#    • Peak Validation Accuracy    : 0.4182
# =====================================================================

# %% [markdown]
# #### Model Summary

# %%
model.summary()
# Out:
# Model: "Thesis_Unified_YNet"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ shared_input_image  │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_c1_3x3          │ (None, 256, 256,  │         51 │ shared_input_ima… │
# │ (SeparableConv2D)   │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_c1_5x5          │ (None, 256, 256,  │         99 │ shared_input_ima… │
# │ (SeparableConv2D)   │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_c1_7x7          │ (None, 256, 256,  │        171 │ shared_input_ima… │
# │ (SeparableConv2D)   │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_c1_1x1          │ (None, 256, 256,  │         27 │ shared_input_ima… │
# │ (SeparableConv2D)   │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 256, 256,  │         32 │ enc_c1_3x3[0][0]  │
# │ (BatchNormalizatio… │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         32 │ enc_c1_5x5[0][0]  │
# │ (BatchNormalizatio… │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         32 │ enc_c1_7x7[0][0]  │
# │ (BatchNormalizatio… │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         32 │ enc_c1_1x1[0][0]  │
# │ (BatchNormalizatio… │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_c1_concat       │ (None, 256, 256,  │          0 │ activation[0][0], │
# │ (Concatenate)       │ 32)               │            │ activation_1[0][… │
# │                     │                   │            │ activation_2[0][… │
# │                     │                   │            │ activation_3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 32)        │          0 │ enc_c1_concat[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 2)         │         64 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 32)        │         64 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape (Reshape)   │ (None, 1, 1, 32)  │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 256, 256,  │          0 │ enc_c1_concat[0]… │
# │                     │ 32)               │            │ reshape[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_p1              │ (None, 128, 128,  │          0 │ multiply[0][0]    │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_c2_3x3          │ (None, 128, 128,  │        800 │ enc_p1[0][0]      │
# │ (SeparableConv2D)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_c2_5x5          │ (None, 128, 128,  │      1,312 │ enc_p1[0][0]      │
# │ (SeparableConv2D)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_c2_7x7          │ (None, 128, 128,  │      2,080 │ enc_p1[0][0]      │
# │ (SeparableConv2D)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_c2_1x1          │ (None, 128, 128,  │        544 │ enc_p1[0][0]      │
# │ (SeparableConv2D)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ enc_c2_3x3[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ enc_c2_5x5[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ enc_c2_7x7[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ enc_c2_1x1[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_c2_concat       │ (None, 128, 128,  │          0 │ activation_4[0][… │
# │ (Concatenate)       │ 64)               │            │ activation_5[0][… │
# │                     │                   │            │ activation_6[0][… │
# │                     │                   │            │ activation_7[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 64)        │          0 │ enc_c2_concat[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 4)         │        256 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 64)        │        256 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_1 (Reshape) │ (None, 1, 1, 64)  │          0 │ dense_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_1          │ (None, 128, 128,  │          0 │ enc_c2_concat[0]… │
# │ (Multiply)          │ 64)               │            │ reshape_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_p2              │ (None, 64, 64,    │          0 │ multiply_1[0][0]  │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_c3_3x3          │ (None, 64, 64,    │      2,624 │ enc_p2[0][0]      │
# │ (SeparableConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_c3_5x5          │ (None, 64, 64,    │      3,648 │ enc_p2[0][0]      │
# │ (SeparableConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_c3_7x7          │ (None, 64, 64,    │      5,184 │ enc_p2[0][0]      │
# │ (SeparableConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_c3_1x1          │ (None, 64, 64,    │      2,112 │ enc_p2[0][0]      │
# │ (SeparableConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ enc_c3_3x3[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ enc_c3_5x5[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ enc_c3_7x7[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ enc_c3_1x1[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_c3_concat       │ (None, 64, 64,    │          0 │ activation_8[0][… │
# │ (Concatenate)       │ 128)              │            │ activation_9[0][… │
# │                     │                   │            │ activation_10[0]… │
# │                     │                   │            │ activation_11[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ enc_c3_concat[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 8)         │      1,024 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 128)       │      1,024 │ dense_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_2 (Reshape) │ (None, 1, 1, 128) │          0 │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_2          │ (None, 64, 64,    │          0 │ enc_c3_concat[0]… │
# │ (Multiply)          │ 128)              │            │ reshape_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_c3_dropout      │ (None, 64, 64,    │          0 │ multiply_2[0][0]  │
# │ (SpatialDropout2D)  │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_p3              │ (None, 32, 32,    │          0 │ enc_c3_dropout[0… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_c4_3x3          │ (None, 32, 32,    │      9,344 │ enc_p3[0][0]      │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_c4_5x5          │ (None, 32, 32,    │     11,392 │ enc_p3[0][0]      │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_c4_7x7          │ (None, 32, 32,    │     14,464 │ enc_p3[0][0]      │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_c4_1x1          │ (None, 32, 32,    │      8,320 │ enc_p3[0][0]      │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ enc_c4_3x3[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ enc_c4_5x5[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ enc_c4_7x7[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ enc_c4_1x1[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_14       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_15       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_c4_concat       │ (None, 32, 32,    │          0 │ activation_12[0]… │
# │ (Concatenate)       │ 256)              │            │ activation_13[0]… │
# │                     │                   │            │ activation_14[0]… │
# │                     │                   │            │ activation_15[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 256)       │          0 │ enc_c4_concat[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 16)        │      4,096 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 256)       │      4,096 │ dense_6[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_3 (Reshape) │ (None, 1, 1, 256) │          0 │ dense_7[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_3          │ (None, 32, 32,    │          0 │ enc_c4_concat[0]… │
# │ (Multiply)          │ 256)              │            │ reshape_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_c4_dropout      │ (None, 32, 32,    │          0 │ multiply_3[0][0]  │
# │ (SpatialDropout2D)  │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_p4              │ (None, 16, 16,    │          0 │ enc_c4_dropout[0… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ shared_bottleneck_… │ (None, 16, 16,    │     35,072 │ enc_p4[0][0]      │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ shared_bottleneck_… │ (None, 16, 16,    │     39,168 │ enc_p4[0][0]      │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ shared_bottleneck_… │ (None, 16, 16,    │     45,312 │ enc_p4[0][0]      │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ shared_bottleneck_… │ (None, 16, 16,    │     33,024 │ enc_p4[0][0]      │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ shared_bottlenec… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ shared_bottlenec… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ shared_bottlenec… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ shared_bottlenec… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_16       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_17       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_18       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_19       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ shared_bottleneck_… │ (None, 16, 16,    │          0 │ activation_16[0]… │
# │ (Concatenate)       │ 512)              │            │ activation_17[0]… │
# │                     │                   │            │ activation_18[0]… │
# │                     │                   │            │ activation_19[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 512)       │          0 │ shared_bottlenec… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 32)        │     16,384 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 512)       │     16,384 │ dense_8[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_4 (Reshape) │ (None, 1, 1, 512) │          0 │ dense_9[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_4          │ (None, 16, 16,    │          0 │ shared_bottlenec… │
# │ (Multiply)          │ 512)              │            │ reshape_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ shared_bottleneck_… │ (None, 16, 16,    │          0 │ multiply_4[0][0]  │
# │ (SpatialDropout2D)  │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_u4              │ (None, 32, 32,    │    524,544 │ shared_bottlenec… │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_concat_4        │ (None, 32, 32,    │          0 │ dec_u4[0][0],     │
# │ (Concatenate)       │ 512)              │            │ enc_c4_dropout[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_c5_3x3          │ (None, 32, 32,    │     37,376 │ dec_concat_4[0][… │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_c5_5x5          │ (None, 32, 32,    │     45,568 │ dec_concat_4[0][… │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_c5_7x7          │ (None, 32, 32,    │     57,856 │ dec_concat_4[0][… │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_c5_1x1          │ (None, 32, 32,    │     33,280 │ dec_concat_4[0][… │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ dec_c5_3x3[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ dec_c5_5x5[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ dec_c5_7x7[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ dec_c5_1x1[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_20       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_21       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_22       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_23       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_c5_concat       │ (None, 32, 32,    │          0 │ activation_20[0]… │
# │ (Concatenate)       │ 256)              │            │ activation_21[0]… │
# │                     │                   │            │ activation_22[0]… │
# │                     │                   │            │ activation_23[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 256)       │          0 │ dec_c5_concat[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_10 (Dense)    │ (None, 16)        │      4,096 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_11 (Dense)    │ (None, 256)       │      4,096 │ dense_10[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_5 (Reshape) │ (None, 1, 1, 256) │          0 │ dense_11[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_5          │ (None, 32, 32,    │          0 │ dec_c5_concat[0]… │
# │ (Multiply)          │ 256)              │            │ reshape_5[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_c5_dropout      │ (None, 32, 32,    │          0 │ multiply_5[0][0]  │
# │ (SpatialDropout2D)  │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_u3              │ (None, 64, 64,    │    131,200 │ dec_c5_dropout[0… │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_concat_3        │ (None, 64, 64,    │          0 │ dec_u3[0][0],     │
# │ (Concatenate)       │ 256)              │            │ enc_c3_dropout[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_c6_3x3          │ (None, 64, 64,    │     10,496 │ dec_concat_3[0][… │
# │ (SeparableConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_c6_5x5          │ (None, 64, 64,    │     14,592 │ dec_concat_3[0][… │
# │ (SeparableConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_c6_7x7          │ (None, 64, 64,    │     20,736 │ dec_concat_3[0][… │
# │ (SeparableConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_c6_1x1          │ (None, 64, 64,    │      8,448 │ dec_concat_3[0][… │
# │ (SeparableConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ dec_c6_3x3[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ dec_c6_5x5[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ dec_c6_7x7[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ dec_c6_1x1[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_24       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_25       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_26       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_27       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_c6_concat       │ (None, 64, 64,    │          0 │ activation_24[0]… │
# │ (Concatenate)       │ 128)              │            │ activation_25[0]… │
# │                     │                   │            │ activation_26[0]… │
# │                     │                   │            │ activation_27[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ dec_c6_concat[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_12 (Dense)    │ (None, 8)         │      1,024 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_13 (Dense)    │ (None, 128)       │      1,024 │ dense_12[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_6 (Reshape) │ (None, 1, 1, 128) │          0 │ dense_13[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_6          │ (None, 64, 64,    │          0 │ dec_c6_concat[0]… │
# │ (Multiply)          │ 128)              │            │ reshape_6[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_c6_dropout      │ (None, 64, 64,    │          0 │ multiply_6[0][0]  │
# │ (SpatialDropout2D)  │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_u2              │ (None, 128, 128,  │     32,832 │ dec_c6_dropout[0… │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_concat_2        │ (None, 128, 128,  │          0 │ dec_u2[0][0],     │
# │ (Concatenate)       │ 128)              │            │ multiply_1[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_c7_3x3          │ (None, 128, 128,  │      3,200 │ dec_concat_2[0][… │
# │ (SeparableConv2D)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_c7_5x5          │ (None, 128, 128,  │      5,248 │ dec_concat_2[0][… │
# │ (SeparableConv2D)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_c7_7x7          │ (None, 128, 128,  │      8,320 │ dec_concat_2[0][… │
# │ (SeparableConv2D)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_c7_1x1          │ (None, 128, 128,  │      2,176 │ dec_concat_2[0][… │
# │ (SeparableConv2D)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ dec_c7_3x3[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ dec_c7_5x5[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ dec_c7_7x7[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ dec_c7_1x1[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_28       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_29       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_30       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_31       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_c7_concat       │ (None, 128, 128,  │          0 │ activation_28[0]… │
# │ (Concatenate)       │ 64)               │            │ activation_29[0]… │
# │                     │                   │            │ activation_30[0]… │
# │                     │                   │            │ activation_31[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 64)        │          0 │ dec_c7_concat[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_14 (Dense)    │ (None, 4)         │        256 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_15 (Dense)    │ (None, 64)        │        256 │ dense_14[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_7 (Reshape) │ (None, 1, 1, 64)  │          0 │ dense_15[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_7          │ (None, 128, 128,  │          0 │ dec_c7_concat[0]… │
# │ (Multiply)          │ 64)               │            │ reshape_7[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_u1              │ (None, 256, 256,  │      8,224 │ multiply_7[0][0]  │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_concat_1        │ (None, 256, 256,  │          0 │ dec_u1[0][0],     │
# │ (Concatenate)       │ 64)               │            │ multiply[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_c8_3x3          │ (None, 256, 256,  │      1,088 │ dec_concat_1[0][… │
# │ (SeparableConv2D)   │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_c8_5x5          │ (None, 256, 256,  │      2,112 │ dec_concat_1[0][… │
# │ (SeparableConv2D)   │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_c8_7x7          │ (None, 256, 256,  │      3,648 │ dec_concat_1[0][… │
# │ (SeparableConv2D)   │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_c8_1x1          │ (None, 256, 256,  │        576 │ dec_concat_1[0][… │
# │ (SeparableConv2D)   │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         32 │ dec_c8_3x3[0][0]  │
# │ (BatchNormalizatio… │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         32 │ dec_c8_5x5[0][0]  │
# │ (BatchNormalizatio… │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         32 │ dec_c8_7x7[0][0]  │
# │ (BatchNormalizatio… │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         32 │ dec_c8_1x1[0][0]  │
# │ (BatchNormalizatio… │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_32       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_33       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_34       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_35       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ clf_pd_cnn          │ (None, 16, 16,    │     21,024 │ shared_bottlenec… │
# │ (SeparableConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_c8_concat       │ (None, 256, 256,  │          0 │ activation_32[0]… │
# │ (Concatenate)       │ 32)               │            │ activation_33[0]… │
# │                     │                   │            │ activation_34[0]… │
# │                     │                   │            │ activation_35[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ clf_maxpool         │ (None, 8, 8, 32)  │          0 │ clf_pd_cnn[0][0]  │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 32)        │          0 │ dec_c8_concat[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ clf_gap             │ (None, 32)        │          0 │ clf_maxpool[0][0] │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_16 (Dense)    │ (None, 2)         │         64 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ clf_pcc_layer       │ (None, 1024)      │          0 │ clf_gap[0][0]     │
# │ (KerasPCCLayer)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_17 (Dense)    │ (None, 32)        │         64 │ dense_16[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ clf_zscore_bn       │ (None, 1024)      │      4,096 │ clf_pcc_layer[0]… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_8 (Reshape) │ (None, 1, 1, 32)  │          0 │ dense_17[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ clf_dense1 (Dense)  │ (None, 64)        │     65,600 │ clf_zscore_bn[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_8          │ (None, 256, 256,  │          0 │ dec_c8_concat[0]… │
# │ (Multiply)          │ 32)               │            │ reshape_8[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ clf_dropout         │ (None, 64)        │          0 │ clf_dense1[0][0]  │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ seg_output (Conv2D) │ (None, 256, 256,  │         33 │ multiply_8[0][0]  │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ clf_output (Dense)  │ (None, 1)         │         65 │ clf_dropout[0][0] │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,494,982 (5.70 MB)
#  Trainable params: 88,737 (346.63 KB)
#  Non-trainable params: 1,228,765 (4.69 MB)
#  Optimizer params: 177,480 (693.29 KB)

# %% [markdown]
# #### Image Segmentation Time

# %%
import time
import numpy as np
import tensorflow as tf

sample_images, _ = next(iter(val_seg_ds.take(1))) 
sample_images = sample_images[:5] 

print("⚡ Running GPU Warm-up iterations...")
for _ in range(2):
    _ = model.predict(sample_images[0:1], verbose=0)

print("⏱️ Measuring exact inference time per image...")
execution_times = []

for i in range(len(sample_images)):
    single_img = tf.expand_dims(sample_images[i], axis=0) # Shape: (1, 256, 256, 3)
    
    start_time = time.perf_counter()
    

    outputs = model.predict(single_img, verbose=0)
    

    _ = tf.cast(outputs[0], tf.float32) 
    
    end_time = time.perf_counter()
    
    elapsed_time = (end_time - start_time) * 1000 
    execution_times.append(elapsed_time)
    print(f"   • Image {i+1}: {elapsed_time:.2f} ms")


avg_time_ms = np.mean(execution_times)
avg_time_sec = avg_time_ms / 1000
fps = 1 / avg_time_sec

print("\n=======================================================")
print("📊 FINAL COMPUTATIONAL EFFICIENCY REPORT")
print("=======================================================")
print(f"🚀 Average Inference Time : {avg_time_ms:.2f} ms per image")
print(f"⏰ In Seconds              : {avg_time_sec:.4f} seconds")
print(f"🎬 Frames Per Second (FPS) : {fps:.2f} FPS 🌟")
print("=======================================================")
# Out:
# ⚡ Running GPU Warm-up iterations...
# ⏱️ Measuring exact inference time per image...
#    • Image 1: 71.70 ms
#    • Image 2: 68.52 ms
#    • Image 3: 65.35 ms
#    • Image 4: 83.21 ms
#
# =======================================================
# 📊 FINAL COMPUTATIONAL EFFICIENCY REPORT
# =======================================================
# 🚀 Average Inference Time : 72.19 ms per image
# ⏰ In Seconds              : 0.0722 seconds
# 🎬 Frames Per Second (FPS) : 13.85 FPS 🌟
# =======================================================
