# %% [markdown]
# # Deep Learning based detection of colorectal polyps using TR-SE-NET and Ensemble ELM architecture with XAI

# %% [markdown]
# 1. ### TR-SE-NET : Triple- Receptive Squeeze-and-Excitation Network
# 2. ELM Extreme Learning Machine is a type of feedforword neural network typically consisting of a single hidden layer, that is designed for high-speed training and efficient computation. It is a one-shot learning mechanizm and also known as single hidden layer feedforward Network (SLFN).
