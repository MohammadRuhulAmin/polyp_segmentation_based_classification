# %%
import tensorflow as tf

print(tf.__version__)
print(tf.config.list_physical_devices('GPU'))
print(tf.test.is_built_with_cuda())
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1778960946.874451   51067 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2.21.0
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# True

# %%
import os
import glob
import numpy as np
import cv2
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, models, Input, mixed_precision
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import (
    ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
)

# %%
# ─────────────────────────────────────────────
# CONFIGURATION
# ─────────────────────────────────────────────
IMG_SIZE   = 256
BATCH_SIZE = 4
EPOCHS     = 100
DATA_PATH  = '/mnt/c/development/Thesis/PolypSegmentationBasedClassification/DataSets/PolypGen2021_MultiCenterData_v2'
MODEL_SAVE = '/mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/unet-trsenet/depth-se-polypgen/best_unet_depthwise_3x3_5x5_7x7_se_v16PM.keras'

# %%
# We will use this function later
import tensorflow as tf

def augment(img, mask):
    # 1. Horizontal Flip:  Both Image and Mask will be flipped
    if tf.random.uniform(()) > 0.5:
        img  = tf.image.flip_left_right(img)
        mask = tf.image.flip_left_right(mask)

    # 2. Vartical Flip:  Both Image and Mask will be flipped
    if tf.random.uniform(()) > 0.5:
        img  = tf.image.flip_up_down(img)
        mask = tf.image.flip_up_down(mask)

    # 3. Brightness adjustment only for Image not mask
    img = tf.image.random_brightness(img, max_delta=0.15)

    # 4. Contrust Adjustment
    # Colab/Drive Crush handle management
    img = tf.image.random_contrast(img, lower=0.85, upper=1.15)

    # 5. Value Clipping
    img = tf.clip_by_value(img, 0.0, 1.0)

    # 6. Shape Gradient, Crusial for medical image pipeline
    # After augmentation no chance to loss the shape
    img.set_shape([IMG_SIZE, IMG_SIZE, 3])
    mask.set_shape([IMG_SIZE, IMG_SIZE, 1])

    return img, mask

# %%
import os
import glob

def load_segmentation_paths(base_path):
    all_images = []
    all_masks = []

    # Taking Loop from C1 to C6
    for i in range(1, 7):
        center_id = f"C{i}"

        img_dir = os.path.join(base_path, f"data_{center_id}", f"images_{center_id}")
        mask_dir = os.path.join(base_path, f"data_{center_id}", f"masks_{center_id}")

        if os.path.exists(img_dir) and os.path.exists(mask_dir):
            # 1. Loading All the images from image folders
            img_paths = (glob.glob(os.path.join(img_dir, "*.jpg")) +
                         glob.glob(os.path.join(img_dir, "*.JPG")) +
                         glob.glob(os.path.join(img_dir, "*.png")) +
                         glob.glob(os.path.join(img_dir, "*.jpeg")))

            #
            for img_p in img_paths:
                filename = os.path.basename(img_p)  #  '425OLCV1_100H0018.jpg'
                name_without_ext, ext = os.path.splitext(filename) # '425OLCV1_100H0018', '.jpg'

                #
                expected_mask_name = f"{name_without_ext}_mask{ext}" # '425OLCV1_100H0018_mask.jpg'
                mask_p = os.path.join(mask_dir, expected_mask_name)

                #
                if os.path.exists(mask_p):
                    all_images.append(img_p)
                    all_masks.append(mask_p)

            print(f"✅ Center {center_id} loaded: {len(img_paths)} images found. Matches successfully paired!")
        else:
            print(f"⚠️ Center {center_id} Folder path not found")

    return all_images, all_masks

# %%
images_list, masks_list = load_segmentation_paths(DATA_PATH)
print(f"\nTotal Parsed Images: {len(images_list)}")
print(f"Total Parsed Masks: {len(masks_list)}")
# Out:
# ✅ Center C1 loaded: 256 images found. Matches successfully paired!
# ✅ Center C2 loaded: 301 images found. Matches successfully paired!
# ✅ Center C3 loaded: 457 images found. Matches successfully paired!
# ✅ Center C4 loaded: 227 images found. Matches successfully paired!
# ✅ Center C5 loaded: 208 images found. Matches successfully paired!
# ✅ Center C6 loaded: 88 images found. Matches successfully paired!
#
# Total Parsed Images: 1536
# Total Parsed Masks: 1536

# %%
import tensorflow as tf

# ─────────────────────────────────────────────
#  UPDATED PROCESS PATH FUNCTION
# ─────────────────────────────────────────────
def process_path_segmentation(img_path, mask_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_image(img, channels=3, expand_animations=False)
    img = tf.image.resize(img, [IMG_SIZE, IMG_SIZE])
    img = tf.cast(img, tf.float32) / 255.0
    img.set_shape([IMG_SIZE, IMG_SIZE, 3])

    # Mask Processing
    mask = tf.io.read_file(mask_path)
    mask = tf.image.decode_image(mask, channels=1, expand_animations=False)
    mask = tf.image.resize(mask, [IMG_SIZE, IMG_SIZE],
                           method=tf.image.ResizeMethod.NEAREST_NEIGHBOR)
    mask = tf.cast(mask, tf.float32) / 255.0
    mask = tf.where(mask > 0.5, 1.0, 0.0)
    mask.set_shape([IMG_SIZE, IMG_SIZE, 1]) # মাস্কের শেপ ফিক্সড করা

    return img, mask

# %%
# ─────────────────────────────────────────────
# 2. UPDATED DATASET GENERATOR FUNCTION
# ─────────────────────────────────────────────
def get_dataset(x, y, batch=BATCH_SIZE, augment_data=False):

    ds = tf.data.Dataset.from_tensor_slices((x, y))
    ds = ds.shuffle(buffer_size=len(x), reshuffle_each_iteration=True)
    ds = ds.map(process_path_segmentation, num_parallel_calls=tf.data.AUTOTUNE)
    if augment_data:
        ds = ds.map(augment, num_parallel_calls=tf.data.AUTOTUNE)


    ds = ds.batch(batch)
    ds = ds.prefetch(tf.data.AUTOTUNE)

    return ds

# %%
# ─────────────────────────────────────────────
#  LOSS & METRICS
# ─────────────────────────────────────────────
def dice_coef(y_true, y_pred, smooth=1.0):
    y_true = tf.cast(tf.reshape(y_true, [-1]), tf.float32)
    y_pred = tf.cast(tf.reshape(y_pred, [-1]), tf.float32)
    intersection = tf.reduce_sum(y_true * y_pred)
    return (2.0 * intersection + smooth) / (
        tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth
    )
def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

def bce_dice_loss(y_true, y_pred):
    y_true_f = tf.cast(y_true, tf.float32)
    y_pred_f = tf.cast(y_pred, tf.float32)
    bce = tf.reduce_mean(
        tf.keras.losses.binary_crossentropy(y_true_f, y_pred_f)
    )
    return bce + dice_loss(y_true_f, y_pred_f)

def iou_metric(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred > 0.5, tf.float32)
    intersection = tf.reduce_sum(y_true * y_pred)
    union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) - intersection
    return (intersection + 1.0) / (union + 1.0)

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, Input

def se_block(input_tensor, ratio=16):
    """Squeeze-and-Excitation Block"""
    channels = input_tensor.shape[-1]

    # Squeeze: Global Information Capture
    # (Batch, H, W, C) -> (Batch, 1, 1, C)
    squeeze = layers.GlobalAveragePooling2D()(input_tensor)

    # Excitation: Learning channel-wise weights
    excitation = layers.Dense(channels // ratio, activation='relu', use_bias=False)(squeeze)
    excitation = layers.Dense(channels, activation='sigmoid', use_bias=False)(excitation)

    # Reshape for multiplication
    excitation = layers.Reshape((1, 1, channels))(excitation)

    # Scale: Multiply original input by learned weights
    return layers.multiply([input_tensor, excitation])

# %%
import tensorflow as tf
from tensorflow.keras import layers

def depthwise_seperable_conv_block(x, filters, dropout_rate=0.0):
    """
    Parallel Multi-Scale Conv -> Concatenate -> SE Block
    এটি একই সাথে ছোট, মাঝারি ও বড় পলিপের ফিচার ক্যাচ করবে এবং 
    অপ্রয়োজনীয় ব্যাকগ্রাউন্ড নয়েজ ফিল্টার করবে।
    """
    # For small polyp (3x3 Kernel) ──
    branch_3x3 = layers.SeparableConv2D(filters // 4, 3, padding='same', use_bias=False)(x)
    branch_3x3 = layers.BatchNormalization()(branch_3x3)
    branch_3x3 = layers.Activation('relu')(branch_3x3)
    
    # For medium level polyp(5x5 Kernel) ──
    branch_5x5 = layers.SeparableConv2D(filters // 4, 5, padding='same', use_bias=False)(x)
    branch_5x5 = layers.BatchNormalization()(branch_5x5)
    branch_5x5 = layers.Activation('relu')(branch_5x5)
    
    # For big Polyp (7x7 Kernel) ──
    branch_7x7 = layers.SeparableConv2D(filters // 4, 7, padding='same', use_bias=False)(x)
    branch_7x7 = layers.BatchNormalization()(branch_7x7)
    branch_7x7 = layers.Activation('relu')(branch_7x7)
    
    # For Global Context (1x1 Kernel - Identity) ──
    branch_1x1 = layers.SeparableConv2D(filters // 4, 1, padding='same', use_bias=False)(x)
    branch_1x1 = layers.BatchNormalization()(branch_1x1)
    branch_1x1 = layers.Activation('relu')(branch_1x1)
    
    # Concat all 4 types of features
    merged = layers.Concatenate()([branch_3x3, branch_5x5, branch_7x7, branch_1x1])
    
    
    x_se = se_block(merged) 
    
    # For maintaining (Residual Connection - Gradient Flow)
    if x.shape[-1] == filters:
        x_se = layers.add([x, x_se])
        
    if dropout_rate > 0:
        x_se = layers.SpatialDropout2D(dropout_rate)(x_se)
        
    return x_se

# %%
def build_unet_depthwise_seperable_se_lite(input_shape=(256, 256, 3)):
    inputs = Input(input_shape)

    # ── Encoder (Downsampling) ──────────────────
    c1 = depthwise_seperable_conv_block(inputs, 32)
    p1 = layers.MaxPooling2D(2)(c1)

    c2 = depthwise_seperable_conv_block(p1, 64)
    p2 = layers.MaxPooling2D(2)(c2)

    c3 = depthwise_seperable_conv_block(p2, 128, dropout_rate=0.1)
    p3 = layers.MaxPooling2D(2)(c3)

    c4 = depthwise_seperable_conv_block(p3, 256, dropout_rate=0.2)
    p4 = layers.MaxPooling2D(2)(c4)

    # ── Bottleneck ──────────────────────────────
    b = depthwise_seperable_conv_block(p4, 512, dropout_rate=0.3)

    # ── Decoder (Upsampling) ────────────────────
    u4 = layers.Conv2DTranspose(256, 2, strides=2, padding='same')(b)
    u4 = layers.concatenate([u4, c4])
    c5 = depthwise_seperable_conv_block(u4, 256, dropout_rate=0.2)

    u3 = layers.Conv2DTranspose(128, 2, strides=2, padding='same')(c5)
    u3 = layers.concatenate([u3, c3])
    c6 = depthwise_seperable_conv_block(u3, 128, dropout_rate=0.1)

    u2 = layers.Conv2DTranspose(64, 2, strides=2, padding='same')(c6)
    u2 = layers.concatenate([u2, c2])
    c7 = depthwise_seperable_conv_block(u2, 64)

    u1 = layers.Conv2DTranspose(32, 2, strides=2, padding='same')(c7)
    u1 = layers.concatenate([u1, c1])
    c8 = depthwise_seperable_conv_block(u1, 32)

    # Output Layer
    outputs = layers.Conv2D(1, 1, activation='sigmoid', dtype='float32')(c8)

    return models.Model(inputs, outputs, name='Depthwise-Seperable-SE-Net-3x5x7')

# %%
# ─────────────────────────────────────────────
#  MAIN RUNNER (FIXED)
# ─────────────────────────────────────────────
if __name__ == '__main__':
    # 1. Loading images from C1 to C6 folders
    images_list, masks_list = load_segmentation_paths(DATA_PATH)

    print(f"\nTotal Parsed Images: {len(images_list)} | Total Parsed Masks: {len(masks_list)}")
    if len(images_list) == 0:
        raise ValueError("No file found in the drive")

    # 2. Train and Validation fixing
    # [FIXED]: Putting images_list and masks_list
    from sklearn.model_selection import train_test_split
    train_x, val_x, train_y, val_y = train_test_split(
        images_list, masks_list, test_size=0.2, random_state=42
    )
    print(f"Train samples: {len(train_x)}  |  Val samples: {len(val_x)}")

    # 3. TF data pipeline calling
    train_ds = get_dataset(train_x, train_y, batch=BATCH_SIZE, augment_data=True)
    val_ds   = get_dataset(val_x,   val_y,   batch=BATCH_SIZE, augment_data=False)


    unet_se = build_unet_depthwise_seperable_se_lite()
    unet_se.summary()


    optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3)
    optimizer = mixed_precision.LossScaleOptimizer(optimizer)


    unet_se.compile(
        optimizer=optimizer,
        loss=bce_dice_loss,
        metrics=[dice_coef, iou_metric, 'accuracy']
    )

    os.makedirs(os.path.dirname(MODEL_SAVE), exist_ok=True)


    callbacks = [
        ModelCheckpoint(MODEL_SAVE, monitor='val_dice_coef',
                        save_best_only=True, mode='max', verbose=1),
        ReduceLROnPlateau(monitor='val_loss', factor=0.5,
                          patience=7, min_lr=1e-7, verbose=1),
        EarlyStopping(monitor='val_dice_coef', patience=20,
                      restore_best_weights=True, mode='max', verbose=1),
    ]

    print("\n========== Training Started ==========")
    history = unet_se.fit(
        train_ds,
        validation_data=val_ds,
        epochs=EPOCHS,
        callbacks=callbacks
    )
    print("========== Training Complete ==========\n")


    fig, axes = plt.subplots(1, 3, figsize=(18, 5))

    # Loss Plot
    axes[0].plot(history.history['loss'],          label='Train')
    axes[0].plot(history.history['val_loss'],      label='Val')
    axes[0].set_title('BCE + Dice Loss'); axes[0].legend()


    dice_key = 'dice_coef' if 'dice_coef' in history.history else 'dice_coefficient'
    axes[1].plot(history.history[dice_key],        label='Train')
    axes[1].plot(history.history[f'val_{dice_key}'],    label='Val')
    axes[1].set_title('Dice Coefficient'); axes[1].legend()


    iou_key = 'iou_metric' if 'iou_metric' in history.history else 'mean_io_u'
    axes[2].plot(history.history[iou_key],        label='Train')
    axes[2].plot(history.history[f'val_{iou_key}'],    label='Val')
    axes[2].set_title('IoU Score'); axes[2].legend()

    plt.tight_layout()
    plt.savefig('training_history.png', dpi=150)
    plt.show()
# Out:
# ✅ Center C1 loaded: 256 images found. Matches successfully paired!
# ✅ Center C2 loaded: 301 images found. Matches successfully paired!
# ✅ Center C3 loaded: 457 images found. Matches successfully paired!
# ✅ Center C4 loaded: 227 images found. Matches successfully paired!
# ✅ Center C5 loaded: 208 images found. Matches successfully paired!
# ✅ Center C6 loaded: 88 images found. Matches successfully paired!
#
# Total Parsed Images: 1536 | Total Parsed Masks: 1536
# Train samples: 1228  |  Val samples: 308
# W0000 00:00:1778961410.843787   51067 gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was false.
# I0000 00:00:1778961410.844366   51067 gpu_device.cc:2043] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5563 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9
# Model: "Depthwise-Seperable-SE-Net-3x5x7"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d    │ (None, 256, 256,  │         51 │ input_layer[0][0] │
# │ (SeparableConv2D)   │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_1  │ (None, 256, 256,  │         99 │ input_layer[0][0] │
# │ (SeparableConv2D)   │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_2  │ (None, 256, 256,  │        171 │ input_layer[0][0] │
# │ (SeparableConv2D)   │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_3  │ (None, 256, 256,  │         27 │ input_layer[0][0] │
# │ (SeparableConv2D)   │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 256, 256,  │         32 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         32 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         32 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         32 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 256, 256,  │          0 │ activation[0][0], │
# │ (Concatenate)       │ 32)               │            │ activation_1[0][… │
# │                     │                   │            │ activation_2[0][… │
# │                     │                   │            │ activation_3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 32)        │          0 │ concatenate[0][0] │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 2)         │         64 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 32)        │         64 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape (Reshape)   │ (None, 1, 1, 32)  │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 256, 256,  │          0 │ concatenate[0][0… │
# │                     │ 32)               │            │ reshape[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 128, 128,  │          0 │ multiply[0][0]    │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_4  │ (None, 128, 128,  │        800 │ max_pooling2d[0]… │
# │ (SeparableConv2D)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_5  │ (None, 128, 128,  │      1,312 │ max_pooling2d[0]… │
# │ (SeparableConv2D)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_6  │ (None, 128, 128,  │      2,080 │ max_pooling2d[0]… │
# │ (SeparableConv2D)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_7  │ (None, 128, 128,  │        544 │ max_pooling2d[0]… │
# │ (SeparableConv2D)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 128, 128,  │          0 │ activation_4[0][… │
# │ (Concatenate)       │ 64)               │            │ activation_5[0][… │
# │                     │                   │            │ activation_6[0][… │
# │                     │                   │            │ activation_7[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 64)        │          0 │ concatenate_1[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 4)         │        256 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 64)        │        256 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_1 (Reshape) │ (None, 1, 1, 64)  │          0 │ dense_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_1          │ (None, 128, 128,  │          0 │ concatenate_1[0]… │
# │ (Multiply)          │ 64)               │            │ reshape_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 64, 64,    │          0 │ multiply_1[0][0]  │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_8  │ (None, 64, 64,    │      2,624 │ max_pooling2d_1[… │
# │ (SeparableConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_9  │ (None, 64, 64,    │      3,648 │ max_pooling2d_1[… │
# │ (SeparableConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_10 │ (None, 64, 64,    │      5,184 │ max_pooling2d_1[… │
# │ (SeparableConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_11 │ (None, 64, 64,    │      2,112 │ max_pooling2d_1[… │
# │ (SeparableConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 64, 64,    │          0 │ activation_8[0][… │
# │ (Concatenate)       │ 128)              │            │ activation_9[0][… │
# │                     │                   │            │ activation_10[0]… │
# │                     │                   │            │ activation_11[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ concatenate_2[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 8)         │      1,024 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 128)       │      1,024 │ dense_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_2 (Reshape) │ (None, 1, 1, 128) │          0 │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_2          │ (None, 64, 64,    │          0 │ concatenate_2[0]… │
# │ (Multiply)          │ 128)              │            │ reshape_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout2d   │ (None, 64, 64,    │          0 │ multiply_2[0][0]  │
# │ (SpatialDropout2D)  │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 32, 32,    │          0 │ spatial_dropout2… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_12 │ (None, 32, 32,    │      9,344 │ max_pooling2d_2[… │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_13 │ (None, 32, 32,    │     11,392 │ max_pooling2d_2[… │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_14 │ (None, 32, 32,    │     14,464 │ max_pooling2d_2[… │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_15 │ (None, 32, 32,    │      8,320 │ max_pooling2d_2[… │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_14       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_15       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 32, 32,    │          0 │ activation_12[0]… │
# │ (Concatenate)       │ 256)              │            │ activation_13[0]… │
# │                     │                   │            │ activation_14[0]… │
# │                     │                   │            │ activation_15[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 256)       │          0 │ concatenate_3[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 16)        │      4,096 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 256)       │      4,096 │ dense_6[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_3 (Reshape) │ (None, 1, 1, 256) │          0 │ dense_7[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_3          │ (None, 32, 32,    │          0 │ concatenate_3[0]… │
# │ (Multiply)          │ 256)              │            │ reshape_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout2d_1 │ (None, 32, 32,    │          0 │ multiply_3[0][0]  │
# │ (SpatialDropout2D)  │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 16, 16,    │          0 │ spatial_dropout2… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_16 │ (None, 16, 16,    │     35,072 │ max_pooling2d_3[… │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_17 │ (None, 16, 16,    │     39,168 │ max_pooling2d_3[… │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_18 │ (None, 16, 16,    │     45,312 │ max_pooling2d_3[… │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_19 │ (None, 16, 16,    │     33,024 │ max_pooling2d_3[… │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_16       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_17       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_18       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_19       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_4       │ (None, 16, 16,    │          0 │ activation_16[0]… │
# │ (Concatenate)       │ 512)              │            │ activation_17[0]… │
# │                     │                   │            │ activation_18[0]… │
# │                     │                   │            │ activation_19[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 512)       │          0 │ concatenate_4[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 32)        │     16,384 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 512)       │     16,384 │ dense_8[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_4 (Reshape) │ (None, 1, 1, 512) │          0 │ dense_9[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_4          │ (None, 16, 16,    │          0 │ concatenate_4[0]… │
# │ (Multiply)          │ 512)              │            │ reshape_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout2d_2 │ (None, 16, 16,    │          0 │ multiply_4[0][0]  │
# │ (SpatialDropout2D)  │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 32, 32,    │    524,544 │ spatial_dropout2… │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_5       │ (None, 32, 32,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 512)              │            │ spatial_dropout2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_20 │ (None, 32, 32,    │     37,376 │ concatenate_5[0]… │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_21 │ (None, 32, 32,    │     45,568 │ concatenate_5[0]… │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_22 │ (None, 32, 32,    │     57,856 │ concatenate_5[0]… │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_23 │ (None, 32, 32,    │     33,280 │ concatenate_5[0]… │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_20       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_21       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_22       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_23       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_6       │ (None, 32, 32,    │          0 │ activation_20[0]… │
# │ (Concatenate)       │ 256)              │            │ activation_21[0]… │
# │                     │                   │            │ activation_22[0]… │
# │                     │                   │            │ activation_23[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 256)       │          0 │ concatenate_6[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_10 (Dense)    │ (None, 16)        │      4,096 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_11 (Dense)    │ (None, 256)       │      4,096 │ dense_10[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_5 (Reshape) │ (None, 1, 1, 256) │          0 │ dense_11[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_5          │ (None, 32, 32,    │          0 │ concatenate_6[0]… │
# │ (Multiply)          │ 256)              │            │ reshape_5[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout2d_3 │ (None, 32, 32,    │          0 │ multiply_5[0][0]  │
# │ (SpatialDropout2D)  │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 64, 64,    │    131,200 │ spatial_dropout2… │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_7       │ (None, 64, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 256)              │            │ spatial_dropout2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_24 │ (None, 64, 64,    │     10,496 │ concatenate_7[0]… │
# │ (SeparableConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_25 │ (None, 64, 64,    │     14,592 │ concatenate_7[0]… │
# │ (SeparableConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_26 │ (None, 64, 64,    │     20,736 │ concatenate_7[0]… │
# │ (SeparableConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_27 │ (None, 64, 64,    │      8,448 │ concatenate_7[0]… │
# │ (SeparableConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_24       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_25       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_26       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_27       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_8       │ (None, 64, 64,    │          0 │ activation_24[0]… │
# │ (Concatenate)       │ 128)              │            │ activation_25[0]… │
# │                     │                   │            │ activation_26[0]… │
# │                     │                   │            │ activation_27[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ concatenate_8[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_12 (Dense)    │ (None, 8)         │      1,024 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_13 (Dense)    │ (None, 128)       │      1,024 │ dense_12[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_6 (Reshape) │ (None, 1, 1, 128) │          0 │ dense_13[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_6          │ (None, 64, 64,    │          0 │ concatenate_8[0]… │
# │ (Multiply)          │ 128)              │            │ reshape_6[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout2d_4 │ (None, 64, 64,    │          0 │ multiply_6[0][0]  │
# │ (SpatialDropout2D)  │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 128, 128,  │     32,832 │ spatial_dropout2… │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_9       │ (None, 128, 128,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ multiply_1[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_28 │ (None, 128, 128,  │      3,200 │ concatenate_9[0]… │
# │ (SeparableConv2D)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_29 │ (None, 128, 128,  │      5,248 │ concatenate_9[0]… │
# │ (SeparableConv2D)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_30 │ (None, 128, 128,  │      8,320 │ concatenate_9[0]… │
# │ (SeparableConv2D)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_31 │ (None, 128, 128,  │      2,176 │ concatenate_9[0]… │
# │ (SeparableConv2D)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_28       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_29       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_30       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_31       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_10      │ (None, 128, 128,  │          0 │ activation_28[0]… │
# │ (Concatenate)       │ 64)               │            │ activation_29[0]… │
# │                     │                   │            │ activation_30[0]… │
# │                     │                   │            │ activation_31[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 64)        │          0 │ concatenate_10[0… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_14 (Dense)    │ (None, 4)         │        256 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_15 (Dense)    │ (None, 64)        │        256 │ dense_14[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_7 (Reshape) │ (None, 1, 1, 64)  │          0 │ dense_15[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_7          │ (None, 128, 128,  │          0 │ concatenate_10[0… │
# │ (Multiply)          │ 64)               │            │ reshape_7[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_3  │ (None, 256, 256,  │      8,224 │ multiply_7[0][0]  │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_11      │ (None, 256, 256,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 64)               │            │ multiply[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_32 │ (None, 256, 256,  │      1,088 │ concatenate_11[0… │
# │ (SeparableConv2D)   │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_33 │ (None, 256, 256,  │      2,112 │ concatenate_11[0… │
# │ (SeparableConv2D)   │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_34 │ (None, 256, 256,  │      3,648 │ concatenate_11[0… │
# │ (SeparableConv2D)   │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_35 │ (None, 256, 256,  │        576 │ concatenate_11[0… │
# │ (SeparableConv2D)   │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         32 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         32 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         32 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         32 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_32       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_33       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_34       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_35       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_12      │ (None, 256, 256,  │          0 │ activation_32[0]… │
# │ (Concatenate)       │ 32)               │            │ activation_33[0]… │
# │                     │                   │            │ activation_34[0]… │
# │                     │                   │            │ activation_35[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 32)        │          0 │ concatenate_12[0… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_16 (Dense)    │ (None, 2)         │         64 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_17 (Dense)    │ (None, 32)        │         64 │ dense_16[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_8 (Reshape) │ (None, 1, 1, 32)  │          0 │ dense_17[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_8          │ (None, 256, 256,  │          0 │ concatenate_12[0… │
# │ (Multiply)          │ 32)               │            │ reshape_8[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 256, 256,  │         33 │ multiply_8[0][0]  │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,226,717 (4.68 MB)
#  Trainable params: 1,223,773 (4.67 MB)
#  Non-trainable params: 2,944 (11.50 KB)
# ========== Training Started ==========
# Epoch 1/100
# I0000 00:00:1778961432.618759   53627 service.cc:153] XLA service 0x758d4c0ab980 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1778961432.618810   53627 service.cc:161]   StreamExecutor [0]: NVIDIA GeForce RTX 4060 Laptop GPU, Compute Capability 8.9 (Driver: 12.7.0; Runtime: 12.9.0; Toolkit: 12.5.0; DNN: 9.21.1)
# I0000 00:00:1778961433.134287   53627 dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1778961439.402254   53627 cuda_dnn.cc:461] Loaded cuDNN version 92101
# I0000 00:00:1778961440.420816   53627 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_39288__.476
# E0000 00:00:1778961446.921020   53627 cuda_timer.cc:87] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1778961450.800545   53627 cuda_timer.cc:87] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1778961452.519126   53627 cuda_timer.cc:87] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1778961463.924303   53627 cuda_timer.cc:87] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1778961472.286456   53627 cuda_timer.cc:87] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# I0000 00:00:1778961490.896110   53910 subprocess_compilation.cc:348] ptxas warning : Registers are spilled to local memory in function 'input_compare_reduce_fusion_1', 12 bytes spill stores, 12 bytes spill loads
#
# I0000 00:00:1778961518.980965   53627 subprocess_compilation.cc:348] ptxas warning : Registers are spilled to local memory in function 'input_compare_reduce_fusion_1', 12 bytes spill stores, 12 bytes spill loads
#
# I0000 00:00:1778961519.191339   53627 device_compiler.h:208] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.8043 - dice_coef: 0.1777 - iou_metric: 0.1770 - loss: 1.2899
# Epoch 1: val_dice_coef improved from None to 0.11073, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/unet-trsenet/depth-se-polypgen/best_unet_depthwise_3x3_5x5_7x7_se_v16PM.keras
#
# Epoch 1: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/unet-trsenet/depth-se-polypgen/best_unet_depthwise_3x3_5x5_7x7_se_v16PM.keras
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 147s 124ms/step - accuracy: 0.8575 - dice_coef: 0.2185 - iou_metric: 0.2070 - loss: 1.1415 - val_accuracy: 0.9197 - val_dice_coef: 0.1107 - val_iou_metric: 6.9671e-05 - val_loss: 1.1932 - learning_rate: 0.0010
# Epoch 2/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.8942 - dice_coef: 0.2838 - iou_metric: 0.2176 - loss: 0.9715
# Epoch 2: val_dice_coef improved from 0.11073 to 0.32266, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/unet-trsenet/depth-se-polypgen/best_unet_depthwise_3x3_5x5_7x7_se_v16PM.keras
#
# Epoch 2: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/unet-trsenet/depth-se-polypgen/best_unet_depthwise_3x3_5x5_7x7_se_v16PM.keras
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 29s 93ms/step - accuracy: 0.8973 - dice_coef: 0.3042 - iou_metric: 0.2329 - loss: 0.9467 - val_accuracy: 0.8574 - val_dice_coef: 0.3227 - val_iou_metric: 0.2365 - val_loss: 0.9820 - learning_rate: 0.0010
# Epoch 3/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.9028 - dice_coef: 0.3233 - iou_metric: 0.2447 - loss: 0.9203
# Epoch 3: val_dice_coef improved from 0.32266 to 0.36151, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/unet-trsenet/depth-se-polypgen/best_unet_depthwise_3x3_5x5_7x7_se_v16PM.keras
#
# Epoch 3: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/unet-trsenet/depth-se-polypgen/best_unet_depthwise_3x3_5x5_7x7_se_v16PM.keras
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 29s 93ms/step - accuracy: 0.9041 - dice_coef: 0.3382 - iou_metric: 0.2577 - loss: 0.9055 - val_accuracy: 0.8715 - val_dice_coef: 0.3615 - val_iou_metric: 0.2530 - val_loss: 0.9821 - learning_rate: 0.0010
# Epoch 4/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.9077 - dice_coef: 0.3706 - iou_metric: 0.2827 - loss: 0.8710
# Epoch 4: val_dice_coef did not improve from 0.36151
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 28s 90ms/step - accuracy: 0.9100 - dice_coef: 0.3728 - iou_metric: 0.2840 - loss: 0.8620 - val_accuracy: 0.9049 - val_dice_coef: 0.3293 - val_iou_metric: 0.2491 - val_loss: 0.9128 - learning_rate: 0.0010
# Epoch 5/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.9117 - dice_coef: 0.3550 - iou_metric: 0.2705 - loss: 0.8801
# Epoch 5: val_dice_coef improved from 0.36151 to 0.39809, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/unet-trsenet/depth-se-polypgen/best_unet_depthwise_3x3_5x5_7x7_se_v16PM.keras
#
# ...
# Epoch 69/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.9740 - dice_coef: 0.7830 - iou_metric: 0.6935 - loss: 0.3105
# Epoch 69: val_dice_coef did not improve from 0.76575
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 27s 89ms/step - accuracy: 0.9732 - dice_coef: 0.7842 - iou_metric: 0.6935 - loss: 0.3122 - val_accuracy: 0.9684 - val_dice_coef: 0.7503 - val_iou_metric: 0.6527 - val_loss: 0.3623 - learning_rate: 5.0000e-04
# Epoch 70/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9730 - dice_coef: 0.7895 - iou_metric: 0.7081 - loss: 0.3115
# Epoch 70: val_dice_coef did not improve from 0.76575
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 27s 89ms/step - accuracy: 0.9735 - dice_coef: 0.7845 - iou_metric: 0.6998 - loss: 0.3119 - val_accuracy: 0.9696 - val_dice_coef: 0.7342 - val_iou_metric: 0.6349 - val_loss: 0.3897 - learning_rate: 5.0000e-04
# Epoch 71/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.9750 - dice_coef: 0.7847 - iou_metric: 0.6955 - loss: 0.3064
# Epoch 71: val_dice_coef did not improve from 0.76575
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 28s 91ms/step - accuracy: 0.9735 - dice_coef: 0.7794 - iou_metric: 0.6891 - loss: 0.3159 - val_accuracy: 0.9582 - val_dice_coef: 0.7146 - val_iou_metric: 0.6216 - val_loss: 0.4364 - learning_rate: 5.0000e-04
# Epoch 72/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.9707 - dice_coef: 0.7486 - iou_metric: 0.6565 - loss: 0.3556
# Epoch 72: val_dice_coef did not improve from 0.76575
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 28s 90ms/step - accuracy: 0.9728 - dice_coef: 0.7784 - iou_metric: 0.6911 - loss: 0.3198 - val_accuracy: 0.9676 - val_dice_coef: 0.7590 - val_iou_metric: 0.6580 - val_loss: 0.3649 - learning_rate: 5.0000e-04
# Epoch 73/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.9743 - dice_coef: 0.7862 - iou_metric: 0.6990 - loss: 0.3081
# Epoch 73: val_dice_coef did not improve from 0.76575
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 28s 90ms/step - accuracy: 0.9745 - dice_coef: 0.7882 - iou_metric: 0.7019 - loss: 0.3036 - val_accuracy: 0.9701 - val_dice_coef: 0.7471 - val_iou_metric: 0.6520 - val_loss: 0.3692 - learning_rate: 5.0000e-04
# Epoch 74/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.9774 - dice_coef: 0.8039 - iou_metric: 0.7189 - loss: 0.2789
# Epoch 74: val_dice_coef improved from 0.76575 to 0.76982, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/unet-trsenet/depth-se-polypgen/best_unet_depthwise_3x3_5x5_7x7_se_v16PM.keras
#
# Epoch 74: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/unet-trsenet/depth-se-polypgen/best_unet_depthwise_3x3_5x5_7x7_se_v16PM.keras
#
# Epoch 74: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 29s 95ms/step - accuracy: 0.9749 - dice_coef: 0.7883 - iou_metric: 0.7003 - loss: 0.3050 - val_accuracy: 0.9704 - val_dice_coef: 0.7698 - val_iou_metric: 0.6695 - val_loss: 0.3447 - learning_rate: 5.0000e-04
# Epoch 75/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.9754 - dice_coef: 0.7952 - iou_metric: 0.7136 - loss: 0.2914
# Epoch 75: val_dice_coef did not improve from 0.76982
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 28s 91ms/step - accuracy: 0.9753 - dice_coef: 0.7975 - iou_metric: 0.7138 - loss: 0.2910 - val_accuracy: 0.9721 - val_dice_coef: 0.7634 - val_iou_metric: 0.6776 - val_loss: 0.3364 - learning_rate: 2.5000e-04
# Epoch 76/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.9748 - dice_coef: 0.8091 - iou_metric: 0.7272 - loss: 0.2803
# Epoch 76: val_dice_coef improved from 0.76982 to 0.77598, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/unet-trsenet/depth-se-polypgen/best_unet_depthwise_3x3_5x5_7x7_se_v16PM.keras
#
# Epoch 76: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/unet-trsenet/depth-se-polypgen/best_unet_depthwise_3x3_5x5_7x7_se_v16PM.keras
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 29s 95ms/step - accuracy: 0.9760 - dice_coef: 0.8021 - iou_metric: 0.7190 - loss: 0.2842 - val_accuracy: 0.9735 - val_dice_coef: 0.7760 - val_iou_metric: 0.6865 - val_loss: 0.3292 - learning_rate: 2.5000e-04
# Epoch 77/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.9764 - dice_coef: 0.8044 - iou_metric: 0.7213 - loss: 0.2777
# Epoch 77: val_dice_coef improved from 0.77598 to 0.78414, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/unet-trsenet/depth-se-polypgen/best_unet_depthwise_3x3_5x5_7x7_se_v16PM.keras
#
# Epoch 77: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/unet-trsenet/depth-se-polypgen/best_unet_depthwise_3x3_5x5_7x7_se_v16PM.keras
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 31s 102ms/step - accuracy: 0.9759 - dice_coef: 0.7962 - iou_metric: 0.7131 - loss: 0.2908 - val_accuracy: 0.9740 - val_dice_coef: 0.7841 - val_iou_metric: 0.6943 - val_loss: 0.3142 - learning_rate: 2.5000e-04
# Epoch 78/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.9743 - dice_coef: 0.7772 - iou_metric: 0.6865 - loss: 0.3235
# Epoch 78: val_dice_coef did not improve from 0.78414
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 29s 94ms/step - accuracy: 0.9762 - dice_coef: 0.7947 - iou_metric: 0.7109 - loss: 0.2931 - val_accuracy: 0.9733 - val_dice_coef: 0.7804 - val_iou_metric: 0.6911 - val_loss: 0.3269 - learning_rate: 2.5000e-04
# Epoch 79/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.9793 - dice_coef: 0.8170 - iou_metric: 0.7397 - loss: 0.2585
# Epoch 79: val_dice_coef did not improve from 0.78414
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 30s 96ms/step - accuracy: 0.9770 - dice_coef: 0.8088 - iou_metric: 0.7256 - loss: 0.2759 - val_accuracy: 0.9718 - val_dice_coef: 0.7637 - val_iou_metric: 0.6682 - val_loss: 0.3444 - learning_rate: 2.5000e-04
# Epoch 80/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.9749 - dice_coef: 0.7879 - iou_metric: 0.7053 - loss: 0.3042
# Epoch 80: val_dice_coef did not improve from 0.78414
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 28s 89ms/step - accuracy: 0.9758 - dice_coef: 0.7972 - iou_metric: 0.7144 - loss: 0.2917 - val_accuracy: 0.9730 - val_dice_coef: 0.7817 - val_iou_metric: 0.6921 - val_loss: 0.3200 - learning_rate: 2.5000e-04
# Epoch 81/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.9783 - dice_coef: 0.8047 - iou_metric: 0.7238 - loss: 0.2759
# Epoch 81: val_dice_coef improved from 0.78414 to 0.79251, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/unet-trsenet/depth-se-polypgen/best_unet_depthwise_3x3_5x5_7x7_se_v16PM.keras
#
# Epoch 81: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/unet-trsenet/depth-se-polypgen/best_unet_depthwise_3x3_5x5_7x7_se_v16PM.keras
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 29s 93ms/step - accuracy: 0.9768 - dice_coef: 0.8062 - iou_metric: 0.7253 - loss: 0.2814 - val_accuracy: 0.9715 - val_dice_coef: 0.7925 - val_iou_metric: 0.7020 - val_loss: 0.3113 - learning_rate: 2.5000e-04
# Epoch 82/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.9753 - dice_coef: 0.7988 - iou_metric: 0.7123 - loss: 0.2930
# Epoch 82: val_dice_coef improved from 0.79251 to 0.79495, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/unet-trsenet/depth-se-polypgen/best_unet_depthwise_3x3_5x5_7x7_se_v16PM.keras
#
# Epoch 82: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/unet-trsenet/depth-se-polypgen/best_unet_depthwise_3x3_5x5_7x7_se_v16PM.keras
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 30s 96ms/step - accuracy: 0.9768 - dice_coef: 0.8040 - iou_metric: 0.7201 - loss: 0.2807 - val_accuracy: 0.9740 - val_dice_coef: 0.7950 - val_iou_metric: 0.7035 - val_loss: 0.3064 - learning_rate: 2.5000e-04
# Epoch 83/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.9774 - dice_coef: 0.8243 - iou_metric: 0.7459 - loss: 0.2555
# Epoch 83: val_dice_coef did not improve from 0.79495
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 31s 100ms/step - accuracy: 0.9769 - dice_coef: 0.8124 - iou_metric: 0.7294 - loss: 0.2710 - val_accuracy: 0.9730 - val_dice_coef: 0.7824 - val_iou_metric: 0.6851 - val_loss: 0.3248 - learning_rate: 2.5000e-04
# Epoch 84/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.9751 - dice_coef: 0.7973 - iou_metric: 0.7123 - loss: 0.2956
# Epoch 84: val_dice_coef did not improve from 0.79495
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 29s 95ms/step - accuracy: 0.9764 - dice_coef: 0.8031 - iou_metric: 0.7199 - loss: 0.2815 - val_accuracy: 0.9741 - val_dice_coef: 0.7878 - val_iou_metric: 0.6993 - val_loss: 0.3161 - learning_rate: 2.5000e-04
# Epoch 85/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.9788 - dice_coef: 0.8131 - iou_metric: 0.7340 - loss: 0.2675
# Epoch 85: val_dice_coef did not improve from 0.79495
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 28s 91ms/step - accuracy: 0.9773 - dice_coef: 0.8069 - iou_metric: 0.7264 - loss: 0.2782 - val_accuracy: 0.9730 - val_dice_coef: 0.7843 - val_iou_metric: 0.6960 - val_loss: 0.3182 - learning_rate: 2.5000e-04
# Epoch 86/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9766 - dice_coef: 0.8117 - iou_metric: 0.7293 - loss: 0.2777
# Epoch 86: val_dice_coef did not improve from 0.79495
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 27s 88ms/step - accuracy: 0.9777 - dice_coef: 0.8162 - iou_metric: 0.7343 - loss: 0.2674 - val_accuracy: 0.9730 - val_dice_coef: 0.7839 - val_iou_metric: 0.6899 - val_loss: 0.3189 - learning_rate: 2.5000e-04
# Epoch 87/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.9768 - dice_coef: 0.8312 - iou_metric: 0.7542 - loss: 0.2528
# Epoch 87: val_dice_coef did not improve from 0.79495
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 27s 89ms/step - accuracy: 0.9777 - dice_coef: 0.8179 - iou_metric: 0.7382 - loss: 0.2643 - val_accuracy: 0.9726 - val_dice_coef: 0.7709 - val_iou_metric: 0.6789 - val_loss: 0.3377 - learning_rate: 2.5000e-04
# Epoch 88/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9776 - dice_coef: 0.8223 - iou_metric: 0.7394 - loss: 0.2618
# Epoch 88: val_dice_coef did not improve from 0.79495
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 27s 88ms/step - accuracy: 0.9782 - dice_coef: 0.8195 - iou_metric: 0.7388 - loss: 0.2608 - val_accuracy: 0.9739 - val_dice_coef: 0.7782 - val_iou_metric: 0.6828 - val_loss: 0.3289 - learning_rate: 2.5000e-04
# Epoch 89/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9782 - dice_coef: 0.8249 - iou_metric: 0.7454 - loss: 0.2531
# Epoch 89: val_dice_coef did not improve from 0.79495
#
# Epoch 89: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 27s 87ms/step - accuracy: 0.9769 - dice_coef: 0.8165 - iou_metric: 0.7338 - loss: 0.2675 - val_accuracy: 0.9716 - val_dice_coef: 0.7802 - val_iou_metric: 0.6897 - val_loss: 0.3268 - learning_rate: 2.5000e-04
# Epoch 90/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.9762 - dice_coef: 0.8125 - iou_metric: 0.7275 - loss: 0.2732
# Epoch 90: val_dice_coef did not improve from 0.79495
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 28s 91ms/step - accuracy: 0.9780 - dice_coef: 0.8171 - iou_metric: 0.7342 - loss: 0.2622 - val_accuracy: 0.9730 - val_dice_coef: 0.7703 - val_iou_metric: 0.6749 - val_loss: 0.3344 - learning_rate: 1.2500e-04
# Epoch 91/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.9777 - dice_coef: 0.8192 - iou_metric: 0.7345 - loss: 0.2626
# Epoch 91: val_dice_coef did not improve from 0.79495
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 28s 91ms/step - accuracy: 0.9773 - dice_coef: 0.8208 - iou_metric: 0.7385 - loss: 0.2620 - val_accuracy: 0.9738 - val_dice_coef: 0.7885 - val_iou_metric: 0.6922 - val_loss: 0.3132 - learning_rate: 1.2500e-04
# Epoch 92/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9788 - dice_coef: 0.8144 - iou_metric: 0.7350 - loss: 0.2660
# Epoch 92: val_dice_coef did not improve from 0.79495
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 27s 88ms/step - accuracy: 0.9783 - dice_coef: 0.8181 - iou_metric: 0.7397 - loss: 0.2622 - val_accuracy: 0.9737 - val_dice_coef: 0.7769 - val_iou_metric: 0.6854 - val_loss: 0.3279 - learning_rate: 1.2500e-04
# Epoch 93/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.9790 - dice_coef: 0.8105 - iou_metric: 0.7302 - loss: 0.2650
# Epoch 93: val_dice_coef improved from 0.79495 to 0.79524, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/unet-trsenet/depth-se-polypgen/best_unet_depthwise_3x3_5x5_7x7_se_v16PM.keras
#
# Epoch 93: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/unet-trsenet/depth-se-polypgen/best_unet_depthwise_3x3_5x5_7x7_se_v16PM.keras
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 30s 97ms/step - accuracy: 0.9786 - dice_coef: 0.8172 - iou_metric: 0.7354 - loss: 0.2606 - val_accuracy: 0.9717 - val_dice_coef: 0.7952 - val_iou_metric: 0.7008 - val_loss: 0.3121 - learning_rate: 1.2500e-04
# Epoch 94/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9794 - dice_coef: 0.8274 - iou_metric: 0.7497 - loss: 0.2510
# Epoch 94: val_dice_coef did not improve from 0.79524
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 27s 87ms/step - accuracy: 0.9796 - dice_coef: 0.8295 - iou_metric: 0.7525 - loss: 0.2488 - val_accuracy: 0.9724 - val_dice_coef: 0.7885 - val_iou_metric: 0.6976 - val_loss: 0.3185 - learning_rate: 1.2500e-04
# Epoch 95/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.9783 - dice_coef: 0.8313 - iou_metric: 0.7548 - loss: 0.2494
# Epoch 95: val_dice_coef did not improve from 0.79524
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 28s 89ms/step - accuracy: 0.9780 - dice_coef: 0.8207 - iou_metric: 0.7401 - loss: 0.2615 - val_accuracy: 0.9723 - val_dice_coef: 0.7695 - val_iou_metric: 0.6772 - val_loss: 0.3390 - learning_rate: 1.2500e-04
# Epoch 96/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.9804 - dice_coef: 0.8309 - iou_metric: 0.7537 - loss: 0.2395
# Epoch 96: val_dice_coef did not improve from 0.79524
#
# Epoch 96: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 28s 92ms/step - accuracy: 0.9785 - dice_coef: 0.8248 - iou_metric: 0.7454 - loss: 0.2544 - val_accuracy: 0.9733 - val_dice_coef: 0.7945 - val_iou_metric: 0.6995 - val_loss: 0.3103 - learning_rate: 1.2500e-04
# Epoch 97/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.9797 - dice_coef: 0.8365 - iou_metric: 0.7588 - loss: 0.2371
# Epoch 97: val_dice_coef did not improve from 0.79524
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 28s 90ms/step - accuracy: 0.9792 - dice_coef: 0.8277 - iou_metric: 0.7481 - loss: 0.2481 - val_accuracy: 0.9735 - val_dice_coef: 0.7722 - val_iou_metric: 0.6857 - val_loss: 0.3319 - learning_rate: 6.2500e-05
# Epoch 98/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.9802 - dice_coef: 0.8324 - iou_metric: 0.7569 - loss: 0.2406
# Epoch 98: val_dice_coef did not improve from 0.79524
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 28s 89ms/step - accuracy: 0.9797 - dice_coef: 0.8267 - iou_metric: 0.7507 - loss: 0.2475 - val_accuracy: 0.9730 - val_dice_coef: 0.7779 - val_iou_metric: 0.6813 - val_loss: 0.3277 - learning_rate: 6.2500e-05
# Epoch 99/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.9800 - dice_coef: 0.8345 - iou_metric: 0.7591 - loss: 0.2372
# Epoch 99: val_dice_coef did not improve from 0.79524
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 28s 90ms/step - accuracy: 0.9799 - dice_coef: 0.8276 - iou_metric: 0.7509 - loss: 0.2469 - val_accuracy: 0.9732 - val_dice_coef: 0.7829 - val_iou_metric: 0.6921 - val_loss: 0.3210 - learning_rate: 6.2500e-05
# Epoch 100/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.9793 - dice_coef: 0.8425 - iou_metric: 0.7667 - loss: 0.2328
# Epoch 100: val_dice_coef did not improve from 0.79524
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 27s 89ms/step - accuracy: 0.9789 - dice_coef: 0.8303 - iou_metric: 0.7497 - loss: 0.2468 - val_accuracy: 0.9723 - val_dice_coef: 0.7841 - val_iou_metric: 0.6951 - val_loss: 0.3203 - learning_rate: 6.2500e-05
# Restoring model weights from the end of the best epoch: 93.
# ========== Training Complete ==========

# %%
#Model Summary
history_dict = history.history

# Finding the best value
best_dice = max(history_dict['dice_coef'])
best_val_dice = max(history_dict['val_dice_coef'])
best_iou = max(history_dict['iou_metric'])
best_val_iou = max(history_dict['val_iou_metric'])
min_loss = min(history_dict['loss'])
min_val_loss = min(history_dict['val_loss'])
best_acc = max(history_dict['accuracy'])
best_val_acc = max(history_dict['val_accuracy'])

print("\n" + "="*30)
print("BEST TRAINING RESULTS")
print("Pipeline Depthwise Separable 3x3, 5x5, 7x7 ---> SE Block ---> Unet")
print("="*30)
print(f"Best Training Dice:    {best_dice:.4f}")
print(f"Best Training IoU:     {best_iou:.4f}")
print(f"Best Training Acc:     {best_acc:.4f}")
print(f"Minimum Training Loss: {min_loss:.4f}")

print("\n" + "="*30)
print("   BEST VALIDATION RESULTS")
print("="*30)
print(f"Best Val Dice:         {best_val_dice:.4f}")
print(f"Best Val IoU:          {best_val_iou:.4f}")
print(f"Best Val Acc:          {best_val_acc:.4f}")
print(f"Minimum Val Loss:      {min_val_loss:.4f}")
print("="*30)
# Out:
# ==============================
# BEST TRAINING RESULTS
# Pipeline Depthwise Separable 3x3, 5x5, 7x7 ---> SE Block ---> Unet
# ==============================
# Best Training Dice:    0.8303
# Best Training IoU:     0.7525
# Best Training Acc:     0.9799
# Minimum Training Loss: 0.2468
#
# ==============================
#    BEST VALIDATION RESULTS
# ==============================
# Best Val Dice:         0.7952
# Best Val IoU:          0.7035
# Best Val Acc:          0.9741
# Minimum Val Loss:      0.3064
# ==============================

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

def draw_bounding_box(image, mask):
    # Copying image
    res_img = image.copy()
    mask_uint8 = (mask > 0.5).astype(np.uint8) * 255
    contours, _ = cv2.findContours(mask_uint8, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    
    for cnt in contours:
        x, y, w, h = cv2.boundingRect(cnt)
        # Draw rectangle
        cv2.rectangle(res_img, (x, y), (x + w, y + h), (0, 255, 0), 2)
        # Texting on the box
        # cv2.putText(res_img, 'Polyp', (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)
        
    return res_img

# def draw_bounding_box(image, mask):
#     res_img = image.copy()
#     mask_uint8 = (mask > 0.5).astype(np.uint8) * 255
#     contours, _ = cv2.findContours(mask_uint8, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
#     pixel_to_cm_ratio = 50 
    
#     for cnt in contours:
#         area_pixel = cv2.contourArea(cnt)
#         area_cm = area_pixel / (pixel_to_cm_ratio ** 2)
#         x, y, w, h = cv2.boundingRect(cnt)
#         width_cm = w / pixel_to_cm_ratio
#         height_cm = h / pixel_to_cm_ratio
#         cv2.rectangle(res_img, (x, y), (x + w, y + h), (0, 255, 0), 2)
#         size_text = f"{width_cm:.1f}cm x {height_cm:.1f}cm"
#         area_text = f"Area: {area_cm:.2f} cm2"
#         cv2.putText(res_img, size_text, (x, y-25), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)
#         cv2.putText(res_img, area_text, (x, y-5), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 0), 2)
        
#     return res_img


def test_and_display(model, image_path):
    img     = cv2.imread(image_path)
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img_res = cv2.resize(img_rgb, (IMG_SIZE, IMG_SIZE))
    inp     = np.expand_dims(img_res / 255.0, axis=0).astype(np.float32)

    pred_mask = model.predict(inp, verbose=0)[0]
    

    mask_bin  = (pred_mask > 0.5).astype(np.uint8)
    mask_3d   = np.concatenate([mask_bin] * 3, axis=-1)
    extracted = (img_res * mask_3d).astype(np.uint8)


    detected_img = draw_bounding_box(img_res, pred_mask)

    titles = ['Original', 'Predicted Mask', 'Extracted', 'Detection']
    display_images = [img_res, pred_mask.squeeze(), extracted, detected_img]
    
    plt.figure(figsize=(20, 5))
    for i in range(4):
        plt.subplot(1, 4, i + 1)
        plt.imshow(display_images[i], cmap='gray' if i == 1 else None)
        plt.title(titles[i], fontsize=14)
        plt.axis('off')
    
    plt.tight_layout()
    plt.savefig('detection_result.png', dpi=150)
    plt.show()


if images_list: 
    test_and_display(unet_se, images_list[2])
# Out:
# E0000 00:00:1778964419.002424   53625 cuda_timer.cc:87] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1778964423.359106   53625 cuda_timer.cc:87] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.

# %%
import random

if images_list:
    for _ in range(3):  # run 3 times
        i = random.randint(1, 25)  # random integer between 1 and 25
        test_and_display(unet_se, images_list[i])

# %%
# Complete
