# %%
import tensorflow as tf

print(tf.__version__)
print(tf.config.list_physical_devices('GPU'))
print(tf.test.is_built_with_cuda())
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1778595031.312981    9206 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2.21.0
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# True

# %%
import os
import glob
import numpy as np
import cv2
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, models, Input, mixed_precision
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import (
    ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
)

# %%
mixed_precision.set_global_policy('mixed_float16')
os.environ['TF_GPU_ALLOCATOR'] = 'cuda_malloc_async'

# %%
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu, True)
    print(f"GPU found: {[g.name for g in gpus]}")
# Out:
# GPU found: ['/physical_device:GPU:0']

# %%
IMG_SIZE   = 256
BATCH_SIZE = 4        
EPOCHS     = 100
DATA_PATH  = '/mnt/c/development/Thesis/PolypSegmentationBasedClassification/DataSets/Kvasir-SEG'
MODEL_SAVE = '/mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v_12_05_26.keras'

# %%
# ─────────────────────────────────────────────
#  AUGMENTATION
# ─────────────────────────────────────────────
def augment(img, mask):
    if tf.random.uniform(()) > 0.5:
        img  = tf.image.flip_left_right(img)
        mask = tf.image.flip_left_right(mask)
    if tf.random.uniform(()) > 0.5:
        img  = tf.image.flip_up_down(img)
        mask = tf.image.flip_up_down(mask)
    img = tf.image.random_brightness(img, 0.15)
    img = tf.image.random_contrast(img, 0.85, 1.15)
    img = tf.clip_by_value(img, 0.0, 1.0)
    return img, mask

# %%
# ─────────────────────────────────────────────
#  PREPROCESSING
# ─────────────────────────────────────────────
def process_path(img_path, mask_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, [IMG_SIZE, IMG_SIZE])
    img = tf.cast(img, tf.float32) / 255.0

    mask = tf.io.read_file(mask_path)
    mask = tf.image.decode_image(mask, channels=1, expand_animations=False)
    mask = tf.image.resize(mask, [IMG_SIZE, IMG_SIZE],
                           method=tf.image.ResizeMethod.NEAREST_NEIGHBOR)
    mask = tf.cast(mask, tf.float32) / 255.0
    mask = tf.where(mask > 0.5, 1.0, 0.0)
    return img, mask

def get_dataset(x, y, batch=BATCH_SIZE, augment_data=False):
    ds = tf.data.Dataset.from_tensor_slices((x, y))
    ds = ds.shuffle(buffer_size=len(x), reshuffle_each_iteration=True)
    ds = ds.map(process_path, num_parallel_calls=tf.data.AUTOTUNE)
    if augment_data:
        ds = ds.map(augment, num_parallel_calls=tf.data.AUTOTUNE)
    ds = ds.batch(batch)
    ds = ds.prefetch(tf.data.AUTOTUNE)
    return ds

# %%
# ─────────────────────────────────────────────
#  LOSS & METRICS
# ─────────────────────────────────────────────
def dice_coef(y_true, y_pred, smooth=1.0):
    y_true = tf.cast(tf.reshape(y_true, [-1]), tf.float32)
    y_pred = tf.cast(tf.reshape(y_pred, [-1]), tf.float32)
    intersection = tf.reduce_sum(y_true * y_pred)
    return (2.0 * intersection + smooth) / (
        tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth
    )

# %%
def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

def bce_dice_loss(y_true, y_pred):
    y_true_f = tf.cast(y_true, tf.float32)
    y_pred_f = tf.cast(y_pred, tf.float32)
    bce = tf.reduce_mean(
        tf.keras.losses.binary_crossentropy(y_true_f, y_pred_f)
    )
    return bce + dice_loss(y_true_f, y_pred_f)

def iou_metric(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred > 0.5, tf.float32)
    intersection = tf.reduce_sum(y_true * y_pred)
    union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) - intersection
    return (intersection + 1.0) / (union + 1.0)

# %%
def conv_block(x, filters, dropout_rate=0.0):
    """Conv → BN → ReLU × 2  (mixed_float16 compatible)"""
    x = layers.Conv2D(filters, 3, padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    if dropout_rate > 0:
        x = layers.SpatialDropout2D(dropout_rate)(x)
    x = layers.Conv2D(filters, 3, padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    return x

# %%
def build_unet_lite(input_shape=(IMG_SIZE, IMG_SIZE, 3)):
    """
    Filter map:  64 → 128 → 256 → 512 (bottleneck)
    """
    inputs = Input(input_shape)

    # ── Encoder ──────────────────────────
    c1 = conv_block(inputs, 32)                      # 256×256×32
    p1 = layers.MaxPooling2D(2)(c1)                  # 128×128

    c2 = conv_block(p1, 64)                          # 128×128×64
    p2 = layers.MaxPooling2D(2)(c2)                  # 64×64

    c3 = conv_block(p2, 128, dropout_rate=0.1)       # 64×64×128
    p3 = layers.MaxPooling2D(2)(c3)                  # 32×32

    c4 = conv_block(p3, 256, dropout_rate=0.2)       # 32×32×256
    p4 = layers.MaxPooling2D(2)(c4)                  # 16×16

    # ── Bottleneck ───────────────────────
    b = conv_block(p4, 512, dropout_rate=0.3)        # 16×16×512  ← আগে 1024 ছিল

    # ── Decoder ──────────────────────────
    u4 = layers.Conv2DTranspose(256, 2, strides=2, padding='same')(b)
    u4 = layers.concatenate([u4, c4])
    c5 = conv_block(u4, 256, dropout_rate=0.2)

    u3 = layers.Conv2DTranspose(128, 2, strides=2, padding='same')(c5)
    u3 = layers.concatenate([u3, c3])
    c6 = conv_block(u3, 128, dropout_rate=0.1)

    u2 = layers.Conv2DTranspose(64, 2, strides=2, padding='same')(c6)
    u2 = layers.concatenate([u2, c2])
    c7 = conv_block(u2, 64)

    u1 = layers.Conv2DTranspose(32, 2, strides=2, padding='same')(c7)
    u1 = layers.concatenate([u1, c1])
    c8 = conv_block(u1, 32)

    outputs = layers.Conv2D(1, 1, activation='sigmoid', dtype='float32')(c8)

    return models.Model(inputs, outputs, name='U-Net-Lite')

# %%
# ─────────────────────────────────────────────
#  TEST & DISPLAY
# ─────────────────────────────────────────────
def test_and_display(model, image_path):
    img     = cv2.imread(image_path)
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img_res = cv2.resize(img_rgb, (IMG_SIZE, IMG_SIZE))
    inp     = np.expand_dims(img_res / 255.0, axis=0).astype(np.float32)

    pred_mask = model.predict(inp, verbose=0)[0]
    mask_bin  = (pred_mask > 0.5).astype(np.uint8)
    mask_3d   = np.concatenate([mask_bin] * 3, axis=-1)
    extracted = (img_res * mask_3d).astype(np.uint8)

    titles = ['Original', 'Predicted Mask', 'Extracted Polyp']
    images = [img_res, pred_mask.squeeze(), extracted]
    plt.figure(figsize=(15, 5))
    for i in range(3):
        plt.subplot(1, 3, i + 1)
        plt.imshow(images[i], cmap='gray' if i == 1 else None)
        plt.title(titles[i], fontsize=14)
        plt.axis('off')
    plt.tight_layout()
    plt.savefig('prediction_result.png', dpi=150)
    plt.show()

# %%
if __name__ == '__main__':

    images = sorted(glob.glob(os.path.join(DATA_PATH, 'images/*.jpg')))
    masks  = sorted(glob.glob(os.path.join(DATA_PATH, 'masks/*.jpg')))
    print(f"Total samples: {len(images)}")

    train_x, val_x, train_y, val_y = train_test_split(
        images, masks, test_size=0.2, random_state=42
    )
    print(f"Train: {len(train_x)}  |  Val: {len(val_x)}")

    train_ds = get_dataset(train_x, train_y, batch=BATCH_SIZE, augment_data=True)
    val_ds   = get_dataset(val_x,   val_y,   batch=BATCH_SIZE, augment_data=False)

    unet = build_unet_lite()
    unet.summary()

    # Mixed precision → optimizer loss scaling দরকার
    optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3)
    optimizer = mixed_precision.LossScaleOptimizer(optimizer)

    unet.compile(
        optimizer=optimizer,
        loss=bce_dice_loss,
        metrics=[dice_coef, iou_metric, 'accuracy']
    )

    os.makedirs(os.path.dirname(MODEL_SAVE), exist_ok=True)

    callbacks = [
        ModelCheckpoint(MODEL_SAVE, monitor='val_dice_coef',
                        save_best_only=True, mode='max', verbose=1),
        ReduceLROnPlateau(monitor='val_loss', factor=0.5,
                          patience=7, min_lr=1e-7, verbose=1),
        EarlyStopping(monitor='val_dice_coef', patience=20,
                      restore_best_weights=True, mode='max', verbose=1),
    ]

    print("\n========== Training Started ==========")
    history = unet.fit(
        train_ds,
        validation_data=val_ds,
        epochs=EPOCHS,
        callbacks=callbacks
    )
    print("========== Training Complete ==========\n")

    # ── Plot ──────────────────────────────────
    fig, axes = plt.subplots(1, 3, figsize=(18, 5))
    axes[0].plot(history.history['loss'],          label='Train')
    axes[0].plot(history.history['val_loss'],      label='Val')
    axes[0].set_title('BCE + Dice Loss'); axes[0].legend()

    axes[1].plot(history.history['dice_coef'],     label='Train')
    axes[1].plot(history.history['val_dice_coef'], label='Val')
    axes[1].set_title('Dice Coefficient'); axes[1].legend()

    axes[2].plot(history.history['iou_metric'],     label='Train')
    axes[2].plot(history.history['val_iou_metric'], label='Val')
    axes[2].set_title('IoU Score'); axes[2].legend()

    plt.tight_layout()
    plt.savefig('training_history.png', dpi=150)
    plt.show()
# Out:
# Total samples: 1000
# Train: 800  |  Val: 200
# I0000 00:00:1778595552.246953    9206 gpu_process_state.cc:208] Using CUDA malloc Async allocator for GPU: 0
# I0000 00:00:1778595552.248821    9206 gpu_device.cc:2043] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5563 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9
# Model: "U-Net-Lite"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 256, 256,  │        864 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 256, 256,  │        128 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 256, 256,  │      9,216 │ activation[0][0]  │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        128 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 128, 128,  │          0 │ activation_1[0][… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 128, 128,  │     18,432 │ max_pooling2d[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 128, 128,  │     36,864 │ activation_2[0][… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 64, 64,    │          0 │ activation_3[0][… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 64, 64,    │     73,728 │ max_pooling2d_1[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout2d   │ (None, 64, 64,    │          0 │ activation_4[0][… │
# │ (SpatialDropout2D)  │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 64, 64,    │    147,456 │ spatial_dropout2… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 32, 32,    │          0 │ activation_5[0][… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 32, 32,    │    294,912 │ max_pooling2d_2[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout2d_1 │ (None, 32, 32,    │          0 │ activation_6[0][… │
# │ (SpatialDropout2D)  │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 32, 32,    │    589,824 │ spatial_dropout2… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 16, 16,    │          0 │ activation_7[0][… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 16, 16,    │  1,179,648 │ max_pooling2d_3[… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      2,048 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout2d_2 │ (None, 16, 16,    │          0 │ activation_8[0][… │
# │ (SpatialDropout2D)  │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 16, 16,    │  2,359,296 │ spatial_dropout2… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      2,048 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 32, 32,    │    524,544 │ activation_9[0][… │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 32, 32,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 512)              │            │ activation_7[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 32, 32,    │  1,179,648 │ concatenate[0][0] │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout2d_3 │ (None, 32, 32,    │          0 │ activation_10[0]… │
# │ (SpatialDropout2D)  │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 32, 32,    │    589,824 │ spatial_dropout2… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 64, 64,    │    131,200 │ activation_11[0]… │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 64, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 256)              │            │ activation_5[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 64, 64,    │    294,912 │ concatenate_1[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_12[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout2d_4 │ (None, 64, 64,    │          0 │ activation_12[0]… │
# │ (SpatialDropout2D)  │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 64, 64,    │    147,456 │ spatial_dropout2… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 128, 128,  │     32,832 │ activation_13[0]… │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 128, 128,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ activation_3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 128, 128,  │     73,728 │ concatenate_2[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_14[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_14       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 128, 128,  │     36,864 │ activation_14[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_15[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_15       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_3  │ (None, 256, 256,  │      8,224 │ activation_15[0]… │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 256, 256,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 64)               │            │ activation_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 256, 256,  │     18,432 │ concatenate_3[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        128 │ conv2d_16[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_16       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 256, 256,  │      9,216 │ activation_16[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        128 │ conv2d_17[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_17       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 256, 256,  │         33 │ activation_17[0]… │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 7,768,929 (29.64 MB)
#  Trainable params: 7,763,041 (29.61 MB)
#  Non-trainable params: 5,888 (23.00 KB)
# ========== Training Started ==========
# Epoch 1/100
# I0000 00:00:1778595563.042009   13676 service.cc:153] XLA service 0x7a3b0005b880 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1778595563.042072   13676 service.cc:161]   StreamExecutor [0]: NVIDIA GeForce RTX 4060 Laptop GPU, Compute Capability 8.9 (Driver: 12.7.0; Runtime: 12.9.0; Toolkit: 12.5.0; DNN: 9.21.1)
# I0000 00:00:1778595563.381118   13676 dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1778595565.587334   13676 cuda_dnn.cc:461] Loaded cuDNN version 92101
# I0000 00:00:1778595620.157672   13676 device_compiler.h:208] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7315 - dice_coef: 0.2986 - iou_metric: 0.2012 - loss: 1.2094
# Epoch 1: val_dice_coef improved from None to 0.18368, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v_12_05_26.keras
#
# Epoch 1: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v_12_05_26.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 76s 51ms/step - accuracy: 0.7742 - dice_coef: 0.3065 - iou_metric: 0.2157 - loss: 1.1236 - val_accuracy: 0.8324 - val_dice_coef: 0.1837 - val_iou_metric: 0.0375 - val_loss: 1.2786 - learning_rate: 0.0010
# Epoch 2/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.7939 - dice_coef: 0.3038 - iou_metric: 0.2200 - loss: 1.0746
# Epoch 2: val_dice_coef improved from 0.18368 to 0.27258, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v_12_05_26.keras
#
# Epoch 2: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v_12_05_26.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - accuracy: 0.7921 - dice_coef: 0.3213 - iou_metric: 0.2334 - loss: 1.0649 - val_accuracy: 0.7527 - val_dice_coef: 0.2726 - val_iou_metric: 0.1784 - val_loss: 1.8412 - learning_rate: 0.0010
# Epoch 3/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8128 - dice_coef: 0.3444 - iou_metric: 0.2657 - loss: 1.0271
# Epoch 3: val_dice_coef improved from 0.27258 to 0.40489, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v_12_05_26.keras
#
# Epoch 3: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v_12_05_26.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - accuracy: 0.8076 - dice_coef: 0.3509 - iou_metric: 0.2719 - loss: 1.0277 - val_accuracy: 0.7059 - val_dice_coef: 0.4049 - val_iou_metric: 0.3045 - val_loss: 1.1007 - learning_rate: 0.0010
# Epoch 4/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8196 - dice_coef: 0.3764 - iou_metric: 0.2969 - loss: 0.9928
# Epoch 4: val_dice_coef did not improve from 0.40489
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - accuracy: 0.8223 - dice_coef: 0.3802 - iou_metric: 0.3006 - loss: 0.9855 - val_accuracy: 0.6167 - val_dice_coef: 0.4022 - val_iou_metric: 0.2720 - val_loss: 1.3863 - learning_rate: 0.0010
# Epoch 5/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8375 - dice_coef: 0.4007 - iou_metric: 0.3146 - loss: 0.9545
# Epoch 5: val_dice_coef did not improve from 0.40489
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 6s 29ms/step - accuracy: 0.8415 - dice_coef: 0.4183 - iou_metric: 0.3301 - loss: 0.9344 - val_accuracy: 0.8282 - val_dice_coef: 0.4033 - val_iou_metric: 0.2942 - val_loss: 1.0102 - learning_rate: 0.0010
# Epoch 6/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8551 - dice_coef: 0.4643 - iou_metric: 0.3720 - loss: 0.8703
# Epoch 6: val_dice_coef improved from 0.40489 to 0.50727, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v_12_05_26.keras
#
# Epoch 6: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v_12_05_26.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - accuracy: 0.8551 - dice_coef: 0.4640 - iou_metric: 0.3731 - loss: 0.8737 - val_accuracy: 0.8478 - val_dice_coef: 0.5073 - val_iou_metric: 0.4070 - val_loss: 0.8636 - learning_rate: 0.0010
# Epoch 7/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8661 - dice_coef: 0.4791 - iou_metric: 0.3902 - loss: 0.8436
# Epoch 7: val_dice_coef did not improve from 0.50727
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - accuracy: 0.8639 - dice_coef: 0.4835 - iou_metric: 0.3899 - loss: 0.8435 - val_accuracy: 0.7509 - val_dice_coef: 0.4642 - val_iou_metric: 0.3379 - val_loss: 1.1577 - learning_rate: 0.0010
# Epoch 8/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8639 - dice_coef: 0.4914 - iou_metric: 0.3923 - loss: 0.8335
# Epoch 8: val_dice_coef did not improve from 0.50727
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 6s 32ms/step - accuracy: 0.8634 - dice_coef: 0.4815 - iou_metric: 0.3838 - loss: 0.8436 - val_accuracy: 0.5795 - val_dice_coef: 0.4065 - val_iou_metric: 0.2620 - val_loss: 1.6955 - learning_rate: 0.0010
# Epoch 9/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8754 - dice_coef: 0.5053 - iou_metric: 0.4132 - loss: 0.8043
# Epoch 9: val_dice_coef did not improve from 0.50727
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 6s 28ms/step - accuracy: 0.8695 - dice_coef: 0.4982 - iou_metric: 0.4007 - loss: 0.8203 - val_accuracy: 0.8665 - val_dice_coef: 0.4371 - val_iou_metric: 0.3191 - val_loss: 0.9267 - learning_rate: 0.0010
# Epoch 10/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8726 - dice_coef: 0.5148 - iou_metric: 0.4188 - loss: 0.7980
# Epoch 10: val_dice_coef improved from 0.50727 to 0.50788, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v_12_05_26.keras
#
# Epoch 10: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v_12_05_26.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - accuracy: 0.8723 - dice_coef: 0.5088 - iou_metric: 0.4101 - loss: 0.8035 - val_accuracy: 0.7953 - val_dice_coef: 0.5079 - val_iou_metric: 0.3811 - val_loss: 0.9943 - learning_rate: 0.0010
# Epoch 11/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8725 - dice_coef: 0.4990 - iou_metric: 0.3997 - loss: 0.8139
# Epoch 11: val_dice_coef did not improve from 0.50788
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 34ms/step - accuracy: 0.8698 - dice_coef: 0.5062 - iou_metric: 0.4081 - loss: 0.8099 - val_accuracy: 0.7845 - val_dice_coef: 0.4739 - val_iou_metric: 0.3590 - val_loss: 0.9692 - learning_rate: 0.0010
# Epoch 12/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8715 - dice_coef: 0.5191 - iou_metric: 0.4270 - loss: 0.7953
# Epoch 12: val_dice_coef improved from 0.50788 to 0.54207, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v_12_05_26.keras
#
# Epoch 12: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v_12_05_26.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - accuracy: 0.8739 - dice_coef: 0.5173 - iou_metric: 0.4221 - loss: 0.7931 - val_accuracy: 0.8864 - val_dice_coef: 0.5421 - val_iou_metric: 0.4456 - val_loss: 0.7594 - learning_rate: 0.0010
# Epoch 13/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8656 - dice_coef: 0.5000 - iou_metric: 0.4029 - loss: 0.8306
# Epoch 13: val_dice_coef improved from 0.54207 to 0.56324, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v_12_05_26.keras
#
# Epoch 13: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v_12_05_26.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - accuracy: 0.8735 - dice_coef: 0.5163 - iou_metric: 0.4196 - loss: 0.7934 - val_accuracy: 0.8782 - val_dice_coef: 0.5632 - val_iou_metric: 0.4730 - val_loss: 0.7323 - learning_rate: 0.0010
# Epoch 14/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8803 - dice_coef: 0.5408 - iou_metric: 0.4408 - loss: 0.7557
# Epoch 14: val_dice_coef did not improve from 0.56324
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - accuracy: 0.8770 - dice_coef: 0.5297 - iou_metric: 0.4280 - loss: 0.7712 - val_accuracy: 0.8883 - val_dice_coef: 0.5364 - val_iou_metric: 0.4583 - val_loss: 0.7444 - learning_rate: 0.0010
# Epoch 15/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8733 - dice_coef: 0.5422 - iou_metric: 0.4421 - loss: 0.7680
# Epoch 15: val_dice_coef did not improve from 0.56324
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 6s 32ms/step - accuracy: 0.8799 - dice_coef: 0.5338 - iou_metric: 0.4352 - loss: 0.7670 - val_accuracy: 0.8395 - val_dice_coef: 0.4934 - val_iou_metric: 0.3981 - val_loss: 0.8913 - learning_rate: 0.0010
# Epoch 16/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8860 - dice_coef: 0.5473 - iou_metric: 0.4477 - loss: 0.7421
# Epoch 16: val_dice_coef did not improve from 0.56324
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - accuracy: 0.8870 - dice_coef: 0.5569 - iou_metric: 0.4572 - loss: 0.7333 - val_accuracy: 0.8222 - val_dice_coef: 0.5430 - val_iou_metric: 0.4198 - val_loss: 0.9299 - learning_rate: 0.0010
# Epoch 17/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8808 - dice_coef: 0.5446 - iou_metric: 0.4481 - loss: 0.7557
# Epoch 17: val_dice_coef did not improve from 0.56324
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - accuracy: 0.8840 - dice_coef: 0.5450 - iou_metric: 0.4471 - loss: 0.7480 - val_accuracy: 0.8133 - val_dice_coef: 0.5440 - val_iou_metric: 0.4087 - val_loss: 0.9552 - learning_rate: 0.0010
# Epoch 18/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8965 - dice_coef: 0.5609 - iou_metric: 0.4597 - loss: 0.7029
# Epoch 18: val_dice_coef improved from 0.56324 to 0.59802, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v_12_05_26.keras
#
# Epoch 18: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v_12_05_26.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 8s 38ms/step - accuracy: 0.8874 - dice_coef: 0.5604 - iou_metric: 0.4572 - loss: 0.7264 - val_accuracy: 0.8903 - val_dice_coef: 0.5980 - val_iou_metric: 0.5007 - val_loss: 0.6956 - learning_rate: 0.0010
# Epoch 19/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8829 - dice_coef: 0.5497 - iou_metric: 0.4531 - loss: 0.7374
# Epoch 19: val_dice_coef did not improve from 0.59802
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - accuracy: 0.8850 - dice_coef: 0.5530 - iou_metric: 0.4524 - loss: 0.7342 - val_accuracy: 0.8912 - val_dice_coef: 0.5100 - val_iou_metric: 0.3847 - val_loss: 0.8254 - learning_rate: 0.0010
# Epoch 20/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8941 - dice_coef: 0.5655 - iou_metric: 0.4679 - loss: 0.7182
# Epoch 20: val_dice_coef did not improve from 0.59802
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - accuracy: 0.8914 - dice_coef: 0.5694 - iou_metric: 0.4697 - loss: 0.7139 - val_accuracy: 0.9046 - val_dice_coef: 0.5754 - val_iou_metric: 0.4773 - val_loss: 0.6970 - learning_rate: 0.0010
# Epoch 21/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8958 - dice_coef: 0.6017 - iou_metric: 0.5055 - loss: 0.6756
# Epoch 21: val_dice_coef did not improve from 0.59802
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 6s 32ms/step - accuracy: 0.8978 - dice_coef: 0.5925 - iou_metric: 0.4930 - loss: 0.6791 - val_accuracy: 0.9046 - val_dice_coef: 0.5805 - val_iou_metric: 0.4890 - val_loss: 0.6819 - learning_rate: 0.0010
# Epoch 22/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8994 - dice_coef: 0.5866 - iou_metric: 0.4853 - loss: 0.6765
# Epoch 22: val_dice_coef improved from 0.59802 to 0.63882, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v_12_05_26.keras
#
# Epoch 22: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v_12_05_26.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - accuracy: 0.8963 - dice_coef: 0.5858 - iou_metric: 0.4853 - loss: 0.6865 - val_accuracy: 0.9050 - val_dice_coef: 0.6388 - val_iou_metric: 0.5299 - val_loss: 0.6398 - learning_rate: 0.0010
# Epoch 23/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8995 - dice_coef: 0.5940 - iou_metric: 0.4972 - loss: 0.6727
# Epoch 23: val_dice_coef did not improve from 0.63882
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - accuracy: 0.8998 - dice_coef: 0.5985 - iou_metric: 0.4991 - loss: 0.6704 - val_accuracy: 0.8389 - val_dice_coef: 0.5799 - val_iou_metric: 0.4520 - val_loss: 0.8266 - learning_rate: 0.0010
# Epoch 24/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8946 - dice_coef: 0.5885 - iou_metric: 0.4884 - loss: 0.6840
# Epoch 24: val_dice_coef did not improve from 0.63882
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - accuracy: 0.9004 - dice_coef: 0.6050 - iou_metric: 0.5062 - loss: 0.6571 - val_accuracy: 0.9035 - val_dice_coef: 0.6092 - val_iou_metric: 0.4960 - val_loss: 0.6699 - learning_rate: 0.0010
# Epoch 25/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9058 - dice_coef: 0.6124 - iou_metric: 0.5152 - loss: 0.6443
# Epoch 25: val_dice_coef did not improve from 0.63882
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - accuracy: 0.9023 - dice_coef: 0.6026 - iou_metric: 0.5050 - loss: 0.6600 - val_accuracy: 0.8856 - val_dice_coef: 0.6358 - val_iou_metric: 0.5244 - val_loss: 0.6658 - learning_rate: 0.0010
# Epoch 26/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9068 - dice_coef: 0.6320 - iou_metric: 0.5303 - loss: 0.6198
# Epoch 26: val_dice_coef did not improve from 0.63882
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - accuracy: 0.9088 - dice_coef: 0.6294 - iou_metric: 0.5310 - loss: 0.6189 - val_accuracy: 0.9070 - val_dice_coef: 0.6144 - val_iou_metric: 0.4903 - val_loss: 0.6800 - learning_rate: 0.0010
# Epoch 27/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9101 - dice_coef: 0.6384 - iou_metric: 0.5378 - loss: 0.6124
# Epoch 27: val_dice_coef improved from 0.63882 to 0.67186, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v_12_05_26.keras
#
# Epoch 27: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v_12_05_26.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 8s 40ms/step - accuracy: 0.9098 - dice_coef: 0.6372 - iou_metric: 0.5377 - loss: 0.6143 - val_accuracy: 0.9164 - val_dice_coef: 0.6719 - val_iou_metric: 0.5779 - val_loss: 0.5671 - learning_rate: 0.0010
# Epoch 28/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9143 - dice_coef: 0.6371 - iou_metric: 0.5435 - loss: 0.5951
# Epoch 28: val_dice_coef did not improve from 0.67186
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 34ms/step - accuracy: 0.9126 - dice_coef: 0.6434 - iou_metric: 0.5478 - loss: 0.5974 - val_accuracy: 0.9043 - val_dice_coef: 0.6036 - val_iou_metric: 0.4872 - val_loss: 0.6815 - learning_rate: 0.0010
# Epoch 29/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9173 - dice_coef: 0.6580 - iou_metric: 0.5553 - loss: 0.5821
# Epoch 29: val_dice_coef did not improve from 0.67186
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - accuracy: 0.9190 - dice_coef: 0.6697 - iou_metric: 0.5697 - loss: 0.5614 - val_accuracy: 0.9154 - val_dice_coef: 0.6594 - val_iou_metric: 0.5510 - val_loss: 0.5940 - learning_rate: 0.0010
# Epoch 30/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9139 - dice_coef: 0.6606 - iou_metric: 0.5626 - loss: 0.5772
# Epoch 30: val_dice_coef did not improve from 0.67186
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - accuracy: 0.9182 - dice_coef: 0.6718 - iou_metric: 0.5737 - loss: 0.5589 - val_accuracy: 0.9071 - val_dice_coef: 0.5764 - val_iou_metric: 0.4592 - val_loss: 0.7112 - learning_rate: 0.0010
# Epoch 31/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9219 - dice_coef: 0.6653 - iou_metric: 0.5701 - loss: 0.5595
# Epoch 31: val_dice_coef did not improve from 0.67186
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 6s 32ms/step - accuracy: 0.9202 - dice_coef: 0.6746 - iou_metric: 0.5815 - loss: 0.5522 - val_accuracy: 0.9081 - val_dice_coef: 0.6240 - val_iou_metric: 0.5121 - val_loss: 0.6545 - learning_rate: 0.0010
# Epoch 32/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9281 - dice_coef: 0.7053 - iou_metric: 0.6110 - loss: 0.5054
# Epoch 32: val_dice_coef did not improve from 0.67186
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - accuracy: 0.9271 - dice_coef: 0.7022 - iou_metric: 0.6068 - loss: 0.5133 - val_accuracy: 0.8996 - val_dice_coef: 0.6449 - val_iou_metric: 0.5388 - val_loss: 0.6304 - learning_rate: 0.0010
# Epoch 33/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9242 - dice_coef: 0.6922 - iou_metric: 0.5982 - loss: 0.5193
# Epoch 33: val_dice_coef improved from 0.67186 to 0.68797, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v_12_05_26.keras
#
# Epoch 33: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v_12_05_26.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - accuracy: 0.9256 - dice_coef: 0.7000 - iou_metric: 0.6083 - loss: 0.5116 - val_accuracy: 0.9221 - val_dice_coef: 0.6880 - val_iou_metric: 0.5709 - val_loss: 0.5729 - learning_rate: 0.0010
# Epoch 34/100
# 198/200 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9315 - dice_coef: 0.7220 - iou_metric: 0.6322 - loss: 0.4785
# Epoch 34: val_dice_coef did not improve from 0.68797
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - accuracy: 0.9315 - dice_coef: 0.7177 - iou_metric: 0.6277 - loss: 0.4850 - val_accuracy: 0.9236 - val_dice_coef: 0.6874 - val_iou_metric: 0.5745 - val_loss: 0.5751 - learning_rate: 0.0010
# Epoch 35/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9314 - dice_coef: 0.7094 - iou_metric: 0.6182 - loss: 0.4935
# Epoch 35: val_dice_coef improved from 0.68797 to 0.74664, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v_12_05_26.keras
#
# Epoch 35: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v_12_05_26.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - accuracy: 0.9329 - dice_coef: 0.7217 - iou_metric: 0.6340 - loss: 0.4786 - val_accuracy: 0.9356 - val_dice_coef: 0.7466 - val_iou_metric: 0.6631 - val_loss: 0.4461 - learning_rate: 5.0000e-04
# Epoch 36/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9296 - dice_coef: 0.7214 - iou_metric: 0.6296 - loss: 0.4811
# Epoch 36: val_dice_coef improved from 0.74664 to 0.75217, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v_12_05_26.keras
#
# Epoch 36: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v_12_05_26.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - accuracy: 0.9336 - dice_coef: 0.7309 - iou_metric: 0.6414 - loss: 0.4625 - val_accuracy: 0.9342 - val_dice_coef: 0.7522 - val_iou_metric: 0.6598 - val_loss: 0.4406 - learning_rate: 5.0000e-04
# Epoch 37/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9384 - dice_coef: 0.7482 - iou_metric: 0.6648 - loss: 0.4390
# Epoch 37: val_dice_coef did not improve from 0.75217
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 6s 32ms/step - accuracy: 0.9377 - dice_coef: 0.7454 - iou_metric: 0.6595 - loss: 0.4420 - val_accuracy: 0.9334 - val_dice_coef: 0.7422 - val_iou_metric: 0.6526 - val_loss: 0.4523 - learning_rate: 5.0000e-04
# Epoch 38/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9364 - dice_coef: 0.7439 - iou_metric: 0.6582 - loss: 0.4410
# Epoch 38: val_dice_coef did not improve from 0.75217
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 34ms/step - accuracy: 0.9381 - dice_coef: 0.7473 - iou_metric: 0.6606 - loss: 0.4344 - val_accuracy: 0.9218 - val_dice_coef: 0.7317 - val_iou_metric: 0.6413 - val_loss: 0.4915 - learning_rate: 5.0000e-04
# Epoch 39/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9343 - dice_coef: 0.7498 - iou_metric: 0.6621 - loss: 0.4473
# Epoch 39: val_dice_coef did not improve from 0.75217
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - accuracy: 0.9405 - dice_coef: 0.7566 - iou_metric: 0.6716 - loss: 0.4213 - val_accuracy: 0.9393 - val_dice_coef: 0.7487 - val_iou_metric: 0.6556 - val_loss: 0.4472 - learning_rate: 5.0000e-04
# Epoch 40/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9369 - dice_coef: 0.7520 - iou_metric: 0.6667 - loss: 0.4395
# Epoch 40: val_dice_coef did not improve from 0.75217
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 6s 32ms/step - accuracy: 0.9384 - dice_coef: 0.7487 - iou_metric: 0.6634 - loss: 0.4380 - val_accuracy: 0.9391 - val_dice_coef: 0.7486 - val_iou_metric: 0.6636 - val_loss: 0.4350 - learning_rate: 5.0000e-04
# Epoch 41/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9421 - dice_coef: 0.7507 - iou_metric: 0.6682 - loss: 0.4265
# Epoch 41: val_dice_coef improved from 0.75217 to 0.77758, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v_12_05_26.keras
#
# Epoch 41: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v_12_05_26.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 8s 40ms/step - accuracy: 0.9416 - dice_coef: 0.7603 - iou_metric: 0.6772 - loss: 0.4156 - val_accuracy: 0.9431 - val_dice_coef: 0.7776 - val_iou_metric: 0.6917 - val_loss: 0.4105 - learning_rate: 5.0000e-04
# Epoch 42/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9430 - dice_coef: 0.7763 - iou_metric: 0.6944 - loss: 0.3986
# Epoch 42: val_dice_coef did not improve from 0.77758
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 34ms/step - accuracy: 0.9432 - dice_coef: 0.7736 - iou_metric: 0.6906 - loss: 0.3989 - val_accuracy: 0.9370 - val_dice_coef: 0.7464 - val_iou_metric: 0.6569 - val_loss: 0.4437 - learning_rate: 5.0000e-04
# Epoch 43/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9406 - dice_coef: 0.7499 - iou_metric: 0.6626 - loss: 0.4252
# Epoch 43: val_dice_coef did not improve from 0.77758
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.9418 - dice_coef: 0.7605 - iou_metric: 0.6744 - loss: 0.4146 - val_accuracy: 0.9362 - val_dice_coef: 0.7704 - val_iou_metric: 0.6767 - val_loss: 0.4215 - learning_rate: 5.0000e-04
# Epoch 44/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9441 - dice_coef: 0.7663 - iou_metric: 0.6815 - loss: 0.4017
# Epoch 44: val_dice_coef did not improve from 0.77758
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 6s 32ms/step - accuracy: 0.9446 - dice_coef: 0.7735 - iou_metric: 0.6911 - loss: 0.3945 - val_accuracy: 0.9358 - val_dice_coef: 0.7327 - val_iou_metric: 0.6449 - val_loss: 0.4623 - learning_rate: 5.0000e-04
# Epoch 45/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9485 - dice_coef: 0.7859 - iou_metric: 0.7078 - loss: 0.3699
# Epoch 45: val_dice_coef did not improve from 0.77758
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 34ms/step - accuracy: 0.9440 - dice_coef: 0.7743 - iou_metric: 0.6919 - loss: 0.3973 - val_accuracy: 0.9343 - val_dice_coef: 0.7272 - val_iou_metric: 0.6388 - val_loss: 0.4839 - learning_rate: 5.0000e-04
# Epoch 46/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9488 - dice_coef: 0.7950 - iou_metric: 0.7181 - loss: 0.3612
# Epoch 46: val_dice_coef did not improve from 0.77758
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - accuracy: 0.9465 - dice_coef: 0.7821 - iou_metric: 0.6991 - loss: 0.3820 - val_accuracy: 0.9378 - val_dice_coef: 0.7698 - val_iou_metric: 0.6811 - val_loss: 0.4182 - learning_rate: 5.0000e-04
# Epoch 47/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9430 - dice_coef: 0.7794 - iou_metric: 0.6972 - loss: 0.3943
# Epoch 47: val_dice_coef did not improve from 0.77758
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - accuracy: 0.9467 - dice_coef: 0.7839 - iou_metric: 0.7035 - loss: 0.3761 - val_accuracy: 0.9355 - val_dice_coef: 0.7436 - val_iou_metric: 0.6475 - val_loss: 0.4616 - learning_rate: 5.0000e-04
# Epoch 48/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9527 - dice_coef: 0.8093 - iou_metric: 0.7359 - loss: 0.3417
# Epoch 48: val_dice_coef improved from 0.77758 to 0.78596, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v_12_05_26.keras
#
# Epoch 48: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v_12_05_26.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 8s 40ms/step - accuracy: 0.9494 - dice_coef: 0.8001 - iou_metric: 0.7219 - loss: 0.3579 - val_accuracy: 0.9448 - val_dice_coef: 0.7860 - val_iou_metric: 0.6951 - val_loss: 0.3949 - learning_rate: 5.0000e-04
# Epoch 49/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9535 - dice_coef: 0.7949 - iou_metric: 0.7132 - loss: 0.3487
# Epoch 49: val_dice_coef did not improve from 0.78596
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - accuracy: 0.9486 - dice_coef: 0.7917 - iou_metric: 0.7106 - loss: 0.3682 - val_accuracy: 0.9322 - val_dice_coef: 0.7220 - val_iou_metric: 0.6144 - val_loss: 0.5018 - learning_rate: 5.0000e-04
# Epoch 50/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9462 - dice_coef: 0.7874 - iou_metric: 0.7102 - loss: 0.3774
# Epoch 50: val_dice_coef did not improve from 0.78596
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - accuracy: 0.9487 - dice_coef: 0.7889 - iou_metric: 0.7121 - loss: 0.3665 - val_accuracy: 0.9336 - val_dice_coef: 0.7663 - val_iou_metric: 0.6689 - val_loss: 0.4521 - learning_rate: 5.0000e-04
# Epoch 51/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9486 - dice_coef: 0.7970 - iou_metric: 0.7126 - loss: 0.3629
# Epoch 51: val_dice_coef did not improve from 0.78596
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - accuracy: 0.9489 - dice_coef: 0.7930 - iou_metric: 0.7112 - loss: 0.3643 - val_accuracy: 0.9432 - val_dice_coef: 0.7837 - val_iou_metric: 0.6989 - val_loss: 0.3951 - learning_rate: 5.0000e-04
# Epoch 52/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9527 - dice_coef: 0.8055 - iou_metric: 0.7246 - loss: 0.3433
# Epoch 52: val_dice_coef did not improve from 0.78596
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - accuracy: 0.9508 - dice_coef: 0.8031 - iou_metric: 0.7226 - loss: 0.3502 - val_accuracy: 0.9416 - val_dice_coef: 0.7762 - val_iou_metric: 0.6902 - val_loss: 0.4039 - learning_rate: 5.0000e-04
# Epoch 53/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9484 - dice_coef: 0.7940 - iou_metric: 0.7149 - loss: 0.3608
# Epoch 53: val_dice_coef did not improve from 0.78596
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - accuracy: 0.9485 - dice_coef: 0.7970 - iou_metric: 0.7171 - loss: 0.3611 - val_accuracy: 0.9437 - val_dice_coef: 0.7663 - val_iou_metric: 0.7029 - val_loss: 0.3917 - learning_rate: 5.0000e-04
# Epoch 54/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9503 - dice_coef: 0.7857 - iou_metric: 0.7114 - loss: 0.3629
# Epoch 54: val_dice_coef did not improve from 0.78596
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - accuracy: 0.9483 - dice_coef: 0.7896 - iou_metric: 0.7100 - loss: 0.3649 - val_accuracy: 0.9207 - val_dice_coef: 0.7075 - val_iou_metric: 0.6230 - val_loss: 0.5069 - learning_rate: 5.0000e-04
# Epoch 55/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9512 - dice_coef: 0.8019 - iou_metric: 0.7254 - loss: 0.3501
# Epoch 55: val_dice_coef did not improve from 0.78596
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - accuracy: 0.9510 - dice_coef: 0.8001 - iou_metric: 0.7249 - loss: 0.3531 - val_accuracy: 0.9401 - val_dice_coef: 0.7683 - val_iou_metric: 0.6757 - val_loss: 0.4312 - learning_rate: 5.0000e-04
# Epoch 56/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9492 - dice_coef: 0.8032 - iou_metric: 0.7239 - loss: 0.3545
# Epoch 56: val_dice_coef did not improve from 0.78596
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - accuracy: 0.9497 - dice_coef: 0.8004 - iou_metric: 0.7212 - loss: 0.3535 - val_accuracy: 0.9388 - val_dice_coef: 0.7676 - val_iou_metric: 0.6816 - val_loss: 0.4128 - learning_rate: 5.0000e-04
# Epoch 57/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9547 - dice_coef: 0.8168 - iou_metric: 0.7438 - loss: 0.3240
# Epoch 57: val_dice_coef improved from 0.78596 to 0.79670, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v_12_05_26.keras
#
# Epoch 57: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v_12_05_26.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - accuracy: 0.9538 - dice_coef: 0.8157 - iou_metric: 0.7415 - loss: 0.3254 - val_accuracy: 0.9475 - val_dice_coef: 0.7967 - val_iou_metric: 0.7082 - val_loss: 0.3773 - learning_rate: 5.0000e-04
# Epoch 58/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9539 - dice_coef: 0.8168 - iou_metric: 0.7407 - loss: 0.3275
# Epoch 58: val_dice_coef improved from 0.79670 to 0.80111, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v_12_05_26.keras
#
# Epoch 58: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v_12_05_26.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - accuracy: 0.9530 - dice_coef: 0.8089 - iou_metric: 0.7303 - loss: 0.3373 - val_accuracy: 0.9484 - val_dice_coef: 0.8011 - val_iou_metric: 0.7195 - val_loss: 0.3619 - learning_rate: 5.0000e-04
# Epoch 59/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9526 - dice_coef: 0.8164 - iou_metric: 0.7400 - loss: 0.3289
# Epoch 59: val_dice_coef did not improve from 0.80111
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - accuracy: 0.9522 - dice_coef: 0.8096 - iou_metric: 0.7308 - loss: 0.3384 - val_accuracy: 0.9463 - val_dice_coef: 0.7914 - val_iou_metric: 0.7083 - val_loss: 0.3810 - learning_rate: 5.0000e-04
# Epoch 60/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9533 - dice_coef: 0.8116 - iou_metric: 0.7338 - loss: 0.3279
# Epoch 60: val_dice_coef did not improve from 0.80111
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 6s 32ms/step - accuracy: 0.9527 - dice_coef: 0.8062 - iou_metric: 0.7283 - loss: 0.3422 - val_accuracy: 0.9401 - val_dice_coef: 0.7606 - val_iou_metric: 0.6613 - val_loss: 0.4361 - learning_rate: 5.0000e-04
# Epoch 61/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9513 - dice_coef: 0.8083 - iou_metric: 0.7327 - loss: 0.3413
# ...
# Epoch 68/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9557 - dice_coef: 0.8288 - iou_metric: 0.7577 - loss: 0.3065
# Epoch 68: val_dice_coef improved from 0.80525 to 0.81164, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v_12_05_26.keras
#
# Epoch 68: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v_12_05_26.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - accuracy: 0.9549 - dice_coef: 0.8234 - iou_metric: 0.7489 - loss: 0.3164 - val_accuracy: 0.9485 - val_dice_coef: 0.8116 - val_iou_metric: 0.7292 - val_loss: 0.3523 - learning_rate: 5.0000e-04
# Epoch 69/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9538 - dice_coef: 0.8154 - iou_metric: 0.7391 - loss: 0.3310
# Epoch 69: val_dice_coef did not improve from 0.81164
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - accuracy: 0.9570 - dice_coef: 0.8249 - iou_metric: 0.7533 - loss: 0.3092 - val_accuracy: 0.9424 - val_dice_coef: 0.7833 - val_iou_metric: 0.7006 - val_loss: 0.3867 - learning_rate: 5.0000e-04
# Epoch 70/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9589 - dice_coef: 0.8345 - iou_metric: 0.7631 - loss: 0.2964
# Epoch 70: val_dice_coef did not improve from 0.81164
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - accuracy: 0.9578 - dice_coef: 0.8296 - iou_metric: 0.7562 - loss: 0.3037 - val_accuracy: 0.9434 - val_dice_coef: 0.7772 - val_iou_metric: 0.6888 - val_loss: 0.4177 - learning_rate: 5.0000e-04
# Epoch 71/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9607 - dice_coef: 0.8340 - iou_metric: 0.7672 - loss: 0.2884
# Epoch 71: val_dice_coef did not improve from 0.81164
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - accuracy: 0.9585 - dice_coef: 0.8294 - iou_metric: 0.7600 - loss: 0.3012 - val_accuracy: 0.9375 - val_dice_coef: 0.7638 - val_iou_metric: 0.6658 - val_loss: 0.4531 - learning_rate: 5.0000e-04
# Epoch 72/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9545 - dice_coef: 0.8275 - iou_metric: 0.7548 - loss: 0.3144
# Epoch 72: val_dice_coef did not improve from 0.81164
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - accuracy: 0.9566 - dice_coef: 0.8259 - iou_metric: 0.7534 - loss: 0.3090 - val_accuracy: 0.9524 - val_dice_coef: 0.8071 - val_iou_metric: 0.7368 - val_loss: 0.3425 - learning_rate: 5.0000e-04
# Epoch 73/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9572 - dice_coef: 0.8359 - iou_metric: 0.7671 - loss: 0.2947
# Epoch 73: val_dice_coef improved from 0.81164 to 0.81763, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v_12_05_26.keras
#
# Epoch 73: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v_12_05_26.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - accuracy: 0.9586 - dice_coef: 0.8392 - iou_metric: 0.7681 - loss: 0.2898 - val_accuracy: 0.9520 - val_dice_coef: 0.8176 - val_iou_metric: 0.7340 - val_loss: 0.3418 - learning_rate: 5.0000e-04
# Epoch 74/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9557 - dice_coef: 0.8191 - iou_metric: 0.7423 - loss: 0.3181
# Epoch 74: val_dice_coef did not improve from 0.81763
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - accuracy: 0.9573 - dice_coef: 0.8286 - iou_metric: 0.7523 - loss: 0.3064 - val_accuracy: 0.9468 - val_dice_coef: 0.7896 - val_iou_metric: 0.6980 - val_loss: 0.3903 - learning_rate: 5.0000e-04
# Epoch 75/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9615 - dice_coef: 0.8353 - iou_metric: 0.7661 - loss: 0.2825
# Epoch 75: val_dice_coef did not improve from 0.81763
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - accuracy: 0.9592 - dice_coef: 0.8355 - iou_metric: 0.7651 - loss: 0.2914 - val_accuracy: 0.9439 - val_dice_coef: 0.8007 - val_iou_metric: 0.7153 - val_loss: 0.3656 - learning_rate: 5.0000e-04
# Epoch 76/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9568 - dice_coef: 0.8270 - iou_metric: 0.7532 - loss: 0.3106
# Epoch 76: val_dice_coef did not improve from 0.81763
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - accuracy: 0.9610 - dice_coef: 0.8399 - iou_metric: 0.7704 - loss: 0.2830 - val_accuracy: 0.9517 - val_dice_coef: 0.8145 - val_iou_metric: 0.7327 - val_loss: 0.3453 - learning_rate: 5.0000e-04
# Epoch 77/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9607 - dice_coef: 0.8374 - iou_metric: 0.7644 - loss: 0.2847
# Epoch 77: val_dice_coef did not improve from 0.81763
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - accuracy: 0.9585 - dice_coef: 0.8361 - iou_metric: 0.7637 - loss: 0.2924 - val_accuracy: 0.9483 - val_dice_coef: 0.7910 - val_iou_metric: 0.7079 - val_loss: 0.3677 - learning_rate: 5.0000e-04
# Epoch 78/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9611 - dice_coef: 0.8483 - iou_metric: 0.7824 - loss: 0.2731
# Epoch 78: val_dice_coef did not improve from 0.81763
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 6s 32ms/step - accuracy: 0.9610 - dice_coef: 0.8431 - iou_metric: 0.7754 - loss: 0.2802 - val_accuracy: 0.9453 - val_dice_coef: 0.8012 - val_iou_metric: 0.7037 - val_loss: 0.3900 - learning_rate: 5.0000e-04
# Epoch 79/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9628 - dice_coef: 0.8467 - iou_metric: 0.7783 - loss: 0.2719
# Epoch 79: val_dice_coef did not improve from 0.81763
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 6s 32ms/step - accuracy: 0.9597 - dice_coef: 0.8365 - iou_metric: 0.7643 - loss: 0.2926 - val_accuracy: 0.9508 - val_dice_coef: 0.8164 - val_iou_metric: 0.7345 - val_loss: 0.3411 - learning_rate: 5.0000e-04
# Epoch 80/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9626 - dice_coef: 0.8510 - iou_metric: 0.7826 - loss: 0.2674
# Epoch 80: val_dice_coef did not improve from 0.81763
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - accuracy: 0.9609 - dice_coef: 0.8470 - iou_metric: 0.7767 - loss: 0.2742 - val_accuracy: 0.9365 - val_dice_coef: 0.7721 - val_iou_metric: 0.6853 - val_loss: 0.4275 - learning_rate: 5.0000e-04
# Epoch 81/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9613 - dice_coef: 0.8478 - iou_metric: 0.7783 - loss: 0.2735
# Epoch 81: val_dice_coef did not improve from 0.81763
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 6s 32ms/step - accuracy: 0.9611 - dice_coef: 0.8460 - iou_metric: 0.7762 - loss: 0.2772 - val_accuracy: 0.9487 - val_dice_coef: 0.8164 - val_iou_metric: 0.7267 - val_loss: 0.3571 - learning_rate: 5.0000e-04
# Epoch 82/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9610 - dice_coef: 0.8479 - iou_metric: 0.7817 - loss: 0.2704
# Epoch 82: val_dice_coef did not improve from 0.81763
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - accuracy: 0.9598 - dice_coef: 0.8428 - iou_metric: 0.7734 - loss: 0.2821 - val_accuracy: 0.9478 - val_dice_coef: 0.7956 - val_iou_metric: 0.7124 - val_loss: 0.3731 - learning_rate: 5.0000e-04
# Epoch 83/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9607 - dice_coef: 0.8386 - iou_metric: 0.7682 - loss: 0.2823
# Epoch 83: val_dice_coef did not improve from 0.81763
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - accuracy: 0.9601 - dice_coef: 0.8376 - iou_metric: 0.7662 - loss: 0.2863 - val_accuracy: 0.9496 - val_dice_coef: 0.8109 - val_iou_metric: 0.7170 - val_loss: 0.3693 - learning_rate: 5.0000e-04
# Epoch 84/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9577 - dice_coef: 0.8317 - iou_metric: 0.7611 - loss: 0.3060
# Epoch 84: val_dice_coef improved from 0.81763 to 0.82868, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v_12_05_26.keras
#
# Epoch 84: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v_12_05_26.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 8s 40ms/step - accuracy: 0.9597 - dice_coef: 0.8385 - iou_metric: 0.7689 - loss: 0.2894 - val_accuracy: 0.9541 - val_dice_coef: 0.8287 - val_iou_metric: 0.7476 - val_loss: 0.3178 - learning_rate: 5.0000e-04
# Epoch 85/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9594 - dice_coef: 0.8369 - iou_metric: 0.7637 - loss: 0.2893
# Epoch 85: val_dice_coef did not improve from 0.82868
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - accuracy: 0.9608 - dice_coef: 0.8402 - iou_metric: 0.7694 - loss: 0.2790 - val_accuracy: 0.9532 - val_dice_coef: 0.8252 - val_iou_metric: 0.7450 - val_loss: 0.3245 - learning_rate: 5.0000e-04
# Epoch 86/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9640 - dice_coef: 0.8535 - iou_metric: 0.7853 - loss: 0.2616
# Epoch 86: val_dice_coef did not improve from 0.82868
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - accuracy: 0.9618 - dice_coef: 0.8487 - iou_metric: 0.7795 - loss: 0.2705 - val_accuracy: 0.9514 - val_dice_coef: 0.8183 - val_iou_metric: 0.7365 - val_loss: 0.3352 - learning_rate: 5.0000e-04
# Epoch 87/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9684 - dice_coef: 0.8687 - iou_metric: 0.8071 - loss: 0.2288
# Epoch 87: val_dice_coef improved from 0.82868 to 0.82946, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v_12_05_26.keras
#
# Epoch 87: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v_12_05_26.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 8s 40ms/step - accuracy: 0.9634 - dice_coef: 0.8561 - iou_metric: 0.7892 - loss: 0.2566 - val_accuracy: 0.9531 - val_dice_coef: 0.8295 - val_iou_metric: 0.7462 - val_loss: 0.3284 - learning_rate: 5.0000e-04
# Epoch 88/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9639 - dice_coef: 0.8506 - iou_metric: 0.7842 - loss: 0.2608
# Epoch 88: val_dice_coef did not improve from 0.82946
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 34ms/step - accuracy: 0.9616 - dice_coef: 0.8459 - iou_metric: 0.7782 - loss: 0.2754 - val_accuracy: 0.9474 - val_dice_coef: 0.8030 - val_iou_metric: 0.7089 - val_loss: 0.3854 - learning_rate: 5.0000e-04
# Epoch 89/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9665 - dice_coef: 0.8577 - iou_metric: 0.7930 - loss: 0.2462
# Epoch 89: val_dice_coef did not improve from 0.82946
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - accuracy: 0.9640 - dice_coef: 0.8561 - iou_metric: 0.7898 - loss: 0.2569 - val_accuracy: 0.9401 - val_dice_coef: 0.8009 - val_iou_metric: 0.7126 - val_loss: 0.3848 - learning_rate: 5.0000e-04
# Epoch 90/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9617 - dice_coef: 0.8439 - iou_metric: 0.7747 - loss: 0.2753
# Epoch 90: val_dice_coef did not improve from 0.82946
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - accuracy: 0.9634 - dice_coef: 0.8532 - iou_metric: 0.7877 - loss: 0.2631 - val_accuracy: 0.9491 - val_dice_coef: 0.8136 - val_iou_metric: 0.7249 - val_loss: 0.3599 - learning_rate: 5.0000e-04
# Epoch 91/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9640 - dice_coef: 0.8446 - iou_metric: 0.7735 - loss: 0.2695
# Epoch 91: val_dice_coef did not improve from 0.82946
#
# Epoch 91: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - accuracy: 0.9644 - dice_coef: 0.8548 - iou_metric: 0.7888 - loss: 0.2578 - val_accuracy: 0.9486 - val_dice_coef: 0.8138 - val_iou_metric: 0.7340 - val_loss: 0.3481 - learning_rate: 5.0000e-04
# Epoch 92/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9666 - dice_coef: 0.8645 - iou_metric: 0.8010 - loss: 0.2423
# Epoch 92: val_dice_coef did not improve from 0.82946
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - accuracy: 0.9679 - dice_coef: 0.8689 - iou_metric: 0.8078 - loss: 0.2334 - val_accuracy: 0.9505 - val_dice_coef: 0.8113 - val_iou_metric: 0.7195 - val_loss: 0.3646 - learning_rate: 2.5000e-04
# Epoch 93/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9684 - dice_coef: 0.8744 - iou_metric: 0.8136 - loss: 0.2245
# Epoch 93: val_dice_coef improved from 0.82946 to 0.83349, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v_12_05_26.keras
#
# Epoch 93: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v_12_05_26.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - accuracy: 0.9670 - dice_coef: 0.8698 - iou_metric: 0.8068 - loss: 0.2353 - val_accuracy: 0.9528 - val_dice_coef: 0.8335 - val_iou_metric: 0.7483 - val_loss: 0.3238 - learning_rate: 2.5000e-04
# Epoch 94/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9677 - dice_coef: 0.8754 - iou_metric: 0.8190 - loss: 0.2260
# Epoch 94: val_dice_coef improved from 0.83349 to 0.83530, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v_12_05_26.keras
#
# Epoch 94: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v_12_05_26.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 8s 40ms/step - accuracy: 0.9674 - dice_coef: 0.8690 - iou_metric: 0.8086 - loss: 0.2339 - val_accuracy: 0.9534 - val_dice_coef: 0.8353 - val_iou_metric: 0.7518 - val_loss: 0.3208 - learning_rate: 2.5000e-04
# Epoch 95/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9684 - dice_coef: 0.8728 - iou_metric: 0.8124 - loss: 0.2285
# Epoch 95: val_dice_coef did not improve from 0.83530
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - accuracy: 0.9680 - dice_coef: 0.8687 - iou_metric: 0.8071 - loss: 0.2327 - val_accuracy: 0.9531 - val_dice_coef: 0.8289 - val_iou_metric: 0.7439 - val_loss: 0.3278 - learning_rate: 2.5000e-04
# Epoch 96/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9657 - dice_coef: 0.8680 - iou_metric: 0.8071 - loss: 0.2470
# Epoch 96: val_dice_coef did not improve from 0.83530
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - accuracy: 0.9679 - dice_coef: 0.8708 - iou_metric: 0.8091 - loss: 0.2330 - val_accuracy: 0.9516 - val_dice_coef: 0.8281 - val_iou_metric: 0.7444 - val_loss: 0.3272 - learning_rate: 2.5000e-04
# Epoch 97/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9672 - dice_coef: 0.8739 - iou_metric: 0.8155 - loss: 0.2292
# Epoch 97: val_dice_coef did not improve from 0.83530
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - accuracy: 0.9679 - dice_coef: 0.8695 - iou_metric: 0.8087 - loss: 0.2324 - val_accuracy: 0.9504 - val_dice_coef: 0.8152 - val_iou_metric: 0.7300 - val_loss: 0.3449 - learning_rate: 2.5000e-04
# Epoch 98/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9686 - dice_coef: 0.8755 - iou_metric: 0.8138 - loss: 0.2203
# Epoch 98: val_dice_coef did not improve from 0.83530
#
# Epoch 98: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - accuracy: 0.9688 - dice_coef: 0.8790 - iou_metric: 0.8191 - loss: 0.2200 - val_accuracy: 0.9521 - val_dice_coef: 0.8291 - val_iou_metric: 0.7436 - val_loss: 0.3269 - learning_rate: 2.5000e-04
# Epoch 99/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9709 - dice_coef: 0.8835 - iou_metric: 0.8311 - loss: 0.2065
# Epoch 99: val_dice_coef improved from 0.83530 to 0.84740, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v_12_05_26.keras
#
# Epoch 99: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v_12_05_26.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 8s 39ms/step - accuracy: 0.9709 - dice_coef: 0.8830 - iou_metric: 0.8287 - loss: 0.2089 - val_accuracy: 0.9575 - val_dice_coef: 0.8474 - val_iou_metric: 0.7715 - val_loss: 0.2982 - learning_rate: 1.2500e-04
# Epoch 100/100
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9688 - dice_coef: 0.8841 - iou_metric: 0.8265 - loss: 0.2146
# Epoch 100: val_dice_coef did not improve from 0.84740
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - accuracy: 0.9706 - dice_coef: 0.8860 - iou_metric: 0.8297 - loss: 0.2074 - val_accuracy: 0.9572 - val_dice_coef: 0.8440 - val_iou_metric: 0.7657 - val_loss: 0.3029 - learning_rate: 1.2500e-04
# Restoring model weights from the end of the best epoch: 99.
# ========== Training Complete ==========

# %%
    if images:
        test_and_display(unet, images[2])

# %%
if images:
    for i in range(0,3):
        test_and_display(unet, images[i])

# %%
import random

if images:
    for _ in range(3):  # run 3 times
        i = random.randint(1, 25)  # random integer between 1 and 25
        test_and_display(unet, images[i])

# %%
if images:
    for _ in range(3):  # run 3 times
        test_and_display(unet, images[i])
