# %%
import tensorflow as tf

print(tf.__version__)
print(tf.config.list_physical_devices('GPU'))
print(tf.test.is_built_with_cuda())
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1778427166.412514   18934 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2.21.0
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# True

# %%
import os
import glob
import numpy as np
import cv2
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, models, Input, mixed_precision
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import (
    ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
)

# %%
mixed_precision.set_global_policy('mixed_float16')
os.environ['TF_GPU_ALLOCATOR'] = 'cuda_malloc_async'

# %%
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu, True)
    print(f"GPU found: {[g.name for g in gpus]}")
# Out:
# GPU found: ['/physical_device:GPU:0']

# %%
IMG_SIZE   = 256
BATCH_SIZE = 4        
EPOCHS     = 100
DATA_PATH  = '/mnt/c/development/Thesis/PolypSegmentationBasedClassification/DataSets/Kvasir-SEG'
MODEL_SAVE = '/mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v1.keras'

# %%
# ─────────────────────────────────────────────
#  AUGMENTATION
# ─────────────────────────────────────────────
def augment(img, mask):
    if tf.random.uniform(()) > 0.5:
        img  = tf.image.flip_left_right(img)
        mask = tf.image.flip_left_right(mask)
    if tf.random.uniform(()) > 0.5:
        img  = tf.image.flip_up_down(img)
        mask = tf.image.flip_up_down(mask)
    img = tf.image.random_brightness(img, 0.15)
    img = tf.image.random_contrast(img, 0.85, 1.15)
    img = tf.clip_by_value(img, 0.0, 1.0)
    return img, mask

# %%
# ─────────────────────────────────────────────
#  PREPROCESSING
# ─────────────────────────────────────────────
def process_path(img_path, mask_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, [IMG_SIZE, IMG_SIZE])
    img = tf.cast(img, tf.float32) / 255.0

    mask = tf.io.read_file(mask_path)
    mask = tf.image.decode_image(mask, channels=1, expand_animations=False)
    mask = tf.image.resize(mask, [IMG_SIZE, IMG_SIZE],
                           method=tf.image.ResizeMethod.NEAREST_NEIGHBOR)
    mask = tf.cast(mask, tf.float32) / 255.0
    mask = tf.where(mask > 0.5, 1.0, 0.0)
    return img, mask

def get_dataset(x, y, batch=BATCH_SIZE, augment_data=False):
    ds = tf.data.Dataset.from_tensor_slices((x, y))
    ds = ds.shuffle(buffer_size=len(x), reshuffle_each_iteration=True)
    ds = ds.map(process_path, num_parallel_calls=tf.data.AUTOTUNE)
    if augment_data:
        ds = ds.map(augment, num_parallel_calls=tf.data.AUTOTUNE)
    ds = ds.batch(batch)
    ds = ds.prefetch(tf.data.AUTOTUNE)
    return ds

# %%
# ─────────────────────────────────────────────
#  LOSS & METRICS
# ─────────────────────────────────────────────
def dice_coef(y_true, y_pred, smooth=1.0):
    y_true = tf.cast(tf.reshape(y_true, [-1]), tf.float32)
    y_pred = tf.cast(tf.reshape(y_pred, [-1]), tf.float32)
    intersection = tf.reduce_sum(y_true * y_pred)
    return (2.0 * intersection + smooth) / (
        tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth
    )

# %%
def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

def bce_dice_loss(y_true, y_pred):
    y_true_f = tf.cast(y_true, tf.float32)
    y_pred_f = tf.cast(y_pred, tf.float32)
    bce = tf.reduce_mean(
        tf.keras.losses.binary_crossentropy(y_true_f, y_pred_f)
    )
    return bce + dice_loss(y_true_f, y_pred_f)

def iou_metric(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred > 0.5, tf.float32)
    intersection = tf.reduce_sum(y_true * y_pred)
    union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) - intersection
    return (intersection + 1.0) / (union + 1.0)

# %%
def conv_block(x, filters, dropout_rate=0.0):
    """Conv → BN → ReLU × 2  (mixed_float16 compatible)"""
    x = layers.Conv2D(filters, 3, padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    if dropout_rate > 0:
        x = layers.SpatialDropout2D(dropout_rate)(x)
    x = layers.Conv2D(filters, 3, padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    return x

# %%
def build_unet_lite(input_shape=(IMG_SIZE, IMG_SIZE, 3)):
    """
    Filter map:  64 → 128 → 256 → 512 (bottleneck)
    """
    inputs = Input(input_shape)

    # ── Encoder ──────────────────────────
    c1 = conv_block(inputs, 32)                      # 256×256×32
    p1 = layers.MaxPooling2D(2)(c1)                  # 128×128

    c2 = conv_block(p1, 64)                          # 128×128×64
    p2 = layers.MaxPooling2D(2)(c2)                  # 64×64

    c3 = conv_block(p2, 128, dropout_rate=0.1)       # 64×64×128
    p3 = layers.MaxPooling2D(2)(c3)                  # 32×32

    c4 = conv_block(p3, 256, dropout_rate=0.2)       # 32×32×256
    p4 = layers.MaxPooling2D(2)(c4)                  # 16×16

    # ── Bottleneck ───────────────────────
    b = conv_block(p4, 512, dropout_rate=0.3)        # 16×16×512  ← আগে 1024 ছিল

    # ── Decoder ──────────────────────────
    u4 = layers.Conv2DTranspose(256, 2, strides=2, padding='same')(b)
    u4 = layers.concatenate([u4, c4])
    c5 = conv_block(u4, 256, dropout_rate=0.2)

    u3 = layers.Conv2DTranspose(128, 2, strides=2, padding='same')(c5)
    u3 = layers.concatenate([u3, c3])
    c6 = conv_block(u3, 128, dropout_rate=0.1)

    u2 = layers.Conv2DTranspose(64, 2, strides=2, padding='same')(c6)
    u2 = layers.concatenate([u2, c2])
    c7 = conv_block(u2, 64)

    u1 = layers.Conv2DTranspose(32, 2, strides=2, padding='same')(c7)
    u1 = layers.concatenate([u1, c1])
    c8 = conv_block(u1, 32)

    outputs = layers.Conv2D(1, 1, activation='sigmoid', dtype='float32')(c8)

    return models.Model(inputs, outputs, name='U-Net-Lite')

# %%
# ─────────────────────────────────────────────
#  TEST & DISPLAY
# ─────────────────────────────────────────────
def test_and_display(model, image_path):
    img     = cv2.imread(image_path)
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img_res = cv2.resize(img_rgb, (IMG_SIZE, IMG_SIZE))
    inp     = np.expand_dims(img_res / 255.0, axis=0).astype(np.float32)

    pred_mask = model.predict(inp, verbose=0)[0]
    mask_bin  = (pred_mask > 0.5).astype(np.uint8)
    mask_3d   = np.concatenate([mask_bin] * 3, axis=-1)
    extracted = (img_res * mask_3d).astype(np.uint8)

    titles = ['Original', 'Predicted Mask', 'Extracted Polyp']
    images = [img_res, pred_mask.squeeze(), extracted]
    plt.figure(figsize=(15, 5))
    for i in range(3):
        plt.subplot(1, 3, i + 1)
        plt.imshow(images[i], cmap='gray' if i == 1 else None)
        plt.title(titles[i], fontsize=14)
        plt.axis('off')
    plt.tight_layout()
    plt.savefig('prediction_result.png', dpi=150)
    plt.show()

# %%
if __name__ == '__main__':

    images = sorted(glob.glob(os.path.join(DATA_PATH, 'images/*.jpg')))
    masks  = sorted(glob.glob(os.path.join(DATA_PATH, 'masks/*.jpg')))
    print(f"Total samples: {len(images)}")

    train_x, val_x, train_y, val_y = train_test_split(
        images, masks, test_size=0.2, random_state=42
    )
    print(f"Train: {len(train_x)}  |  Val: {len(val_x)}")

    train_ds = get_dataset(train_x, train_y, batch=BATCH_SIZE, augment_data=True)
    val_ds   = get_dataset(val_x,   val_y,   batch=BATCH_SIZE, augment_data=False)

    unet = build_unet_lite()
    unet.summary()

    # Mixed precision → optimizer loss scaling দরকার
    optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3)
    optimizer = mixed_precision.LossScaleOptimizer(optimizer)

    unet.compile(
        optimizer=optimizer,
        loss=bce_dice_loss,
        metrics=[dice_coef, iou_metric, 'accuracy']
    )

    os.makedirs(os.path.dirname(MODEL_SAVE), exist_ok=True)

    callbacks = [
        ModelCheckpoint(MODEL_SAVE, monitor='val_dice_coef',
                        save_best_only=True, mode='max', verbose=1),
        ReduceLROnPlateau(monitor='val_loss', factor=0.5,
                          patience=7, min_lr=1e-7, verbose=1),
        EarlyStopping(monitor='val_dice_coef', patience=20,
                      restore_best_weights=True, mode='max', verbose=1),
    ]

    print("\n========== Training Started ==========")
    history = unet.fit(
        train_ds,
        validation_data=val_ds,
        epochs=EPOCHS,
        callbacks=callbacks
    )
    print("========== Training Complete ==========\n")

    # ── Plot ──────────────────────────────────
    fig, axes = plt.subplots(1, 3, figsize=(18, 5))
    axes[0].plot(history.history['loss'],          label='Train')
    axes[0].plot(history.history['val_loss'],      label='Val')
    axes[0].set_title('BCE + Dice Loss'); axes[0].legend()

    axes[1].plot(history.history['dice_coef'],     label='Train')
    axes[1].plot(history.history['val_dice_coef'], label='Val')
    axes[1].set_title('Dice Coefficient'); axes[1].legend()

    axes[2].plot(history.history['iou_metric'],     label='Train')
    axes[2].plot(history.history['val_iou_metric'], label='Val')
    axes[2].set_title('IoU Score'); axes[2].legend()

    plt.tight_layout()
    plt.savefig('training_history.png', dpi=150)
    plt.show()
# Out:
# Total samples: 1000
# Train: 800  |  Val: 200
# Model: "U-Net-Lite"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 256, 256,  │        864 │ input_layer_1[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        128 │ conv2d_19[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_18       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 256, 256,  │      9,216 │ activation_18[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        128 │ conv2d_20[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_19       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_4     │ (None, 128, 128,  │          0 │ activation_19[0]… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_21 (Conv2D)  │ (None, 128, 128,  │     18,432 │ max_pooling2d_4[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_21[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_20       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_22 (Conv2D)  │ (None, 128, 128,  │     36,864 │ activation_20[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_22[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_21       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_5     │ (None, 64, 64,    │          0 │ activation_21[0]… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_23 (Conv2D)  │ (None, 64, 64,    │     73,728 │ max_pooling2d_5[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_23[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_22       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout2d_5 │ (None, 64, 64,    │          0 │ activation_22[0]… │
# │ (SpatialDropout2D)  │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_24 (Conv2D)  │ (None, 64, 64,    │    147,456 │ spatial_dropout2… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_24[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_23       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_6     │ (None, 32, 32,    │          0 │ activation_23[0]… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_25 (Conv2D)  │ (None, 32, 32,    │    294,912 │ max_pooling2d_6[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_25[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_24       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout2d_6 │ (None, 32, 32,    │          0 │ activation_24[0]… │
# │ (SpatialDropout2D)  │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_26 (Conv2D)  │ (None, 32, 32,    │    589,824 │ spatial_dropout2… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_26[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_25       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_7     │ (None, 16, 16,    │          0 │ activation_25[0]… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_27 (Conv2D)  │ (None, 16, 16,    │  1,179,648 │ max_pooling2d_7[… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      2,048 │ conv2d_27[0][0]   │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_26       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout2d_7 │ (None, 16, 16,    │          0 │ activation_26[0]… │
# │ (SpatialDropout2D)  │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_28 (Conv2D)  │ (None, 16, 16,    │  2,359,296 │ spatial_dropout2… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      2,048 │ conv2d_28[0][0]   │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_27       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_4  │ (None, 32, 32,    │    524,544 │ activation_27[0]… │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_4       │ (None, 32, 32,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 512)              │            │ activation_25[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_29 (Conv2D)  │ (None, 32, 32,    │  1,179,648 │ concatenate_4[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_29[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_28       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout2d_8 │ (None, 32, 32,    │          0 │ activation_28[0]… │
# │ (SpatialDropout2D)  │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_30 (Conv2D)  │ (None, 32, 32,    │    589,824 │ spatial_dropout2… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_30[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_29       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_5  │ (None, 64, 64,    │    131,200 │ activation_29[0]… │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_5       │ (None, 64, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 256)              │            │ activation_23[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_31 (Conv2D)  │ (None, 64, 64,    │    294,912 │ concatenate_5[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_31[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_30       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout2d_9 │ (None, 64, 64,    │          0 │ activation_30[0]… │
# │ (SpatialDropout2D)  │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_32 (Conv2D)  │ (None, 64, 64,    │    147,456 │ spatial_dropout2… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_32[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_31       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_6  │ (None, 128, 128,  │     32,832 │ activation_31[0]… │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_6       │ (None, 128, 128,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ activation_21[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_33 (Conv2D)  │ (None, 128, 128,  │     73,728 │ concatenate_6[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_33[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_32       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_34 (Conv2D)  │ (None, 128, 128,  │     36,864 │ activation_32[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_34[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_33       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_7  │ (None, 256, 256,  │      8,224 │ activation_33[0]… │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_7       │ (None, 256, 256,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 64)               │            │ activation_19[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_35 (Conv2D)  │ (None, 256, 256,  │     18,432 │ concatenate_7[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        128 │ conv2d_35[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_34       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_36 (Conv2D)  │ (None, 256, 256,  │      9,216 │ activation_34[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        128 │ conv2d_36[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_35       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_37 (Conv2D)  │ (None, 256, 256,  │         33 │ activation_35[0]… │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 7,768,929 (29.64 MB)
#  Trainable params: 7,763,041 (29.61 MB)
#  Non-trainable params: 5,888 (23.00 KB)
# ========== Training Started ==========
# Epoch 1/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.7612 - dice_coef: 0.2913 - iou_metric: 0.1950 - loss: 1.1543
# Epoch 1: val_dice_coef improved from None to 0.21486, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v1.keras
#
# Epoch 1: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v1.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 44s 90ms/step - accuracy: 0.7784 - dice_coef: 0.3105 - iou_metric: 0.2165 - loss: 1.0998 - val_accuracy: 0.7074 - val_dice_coef: 0.2149 - val_iou_metric: 0.1166 - val_loss: 1.3793 - learning_rate: 0.0010
# Epoch 2/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.8002 - dice_coef: 0.3347 - iou_metric: 0.2628 - loss: 1.0402
# Epoch 2: val_dice_coef improved from 0.21486 to 0.38948, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v1.keras
#
# Epoch 2: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v1.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 16s 77ms/step - accuracy: 0.8073 - dice_coef: 0.3539 - iou_metric: 0.2768 - loss: 1.0224 - val_accuracy: 0.5936 - val_dice_coef: 0.3895 - val_iou_metric: 0.2544 - val_loss: 1.5474 - learning_rate: 0.0010
# Epoch 3/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.8268 - dice_coef: 0.4028 - iou_metric: 0.3214 - loss: 0.9590
# Epoch 3: val_dice_coef did not improve from 0.38948
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 67ms/step - accuracy: 0.8290 - dice_coef: 0.4020 - iou_metric: 0.3187 - loss: 0.9580 - val_accuracy: 0.7328 - val_dice_coef: 0.3828 - val_iou_metric: 0.2951 - val_loss: 1.0883 - learning_rate: 0.0010
# Epoch 4/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.8329 - dice_coef: 0.4039 - iou_metric: 0.3189 - loss: 0.9560
# Epoch 4: val_dice_coef improved from 0.38948 to 0.45322, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v1.keras
#
# Epoch 4: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v1.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 16s 78ms/step - accuracy: 0.8384 - dice_coef: 0.4128 - iou_metric: 0.3269 - loss: 0.9398 - val_accuracy: 0.7375 - val_dice_coef: 0.4532 - val_iou_metric: 0.3206 - val_loss: 1.1713 - learning_rate: 0.0010
# Epoch 5/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.8481 - dice_coef: 0.4401 - iou_metric: 0.3504 - loss: 0.9038
# Epoch 5: val_dice_coef did not improve from 0.45322
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 68ms/step - accuracy: 0.8465 - dice_coef: 0.4383 - iou_metric: 0.3489 - loss: 0.9080 - val_accuracy: 0.4894 - val_dice_coef: 0.3551 - val_iou_metric: 0.2226 - val_loss: 2.9729 - learning_rate: 0.0010
# Epoch 6/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.8475 - dice_coef: 0.4168 - iou_metric: 0.3224 - loss: 0.9302
# Epoch 6: val_dice_coef did not improve from 0.45322
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 69ms/step - accuracy: 0.8484 - dice_coef: 0.4349 - iou_metric: 0.3416 - loss: 0.9088 - val_accuracy: 0.8599 - val_dice_coef: 0.3994 - val_iou_metric: 0.3071 - val_loss: 0.9683 - learning_rate: 0.0010
# Epoch 7/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.8518 - dice_coef: 0.4524 - iou_metric: 0.3611 - loss: 0.8916
# Epoch 7: val_dice_coef improved from 0.45322 to 0.52832, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v1.keras
#
# Epoch 7: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v1.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 15s 77ms/step - accuracy: 0.8572 - dice_coef: 0.4622 - iou_metric: 0.3699 - loss: 0.8718 - val_accuracy: 0.8475 - val_dice_coef: 0.5283 - val_iou_metric: 0.4282 - val_loss: 0.8249 - learning_rate: 0.0010
# Epoch 8/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.8590 - dice_coef: 0.4715 - iou_metric: 0.3755 - loss: 0.8650
# Epoch 8: val_dice_coef did not improve from 0.52832
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 68ms/step - accuracy: 0.8585 - dice_coef: 0.4666 - iou_metric: 0.3711 - loss: 0.8672 - val_accuracy: 0.8708 - val_dice_coef: 0.4868 - val_iou_metric: 0.3972 - val_loss: 0.8269 - learning_rate: 0.0010
# Epoch 9/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.8637 - dice_coef: 0.4804 - iou_metric: 0.3892 - loss: 0.8415
# Epoch 9: val_dice_coef did not improve from 0.52832
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 68ms/step - accuracy: 0.8620 - dice_coef: 0.4781 - iou_metric: 0.3864 - loss: 0.8493 - val_accuracy: 0.8782 - val_dice_coef: 0.4375 - val_iou_metric: 0.3250 - val_loss: 0.9081 - learning_rate: 0.0010
# Epoch 10/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.8602 - dice_coef: 0.4788 - iou_metric: 0.3814 - loss: 0.8452
# Epoch 10: val_dice_coef did not improve from 0.52832
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 69ms/step - accuracy: 0.8617 - dice_coef: 0.4817 - iou_metric: 0.3868 - loss: 0.8404 - val_accuracy: 0.8575 - val_dice_coef: 0.5160 - val_iou_metric: 0.3950 - val_loss: 0.9115 - learning_rate: 0.0010
# Epoch 11/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.8696 - dice_coef: 0.4967 - iou_metric: 0.3984 - loss: 0.8163
# Epoch 11: val_dice_coef improved from 0.52832 to 0.55397, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v1.keras
#
# Epoch 11: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v1.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 16s 80ms/step - accuracy: 0.8651 - dice_coef: 0.4820 - iou_metric: 0.3866 - loss: 0.8392 - val_accuracy: 0.8697 - val_dice_coef: 0.5540 - val_iou_metric: 0.4647 - val_loss: 0.7549 - learning_rate: 0.0010
# Epoch 12/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.8692 - dice_coef: 0.5100 - iou_metric: 0.4120 - loss: 0.8131
# Epoch 12: val_dice_coef did not improve from 0.55397
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 68ms/step - accuracy: 0.8670 - dice_coef: 0.4968 - iou_metric: 0.3979 - loss: 0.8251 - val_accuracy: 0.8748 - val_dice_coef: 0.4916 - val_iou_metric: 0.4134 - val_loss: 0.8138 - learning_rate: 0.0010
# Epoch 13/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.8679 - dice_coef: 0.4813 - iou_metric: 0.3870 - loss: 0.8335
# Epoch 13: val_dice_coef did not improve from 0.55397
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 70ms/step - accuracy: 0.8661 - dice_coef: 0.4935 - iou_metric: 0.3986 - loss: 0.8250 - val_accuracy: 0.8129 - val_dice_coef: 0.5283 - val_iou_metric: 0.4074 - val_loss: 0.9452 - learning_rate: 0.0010
# Epoch 14/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.8681 - dice_coef: 0.5105 - iou_metric: 0.4155 - loss: 0.8132
# Epoch 14: val_dice_coef did not improve from 0.55397
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 69ms/step - accuracy: 0.8716 - dice_coef: 0.5071 - iou_metric: 0.4098 - loss: 0.8083 - val_accuracy: 0.8837 - val_dice_coef: 0.5388 - val_iou_metric: 0.4520 - val_loss: 0.7463 - learning_rate: 0.0010
# Epoch 15/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.8684 - dice_coef: 0.5091 - iou_metric: 0.4143 - loss: 0.8071
# Epoch 15: val_dice_coef did not improve from 0.55397
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 69ms/step - accuracy: 0.8774 - dice_coef: 0.5248 - iou_metric: 0.4273 - loss: 0.7758 - val_accuracy: 0.7193 - val_dice_coef: 0.4642 - val_iou_metric: 0.3270 - val_loss: 1.3055 - learning_rate: 0.0010
# Epoch 16/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.8725 - dice_coef: 0.5234 - iou_metric: 0.4230 - loss: 0.7905
# Epoch 16: val_dice_coef did not improve from 0.55397
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 69ms/step - accuracy: 0.8772 - dice_coef: 0.5218 - iou_metric: 0.4246 - loss: 0.7838 - val_accuracy: 0.8618 - val_dice_coef: 0.5388 - val_iou_metric: 0.4457 - val_loss: 0.8172 - learning_rate: 0.0010
# Epoch 17/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.8799 - dice_coef: 0.5305 - iou_metric: 0.4293 - loss: 0.7701
# Epoch 17: val_dice_coef improved from 0.55397 to 0.55554, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v1.keras
#
# Epoch 17: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v1.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 16s 78ms/step - accuracy: 0.8783 - dice_coef: 0.5306 - iou_metric: 0.4329 - loss: 0.7720 - val_accuracy: 0.8270 - val_dice_coef: 0.5555 - val_iou_metric: 0.4332 - val_loss: 0.8541 - learning_rate: 0.0010
# Epoch 18/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.8819 - dice_coef: 0.5382 - iou_metric: 0.4403 - loss: 0.7649
# Epoch 18: val_dice_coef did not improve from 0.55554
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 69ms/step - accuracy: 0.8800 - dice_coef: 0.5318 - iou_metric: 0.4333 - loss: 0.7715 - val_accuracy: 0.6513 - val_dice_coef: 0.4280 - val_iou_metric: 0.2919 - val_loss: 1.5093 - learning_rate: 0.0010
# Epoch 19/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.8834 - dice_coef: 0.5229 - iou_metric: 0.4233 - loss: 0.7708
# Epoch 19: val_dice_coef improved from 0.55554 to 0.57798, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v1.keras
#
# Epoch 19: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v1.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 16s 78ms/step - accuracy: 0.8808 - dice_coef: 0.5328 - iou_metric: 0.4326 - loss: 0.7692 - val_accuracy: 0.8719 - val_dice_coef: 0.5780 - val_iou_metric: 0.4792 - val_loss: 0.7262 - learning_rate: 0.0010
# Epoch 20/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.8741 - dice_coef: 0.5371 - iou_metric: 0.4371 - loss: 0.7768
# Epoch 20: val_dice_coef did not improve from 0.57798
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 67ms/step - accuracy: 0.8839 - dice_coef: 0.5462 - iou_metric: 0.4466 - loss: 0.7479 - val_accuracy: 0.8569 - val_dice_coef: 0.4537 - val_iou_metric: 0.3693 - val_loss: 0.8724 - learning_rate: 0.0010
# Epoch 21/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8895 - dice_coef: 0.5553 - iou_metric: 0.4571 - loss: 0.7270
# Epoch 21: val_dice_coef did not improve from 0.57798
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 13s 66ms/step - accuracy: 0.8878 - dice_coef: 0.5587 - iou_metric: 0.4600 - loss: 0.7299 - val_accuracy: 0.7093 - val_dice_coef: 0.4677 - val_iou_metric: 0.3320 - val_loss: 1.2884 - learning_rate: 0.0010
# Epoch 22/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.8816 - dice_coef: 0.5522 - iou_metric: 0.4535 - loss: 0.7545
# Epoch 22: val_dice_coef did not improve from 0.57798
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 67ms/step - accuracy: 0.8883 - dice_coef: 0.5590 - iou_metric: 0.4615 - loss: 0.7311 - val_accuracy: 0.8822 - val_dice_coef: 0.5490 - val_iou_metric: 0.4533 - val_loss: 0.7569 - learning_rate: 0.0010
# Epoch 23/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.8914 - dice_coef: 0.5647 - iou_metric: 0.4558 - loss: 0.7108
# Epoch 23: val_dice_coef did not improve from 0.57798
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 13s 67ms/step - accuracy: 0.8906 - dice_coef: 0.5664 - iou_metric: 0.4637 - loss: 0.7156 - val_accuracy: 0.8756 - val_dice_coef: 0.4945 - val_iou_metric: 0.3940 - val_loss: 0.8162 - learning_rate: 0.0010
# Epoch 24/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8882 - dice_coef: 0.5573 - iou_metric: 0.4532 - loss: 0.7378
# Epoch 24: val_dice_coef improved from 0.57798 to 0.58667, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v1.keras
#
# Epoch 24: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v1.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 15s 75ms/step - accuracy: 0.8919 - dice_coef: 0.5714 - iou_metric: 0.4704 - loss: 0.7104 - val_accuracy: 0.8870 - val_dice_coef: 0.5867 - val_iou_metric: 0.4847 - val_loss: 0.6943 - learning_rate: 0.0010
# Epoch 25/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.8990 - dice_coef: 0.5887 - iou_metric: 0.4884 - loss: 0.6804
# Epoch 25: val_dice_coef did not improve from 0.58667
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 13s 67ms/step - accuracy: 0.8957 - dice_coef: 0.5846 - iou_metric: 0.4848 - loss: 0.6937 - val_accuracy: 0.8924 - val_dice_coef: 0.5731 - val_iou_metric: 0.4766 - val_loss: 0.7112 - learning_rate: 0.0010
# Epoch 26/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.8935 - dice_coef: 0.5842 - iou_metric: 0.4864 - loss: 0.6937
# Epoch 26: val_dice_coef did not improve from 0.58667
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 13s 67ms/step - accuracy: 0.9003 - dice_coef: 0.5996 - iou_metric: 0.5021 - loss: 0.6639 - val_accuracy: 0.9022 - val_dice_coef: 0.5718 - val_iou_metric: 0.4630 - val_loss: 0.7151 - learning_rate: 0.0010
# Epoch 27/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.8927 - dice_coef: 0.5934 - iou_metric: 0.4848 - loss: 0.6866
# Epoch 27: val_dice_coef improved from 0.58667 to 0.62663, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v1.keras
#
# Epoch 27: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v1.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 16s 79ms/step - accuracy: 0.8971 - dice_coef: 0.5928 - iou_metric: 0.4905 - loss: 0.6812 - val_accuracy: 0.9026 - val_dice_coef: 0.6266 - val_iou_metric: 0.5206 - val_loss: 0.6474 - learning_rate: 0.0010
# Epoch 28/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9003 - dice_coef: 0.5965 - iou_metric: 0.4993 - loss: 0.6766
# Epoch 28: val_dice_coef did not improve from 0.62663
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 67ms/step - accuracy: 0.9003 - dice_coef: 0.5970 - iou_metric: 0.4983 - loss: 0.6699 - val_accuracy: 0.8898 - val_dice_coef: 0.5907 - val_iou_metric: 0.4956 - val_loss: 0.6884 - learning_rate: 0.0010
# Epoch 29/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9107 - dice_coef: 0.6204 - iou_metric: 0.5239 - loss: 0.6270
# Epoch 29: val_dice_coef did not improve from 0.62663
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 68ms/step - accuracy: 0.9050 - dice_coef: 0.6158 - iou_metric: 0.5177 - loss: 0.6443 - val_accuracy: 0.9057 - val_dice_coef: 0.6132 - val_iou_metric: 0.5179 - val_loss: 0.6509 - learning_rate: 0.0010
# Epoch 30/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9054 - dice_coef: 0.6304 - iou_metric: 0.5341 - loss: 0.6227
# Epoch 30: val_dice_coef did not improve from 0.62663
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 68ms/step - accuracy: 0.9067 - dice_coef: 0.6254 - iou_metric: 0.5286 - loss: 0.6291 - val_accuracy: 0.8692 - val_dice_coef: 0.6158 - val_iou_metric: 0.4970 - val_loss: 0.7409 - learning_rate: 0.0010
# Epoch 31/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9058 - dice_coef: 0.6221 - iou_metric: 0.5191 - loss: 0.6377
# Epoch 31: val_dice_coef improved from 0.62663 to 0.63966, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v1.keras
#
# Epoch 31: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v1.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 16s 78ms/step - accuracy: 0.9081 - dice_coef: 0.6317 - iou_metric: 0.5328 - loss: 0.6214 - val_accuracy: 0.9131 - val_dice_coef: 0.6397 - val_iou_metric: 0.5352 - val_loss: 0.6093 - learning_rate: 0.0010
# Epoch 32/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9120 - dice_coef: 0.6434 - iou_metric: 0.5461 - loss: 0.5998
# Epoch 32: val_dice_coef improved from 0.63966 to 0.67026, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v1.keras
#
# Epoch 32: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v1.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 16s 81ms/step - accuracy: 0.9098 - dice_coef: 0.6392 - iou_metric: 0.5430 - loss: 0.6140 - val_accuracy: 0.9178 - val_dice_coef: 0.6703 - val_iou_metric: 0.5568 - val_loss: 0.5816 - learning_rate: 0.0010
# Epoch 33/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9111 - dice_coef: 0.6477 - iou_metric: 0.5515 - loss: 0.5934
# Epoch 33: val_dice_coef did not improve from 0.67026
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 13s 65ms/step - accuracy: 0.9106 - dice_coef: 0.6402 - iou_metric: 0.5432 - loss: 0.6036 - val_accuracy: 0.8392 - val_dice_coef: 0.5854 - val_iou_metric: 0.4567 - val_loss: 0.9708 - learning_rate: 0.0010
# Epoch 34/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9177 - dice_coef: 0.6562 - iou_metric: 0.5588 - loss: 0.5866
# Epoch 34: val_dice_coef did not improve from 0.67026
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 71ms/step - accuracy: 0.9166 - dice_coef: 0.6596 - iou_metric: 0.5631 - loss: 0.5814 - val_accuracy: 0.9113 - val_dice_coef: 0.6572 - val_iou_metric: 0.5722 - val_loss: 0.5703 - learning_rate: 0.0010
# Epoch 35/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.9133 - dice_coef: 0.6582 - iou_metric: 0.5627 - loss: 0.5907
# Epoch 35: val_dice_coef did not improve from 0.67026
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 72ms/step - accuracy: 0.9190 - dice_coef: 0.6754 - iou_metric: 0.5832 - loss: 0.5565 - val_accuracy: 0.8534 - val_dice_coef: 0.2344 - val_iou_metric: 0.1088 - val_loss: 1.2446 - learning_rate: 0.0010
# Epoch 36/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9192 - dice_coef: 0.6748 - iou_metric: 0.5767 - loss: 0.5539
# Epoch 36: val_dice_coef improved from 0.67026 to 0.69373, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v1.keras
#
# Epoch 36: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v1.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 15s 76ms/step - accuracy: 0.9196 - dice_coef: 0.6758 - iou_metric: 0.5765 - loss: 0.5560 - val_accuracy: 0.9285 - val_dice_coef: 0.6937 - val_iou_metric: 0.6172 - val_loss: 0.5152 - learning_rate: 0.0010
# Epoch 37/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9170 - dice_coef: 0.6763 - iou_metric: 0.5806 - loss: 0.5538
# Epoch 37: val_dice_coef did not improve from 0.69373
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 67ms/step - accuracy: 0.9212 - dice_coef: 0.6834 - iou_metric: 0.5890 - loss: 0.5373 - val_accuracy: 0.8948 - val_dice_coef: 0.5206 - val_iou_metric: 0.3889 - val_loss: 0.8009 - learning_rate: 0.0010
# Epoch 38/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9205 - dice_coef: 0.6667 - iou_metric: 0.5695 - loss: 0.5560
# Epoch 38: val_dice_coef improved from 0.69373 to 0.71040, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v1.keras
#
# Epoch 38: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v1.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 16s 78ms/step - accuracy: 0.9204 - dice_coef: 0.6791 - iou_metric: 0.5830 - loss: 0.5494 - val_accuracy: 0.9273 - val_dice_coef: 0.7104 - val_iou_metric: 0.6154 - val_loss: 0.5028 - learning_rate: 0.0010
# Epoch 39/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9279 - dice_coef: 0.6941 - iou_metric: 0.6037 - loss: 0.5156
# Epoch 39: val_dice_coef did not improve from 0.71040
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 68ms/step - accuracy: 0.9261 - dice_coef: 0.6963 - iou_metric: 0.6051 - loss: 0.5180 - val_accuracy: 0.9258 - val_dice_coef: 0.6960 - val_iou_metric: 0.6057 - val_loss: 0.5145 - learning_rate: 0.0010
# Epoch 40/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9327 - dice_coef: 0.7198 - iou_metric: 0.6328 - loss: 0.4759
# Epoch 40: val_dice_coef did not improve from 0.71040
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 13s 67ms/step - accuracy: 0.9282 - dice_coef: 0.7124 - iou_metric: 0.6196 - loss: 0.4968 - val_accuracy: 0.9157 - val_dice_coef: 0.6402 - val_iou_metric: 0.5591 - val_loss: 0.6014 - learning_rate: 0.0010
# Epoch 41/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9263 - dice_coef: 0.7154 - iou_metric: 0.6252 - loss: 0.4903
# Epoch 41: val_dice_coef did not improve from 0.71040
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 13s 67ms/step - accuracy: 0.9266 - dice_coef: 0.7101 - iou_metric: 0.6180 - loss: 0.4983 - val_accuracy: 0.8859 - val_dice_coef: 0.4548 - val_iou_metric: 0.3143 - val_loss: 0.9805 - learning_rate: 0.0010
# Epoch 42/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9249 - dice_coef: 0.7012 - iou_metric: 0.6055 - loss: 0.5204
# Epoch 42: val_dice_coef improved from 0.71040 to 0.73534, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v1.keras
#
# Epoch 42: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v1.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 15s 77ms/step - accuracy: 0.9279 - dice_coef: 0.7109 - iou_metric: 0.6192 - loss: 0.5017 - val_accuracy: 0.9288 - val_dice_coef: 0.7353 - val_iou_metric: 0.6384 - val_loss: 0.4731 - learning_rate: 0.0010
# Epoch 43/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9357 - dice_coef: 0.7285 - iou_metric: 0.6420 - loss: 0.4621
# Epoch 43: val_dice_coef did not improve from 0.73534
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 70ms/step - accuracy: 0.9319 - dice_coef: 0.7304 - iou_metric: 0.6419 - loss: 0.4736 - val_accuracy: 0.9206 - val_dice_coef: 0.6997 - val_iou_metric: 0.6139 - val_loss: 0.5132 - learning_rate: 0.0010
# Epoch 44/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9286 - dice_coef: 0.7194 - iou_metric: 0.6291 - loss: 0.4848
# Epoch 44: val_dice_coef did not improve from 0.73534
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 68ms/step - accuracy: 0.9291 - dice_coef: 0.7165 - iou_metric: 0.6262 - loss: 0.4871 - val_accuracy: 0.9270 - val_dice_coef: 0.7182 - val_iou_metric: 0.6184 - val_loss: 0.5007 - learning_rate: 0.0010
# Epoch 45/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9361 - dice_coef: 0.7490 - iou_metric: 0.6616 - loss: 0.4350
# Epoch 45: val_dice_coef did not improve from 0.73534
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 13s 67ms/step - accuracy: 0.9335 - dice_coef: 0.7351 - iou_metric: 0.6434 - loss: 0.4585 - val_accuracy: 0.9332 - val_dice_coef: 0.7277 - val_iou_metric: 0.6307 - val_loss: 0.4806 - learning_rate: 0.0010
# Epoch 46/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9297 - dice_coef: 0.7226 - iou_metric: 0.6361 - loss: 0.4806
# Epoch 46: val_dice_coef did not improve from 0.73534
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 71ms/step - accuracy: 0.9347 - dice_coef: 0.7387 - iou_metric: 0.6534 - loss: 0.4515 - val_accuracy: 0.9176 - val_dice_coef: 0.6604 - val_iou_metric: 0.5524 - val_loss: 0.5873 - learning_rate: 0.0010
# Epoch 47/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9371 - dice_coef: 0.7414 - iou_metric: 0.6502 - loss: 0.4504
# Epoch 47: val_dice_coef did not improve from 0.73534
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 13s 67ms/step - accuracy: 0.9362 - dice_coef: 0.7410 - iou_metric: 0.6519 - loss: 0.4545 - val_accuracy: 0.9207 - val_dice_coef: 0.7011 - val_iou_metric: 0.6135 - val_loss: 0.5168 - learning_rate: 0.0010
# Epoch 48/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.9369 - dice_coef: 0.7497 - iou_metric: 0.6664 - loss: 0.4411
# Epoch 48: val_dice_coef improved from 0.73534 to 0.76570, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v1.keras
#
# Epoch 48: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v1.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 16s 82ms/step - accuracy: 0.9377 - dice_coef: 0.7483 - iou_metric: 0.6649 - loss: 0.4396 - val_accuracy: 0.9388 - val_dice_coef: 0.7657 - val_iou_metric: 0.6669 - val_loss: 0.4353 - learning_rate: 0.0010
# Epoch 49/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.9402 - dice_coef: 0.7555 - iou_metric: 0.6666 - loss: 0.4214
# Epoch 49: val_dice_coef did not improve from 0.76570
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 70ms/step - accuracy: 0.9368 - dice_coef: 0.7456 - iou_metric: 0.6555 - loss: 0.4416 - val_accuracy: 0.9296 - val_dice_coef: 0.7275 - val_iou_metric: 0.6425 - val_loss: 0.4810 - learning_rate: 0.0010
# Epoch 50/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9388 - dice_coef: 0.7443 - iou_metric: 0.6610 - loss: 0.4354
# Epoch 50: val_dice_coef did not improve from 0.76570
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 13s 64ms/step - accuracy: 0.9391 - dice_coef: 0.7540 - iou_metric: 0.6669 - loss: 0.4281 - val_accuracy: 0.9406 - val_dice_coef: 0.7505 - val_iou_metric: 0.6716 - val_loss: 0.4259 - learning_rate: 0.0010
# Epoch 51/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9446 - dice_coef: 0.7752 - iou_metric: 0.6973 - loss: 0.3945
# Epoch 51: val_dice_coef improved from 0.76570 to 0.76971, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v1.keras
#
# Epoch 51: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v1.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 72ms/step - accuracy: 0.9417 - dice_coef: 0.7649 - iou_metric: 0.6813 - loss: 0.4140 - val_accuracy: 0.9425 - val_dice_coef: 0.7697 - val_iou_metric: 0.6961 - val_loss: 0.3993 - learning_rate: 0.0010
# Epoch 52/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9379 - dice_coef: 0.7541 - iou_metric: 0.6632 - loss: 0.4270
# Epoch 52: val_dice_coef did not improve from 0.76971
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 13s 65ms/step - accuracy: 0.9402 - dice_coef: 0.7592 - iou_metric: 0.6738 - loss: 0.4218 - val_accuracy: 0.9169 - val_dice_coef: 0.6561 - val_iou_metric: 0.5607 - val_loss: 0.5780 - learning_rate: 0.0010
# Epoch 53/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9412 - dice_coef: 0.7663 - iou_metric: 0.6847 - loss: 0.4110
# Epoch 53: val_dice_coef did not improve from 0.76971
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 13s 66ms/step - accuracy: 0.9426 - dice_coef: 0.7699 - iou_metric: 0.6873 - loss: 0.4030 - val_accuracy: 0.9418 - val_dice_coef: 0.7645 - val_iou_metric: 0.6868 - val_loss: 0.4092 - learning_rate: 0.0010
# Epoch 54/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9445 - dice_coef: 0.7861 - iou_metric: 0.7068 - loss: 0.3814
# Epoch 54: val_dice_coef did not improve from 0.76971
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 13s 65ms/step - accuracy: 0.9442 - dice_coef: 0.7796 - iou_metric: 0.6951 - loss: 0.3922 - val_accuracy: 0.9260 - val_dice_coef: 0.6860 - val_iou_metric: 0.5749 - val_loss: 0.5484 - learning_rate: 0.0010
# Epoch 55/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9448 - dice_coef: 0.7716 - iou_metric: 0.6923 - loss: 0.3962
# Epoch 55: val_dice_coef did not improve from 0.76971
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 13s 65ms/step - accuracy: 0.9434 - dice_coef: 0.7722 - iou_metric: 0.6915 - loss: 0.4006 - val_accuracy: 0.9350 - val_dice_coef: 0.7664 - val_iou_metric: 0.6768 - val_loss: 0.4171 - learning_rate: 0.0010
# Epoch 56/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9404 - dice_coef: 0.7753 - iou_metric: 0.6919 - loss: 0.3991
# Epoch 56: val_dice_coef improved from 0.76971 to 0.77378, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v1.keras
#
# Epoch 56: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v1.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 15s 75ms/step - accuracy: 0.9425 - dice_coef: 0.7686 - iou_metric: 0.6871 - loss: 0.4033 - val_accuracy: 0.9419 - val_dice_coef: 0.7738 - val_iou_metric: 0.6883 - val_loss: 0.4082 - learning_rate: 0.0010
# Epoch 57/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9464 - dice_coef: 0.7883 - iou_metric: 0.7069 - loss: 0.3767
# Epoch 57: val_dice_coef did not improve from 0.77378
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 13s 66ms/step - accuracy: 0.9457 - dice_coef: 0.7852 - iou_metric: 0.7050 - loss: 0.3800 - val_accuracy: 0.9339 - val_dice_coef: 0.7212 - val_iou_metric: 0.6464 - val_loss: 0.4672 - learning_rate: 0.0010
# Epoch 58/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9435 - dice_coef: 0.7767 - iou_metric: 0.6940 - loss: 0.3973
# Epoch 58: val_dice_coef did not improve from 0.77378
#
# Epoch 58: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 13s 65ms/step - accuracy: 0.9444 - dice_coef: 0.7795 - iou_metric: 0.6967 - loss: 0.3912 - val_accuracy: 0.9363 - val_dice_coef: 0.7609 - val_iou_metric: 0.6755 - val_loss: 0.4152 - learning_rate: 0.0010
# Epoch 59/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9501 - dice_coef: 0.7964 - iou_metric: 0.7206 - loss: 0.3551
# Epoch 59: val_dice_coef did not improve from 0.77378
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 13s 65ms/step - accuracy: 0.9499 - dice_coef: 0.7975 - iou_metric: 0.7197 - loss: 0.3531 - val_accuracy: 0.9366 - val_dice_coef: 0.7608 - val_iou_metric: 0.6834 - val_loss: 0.4155 - learning_rate: 5.0000e-04
# Epoch 60/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.9560 - dice_coef: 0.8215 - iou_metric: 0.7545 - loss: 0.3111
# Epoch 60: val_dice_coef improved from 0.77378 to 0.79547, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v1.keras
#
# Epoch 60: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v1.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 17s 83ms/step - accuracy: 0.9531 - dice_coef: 0.8122 - iou_metric: 0.7369 - loss: 0.3329 - val_accuracy: 0.9507 - val_dice_coef: 0.7955 - val_iou_metric: 0.7332 - val_loss: 0.3532 - learning_rate: 5.0000e-04
# Epoch 61/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9550 - dice_coef: 0.8122 - iou_metric: 0.7370 - loss: 0.3248
# Epoch 61: val_dice_coef did not improve from 0.79547
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 68ms/step - accuracy: 0.9511 - dice_coef: 0.8019 - iou_metric: 0.7248 - loss: 0.3502 - val_accuracy: 0.9405 - val_dice_coef: 0.7852 - val_iou_metric: 0.7115 - val_loss: 0.3887 - learning_rate: 5.0000e-04
# Epoch 62/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9543 - dice_coef: 0.8155 - iou_metric: 0.7398 - loss: 0.3258
# Epoch 62: val_dice_coef improved from 0.79547 to 0.79935, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v1.keras
#
# Epoch 62: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v1.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 16s 79ms/step - accuracy: 0.9540 - dice_coef: 0.8137 - iou_metric: 0.7406 - loss: 0.3283 - val_accuracy: 0.9519 - val_dice_coef: 0.7993 - val_iou_metric: 0.7409 - val_loss: 0.3476 - learning_rate: 5.0000e-04
# Epoch 63/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9579 - dice_coef: 0.8280 - iou_metric: 0.7587 - loss: 0.2993
# Epoch 63: val_dice_coef did not improve from 0.79935
# ...
# Epoch 67/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.9592 - dice_coef: 0.8357 - iou_metric: 0.7656 - loss: 0.2912
# Epoch 67: val_dice_coef did not improve from 0.81005
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 69ms/step - accuracy: 0.9560 - dice_coef: 0.8265 - iou_metric: 0.7535 - loss: 0.3123 - val_accuracy: 0.9468 - val_dice_coef: 0.7916 - val_iou_metric: 0.7122 - val_loss: 0.3722 - learning_rate: 5.0000e-04
# Epoch 68/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9561 - dice_coef: 0.8230 - iou_metric: 0.7511 - loss: 0.3108
# Epoch 68: val_dice_coef improved from 0.81005 to 0.81911, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v1.keras
#
# Epoch 68: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v1.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 15s 77ms/step - accuracy: 0.9557 - dice_coef: 0.8226 - iou_metric: 0.7491 - loss: 0.3119 - val_accuracy: 0.9532 - val_dice_coef: 0.8191 - val_iou_metric: 0.7437 - val_loss: 0.3409 - learning_rate: 5.0000e-04
# Epoch 69/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9557 - dice_coef: 0.8270 - iou_metric: 0.7541 - loss: 0.3126
# Epoch 69: val_dice_coef did not improve from 0.81911
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 68ms/step - accuracy: 0.9554 - dice_coef: 0.8267 - iou_metric: 0.7538 - loss: 0.3120 - val_accuracy: 0.9482 - val_dice_coef: 0.8002 - val_iou_metric: 0.7208 - val_loss: 0.3630 - learning_rate: 5.0000e-04
# Epoch 70/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9568 - dice_coef: 0.8223 - iou_metric: 0.7472 - loss: 0.3109
# Epoch 70: val_dice_coef did not improve from 0.81911
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 68ms/step - accuracy: 0.9557 - dice_coef: 0.8227 - iou_metric: 0.7493 - loss: 0.3155 - val_accuracy: 0.9507 - val_dice_coef: 0.8023 - val_iou_metric: 0.7344 - val_loss: 0.3485 - learning_rate: 5.0000e-04
# Epoch 71/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9551 - dice_coef: 0.8287 - iou_metric: 0.7577 - loss: 0.3078
# Epoch 71: val_dice_coef did not improve from 0.81911
#
# Epoch 71: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 13s 67ms/step - accuracy: 0.9546 - dice_coef: 0.8202 - iou_metric: 0.7465 - loss: 0.3203 - val_accuracy: 0.9448 - val_dice_coef: 0.7973 - val_iou_metric: 0.7062 - val_loss: 0.3922 - learning_rate: 5.0000e-04
# Epoch 72/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9578 - dice_coef: 0.8406 - iou_metric: 0.7735 - loss: 0.2901
# Epoch 72: val_dice_coef did not improve from 0.81911
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 68ms/step - accuracy: 0.9578 - dice_coef: 0.8332 - iou_metric: 0.7629 - loss: 0.2958 - val_accuracy: 0.9543 - val_dice_coef: 0.8156 - val_iou_metric: 0.7517 - val_loss: 0.3202 - learning_rate: 2.5000e-04
# Epoch 73/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9594 - dice_coef: 0.8292 - iou_metric: 0.7585 - loss: 0.2999
# Epoch 73: val_dice_coef did not improve from 0.81911
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 67ms/step - accuracy: 0.9595 - dice_coef: 0.8335 - iou_metric: 0.7636 - loss: 0.2918 - val_accuracy: 0.9555 - val_dice_coef: 0.8182 - val_iou_metric: 0.7480 - val_loss: 0.3151 - learning_rate: 2.5000e-04
# Epoch 74/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9609 - dice_coef: 0.8443 - iou_metric: 0.7783 - loss: 0.2741
# Epoch 74: val_dice_coef improved from 0.81911 to 0.82928, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v1.keras
#
# Epoch 74: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v1.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 15s 75ms/step - accuracy: 0.9610 - dice_coef: 0.8400 - iou_metric: 0.7710 - loss: 0.2817 - val_accuracy: 0.9565 - val_dice_coef: 0.8293 - val_iou_metric: 0.7582 - val_loss: 0.3050 - learning_rate: 2.5000e-04
# Epoch 75/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9610 - dice_coef: 0.8462 - iou_metric: 0.7780 - loss: 0.2755
# Epoch 75: val_dice_coef did not improve from 0.82928
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 13s 67ms/step - accuracy: 0.9600 - dice_coef: 0.8417 - iou_metric: 0.7725 - loss: 0.2835 - val_accuracy: 0.9534 - val_dice_coef: 0.8058 - val_iou_metric: 0.7385 - val_loss: 0.3381 - learning_rate: 2.5000e-04
# Epoch 76/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9608 - dice_coef: 0.8448 - iou_metric: 0.7768 - loss: 0.2757
# Epoch 76: val_dice_coef did not improve from 0.82928
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 13s 66ms/step - accuracy: 0.9607 - dice_coef: 0.8446 - iou_metric: 0.7761 - loss: 0.2764 - val_accuracy: 0.9547 - val_dice_coef: 0.8229 - val_iou_metric: 0.7496 - val_loss: 0.3233 - learning_rate: 2.5000e-04
# Epoch 77/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9648 - dice_coef: 0.8504 - iou_metric: 0.7865 - loss: 0.2589
# Epoch 77: val_dice_coef did not improve from 0.82928
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 68ms/step - accuracy: 0.9618 - dice_coef: 0.8450 - iou_metric: 0.7779 - loss: 0.2739 - val_accuracy: 0.9535 - val_dice_coef: 0.8204 - val_iou_metric: 0.7521 - val_loss: 0.3182 - learning_rate: 2.5000e-04
# Epoch 78/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9634 - dice_coef: 0.8530 - iou_metric: 0.7905 - loss: 0.2583
# Epoch 78: val_dice_coef did not improve from 0.82928
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 13s 67ms/step - accuracy: 0.9626 - dice_coef: 0.8483 - iou_metric: 0.7827 - loss: 0.2693 - val_accuracy: 0.9572 - val_dice_coef: 0.8288 - val_iou_metric: 0.7647 - val_loss: 0.3058 - learning_rate: 2.5000e-04
# Epoch 79/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9605 - dice_coef: 0.8410 - iou_metric: 0.7723 - loss: 0.2795
# Epoch 79: val_dice_coef did not improve from 0.82928
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 12s 60ms/step - accuracy: 0.9627 - dice_coef: 0.8476 - iou_metric: 0.7810 - loss: 0.2662 - val_accuracy: 0.9555 - val_dice_coef: 0.8287 - val_iou_metric: 0.7589 - val_loss: 0.3121 - learning_rate: 2.5000e-04
# Epoch 80/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9613 - dice_coef: 0.8387 - iou_metric: 0.7652 - loss: 0.2803
# Epoch 80: val_dice_coef did not improve from 0.82928
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 70ms/step - accuracy: 0.9610 - dice_coef: 0.8434 - iou_metric: 0.7731 - loss: 0.2785 - val_accuracy: 0.9535 - val_dice_coef: 0.8197 - val_iou_metric: 0.7432 - val_loss: 0.3263 - learning_rate: 2.5000e-04
# Epoch 81/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9659 - dice_coef: 0.8518 - iou_metric: 0.7836 - loss: 0.2559
# Epoch 81: val_dice_coef did not improve from 0.82928
#
# Epoch 81: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 69ms/step - accuracy: 0.9625 - dice_coef: 0.8494 - iou_metric: 0.7812 - loss: 0.2686 - val_accuracy: 0.9423 - val_dice_coef: 0.7810 - val_iou_metric: 0.7020 - val_loss: 0.3889 - learning_rate: 2.5000e-04
# Epoch 82/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9600 - dice_coef: 0.8423 - iou_metric: 0.7740 - loss: 0.2805
# Epoch 82: val_dice_coef did not improve from 0.82928
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 69ms/step - accuracy: 0.9632 - dice_coef: 0.8531 - iou_metric: 0.7890 - loss: 0.2596 - val_accuracy: 0.9559 - val_dice_coef: 0.8289 - val_iou_metric: 0.7572 - val_loss: 0.3100 - learning_rate: 1.2500e-04
# Epoch 83/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9633 - dice_coef: 0.8533 - iou_metric: 0.7903 - loss: 0.2626
# Epoch 83: val_dice_coef improved from 0.82928 to 0.83363, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v1.keras
#
# Epoch 83: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v1.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 15s 76ms/step - accuracy: 0.9641 - dice_coef: 0.8552 - iou_metric: 0.7923 - loss: 0.2588 - val_accuracy: 0.9563 - val_dice_coef: 0.8336 - val_iou_metric: 0.7599 - val_loss: 0.3037 - learning_rate: 1.2500e-04
# Epoch 84/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.9609 - dice_coef: 0.8457 - iou_metric: 0.7762 - loss: 0.2758
# Epoch 84: val_dice_coef did not improve from 0.83363
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 70ms/step - accuracy: 0.9632 - dice_coef: 0.8503 - iou_metric: 0.7824 - loss: 0.2654 - val_accuracy: 0.9560 - val_dice_coef: 0.8318 - val_iou_metric: 0.7588 - val_loss: 0.3037 - learning_rate: 1.2500e-04
# Epoch 85/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9657 - dice_coef: 0.8569 - iou_metric: 0.7906 - loss: 0.2533
# Epoch 85: val_dice_coef did not improve from 0.83363
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 13s 64ms/step - accuracy: 0.9641 - dice_coef: 0.8579 - iou_metric: 0.7940 - loss: 0.2543 - val_accuracy: 0.9558 - val_dice_coef: 0.8314 - val_iou_metric: 0.7607 - val_loss: 0.3023 - learning_rate: 1.2500e-04
# Epoch 86/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9649 - dice_coef: 0.8603 - iou_metric: 0.7967 - loss: 0.2515
# Epoch 86: val_dice_coef did not improve from 0.83363
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 13s 65ms/step - accuracy: 0.9634 - dice_coef: 0.8552 - iou_metric: 0.7886 - loss: 0.2603 - val_accuracy: 0.9548 - val_dice_coef: 0.8294 - val_iou_metric: 0.7479 - val_loss: 0.3179 - learning_rate: 1.2500e-04
# Epoch 87/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9633 - dice_coef: 0.8545 - iou_metric: 0.7906 - loss: 0.2596
# Epoch 87: val_dice_coef did not improve from 0.83363
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 13s 66ms/step - accuracy: 0.9633 - dice_coef: 0.8546 - iou_metric: 0.7905 - loss: 0.2585 - val_accuracy: 0.9565 - val_dice_coef: 0.8264 - val_iou_metric: 0.7573 - val_loss: 0.3077 - learning_rate: 1.2500e-04
# Epoch 88/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9682 - dice_coef: 0.8676 - iou_metric: 0.8097 - loss: 0.2339
# Epoch 88: val_dice_coef improved from 0.83363 to 0.83884, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v1.keras
#
# Epoch 88: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v1.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 15s 75ms/step - accuracy: 0.9652 - dice_coef: 0.8612 - iou_metric: 0.7988 - loss: 0.2491 - val_accuracy: 0.9558 - val_dice_coef: 0.8388 - val_iou_metric: 0.7668 - val_loss: 0.2991 - learning_rate: 1.2500e-04
# Epoch 89/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9669 - dice_coef: 0.8599 - iou_metric: 0.7952 - loss: 0.2417
# Epoch 89: val_dice_coef did not improve from 0.83884
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 13s 65ms/step - accuracy: 0.9653 - dice_coef: 0.8600 - iou_metric: 0.7967 - loss: 0.2481 - val_accuracy: 0.9557 - val_dice_coef: 0.8346 - val_iou_metric: 0.7613 - val_loss: 0.3044 - learning_rate: 1.2500e-04
# Epoch 90/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9626 - dice_coef: 0.8556 - iou_metric: 0.7877 - loss: 0.2567
# Epoch 90: val_dice_coef did not improve from 0.83884
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 13s 65ms/step - accuracy: 0.9647 - dice_coef: 0.8571 - iou_metric: 0.7913 - loss: 0.2513 - val_accuracy: 0.9550 - val_dice_coef: 0.8265 - val_iou_metric: 0.7504 - val_loss: 0.3131 - learning_rate: 1.2500e-04
# Epoch 91/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9629 - dice_coef: 0.8507 - iou_metric: 0.7793 - loss: 0.2680
# Epoch 91: val_dice_coef did not improve from 0.83884
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 69ms/step - accuracy: 0.9659 - dice_coef: 0.8629 - iou_metric: 0.7992 - loss: 0.2434 - val_accuracy: 0.9562 - val_dice_coef: 0.8382 - val_iou_metric: 0.7623 - val_loss: 0.3020 - learning_rate: 1.2500e-04
# Epoch 92/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.9655 - dice_coef: 0.8726 - iou_metric: 0.8145 - loss: 0.2371
# Epoch 92: val_dice_coef did not improve from 0.83884
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 69ms/step - accuracy: 0.9658 - dice_coef: 0.8644 - iou_metric: 0.8039 - loss: 0.2434 - val_accuracy: 0.9570 - val_dice_coef: 0.8387 - val_iou_metric: 0.7668 - val_loss: 0.3017 - learning_rate: 1.2500e-04
# Epoch 93/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9666 - dice_coef: 0.8578 - iou_metric: 0.7928 - loss: 0.2523
# Epoch 93: val_dice_coef did not improve from 0.83884
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 69ms/step - accuracy: 0.9653 - dice_coef: 0.8596 - iou_metric: 0.7946 - loss: 0.2498 - val_accuracy: 0.9572 - val_dice_coef: 0.8351 - val_iou_metric: 0.7641 - val_loss: 0.3001 - learning_rate: 1.2500e-04
# Epoch 94/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9677 - dice_coef: 0.8679 - iou_metric: 0.8098 - loss: 0.2335
# Epoch 94: val_dice_coef did not improve from 0.83884
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 70ms/step - accuracy: 0.9665 - dice_coef: 0.8648 - iou_metric: 0.8039 - loss: 0.2403 - val_accuracy: 0.9567 - val_dice_coef: 0.8317 - val_iou_metric: 0.7602 - val_loss: 0.3049 - learning_rate: 1.2500e-04
# Epoch 95/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9677 - dice_coef: 0.8672 - iou_metric: 0.8071 - loss: 0.2336
# Epoch 95: val_dice_coef did not improve from 0.83884
#
# Epoch 95: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 69ms/step - accuracy: 0.9670 - dice_coef: 0.8680 - iou_metric: 0.8062 - loss: 0.2355 - val_accuracy: 0.9565 - val_dice_coef: 0.8322 - val_iou_metric: 0.7554 - val_loss: 0.3058 - learning_rate: 1.2500e-04
# Epoch 96/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9662 - dice_coef: 0.8621 - iou_metric: 0.7981 - loss: 0.2445
# Epoch 96: val_dice_coef did not improve from 0.83884
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 67ms/step - accuracy: 0.9670 - dice_coef: 0.8646 - iou_metric: 0.8009 - loss: 0.2402 - val_accuracy: 0.9567 - val_dice_coef: 0.8357 - val_iou_metric: 0.7624 - val_loss: 0.3013 - learning_rate: 6.2500e-05
# Epoch 97/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.9646 - dice_coef: 0.8617 - iou_metric: 0.7964 - loss: 0.2450
# Epoch 97: val_dice_coef did not improve from 0.83884
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 70ms/step - accuracy: 0.9663 - dice_coef: 0.8676 - iou_metric: 0.8058 - loss: 0.2372 - val_accuracy: 0.9565 - val_dice_coef: 0.8316 - val_iou_metric: 0.7560 - val_loss: 0.3047 - learning_rate: 6.2500e-05
# Epoch 98/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9675 - dice_coef: 0.8722 - iou_metric: 0.8139 - loss: 0.2275
# Epoch 98: val_dice_coef improved from 0.83884 to 0.84091, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v1.keras
#
# Epoch 98: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/best_unet_v1.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 16s 81ms/step - accuracy: 0.9668 - dice_coef: 0.8659 - iou_metric: 0.8035 - loss: 0.2381 - val_accuracy: 0.9568 - val_dice_coef: 0.8409 - val_iou_metric: 0.7654 - val_loss: 0.2953 - learning_rate: 6.2500e-05
# Epoch 99/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9676 - dice_coef: 0.8666 - iou_metric: 0.8047 - loss: 0.2354
# Epoch 99: val_dice_coef did not improve from 0.84091
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 67ms/step - accuracy: 0.9669 - dice_coef: 0.8673 - iou_metric: 0.8044 - loss: 0.2372 - val_accuracy: 0.9556 - val_dice_coef: 0.8361 - val_iou_metric: 0.7620 - val_loss: 0.3007 - learning_rate: 6.2500e-05
# Epoch 100/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.9657 - dice_coef: 0.8614 - iou_metric: 0.8014 - loss: 0.2472
# Epoch 100: val_dice_coef did not improve from 0.84091
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 14s 69ms/step - accuracy: 0.9672 - dice_coef: 0.8649 - iou_metric: 0.8052 - loss: 0.2393 - val_accuracy: 0.9568 - val_dice_coef: 0.8409 - val_iou_metric: 0.7713 - val_loss: 0.2948 - learning_rate: 6.2500e-05
# Restoring model weights from the end of the best epoch: 98.
# ========== Training Complete ==========

# %%
    if images:
        test_and_display(unet, images[2])

# %%
if images:
    for i in range(0,3):
        test_and_display(unet, images[i])

# %%
import random

if images:
    for _ in range(3):  # run 3 times
        i = random.randint(1, 25)  # random integer between 1 and 25
        test_and_display(unet, images[i])
