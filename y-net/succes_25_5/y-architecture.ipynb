# %%
import os
import glob
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras import layers, models, Input, mixed_precision
from sklearn.model_selection import train_test_split
import cv2
print("library loaded successfully")
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1779787996.530991    6186 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
IMG_SIZE = 256  # Standardized input resolution for both phases
BATCH_SIZE = 4 # Batch size
EPOCHS_PHASE1 = 100  # Semantic Segmentation Focus, for Segmentation 
EPOCHS_PHASE2 = 100   # Segmentation-Based Classification Focus for classification Polyp and Non-Polyp

# %% [markdown]
# #### Declaring dataset path for segmentation and classification

# %%
# Directory and Artifact Paths
DATA_PATH = '/mnt/c/development/Thesis/PolypSegmentationBasedClassification/DataSets/PolypGen2021_MultiCenterData_v2'
POSITIVE_DIR = os.path.join(DATA_PATH, 'imagesAll_positive') # For Polyp classification
NEGATIVE_DIR = os.path.join(DATA_PATH, 'sequenceData/negativeOnly')  # For non polyp classification
MODEL_SAVE_PATH = "/mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_26_5_01.keras"

# %% [markdown]
# #### mixed_precision
# Activate mixed precision training for efficiency and memory optimization
# It is a performance optimization for GPU. It utilize half of the GPU Memory,
# increases the the model training speed 3 times without effecting on accuracy.
# mixed_float16, 16 bits helps to get speedy calculation when need, Flawless accuracy performed by 32-bits

# %%
mixed_precision.set_global_policy('mixed_float16')

# %% [markdown]
# #### Image Augmentation
# As we have limited datasources we have to augment images. If we train with limited datasets Model can memorize
# instead of learning which causes overfitting. An overfitted model cannot predict other image except training dataset. Even it cannot predict on validation dataset as well.The **overfitting occurs** when The Training Loss going down but the validation loss increases at a time

# %%
def augment(img, mask):
    """Applies shape-preserving geometric and radiometric transformations."""
    if tf.random.uniform(()) > 0.5:
        img = tf.image.flip_left_right(img)
        mask = tf.image.flip_left_right(mask)
    if tf.random.uniform(()) > 0.5:
        img = tf.image.flip_up_down(img)
        mask = tf.image.flip_up_down(mask)
    
    img = tf.image.random_brightness(img, max_delta=0.15)
    img = tf.image.random_contrast(img, lower=0.85, upper=1.15)
    img = tf.clip_by_value(img, 0.0, 1.0)
    
    img.set_shape([IMG_SIZE, IMG_SIZE, 3])
    mask.set_shape([IMG_SIZE, IMG_SIZE, 1])
    return img, mask

# %% [markdown]
# #### Data / Image pre-processing pipeline for segmentation
# This functions primary task is to load raw images corresponding its mask image from the file storage, clean them up, standardizing the image size finally convert them into clean tensor ( or a 2D matrix) suitable for the model to be trained.

# %%
def process_path_segmentation(img_path, mask_path):
    """
    Advanced Preprocessing Wrapper for Dataset B.
    Applies CLAHE and Mild Sharpening via OpenCV with strict EagerTensor handles.
    """
    def _read_and_process(img_p, mask_p):
        img_p_str = img_p.numpy().decode('utf-8') if hasattr(img_p, 'numpy') else img_p.decode('utf-8')
        mask_p_str = mask_p.numpy().decode('utf-8') if hasattr(mask_p, 'numpy') else mask_p.decode('utf-8')
        
        img = cv2.imread(img_p_str)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        img = cv2.resize(img, (IMG_SIZE, IMG_SIZE))
        
        mask = cv2.imread(mask_p_str, cv2.IMREAD_GRAYSCALE)
        mask = cv2.resize(mask, (IMG_SIZE, IMG_SIZE))
        

        lab = cv2.cvtColor(img, cv2.COLOR_RGB2LAB)
        l_channel, a_channel, b_channel = cv2.split(lab)
        
        clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
        cl = clahe.apply(l_channel)
        
        limg = cv2.merge((cl, a_channel, b_channel))
        enhanced_img = cv2.cvtColor(limg, cv2.COLOR_LAB2RGB)
        

        gaussian_blur = cv2.GaussianBlur(enhanced_img, (5, 5), 1.0)
        sharpened = cv2.addWeighted(enhanced_img, 1.5, gaussian_blur, -0.5, 0)
        
        normalized_img = sharpened / 255.0
        normalized_mask = mask / 255.0
        normalized_mask = np.where(normalized_mask > 0.5, 1.0, 0.0)
        
        normalized_mask = np.expand_dims(normalized_mask, axis=-1)
        
        return normalized_img.astype(np.float32), normalized_mask.astype(np.float32)


    [img_tensor, mask_tensor] = tf.py_function(
        _read_and_process, 
        [img_path, mask_path], 
        [tf.float32, tf.float32]
    )
    

    img_tensor.set_shape([IMG_SIZE, IMG_SIZE, 3])
    mask_tensor.set_shape([IMG_SIZE, IMG_SIZE, 1])
    
    return img_tensor, mask_tensor

# %% [markdown]
# #### Data / Image Pre-processing for classification
# getting the image and label wheather it is polyp or not, also converting the image for standardization

# %%
def process_path_classification(img_path, label):
    """Preprocesses input tensors and categorical targets for Dataset A."""
    img = tf.io.read_file(img_path)
    img = tf.image.decode_image(img, channels=3, expand_animations=False)
    img = tf.image.resize(img, [IMG_SIZE, IMG_SIZE])
    img = tf.cast(img, tf.float32) / 255.0
    img.set_shape([IMG_SIZE, IMG_SIZE, 3])
    return img, label

# %% [markdown]
# #### Load Segmentation data path
# Instead of loading the actual images into memory, it loads the images path dynamically,
# The image is only collected for segmentation training, it it's exact mask match in the dataset directory.

# %%
def load_segmentation_paths(base_path):
    """Extracts paired image and mask absolute paths from multi-center repositories."""
    all_images, all_masks = [], []
    for i in range(1, 7):
        center_id = f"C{i}"
        img_dir = os.path.join(base_path, f"data_{center_id}", f"images_{center_id}")
        mask_dir = os.path.join(base_path, f"data_{center_id}", f"masks_{center_id}")
        if os.path.exists(img_dir) and os.path.exists(mask_dir):
            img_paths = (glob.glob(os.path.join(img_dir, "*.jpg")) + glob.glob(os.path.join(img_dir, "*.JPG")) +
                         glob.glob(os.path.join(img_dir, "*.png")) + glob.glob(os.path.join(img_dir, "*.jpeg")))
            for img_p in img_paths:
                filename = os.path.basename(img_p)
                name_without_ext, ext = os.path.splitext(filename)
                expected_mask_name = f"{name_without_ext}_mask{ext}"
                mask_p = os.path.join(mask_dir, expected_mask_name)
                if os.path.exists(mask_p):
                    all_images.append(img_p)
                    all_masks.append(mask_p)
    return all_images, all_masks

# %% [markdown]
# #### Load Classification data path
# this function labels the images into two classes -0 for Negative image or Non-Polyp and 1 for Positive image or Polyp
# **Note:** When your dataset has 90% negative and 10% positive, highly imbalance dataset it creates a cheat code to get high accuracy. thus it causes a Accuracy Paradox, and for this reason it misclassify the image.

# %%
def load_classification_paths():
    """Compiles absolute paths for global positive and artifact-heavy negative sequences."""
    valid_exts = ('*.png', '*.jpg', '*.jpeg', '*.bmp', '*.tif', '*.PNG', '*.JPG', '*.JPEG')
    pos_files, neg_files = [], []
    for ext in valid_exts:
        pos_files.extend(glob.glob(os.path.join(POSITIVE_DIR, "**", ext), recursive=True))
    for i in range(1, 14):
        target_folder = os.path.join(NEGATIVE_DIR, f"seq{i}_neg")
        if os.path.exists(target_folder):
            for ext in valid_exts:
                neg_files.extend(glob.glob(os.path.join(target_folder, "**", ext), recursive=True))
    pos_files = [f for f in pos_files if os.path.isfile(f)]
    neg_files = [f for f in neg_files if os.path.isfile(f)]
    
    file_paths = pos_files + neg_files
    labels = [1.0] * len(pos_files) + [0.0] * len(neg_files)
    return np.array(file_paths), np.array(labels, dtype=np.float32)

# %% [markdown]
# #### Squeeze-and-Excitation Block
# To get channel-wise attention it is very much powerful for CNN. An SE_Block dynamically learns which channel/features are the most important for a specific image and scale up the specific features with dimming down the noise with irrelevent ones.
# Standard CNN only looks at the small neighbour of the pixel at a time, But GlobalAveragePooling2D gets the average value of pixels.  from the total height and weight of a channel.
# __How Squeeze works:__
# We can consider an image with a 3D feature map, as it has three distinct geometric dimentions: Height, Width and Depth (Channels).
# Image Height (H) : Vertical Pixels (256 pixels height)
# Image Width (W) : Horizontal Pixels (256 pixels width)
# Channels (C): The depth layer, this is 3 (RGB)
# So an image has a 3D block dimentions = 256x256x3.
# When an image passes through convolutional layers, the spatial dimentions (H and W) usually shrink, but the number of channels (C) expands dramatically, Deep in your network you might have a feature map of size 16x16x512 that is a literal 3D cube made of 131,072 numarial values.
# ** The Sqeeze Turns 3D into 1D** ```layers.GlobalAveragePooling2D()(input_tensor)``` this sentence takes the 3D Cube and flattens its spatial dimentions.
#
# ```sh
# 3D CUBE[16x16x512] -----Global Average Pooling------> 1D vector [512]
#
# Before Squeeze (3D Cube):
#        _______
#       /      /|
#      /______/ |  <- 512 separate 16x16 slices stacked deep
#     |       | |
#     |_______|/
#   16x16 spatial grid
#
# After Squeeze (1D Array/Vector):
#     [ 0.78,  0.12,  0.91,  0.03, ... , 0.55 ]  <- Exactly 512 numbers long
# ```
# __How Excitation Works:__
# Excitation works with 3 steps.
# 1. (512-->32) Make the flatten array smaller from 512 to 32 by removing the noices and connecting the relation between hidden relations.
# 2. Employee ReLU filter: negative or week features are converted to 0
# 3. (32-->512) Revert the process.

# %%
def se_block(input_tensor, ratio=16):
    """Channel-wise Squeeze-and-Excitation Attention Layer."""
    channels = input_tensor.shape[-1]
    squeeze = layers.GlobalAveragePooling2D()(input_tensor)
    excitation = layers.Dense(channels // ratio, activation='relu', use_bias=False)(squeeze)
    excitation = layers.Dense(channels, activation='sigmoid', use_bias=False)(excitation)
    excitation = layers.Reshape((1, 1, channels))(excitation)
    return layers.multiply([input_tensor, excitation])

# %% [markdown]
# #### depthwise_separable_conv_block
# Instead of using Conv2D block, we integrated Depthwise Separable for optimizing the operation.

# %%
def depthwise_seperable_conv_block(x, filters, dropout_rate=0.0, name_prefix=""):
    """Multi-Scale Parallel Kernels (3x3, 5x5, 7x7, 1x1) with Depthwise Separable Convolutions."""
    f4 = filters // 4
    b3 = layers.SeparableConv2D(f4, 3, padding='same', use_bias=False, name=f"{name_prefix}_3x3")(x)
    b3 = layers.BatchNormalization()(b3); b3 = layers.Activation('relu')(b3)
    
    b5 = layers.SeparableConv2D(f4, 5, padding='same', use_bias=False, name=f"{name_prefix}_5x5")(x)
    b5 = layers.BatchNormalization()(b5); b5 = layers.Activation('relu')(b5)
    
    b7 = layers.SeparableConv2D(f4, 7, padding='same', use_bias=False, name=f"{name_prefix}_7x7")(x)
    b7 = layers.BatchNormalization()(b7); b7 = layers.Activation('relu')(b7)
    
    b1 = layers.SeparableConv2D(f4, 1, padding='same', use_bias=False, name=f"{name_prefix}_1x1")(x)
    b1 = layers.BatchNormalization()(b1); b1 = layers.Activation('relu')(b1)
    
    merged = layers.Concatenate(name=f"{name_prefix}_concat")([b3, b5, b7, b1])
    x_se = se_block(merged, ratio=16) 
    
    if x.shape[-1] == filters:
        x_se = layers.add([x, x_se], name=f"{name_prefix}_residual")
    if dropout_rate > 0:
        x_se = layers.SpatialDropout2D(dropout_rate, name=f"{name_prefix}_dropout")(x_se)
    return x_se

# %% [markdown]
# #### Pearson Corelation Coefficient
# As Global Average Pooling returns 1D feature vector, the relation can be found by employing PCC on this feature.
# The first and formost condition is to standardize the feature before employing PCC on 1D feature vector.

# %%
@tf.keras.utils.register_keras_serializable()
class KerasPCCLayer(layers.Layer):
    """Natively computes spatial Pearson Correlation Coefficients within the network graph."""
    def __init__(self, **kwargs):
        super(KerasPCCLayer, self).__init__(**kwargs)

    def call(self, inputs):
        # We used epsilon sothat standard deviation value cannot be zero, otherwise code will crash
        epsilon = 1e-8
        # finds the average standard deviaiton
        mean = tf.reduce_mean(inputs, axis=-1, keepdims=True)
        std = tf.math.reduce_std(inputs, axis=-1, keepdims=True) + epsilon
        # data normalization or (Z-Score)
        norm_inputs = (inputs - mean) / std
        pcc_matrix = tf.matmul(tf.expand_dims(norm_inputs, -1), tf.expand_dims(norm_inputs, 1))
        return layers.Flatten()(pcc_matrix)

# %% [markdown]
# #### Build Unified Segmentation based Model
# A multi-task Y-Net model building for both segmentation and classification for Colorectal Polyp.

# %%
def build_unified_segmentation_based_model(input_shape=(256, 256, 3)):
    """
    Constructs a dual-headed multi-task Y-Net architecture.
    Shares a deeply regularized, multi-scale latent space to simultaneously
    perform semantic image segmentation and unified scene classification.
    """
    # [Input Layer]: Defines the input tensor shape holding the raw 3-channel RGB medical images.
    inputs = Input(shape=input_shape, name="shared_input_image")

    # ── Shared Custom Multi-Scale Encoder ─────────────────────────────────────
    # Extracts multi-scale localized features down the spatial hierarchy while compressing parameters.
    
    # [Enc Block 1]: Processes raw input into 32 multi-scale feature channels. Output dim: (256, 256, 32)
    c1 = depthwise_seperable_conv_block(inputs, 32, name_prefix="enc_c1")
    # [Max Pooling 1]: Downsamples spatial dimensions by a factor of 2 via neighborhood max selection. Dim: (128, 128, 32)
    p1 = layers.MaxPooling2D(2, name="enc_p1")(c1)

    # [Enc Block 2]: Extracts deeper geometric abstractions into 64 semantic channels. Output dim: (128, 128, 64)
    c2 = depthwise_seperable_conv_block(p1, 64, name_prefix="enc_c2")
    # [Max Pooling 2]: Downsamples spatial dimensions further to compress representation. Dim: (64, 64, 64)
    p2 = layers.MaxPooling2D(2, name="enc_p2")(c2)

    # [Enc Block 3]: Scales representation to 128 channels; introduces 10% spatial dropout to avoid co-adaptation. Dim: (64, 64, 128)
    c3 = depthwise_seperable_conv_block(p2, 128, dropout_rate=0.1, name_prefix="enc_c3")
    # [Max Pooling 3]: Reduces resolution further, forcing the model to learn translation invariance. Dim: (32, 32, 128)
    p3 = layers.MaxPooling2D(2, name="enc_p3")(c3)

    # [Enc Block 4]: Captures high-level contextual abstracts across 256 channels with 20% spatial dropout. Dim: (32, 32, 256)
    c4 = depthwise_seperable_conv_block(p3, 256, dropout_rate=0.2, name_prefix="enc_c4")
    # [Max Pooling 4]: Compresses spatial grid to its lowest native encoder resolution. Dim: (16, 16, 256)
    p4 = layers.MaxPooling2D(2, name="enc_p4")(c4)
    
    # ── Shared Representation Latent Bottleneck ───────────────────────────────
    # The lowest spatial resolution holding the densest and most global abstract features.
    
    # [Shared Bottleneck]: Maps the compressed grid into a highly dense 512-channel latent feature space. Dim: (16, 16, 512)
    b = depthwise_seperable_conv_block(p4, 512, dropout_rate=0.3, name_prefix="shared_bottleneck")

    # ── Output Branch A: Semantic Segmentation Decoder ────────────────────────
    # Reconstructs spatial resolution progressively, using skip connections to retain fine edge details.
    
    # [Upsampling 4]: Uses learned transpose convolution filters to upscale the latent grid. Dim: (32, 32, 256)
    u4 = layers.Conv2DTranspose(256, 2, strides=2, padding='same', name="dec_u4")(b)
    # [Skip Connection 4]: Concatenates low-level encoder features (c4) along the channel axis. Total channels: 256 + 256 = 512
    u4 = layers.concatenate([u4, c4], name="dec_concat_4")
    # [Dec Block 5]: Regularizes concatenated representation back to 256 optimized multi-scale features. Dim: (32, 32, 256)
    c5 = depthwise_seperable_conv_block(u4, 256, dropout_rate=0.2, name_prefix="dec_c5")

    # [Upsampling 3]: Expands spatial dimensions by a factor of 2 using fractionally strided convolutions. Dim: (64, 64, 128)
    u3 = layers.Conv2DTranspose(128, 2, strides=2, padding='same', name="dec_u3")(c5)
    # [Skip Connection 3]: Merges encoder's mid-level spatial structural details (c3). Total channels: 128 + 128 = 256
    u3 = layers.concatenate([u3, c3], name="dec_concat_3")
    # [Dec Block 6]: Consolidates features and applies 10% dropout to eliminate localization noise. Dim: (64, 64, 128)
    c6 = depthwise_seperable_conv_block(u3, 128, dropout_rate=0.1, name_prefix="dec_c6")

    # [Upsampling 2]: Inverts the pooling operation of the encoder stage p2. Output dim: (128, 128, 64)
    u2 = layers.Conv2DTranspose(64, 2, strides=2, padding='same', name="dec_u2")(c6)
    # [Skip Connection 2]: Re-introduces high-resolution textures directly from encoder block c2. Total channels: 64 + 64 = 128
    u2 = layers.concatenate([u2, c2], name="dec_concat_2")
    # [Dec Block 7]: Harmonizes concatenated maps into 64 optimized spatial-channel streams. Dim: (128, 128, 64)
    c7 = depthwise_seperable_conv_block(u2, 64, name_prefix="dec_c7")

    # [Upsampling 1]: Restores feature maps back to the original input spatial size. Output dim: (256, 256, 32)
    u1 = layers.Conv2DTranspose(32, 2, strides=2, padding='same', name="dec_u1")(c7)
    # [Skip Connection 1]: Concat-links raw spatial coordinates and fine boundaries directly from c1. Total channels: 32 + 32 = 64
    u1 = layers.concatenate([u1, c1], name="dec_concat_1")
    # [Dec Block 8]: Refines final decoded features prior to pixel-level threshold mapping. Dim: (256, 256, 32)
    c8 = depthwise_seperable_conv_block(u1, 32, name_prefix="dec_c8")

    # [Segmentation Mask Output]: Maps 32 channels to a 1-channel binary pixel map via a 1x1 Conv with Sigmoid. Dim: (256, 256, 1)
    segmentation_output = layers.Conv2D(1, 1, activation='sigmoid', dtype='float32', name='seg_output')(c8)

    # ── Output Branch B: Segmentation-Guided Classification Head ──────────────
    # Re-purposes the rich latent space to predict global clinical states (e.g., normal vs abnormal).
    
    # [Classification CNN]: Performs light 3x3 depthwise separable convolution to filter classification cues. Dim: (16, 16, 128)
    pd_cnn = layers.SeparableConv2D(32, (3, 3), padding='same', activation='relu', name="clf_pd_cnn")(b)
    # [Max Pooling]: Downsamples classification maps spatially to distill localized signals. Output dim: (8, 8, 128)
    p_pool = layers.MaxPooling2D((2, 2), name="clf_maxpool")(pd_cnn)
    
    # [Global Average Pooling (GAP)]: Collapses spatial dimensions (8x8) into a single 128-dimensional global vector.
    flat_features = layers.GlobalAveragePooling2D(name="clf_gap")(p_pool)
    # [Keras PCC Layer]: Computes an all-to-all Pearson Correlation Matrix tracking linear statistical dependency between features.
    pcc_features = KerasPCCLayer(name="clf_pcc_layer")(flat_features)
    # [Z-Score Normalization]: Shifts feature distribution to a mean of 0 and variance of 1 to stabilize dense convergence.
    standardized = layers.BatchNormalization(name="clf_zscore_bn")(pcc_features)
    
    # [Fully Connected Dense]: Learns non-linear inter-feature correlation states over 64 hidden nodes.
    d1 = layers.Dense(64, activation='relu', name="clf_dense1")(standardized)
    # [Dropout]: Randomly zeros out 30% of connections during training iterations to deter neural memorization.
    d1 = layers.Dropout(0.3, name="clf_dropout")(d1)
    # [Classification Score Output]: Yields a singular scalar value (0 to 1) indicating global disease probability.
    classification_output = layers.Dense(1, activation='sigmoid', dtype='float32', name='clf_output')(d1)

    # [Model Compilation Graph]: Maps the input node to both parallel output tensors, finalizing the multi-task network.
    return models.Model(inputs=inputs, outputs=[segmentation_output, classification_output], name="Thesis_Unified_YNet")

# %% [markdown]
# #### Mathematical Criteria and Performance Metrics

# %% [markdown]
# #### Dice Coefficient
# The most popular performance matrix for segmentation. the more close to 100% means the better performance.
# Excellent dice Coef score between 0.8 to 0.9
# Good Score 0.70 to 0.80

# %%
def dice_coef(y_true, y_pred, smooth=1.0):
    y_true_f = tf.cast(tf.reshape(y_true, [-1]), tf.float32)
    y_pred_f = tf.cast(tf.reshape(y_pred, [-1]), tf.float32)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return (2.0 * intersection + smooth) / (tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + smooth)

# %%
def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

# %%
def bce_dice_loss(y_true, y_pred):
    bce = tf.reduce_mean(tf.keras.losses.binary_crossentropy(y_true, y_pred))
    return bce + dice_loss(y_true, y_pred)

# %%
def focal_tversky_loss(y_true, y_pred, alpha=0.7, beta=0.3, gamma=0.75):
    """
    Focal Tversky Loss for imbalanced medical image segmentation.
    alpha: controls penalty for False Negatives (FN) -> keeping it higher (0.7) focuses on small polyps.
    beta: controls penalty for False Positives (FP).
    """
    y_true_f = tf.cast(tf.reshape(y_true, [-1]), tf.float32)
    y_pred_f = tf.cast(tf.reshape(y_pred, [-1]), tf.float32)
    
    # Calculate True Positives, False Negatives, and False Positives
    tp = tf.reduce_sum(y_true_f * y_pred_f)
    fn = tf.reduce_sum(y_true_f * (1.0 - y_pred_f))
    fp = tf.reduce_sum((1.0 - y_true_f) * y_pred_f)
    
    # Tversky Index
    smooth = 1e-6
    tversky_index = (tp + smooth) / (tp + alpha * fn + beta * fp + smooth)
    
    # Focal Tversky Loss
    return tf.math.pow((1.0 - tversky_index), gamma)

# %%
def iou_metric(y_true, y_pred):
    y_true_f = tf.cast(y_true, tf.float32)
    y_pred_f = tf.cast(y_pred > 0.5, tf.float32)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    union = tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) - intersection
    return (intersection + 1.0) / (union + 1.0)

# %% [markdown]
# ### Master Pipeline Controller

# %%
# Initialize allocation strategy for physical compute hardware by scanning for available GPU units.
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus: tf.config.experimental.set_memory_growth(gpu, True)
        print("✓ Tensor Graph Allocation Locked over available GPU nodes.")
    except RuntimeError as e: print(e)

# 1. PARSE PIPELINE DIRECTORIES
print("\n[Data Ingestion] Parsing Multi-Center Localization Data (Dataset B)...")
seg_imgs, seg_masks = load_segmentation_paths(DATA_PATH)
s_train_x, s_val_x, s_train_y, s_val_y = train_test_split(seg_imgs, seg_masks, test_size=0.2, random_state=42)

print("[Data Ingestion] Parsing Balanced Sequence Arrays (Dataset A)...")
clf_imgs, clf_labels = load_classification_paths()
indices = np.arange(len(clf_imgs))
np.random.seed(42); np.random.shuffle(indices)
clf_imgs, clf_labels = clf_imgs[indices], clf_labels[indices]
c_split = int(0.8 * len(clf_imgs))

# 2. GENERATE HIGH-THROUGHPUT ITERATORS
print("\n⚡ Initializing Multi-Threaded High-Throughput Iterators via AUTOTUNE...")

# --- Segmentation Datasets ---
train_seg_ds = tf.data.Dataset.from_tensor_slices((s_train_x, s_train_y)) \
    .shuffle(len(s_train_x)) \
    .map(process_path_segmentation, num_parallel_calls=tf.data.AUTOTUNE) \
    .map(augment, num_parallel_calls=tf.data.AUTOTUNE) \
    .batch(BATCH_SIZE) \
    .prefetch(tf.data.AUTOTUNE)

val_seg_ds = tf.data.Dataset.from_tensor_slices((s_val_x, s_val_y)) \
    .map(process_path_segmentation, num_parallel_calls=tf.data.AUTOTUNE) \
    .batch(BATCH_SIZE) \
    .prefetch(tf.data.AUTOTUNE)


train_clf_ds = tf.data.Dataset.from_tensor_slices((clf_imgs[:c_split], clf_labels[:c_split])) \
    .shuffle(1024) \
    .map(process_path_classification, num_parallel_calls=tf.data.AUTOTUNE) \
    .batch(BATCH_SIZE) \
    .prefetch(tf.data.AUTOTUNE)

val_clf_ds = tf.data.Dataset.from_tensor_slices((clf_imgs[c_split:], clf_labels[c_split:])) \
    .map(process_path_classification, num_parallel_calls=tf.data.AUTOTUNE) \
    .batch(BATCH_SIZE) \
    .prefetch(tf.data.AUTOTUNE)

# 3. GRAPH INSTANTIATION
print("\n🏗️ Compiling Dual-Head Computation Topology...")
model = build_unified_segmentation_based_model()

# 🌟 STAGE 1: SEMANTIC SEGMENTATION MAXIMIZATION (Dataset B Only)
print("\n=======================================================")
print("[PHASE 1] Optimizing Localization Ensembles & Structural Layers")
print("=======================================================")

# Freeze classification branch entirely to avoid uninitialized variable gradients
for layer in model.layers:
    if "clf_" in layer.name:
        layer.trainable = False
    else:
        layer.trainable = True

model.compile(
    optimizer=mixed_precision.LossScaleOptimizer(tf.keras.optimizers.Adam(learning_rate=1e-3)),
    loss=[focal_tversky_loss, None],
    #metrics=[[dice_coef, iou_metric, 'accuracy'], []]
    metrics = {
        'seg_output': [
            'accuracy',                                      
            tf.keras.metrics.Recall(name='recall'),          
            tf.keras.metrics.Specificity(name='tnr'),       
            tf.keras.metrics.OneHotMeanIoU(num_classes=2, name='iou'),
            dice_coef,
            iou_metric
        ]
    }
)

# ── FIXED CALLBACKS FOR PHASE 1 ──────────────────────────────────────────
phase1_callbacks = [
    tf.keras.callbacks.ModelCheckpoint(MODEL_SAVE_PATH, monitor='val_seg_output_dice_coef', save_best_only=True, mode='max', verbose=1),
    tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=6, min_lr=3e-6, verbose=1)
]

# PHASE 1 Training started ...
history_p1 = model.fit(train_seg_ds, validation_data=val_seg_ds, epochs=EPOCHS_PHASE1, callbacks=phase1_callbacks, verbose=1)
print("[PHASE 1 COMPLETE] Spatial boundaries locked successfully.")

#  STAGE 2: SEGMENTATION-BASED CLASSIFICATION FINE-TUNING (Dataset A Only)
print("\n =======================================================")
print(" [PHASE 2] Initializing Classification Head over Locked Feature Embeddings")
print(" =======================================================")

# Reload historical weights to secure maximum localization properties
print(f"🔄 Fetching peak localization weights from storage: {MODEL_SAVE_PATH}")
model = tf.keras.models.load_model(MODEL_SAVE_PATH, custom_objects={
    'KerasPCCLayer': KerasPCCLayer, 
    'dice_coef': dice_coef, 
    'iou_metric': iou_metric, 
    'bce_dice_loss': bce_dice_loss,
    'focal_tversky_loss': focal_tversky_loss
})

# CRITICAL FIX: Explicitly freeze layers on the freshly reloaded model object 
print("🔒 Enforcing Strict Structural Freeze on the Shared Features Sub-Graph...")
for layer in model.layers:
    if "clf_" in layer.name:
        layer.trainable = True  # Unlock only the classification head
    else:
        layer.trainable = False # Permanently lock Encoder and Decoder paths to stop Catastrophic Forgetting

# Compile targeting classification targets mapped to Output Index 1
# model.compile(
#     optimizer=mixed_precision.LossScaleOptimizer(tf.keras.optimizers.Adam(learning_rate=1e-4)),
#     loss=[None, 'binary_crossentropy'],
#     metrics=[[], ['accuracy', tf.keras.metrics.AUC(name='auc')]]
# )

model.compile(
    optimizer=mixed_precision.LossScaleOptimizer(tf.keras.optimizers.Adam(learning_rate=1e-4)),
    loss=[None, 'binary_crossentropy'],
    metrics=['accuracy', tf.keras.metrics.AUC(name='auc')]
)

phase2_callbacks = [
    tf.keras.callbacks.ModelCheckpoint(MODEL_SAVE_PATH, monitor='val_loss', save_best_only=True, mode='min', verbose=1),
    tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=25, restore_best_weights=True, mode='min', verbose=1)
]
history_p2 = model.fit(train_clf_ds, validation_data=val_clf_ds, epochs=EPOCHS_PHASE2, callbacks=phase2_callbacks, verbose=1)
print(f"🏆 [TRAINING COMPLETE] Unified Graph successfully archived at: {MODEL_SAVE_PATH}")
# Out:
# ✓ Tensor Graph Allocation Locked over available GPU nodes.
#
# [Data Ingestion] Parsing Multi-Center Localization Data (Dataset B)...
# [Data Ingestion] Parsing Balanced Sequence Arrays (Dataset A)...
#
# ⚡ Initializing Multi-Threaded High-Throughput Iterators via AUTOTUNE...
#
# 🏗️ Compiling Dual-Head Computation Topology...
#
# =======================================================
# [PHASE 1] Optimizing Localization Ensembles & Structural Layers
# =======================================================
# Epoch 1/100
# I0000 00:00:1779702713.757603   41137 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_1738990__.480
# I0000 00:00:1779702741.132094   41137 subprocess_compilation.cc:348] ptxas warning : Registers are spilled to local memory in function 'input_reduce_fusion_215', 44 bytes spill stores, 44 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'input_reduce_fusion_179', 56 bytes spill stores, 56 bytes spill loads
# 306/307 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.7517 - seg_output_accuracy: 0.6725 - seg_output_dice_coef: 0.2375 - seg_output_iou_metric: 0.1649
# I0000 00:00:1779702787.394416   41138 subprocess_compilation.cc:348] ptxas warning : Registers are spilled to local memory in function 'input_reduce_fusion_3', 56 bytes spill stores, 56 bytes spill loads
# Epoch 1: val_seg_output_dice_coef improved from None to 0.25431, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras
#
# Epoch 1: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 138s 130ms/step - loss: 0.7168 - seg_output_accuracy: 0.7207 - seg_output_dice_coef: 0.2763 - seg_output_iou_metric: 0.1836 - val_loss: 0.7890 - val_seg_output_accuracy: 0.9035 - val_seg_output_dice_coef: 0.2543 - val_seg_output_iou_metric: 0.1795 - learning_rate: 0.0010
# Epoch 2/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.6540 - seg_output_accuracy: 0.8080 - seg_output_dice_coef: 0.3533 - seg_output_iou_metric: 0.2275
# Epoch 2: val_seg_output_dice_coef improved from 0.25431 to 0.33575, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras
#
# Epoch 2: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 27s 85ms/step - loss: 0.6544 - seg_output_accuracy: 0.8188 - seg_output_dice_coef: 0.3560 - seg_output_iou_metric: 0.2298 - val_loss: 0.6783 - val_seg_output_accuracy: 0.8207 - val_seg_output_dice_coef: 0.3357 - val_seg_output_iou_metric: 0.2149 - learning_rate: 0.0010
# Epoch 3/100
# 306/307 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.6462 - seg_output_accuracy: 0.8351 - seg_output_dice_coef: 0.3645 - seg_output_iou_metric: 0.2356
# Epoch 3: val_seg_output_dice_coef did not improve from 0.33575
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 23s 75ms/step - loss: 0.6336 - seg_output_accuracy: 0.8383 - seg_output_dice_coef: 0.3817 - seg_output_iou_metric: 0.2482 - val_loss: 0.6594 - val_seg_output_accuracy: 0.7432 - val_seg_output_dice_coef: 0.3276 - val_seg_output_iou_metric: 0.2063 - learning_rate: 0.0010
# Epoch 4/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.6360 - seg_output_accuracy: 0.8479 - seg_output_dice_coef: 0.3834 - seg_output_iou_metric: 0.2503
# Epoch 4: val_seg_output_dice_coef improved from 0.33575 to 0.38518, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras
#
# Epoch 4: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 24s 76ms/step - loss: 0.6273 - seg_output_accuracy: 0.8529 - seg_output_dice_coef: 0.3936 - seg_output_iou_metric: 0.2591 - val_loss: 0.6258 - val_seg_output_accuracy: 0.8370 - val_seg_output_dice_coef: 0.3852 - val_seg_output_iou_metric: 0.2534 - learning_rate: 0.0010
# Epoch 5/100
# 306/307 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.6080 - seg_output_accuracy: 0.8566 - seg_output_dice_coef: 0.4117 - seg_output_iou_metric: 0.2728
# Epoch 5: val_seg_output_dice_coef did not improve from 0.38518
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 22s 71ms/step - loss: 0.6188 - seg_output_accuracy: 0.8540 - seg_output_dice_coef: 0.4014 - seg_output_iou_metric: 0.2665 - val_loss: 0.6287 - val_seg_output_accuracy: 0.8283 - val_seg_output_dice_coef: 0.3786 - val_seg_output_iou_metric: 0.2466 - learning_rate: 0.0010
# Epoch 6/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.6174 - seg_output_accuracy: 0.8619 - seg_output_dice_coef: 0.4061 - seg_output_iou_metric: 0.2696
# Epoch 6: val_seg_output_dice_coef improved from 0.38518 to 0.42377, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras
#
# Epoch 6: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 24s 79ms/step - loss: 0.6125 - seg_output_accuracy: 0.8653 - seg_output_dice_coef: 0.4136 - seg_output_iou_metric: 0.2771 - val_loss: 0.5942 - val_seg_output_accuracy: 0.8617 - val_seg_output_dice_coef: 0.4238 - val_seg_output_iou_metric: 0.2845 - learning_rate: 0.0010
# Epoch 7/100
# 306/307 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.5886 - seg_output_accuracy: 0.8702 - seg_output_dice_coef: 0.4419 - seg_output_iou_metric: 0.3013
# Epoch 7: val_seg_output_dice_coef did not improve from 0.42377
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 22s 71ms/step - loss: 0.5981 - seg_output_accuracy: 0.8734 - seg_output_dice_coef: 0.4317 - seg_output_iou_metric: 0.2914 - val_loss: 0.6504 - val_seg_output_accuracy: 0.7806 - val_seg_output_dice_coef: 0.3444 - val_seg_output_iou_metric: 0.2189 - learning_rate: 0.0010
# Epoch 8/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.5762 - seg_output_accuracy: 0.8720 - seg_output_dice_coef: 0.4515 - seg_output_iou_metric: 0.3097
# Epoch 8: val_seg_output_dice_coef improved from 0.42377 to 0.43722, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras
#
# Epoch 8: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 25s 82ms/step - loss: 0.5868 - seg_output_accuracy: 0.8733 - seg_output_dice_coef: 0.4409 - seg_output_iou_metric: 0.2995 - val_loss: 0.5891 - val_seg_output_accuracy: 0.8762 - val_seg_output_dice_coef: 0.4372 - val_seg_output_iou_metric: 0.2961 - learning_rate: 0.0010
# Epoch 9/100
# 306/307 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.5659 - seg_output_accuracy: 0.8842 - seg_output_dice_coef: 0.4688 - seg_output_iou_metric: 0.3264
# Epoch 9: val_seg_output_dice_coef improved from 0.43722 to 0.46423, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras
#
# Epoch 9: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 25s 80ms/step - loss: 0.5860 - seg_output_accuracy: 0.8786 - seg_output_dice_coef: 0.4445 - seg_output_iou_metric: 0.3032 - val_loss: 0.6135 - val_seg_output_accuracy: 0.9251 - val_seg_output_dice_coef: 0.4642 - val_seg_output_iou_metric: 0.3274 - learning_rate: 0.0010
# Epoch 10/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.5723 - seg_output_accuracy: 0.8884 - seg_output_dice_coef: 0.4663 - seg_output_iou_metric: 0.3251
# Epoch 10: val_seg_output_dice_coef did not improve from 0.46423
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 23s 75ms/step - loss: 0.5801 - seg_output_accuracy: 0.8876 - seg_output_dice_coef: 0.4559 - seg_output_iou_metric: 0.3155 - val_loss: 0.6166 - val_seg_output_accuracy: 0.9106 - val_seg_output_dice_coef: 0.4454 - val_seg_output_iou_metric: 0.3057 - learning_rate: 0.0010
# Epoch 11/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.5772 - seg_output_accuracy: 0.8863 - seg_output_dice_coef: 0.4584 - seg_output_iou_metric: 0.3161
# Epoch 11: val_seg_output_dice_coef did not improve from 0.46423
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 24s 77ms/step - loss: 0.5728 - seg_output_accuracy: 0.8888 - seg_output_dice_coef: 0.4647 - seg_output_iou_metric: 0.3218 - val_loss: 0.5923 - val_seg_output_accuracy: 0.8597 - val_seg_output_dice_coef: 0.4238 - val_seg_output_iou_metric: 0.2842 - learning_rate: 0.0010
# Epoch 12/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.5725 - seg_output_accuracy: 0.8899 - seg_output_dice_coef: 0.4609 - seg_output_iou_metric: 0.3189
# Epoch 12: val_seg_output_dice_coef did not improve from 0.46423
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 23s 76ms/step - loss: 0.5685 - seg_output_accuracy: 0.8866 - seg_output_dice_coef: 0.4652 - seg_output_iou_metric: 0.3216 - val_loss: 0.5615 - val_seg_output_accuracy: 0.8819 - val_seg_output_dice_coef: 0.4628 - val_seg_output_iou_metric: 0.3206 - learning_rate: 0.0010
# Epoch 13/100
# 306/307 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.5561 - seg_output_accuracy: 0.8936 - seg_output_dice_coef: 0.4814 - seg_output_iou_metric: 0.3361
# Epoch 13: val_seg_output_dice_coef improved from 0.46423 to 0.50471, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras
#
# Epoch 13: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 24s 78ms/step - loss: 0.5548 - seg_output_accuracy: 0.8931 - seg_output_dice_coef: 0.4822 - seg_output_iou_metric: 0.3389 - val_loss: 0.5610 - val_seg_output_accuracy: 0.9216 - val_seg_output_dice_coef: 0.5047 - val_seg_output_iou_metric: 0.3587 - learning_rate: 0.0010
# Epoch 14/100
# 306/307 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.5413 - seg_output_accuracy: 0.9078 - seg_output_dice_coef: 0.5037 - seg_output_iou_metric: 0.3583
# Epoch 14: val_seg_output_dice_coef did not improve from 0.50471
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 23s 75ms/step - loss: 0.5417 - seg_output_accuracy: 0.9056 - seg_output_dice_coef: 0.5047 - seg_output_iou_metric: 0.3595 - val_loss: 0.5393 - val_seg_output_accuracy: 0.8963 - val_seg_output_dice_coef: 0.4895 - val_seg_output_iou_metric: 0.3445 - learning_rate: 0.0010
# Epoch 15/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.5526 - seg_output_accuracy: 0.8936 - seg_output_dice_coef: 0.4878 - seg_output_iou_metric: 0.3424
# Epoch 15: val_seg_output_dice_coef improved from 0.50471 to 0.52730, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras
#
# Epoch 15: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 24s 78ms/step - loss: 0.5425 - seg_output_accuracy: 0.9013 - seg_output_dice_coef: 0.5005 - seg_output_iou_metric: 0.3546 - val_loss: 0.5575 - val_seg_output_accuracy: 0.9362 - val_seg_output_dice_coef: 0.5273 - val_seg_output_iou_metric: 0.3861 - learning_rate: 0.0010
# Epoch 16/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.5387 - seg_output_accuracy: 0.9111 - seg_output_dice_coef: 0.5078 - seg_output_iou_metric: 0.3627
# Epoch 16: val_seg_output_dice_coef improved from 0.52730 to 0.53162, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras
#
# Epoch 16: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 25s 79ms/step - loss: 0.5373 - seg_output_accuracy: 0.9058 - seg_output_dice_coef: 0.5077 - seg_output_iou_metric: 0.3614 - val_loss: 0.5309 - val_seg_output_accuracy: 0.9275 - val_seg_output_dice_coef: 0.5316 - val_seg_output_iou_metric: 0.3858 - learning_rate: 0.0010
# Epoch 17/100
# 306/307 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.5322 - seg_output_accuracy: 0.9096 - seg_output_dice_coef: 0.5192 - seg_output_iou_metric: 0.3776
# Epoch 17: val_seg_output_dice_coef improved from 0.53162 to 0.53471, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras
#
# Epoch 17: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 24s 79ms/step - loss: 0.5317 - seg_output_accuracy: 0.9111 - seg_output_dice_coef: 0.5182 - seg_output_iou_metric: 0.3743 - val_loss: 0.5264 - val_seg_output_accuracy: 0.9253 - val_seg_output_dice_coef: 0.5347 - val_seg_output_iou_metric: 0.3893 - learning_rate: 0.0010
# Epoch 18/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.5424 - seg_output_accuracy: 0.9076 - seg_output_dice_coef: 0.5078 - seg_output_iou_metric: 0.3641
# Epoch 18: val_seg_output_dice_coef did not improve from 0.53471
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 23s 75ms/step - loss: 0.5352 - seg_output_accuracy: 0.9084 - seg_output_dice_coef: 0.5124 - seg_output_iou_metric: 0.3686 - val_loss: 0.5531 - val_seg_output_accuracy: 0.8684 - val_seg_output_dice_coef: 0.4573 - val_seg_output_iou_metric: 0.3143 - learning_rate: 0.0010
# Epoch 19/100
# 306/307 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.5202 - seg_output_accuracy: 0.9066 - seg_output_dice_coef: 0.5237 - seg_output_iou_metric: 0.3784
# Epoch 19: val_seg_output_dice_coef did not improve from 0.53471
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 23s 74ms/step - loss: 0.5204 - seg_output_accuracy: 0.9106 - seg_output_dice_coef: 0.5284 - seg_output_iou_metric: 0.3803 - val_loss: 0.5290 - val_seg_output_accuracy: 0.9128 - val_seg_output_dice_coef: 0.5167 - val_seg_output_iou_metric: 0.3702 - learning_rate: 0.0010
# Epoch 20/100
# 306/307 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.5396 - seg_output_accuracy: 0.9104 - seg_output_dice_coef: 0.5083 - seg_output_iou_metric: 0.3636
# Epoch 20: val_seg_output_dice_coef did not improve from 0.53471
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 23s 74ms/step - loss: 0.5170 - seg_output_accuracy: 0.9145 - seg_output_dice_coef: 0.5352 - seg_output_iou_metric: 0.3879 - val_loss: 0.5700 - val_seg_output_accuracy: 0.9072 - val_seg_output_dice_coef: 0.4772 - val_seg_output_iou_metric: 0.3352 - learning_rate: 0.0010
# Epoch 21/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.5115 - seg_output_accuracy: 0.9181 - seg_output_dice_coef: 0.5390 - seg_output_iou_metric: 0.3924
# Epoch 21: val_seg_output_dice_coef improved from 0.53471 to 0.53596, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras
#
# Epoch 21: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 25s 81ms/step - loss: 0.5030 - seg_output_accuracy: 0.9184 - seg_output_dice_coef: 0.5485 - seg_output_iou_metric: 0.4013 - val_loss: 0.5171 - val_seg_output_accuracy: 0.9223 - val_seg_output_dice_coef: 0.5360 - val_seg_output_iou_metric: 0.3877 - learning_rate: 0.0010
# Epoch 22/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.4998 - seg_output_accuracy: 0.9191 - seg_output_dice_coef: 0.5543 - seg_output_iou_metric: 0.4060
# Epoch 22: val_seg_output_dice_coef improved from 0.53596 to 0.55894, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras
#
# Epoch 22: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 25s 81ms/step - loss: 0.5046 - seg_output_accuracy: 0.9208 - seg_output_dice_coef: 0.5493 - seg_output_iou_metric: 0.4009 - val_loss: 0.4969 - val_seg_output_accuracy: 0.9273 - val_seg_output_dice_coef: 0.5589 - val_seg_output_iou_metric: 0.4085 - learning_rate: 0.0010
# Epoch 23/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.4821 - seg_output_accuracy: 0.9278 - seg_output_dice_coef: 0.5745 - seg_output_iou_metric: 0.4271
# Epoch 23: val_seg_output_dice_coef did not improve from 0.55894
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 24s 77ms/step - loss: 0.4926 - seg_output_accuracy: 0.9243 - seg_output_dice_coef: 0.5653 - seg_output_iou_metric: 0.4170 - val_loss: 0.4988 - val_seg_output_accuracy: 0.9245 - val_seg_output_dice_coef: 0.5534 - val_seg_output_iou_metric: 0.4071 - learning_rate: 0.0010
# Epoch 24/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.4999 - seg_output_accuracy: 0.9164 - seg_output_dice_coef: 0.5521 - seg_output_iou_metric: 0.4054
# Epoch 24: val_seg_output_dice_coef did not improve from 0.55894
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 24s 77ms/step - loss: 0.4896 - seg_output_accuracy: 0.9229 - seg_output_dice_coef: 0.5666 - seg_output_iou_metric: 0.4194 - val_loss: 0.5090 - val_seg_output_accuracy: 0.9064 - val_seg_output_dice_coef: 0.5229 - val_seg_output_iou_metric: 0.3750 - learning_rate: 0.0010
# Epoch 25/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.4773 - seg_output_accuracy: 0.9271 - seg_output_dice_coef: 0.5768 - seg_output_iou_metric: 0.4313
# Epoch 25: val_seg_output_dice_coef improved from 0.55894 to 0.61325, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras
#
# Epoch 25: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 25s 79ms/step - loss: 0.4738 - seg_output_accuracy: 0.9284 - seg_output_dice_coef: 0.5865 - seg_output_iou_metric: 0.4400 - val_loss: 0.4714 - val_seg_output_accuracy: 0.9461 - val_seg_output_dice_coef: 0.6132 - val_seg_output_iou_metric: 0.4689 - learning_rate: 0.0010
# Epoch 26/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.4799 - seg_output_accuracy: 0.9258 - seg_output_dice_coef: 0.5841 - seg_output_iou_metric: 0.4356
# Epoch 26: val_seg_output_dice_coef did not improve from 0.61325
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 24s 78ms/step - loss: 0.4844 - seg_output_accuracy: 0.9268 - seg_output_dice_coef: 0.5747 - seg_output_iou_metric: 0.4285 - val_loss: 0.4982 - val_seg_output_accuracy: 0.9199 - val_seg_output_dice_coef: 0.5465 - val_seg_output_iou_metric: 0.3974 - learning_rate: 0.0010
# Epoch 27/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.4513 - seg_output_accuracy: 0.9355 - seg_output_dice_coef: 0.6101 - seg_output_iou_metric: 0.4648
# Epoch 27: val_seg_output_dice_coef did not improve from 0.61325
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 25s 81ms/step - loss: 0.4618 - seg_output_accuracy: 0.9318 - seg_output_dice_coef: 0.5994 - seg_output_iou_metric: 0.4542 - val_loss: 0.5076 - val_seg_output_accuracy: 0.9197 - val_seg_output_dice_coef: 0.5382 - val_seg_output_iou_metric: 0.3915 - learning_rate: 0.0010
# Epoch 28/100
# 306/307 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.4705 - seg_output_accuracy: 0.9275 - seg_output_dice_coef: 0.5826 - seg_output_iou_metric: 0.4377
# Epoch 28: val_seg_output_dice_coef did not improve from 0.61325
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 26s 85ms/step - loss: 0.4658 - seg_output_accuracy: 0.9289 - seg_output_dice_coef: 0.5924 - seg_output_iou_metric: 0.4468 - val_loss: 0.4712 - val_seg_output_accuracy: 0.9219 - val_seg_output_dice_coef: 0.5695 - val_seg_output_iou_metric: 0.4187 - learning_rate: 0.0010
# Epoch 29/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.4426 - seg_output_accuracy: 0.9328 - seg_output_dice_coef: 0.6181 - seg_output_iou_metric: 0.4737
# Epoch 29: val_seg_output_dice_coef improved from 0.61325 to 0.63348, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras
#
# Epoch 29: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 26s 84ms/step - loss: 0.4517 - seg_output_accuracy: 0.9331 - seg_output_dice_coef: 0.6084 - seg_output_iou_metric: 0.4643 - val_loss: 0.4400 - val_seg_output_accuracy: 0.9452 - val_seg_output_dice_coef: 0.6335 - val_seg_output_iou_metric: 0.4865 - learning_rate: 0.0010
# Epoch 30/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.4326 - seg_output_accuracy: 0.9385 - seg_output_dice_coef: 0.6353 - seg_output_iou_metric: 0.4885
# Epoch 30: val_seg_output_dice_coef did not improve from 0.63348
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 26s 83ms/step - loss: 0.4480 - seg_output_accuracy: 0.9371 - seg_output_dice_coef: 0.6176 - seg_output_iou_metric: 0.4717 - val_loss: 0.4750 - val_seg_output_accuracy: 0.9471 - val_seg_output_dice_coef: 0.6137 - val_seg_output_iou_metric: 0.4693 - learning_rate: 0.0010
# Epoch 31/100
# 306/307 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.4296 - seg_output_accuracy: 0.9386 - seg_output_dice_coef: 0.6323 - seg_output_iou_metric: 0.4884
# Epoch 31: val_seg_output_dice_coef did not improve from 0.63348
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 26s 83ms/step - loss: 0.4355 - seg_output_accuracy: 0.9371 - seg_output_dice_coef: 0.6274 - seg_output_iou_metric: 0.4810 - val_loss: 0.4831 - val_seg_output_accuracy: 0.9509 - val_seg_output_dice_coef: 0.6253 - val_seg_output_iou_metric: 0.4830 - learning_rate: 0.0010
# Epoch 32/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.4272 - seg_output_accuracy: 0.9382 - seg_output_dice_coef: 0.6343 - seg_output_iou_metric: 0.4932
# Epoch 32: val_seg_output_dice_coef improved from 0.63348 to 0.65555, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras
#
# Epoch 32: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 25s 79ms/step - loss: 0.4425 - seg_output_accuracy: 0.9374 - seg_output_dice_coef: 0.6190 - seg_output_iou_metric: 0.4760 - val_loss: 0.4256 - val_seg_output_accuracy: 0.9500 - val_seg_output_dice_coef: 0.6555 - val_seg_output_iou_metric: 0.5098 - learning_rate: 0.0010
# Epoch 33/100
# 306/307 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.4274 - seg_output_accuracy: 0.9427 - seg_output_dice_coef: 0.6403 - seg_output_iou_metric: 0.4971
# Epoch 33: val_seg_output_dice_coef did not improve from 0.65555
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 23s 74ms/step - loss: 0.4277 - seg_output_accuracy: 0.9406 - seg_output_dice_coef: 0.6387 - seg_output_iou_metric: 0.4950 - val_loss: 0.5702 - val_seg_output_accuracy: 0.9440 - val_seg_output_dice_coef: 0.5397 - val_seg_output_iou_metric: 0.3992 - learning_rate: 0.0010
# Epoch 34/100
# 306/307 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.4393 - seg_output_accuracy: 0.9335 - seg_output_dice_coef: 0.6270 - seg_output_iou_metric: 0.4796
# Epoch 34: val_seg_output_dice_coef did not improve from 0.65555
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 42s 78ms/step - loss: 0.4273 - seg_output_accuracy: 0.9405 - seg_output_dice_coef: 0.6381 - seg_output_iou_metric: 0.4938 - val_loss: 0.4690 - val_seg_output_accuracy: 0.9547 - val_seg_output_dice_coef: 0.6381 - val_seg_output_iou_metric: 0.5064 - learning_rate: 0.0010
# Epoch 35/100
# 306/307 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.4055 - seg_output_accuracy: 0.9441 - seg_output_dice_coef: 0.6646 - seg_output_iou_metric: 0.5201
# Epoch 35: val_seg_output_dice_coef did not improve from 0.65555
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 25s 81ms/step - loss: 0.4220 - seg_output_accuracy: 0.9433 - seg_output_dice_coef: 0.6474 - seg_output_iou_metric: 0.5031 - val_loss: 0.4305 - val_seg_output_accuracy: 0.9480 - val_seg_output_dice_coef: 0.6503 - val_seg_output_iou_metric: 0.5039 - learning_rate: 0.0010
# Epoch 36/100
# 306/307 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.4106 - seg_output_accuracy: 0.9440 - seg_output_dice_coef: 0.6560 - seg_output_iou_metric: 0.5130
# Epoch 36: val_seg_output_dice_coef did not improve from 0.65555
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 23s 73ms/step - loss: 0.4206 - seg_output_accuracy: 0.9419 - seg_output_dice_coef: 0.6450 - seg_output_iou_metric: 0.5012 - val_loss: 0.4370 - val_seg_output_accuracy: 0.9388 - val_seg_output_dice_coef: 0.6245 - val_seg_output_iou_metric: 0.4796 - learning_rate: 0.0010
# Epoch 37/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.4000 - seg_output_accuracy: 0.9458 - seg_output_dice_coef: 0.6689 - seg_output_iou_metric: 0.5299
# Epoch 37: val_seg_output_dice_coef did not improve from 0.65555
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 23s 74ms/step - loss: 0.4210 - seg_output_accuracy: 0.9417 - seg_output_dice_coef: 0.6438 - seg_output_iou_metric: 0.5016 - val_loss: 0.4296 - val_seg_output_accuracy: 0.9412 - val_seg_output_dice_coef: 0.6292 - val_seg_output_iou_metric: 0.4826 - learning_rate: 0.0010
# Epoch 38/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.4139 - seg_output_accuracy: 0.9443 - seg_output_dice_coef: 0.6546 - seg_output_iou_metric: 0.5105
# Epoch 38: val_seg_output_dice_coef improved from 0.65555 to 0.66703, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras
#
# Epoch 38: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 24s 79ms/step - loss: 0.4087 - seg_output_accuracy: 0.9455 - seg_output_dice_coef: 0.6597 - seg_output_iou_metric: 0.5168 - val_loss: 0.4140 - val_seg_output_accuracy: 0.9520 - val_seg_output_dice_coef: 0.6670 - val_seg_output_iou_metric: 0.5305 - learning_rate: 0.0010
# Epoch 39/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.4253 - seg_output_accuracy: 0.9441 - seg_output_dice_coef: 0.6405 - seg_output_iou_metric: 0.4991
# Epoch 39: val_seg_output_dice_coef did not improve from 0.66703
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 23s 74ms/step - loss: 0.4022 - seg_output_accuracy: 0.9457 - seg_output_dice_coef: 0.6647 - seg_output_iou_metric: 0.5256 - val_loss: 0.4907 - val_seg_output_accuracy: 0.9583 - val_seg_output_dice_coef: 0.6324 - val_seg_output_iou_metric: 0.5040 - learning_rate: 0.0010
# Epoch 40/100
# 306/307 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.4070 - seg_output_accuracy: 0.9491 - seg_output_dice_coef: 0.6614 - seg_output_iou_metric: 0.5199
# Epoch 40: val_seg_output_dice_coef did not improve from 0.66703
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 23s 74ms/step - loss: 0.4003 - seg_output_accuracy: 0.9472 - seg_output_dice_coef: 0.6675 - seg_output_iou_metric: 0.5280 - val_loss: 0.4588 - val_seg_output_accuracy: 0.9558 - val_seg_output_dice_coef: 0.6452 - val_seg_output_iou_metric: 0.5123 - learning_rate: 0.0010
# Epoch 41/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.3868 - seg_output_accuracy: 0.9502 - seg_output_dice_coef: 0.6853 - seg_output_iou_metric: 0.5483
# Epoch 41: val_seg_output_dice_coef did not improve from 0.66703
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 23s 74ms/step - loss: 0.3936 - seg_output_accuracy: 0.9472 - seg_output_dice_coef: 0.6727 - seg_output_iou_metric: 0.5362 - val_loss: 0.4220 - val_seg_output_accuracy: 0.9538 - val_seg_output_dice_coef: 0.6649 - val_seg_output_iou_metric: 0.5256 - learning_rate: 0.0010
# Epoch 42/100
# 306/307 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.3875 - seg_output_accuracy: 0.9491 - seg_output_dice_coef: 0.6780 - seg_output_iou_metric: 0.5419
# Epoch 42: val_seg_output_dice_coef improved from 0.66703 to 0.66941, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras
#
# Epoch 42: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 24s 77ms/step - loss: 0.4025 - seg_output_accuracy: 0.9461 - seg_output_dice_coef: 0.6631 - seg_output_iou_metric: 0.5249 - val_loss: 0.4020 - val_seg_output_accuracy: 0.9505 - val_seg_output_dice_coef: 0.6694 - val_seg_output_iou_metric: 0.5278 - learning_rate: 0.0010
# Epoch 43/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.3878 - seg_output_accuracy: 0.9477 - seg_output_dice_coef: 0.6778 - seg_output_iou_metric: 0.5397
# Epoch 43: val_seg_output_dice_coef improved from 0.66941 to 0.67315, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras
#
# Epoch 43: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 24s 78ms/step - loss: 0.3849 - seg_output_accuracy: 0.9484 - seg_output_dice_coef: 0.6812 - seg_output_iou_metric: 0.5440 - val_loss: 0.4018 - val_seg_output_accuracy: 0.9498 - val_seg_output_dice_coef: 0.6732 - val_seg_output_iou_metric: 0.5356 - learning_rate: 0.0010
# Epoch 44/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.3725 - seg_output_accuracy: 0.9473 - seg_output_dice_coef: 0.6944 - seg_output_iou_metric: 0.5572
# Epoch 44: val_seg_output_dice_coef improved from 0.67315 to 0.67634, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras
#
# Epoch 44: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 25s 80ms/step - loss: 0.3787 - seg_output_accuracy: 0.9490 - seg_output_dice_coef: 0.6863 - seg_output_iou_metric: 0.5496 - val_loss: 0.4336 - val_seg_output_accuracy: 0.9565 - val_seg_output_dice_coef: 0.6763 - val_seg_output_iou_metric: 0.5385 - learning_rate: 0.0010
# Epoch 45/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.3917 - seg_output_accuracy: 0.9479 - seg_output_dice_coef: 0.6766 - seg_output_iou_metric: 0.5418
# Epoch 45: val_seg_output_dice_coef did not improve from 0.67634
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 23s 74ms/step - loss: 0.3814 - seg_output_accuracy: 0.9498 - seg_output_dice_coef: 0.6868 - seg_output_iou_metric: 0.5516 - val_loss: 0.4143 - val_seg_output_accuracy: 0.9376 - val_seg_output_dice_coef: 0.6395 - val_seg_output_iou_metric: 0.4941 - learning_rate: 0.0010
# Epoch 46/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.3783 - seg_output_accuracy: 0.9551 - seg_output_dice_coef: 0.6921 - seg_output_iou_metric: 0.5550
# Epoch 46: val_seg_output_dice_coef improved from 0.67634 to 0.69859, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras
#
# Epoch 46: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 24s 77ms/step - loss: 0.3706 - seg_output_accuracy: 0.9533 - seg_output_dice_coef: 0.7008 - seg_output_iou_metric: 0.5651 - val_loss: 0.3718 - val_seg_output_accuracy: 0.9551 - val_seg_output_dice_coef: 0.6986 - val_seg_output_iou_metric: 0.5637 - learning_rate: 0.0010
# Epoch 47/100
# 306/307 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.3906 - seg_output_accuracy: 0.9517 - seg_output_dice_coef: 0.6824 - seg_output_iou_metric: 0.5455
# Epoch 47: val_seg_output_dice_coef did not improve from 0.69859
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 24s 79ms/step - loss: 0.3879 - seg_output_accuracy: 0.9511 - seg_output_dice_coef: 0.6822 - seg_output_iou_metric: 0.5454 - val_loss: 0.4213 - val_seg_output_accuracy: 0.9539 - val_seg_output_dice_coef: 0.6722 - val_seg_output_iou_metric: 0.5332 - learning_rate: 0.0010
# Epoch 48/100
# 306/307 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.3788 - seg_output_accuracy: 0.9528 - seg_output_dice_coef: 0.6912 - seg_output_iou_metric: 0.5531
# Epoch 48: val_seg_output_dice_coef did not improve from 0.69859
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 24s 76ms/step - loss: 0.3726 - seg_output_accuracy: 0.9530 - seg_output_dice_coef: 0.6972 - seg_output_iou_metric: 0.5623 - val_loss: 0.4363 - val_seg_output_accuracy: 0.9564 - val_seg_output_dice_coef: 0.6694 - val_seg_output_iou_metric: 0.5320 - learning_rate: 0.0010
# Epoch 49/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.3651 - seg_output_accuracy: 0.9533 - seg_output_dice_coef: 0.7029 - seg_output_iou_metric: 0.5668
# Epoch 49: val_seg_output_dice_coef did not improve from 0.69859
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 22s 73ms/step - loss: 0.3758 - seg_output_accuracy: 0.9524 - seg_output_dice_coef: 0.6938 - seg_output_iou_metric: 0.5571 - val_loss: 0.3929 - val_seg_output_accuracy: 0.9539 - val_seg_output_dice_coef: 0.6852 - val_seg_output_iou_metric: 0.5489 - learning_rate: 0.0010
# Epoch 50/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.3910 - seg_output_accuracy: 0.9498 - seg_output_dice_coef: 0.6729 - seg_output_iou_metric: 0.5368
# Epoch 50: val_seg_output_dice_coef improved from 0.69859 to 0.71437, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras
#
# Epoch 50: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 30s 96ms/step - loss: 0.3774 - seg_output_accuracy: 0.9512 - seg_output_dice_coef: 0.6888 - seg_output_iou_metric: 0.5548 - val_loss: 0.3661 - val_seg_output_accuracy: 0.9594 - val_seg_output_dice_coef: 0.7144 - val_seg_output_iou_metric: 0.5845 - learning_rate: 0.0010
# Epoch 51/100
# 306/307 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.3561 - seg_output_accuracy: 0.9548 - seg_output_dice_coef: 0.7096 - seg_output_iou_metric: 0.5792
# Epoch 51: val_seg_output_dice_coef did not improve from 0.71437
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 23s 72ms/step - loss: 0.3540 - seg_output_accuracy: 0.9556 - seg_output_dice_coef: 0.7149 - seg_output_iou_metric: 0.5817 - val_loss: 0.4274 - val_seg_output_accuracy: 0.9588 - val_seg_output_dice_coef: 0.6713 - val_seg_output_iou_metric: 0.5415 - learning_rate: 0.0010
# Epoch 52/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.3549 - seg_output_accuracy: 0.9528 - seg_output_dice_coef: 0.7142 - seg_output_iou_metric: 0.5808
# Epoch 52: val_seg_output_dice_coef did not improve from 0.71437
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 23s 74ms/step - loss: 0.3759 - seg_output_accuracy: 0.9516 - seg_output_dice_coef: 0.6934 - seg_output_iou_metric: 0.5594 - val_loss: 0.3724 - val_seg_output_accuracy: 0.9508 - val_seg_output_dice_coef: 0.6834 - val_seg_output_iou_metric: 0.5471 - learning_rate: 0.0010
# Epoch 53/100
# 306/307 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.3661 - seg_output_accuracy: 0.9501 - seg_output_dice_coef: 0.6940 - seg_output_iou_metric: 0.5590
# Epoch 53: val_seg_output_dice_coef did not improve from 0.71437
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 23s 74ms/step - loss: 0.3644 - seg_output_accuracy: 0.9510 - seg_output_dice_coef: 0.6984 - seg_output_iou_metric: 0.5634 - val_loss: 0.4436 - val_seg_output_accuracy: 0.9044 - val_seg_output_dice_coef: 0.5736 - val_seg_output_iou_metric: 0.4337 - learning_rate: 0.0010
# Epoch 54/100
# 306/307 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.3792 - seg_output_accuracy: 0.9537 - seg_output_dice_coef: 0.6866 - seg_output_iou_metric: 0.5506
# Epoch 54: val_seg_output_dice_coef did not improve from 0.71437
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 23s 74ms/step - loss: 0.3659 - seg_output_accuracy: 0.9540 - seg_output_dice_coef: 0.7035 - seg_output_iou_metric: 0.5687 - val_loss: 0.4319 - val_seg_output_accuracy: 0.9302 - val_seg_output_dice_coef: 0.6118 - val_seg_output_iou_metric: 0.4738 - learning_rate: 0.0010
# Epoch 55/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.3740 - seg_output_accuracy: 0.9487 - seg_output_dice_coef: 0.6874 - seg_output_iou_metric: 0.5516
# Epoch 55: val_seg_output_dice_coef improved from 0.71437 to 0.71576, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras
#
# Epoch 55: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 27s 86ms/step - loss: 0.3665 - seg_output_accuracy: 0.9530 - seg_output_dice_coef: 0.6999 - seg_output_iou_metric: 0.5657 - val_loss: 0.3769 - val_seg_output_accuracy: 0.9618 - val_seg_output_dice_coef: 0.7158 - val_seg_output_iou_metric: 0.5883 - learning_rate: 0.0010
# Epoch 56/100
# 306/307 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.3284 - seg_output_accuracy: 0.9604 - seg_output_dice_coef: 0.7490 - seg_output_iou_metric: 0.6201
# Epoch 56: val_seg_output_dice_coef improved from 0.71576 to 0.74145, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras
#
# Epoch 56: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 24s 78ms/step - loss: 0.3477 - seg_output_accuracy: 0.9576 - seg_output_dice_coef: 0.7251 - seg_output_iou_metric: 0.5933 - val_loss: 0.3519 - val_seg_output_accuracy: 0.9647 - val_seg_output_dice_coef: 0.7414 - val_seg_output_iou_metric: 0.6201 - learning_rate: 0.0010
# Epoch 57/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.3425 - seg_output_accuracy: 0.9588 - seg_output_dice_coef: 0.7314 - seg_output_iou_metric: 0.6017
# Epoch 57: val_seg_output_dice_coef did not improve from 0.74145
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 22s 72ms/step - loss: 0.3442 - seg_output_accuracy: 0.9591 - seg_output_dice_coef: 0.7291 - seg_output_iou_metric: 0.5979 - val_loss: 0.3658 - val_seg_output_accuracy: 0.9478 - val_seg_output_dice_coef: 0.6840 - val_seg_output_iou_metric: 0.5504 - learning_rate: 0.0010
# Epoch 58/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.3368 - seg_output_accuracy: 0.9583 - seg_output_dice_coef: 0.7384 - seg_output_iou_metric: 0.6080
# Epoch 58: val_seg_output_dice_coef did not improve from 0.74145
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 22s 72ms/step - loss: 0.3459 - seg_output_accuracy: 0.9578 - seg_output_dice_coef: 0.7292 - seg_output_iou_metric: 0.5964 - val_loss: 0.4300 - val_seg_output_accuracy: 0.9554 - val_seg_output_dice_coef: 0.6732 - val_seg_output_iou_metric: 0.5395 - learning_rate: 0.0010
# Epoch 59/100
# 306/307 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.3556 - seg_output_accuracy: 0.9569 - seg_output_dice_coef: 0.7217 - seg_output_iou_metric: 0.5897
# Epoch 59: val_seg_output_dice_coef did not improve from 0.74145
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 23s 74ms/step - loss: 0.3516 - seg_output_accuracy: 0.9579 - seg_output_dice_coef: 0.7193 - seg_output_iou_metric: 0.5881 - val_loss: 0.3822 - val_seg_output_accuracy: 0.9528 - val_seg_output_dice_coef: 0.6856 - val_seg_output_iou_metric: 0.5498 - learning_rate: 0.0010
# Epoch 60/100
# 306/307 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.3374 - seg_output_accuracy: 0.9569 - seg_output_dice_coef: 0.7301 - seg_output_iou_metric: 0.6022
# Epoch 60: val_seg_output_dice_coef did not improve from 0.74145
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 23s 75ms/step - loss: 0.3470 - seg_output_accuracy: 0.9569 - seg_output_dice_coef: 0.7208 - seg_output_iou_metric: 0.5927 - val_loss: 0.4117 - val_seg_output_accuracy: 0.9603 - val_seg_output_dice_coef: 0.6992 - val_seg_output_iou_metric: 0.5670 - learning_rate: 0.0010
# Epoch 61/100
# 306/307 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.3521 - seg_output_accuracy: 0.9551 - seg_output_dice_coef: 0.7205 - seg_output_iou_metric: 0.5870
# Epoch 61: val_seg_output_dice_coef did not improve from 0.74145
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 23s 74ms/step - loss: 0.3605 - seg_output_accuracy: 0.9548 - seg_output_dice_coef: 0.7100 - seg_output_iou_metric: 0.5755 - val_loss: 0.3754 - val_seg_output_accuracy: 0.9618 - val_seg_output_dice_coef: 0.7157 - val_seg_output_iou_metric: 0.5850 - learning_rate: 0.0010
# Epoch 62/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.3379 - seg_output_accuracy: 0.9615 - seg_output_dice_coef: 0.7342 - seg_output_iou_metric: 0.6064
# Epoch 62: val_seg_output_dice_coef did not improve from 0.74145
#
# Epoch 62: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 23s 73ms/step - loss: 0.3406 - seg_output_accuracy: 0.9587 - seg_output_dice_coef: 0.7297 - seg_output_iou_metric: 0.5998 - val_loss: 0.3612 - val_seg_output_accuracy: 0.9511 - val_seg_output_dice_coef: 0.6957 - val_seg_output_iou_metric: 0.5633 - learning_rate: 0.0010
# Epoch 63/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.3263 - seg_output_accuracy: 0.9598 - seg_output_dice_coef: 0.7413 - seg_output_iou_metric: 0.6194
# Epoch 63: val_seg_output_dice_coef did not improve from 0.74145
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 25s 82ms/step - loss: 0.3303 - seg_output_accuracy: 0.9625 - seg_output_dice_coef: 0.7432 - seg_output_iou_metric: 0.6195 - val_loss: 0.3445 - val_seg_output_accuracy: 0.9608 - val_seg_output_dice_coef: 0.7365 - val_seg_output_iou_metric: 0.6096 - learning_rate: 5.0000e-04
# Epoch 64/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.3215 - seg_output_accuracy: 0.9604 - seg_output_dice_coef: 0.7481 - seg_output_iou_metric: 0.6229
# Epoch 64: val_seg_output_dice_coef improved from 0.74145 to 0.74925, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras
#
# Epoch 64: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 24s 77ms/step - loss: 0.3223 - seg_output_accuracy: 0.9625 - seg_output_dice_coef: 0.7491 - seg_output_iou_metric: 0.6234 - val_loss: 0.3409 - val_seg_output_accuracy: 0.9656 - val_seg_output_dice_coef: 0.7492 - val_seg_output_iou_metric: 0.6254 - learning_rate: 5.0000e-04
# Epoch 65/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.3079 - seg_output_accuracy: 0.9659 - seg_output_dice_coef: 0.7664 - seg_output_iou_metric: 0.6439
# Epoch 65: val_seg_output_dice_coef did not improve from 0.74925
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 23s 75ms/step - loss: 0.3117 - seg_output_accuracy: 0.9637 - seg_output_dice_coef: 0.7577 - seg_output_iou_metric: 0.6361 - val_loss: 0.3176 - val_seg_output_accuracy: 0.9612 - val_seg_output_dice_coef: 0.7454 - val_seg_output_iou_metric: 0.6230 - learning_rate: 5.0000e-04
# Epoch 66/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.3169 - seg_output_accuracy: 0.9646 - seg_output_dice_coef: 0.7516 - seg_output_iou_metric: 0.6308
# Epoch 66: val_seg_output_dice_coef improved from 0.74925 to 0.75064, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras
#
# Epoch 66: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 24s 78ms/step - loss: 0.3148 - seg_output_accuracy: 0.9640 - seg_output_dice_coef: 0.7523 - seg_output_iou_metric: 0.6313 - val_loss: 0.3300 - val_seg_output_accuracy: 0.9647 - val_seg_output_dice_coef: 0.7506 - val_seg_output_iou_metric: 0.6322 - learning_rate: 5.0000e-04
# Epoch 67/100
# 306/307 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.3234 - seg_output_accuracy: 0.9650 - seg_output_dice_coef: 0.7521 - seg_output_iou_metric: 0.6270
# Epoch 67: val_seg_output_dice_coef improved from 0.75064 to 0.75605, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras
#
# Epoch 67: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 24s 78ms/step - loss: 0.3093 - seg_output_accuracy: 0.9659 - seg_output_dice_coef: 0.7651 - seg_output_iou_metric: 0.6413 - val_loss: 0.3208 - val_seg_output_accuracy: 0.9648 - val_seg_output_dice_coef: 0.7560 - val_seg_output_iou_metric: 0.6323 - learning_rate: 5.0000e-04
# Epoch 68/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.3266 - seg_output_accuracy: 0.9634 - seg_output_dice_coef: 0.7399 - seg_output_iou_metric: 0.6195
# Epoch 68: val_seg_output_dice_coef did not improve from 0.75605
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 23s 74ms/step - loss: 0.3097 - seg_output_accuracy: 0.9642 - seg_output_dice_coef: 0.7573 - seg_output_iou_metric: 0.6381 - val_loss: 0.3217 - val_seg_output_accuracy: 0.9639 - val_seg_output_dice_coef: 0.7526 - val_seg_output_iou_metric: 0.6300 - learning_rate: 5.0000e-04
# Epoch 69/100
# 306/307 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.2963 - seg_output_accuracy: 0.9683 - seg_output_dice_coef: 0.7764 - seg_output_iou_metric: 0.6553
# Epoch 69: val_seg_output_dice_coef did not improve from 0.75605
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 23s 73ms/step - loss: 0.3023 - seg_output_accuracy: 0.9668 - seg_output_dice_coef: 0.7733 - seg_output_iou_metric: 0.6513 - val_loss: 0.3250 - val_seg_output_accuracy: 0.9574 - val_seg_output_dice_coef: 0.7329 - val_seg_output_iou_metric: 0.6096 - learning_rate: 5.0000e-04
# Epoch 70/100
# 306/307 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.3074 - seg_output_accuracy: 0.9642 - seg_output_dice_coef: 0.7589 - seg_output_iou_metric: 0.6353
# Epoch 70: val_seg_output_dice_coef improved from 0.75605 to 0.76609, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras
#
# Epoch 70: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 24s 77ms/step - loss: 0.3078 - seg_output_accuracy: 0.9646 - seg_output_dice_coef: 0.7603 - seg_output_iou_metric: 0.6373 - val_loss: 0.3156 - val_seg_output_accuracy: 0.9665 - val_seg_output_dice_coef: 0.7661 - val_seg_output_iou_metric: 0.6466 - learning_rate: 5.0000e-04
# Epoch 71/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.3101 - seg_output_accuracy: 0.9648 - seg_output_dice_coef: 0.7567 - seg_output_iou_metric: 0.6388
# Epoch 71: val_seg_output_dice_coef did not improve from 0.76609
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 23s 75ms/step - loss: 0.3113 - seg_output_accuracy: 0.9646 - seg_output_dice_coef: 0.7580 - seg_output_iou_metric: 0.6356 - val_loss: 0.3226 - val_seg_output_accuracy: 0.9639 - val_seg_output_dice_coef: 0.7518 - val_seg_output_iou_metric: 0.6311 - learning_rate: 5.0000e-04
# Epoch 72/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.3039 - seg_output_accuracy: 0.9651 - seg_output_dice_coef: 0.7673 - seg_output_iou_metric: 0.6464
# Epoch 72: val_seg_output_dice_coef did not improve from 0.76609
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 23s 73ms/step - loss: 0.3057 - seg_output_accuracy: 0.9661 - seg_output_dice_coef: 0.7654 - seg_output_iou_metric: 0.6432 - val_loss: 0.3255 - val_seg_output_accuracy: 0.9630 - val_seg_output_dice_coef: 0.7457 - val_seg_output_iou_metric: 0.6252 - learning_rate: 5.0000e-04
# Epoch 73/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.2894 - seg_output_accuracy: 0.9667 - seg_output_dice_coef: 0.7801 - seg_output_iou_metric: 0.6615
# Epoch 73: val_seg_output_dice_coef improved from 0.76609 to 0.76817, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras
#
# Epoch 73: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 24s 79ms/step - loss: 0.2969 - seg_output_accuracy: 0.9672 - seg_output_dice_coef: 0.7737 - seg_output_iou_metric: 0.6541 - val_loss: 0.3096 - val_seg_output_accuracy: 0.9660 - val_seg_output_dice_coef: 0.7682 - val_seg_output_iou_metric: 0.6509 - learning_rate: 5.0000e-04
# Epoch 74/100
# ...
# Epoch 34/100
# 1253/1257 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1383
# Epoch 34: val_loss did not improve from 0.08820
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 22s 17ms/step - loss: 0.1366 - val_loss: 0.1198
# Epoch 35/100
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1285
# Epoch 35: val_loss improved from 0.08820 to 0.07726, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras
#
# Epoch 35: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 22s 17ms/step - loss: 0.1366 - val_loss: 0.0773
# Epoch 36/100
# 1254/1257 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1418
# Epoch 36: val_loss did not improve from 0.07726
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 20s 16ms/step - loss: 0.1473 - val_loss: 0.0903
# Epoch 37/100
# 1254/1257 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1236
# Epoch 37: val_loss did not improve from 0.07726
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 20s 16ms/step - loss: 0.1292 - val_loss: 0.1020
# Epoch 38/100
# 1255/1257 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1345
# Epoch 38: val_loss did not improve from 0.07726
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 20s 16ms/step - loss: 0.1301 - val_loss: 0.1076
# Epoch 39/100
# 1253/1257 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1255
# Epoch 39: val_loss did not improve from 0.07726
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 20s 16ms/step - loss: 0.1234 - val_loss: 0.0973
# Epoch 40/100
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1157
# Epoch 40: val_loss did not improve from 0.07726
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 22s 18ms/step - loss: 0.1245 - val_loss: 0.1302
# Epoch 41/100
# 1253/1257 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1200
# Epoch 41: val_loss did not improve from 0.07726
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 20s 16ms/step - loss: 0.1233 - val_loss: 0.0843
# Epoch 42/100
# 1255/1257 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1101
# Epoch 42: val_loss improved from 0.07726 to 0.06820, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras
#
# Epoch 42: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 20s 16ms/step - loss: 0.1153 - val_loss: 0.0682
# Epoch 43/100
# 1255/1257 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1141
# Epoch 43: val_loss improved from 0.06820 to 0.06487, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras
#
# Epoch 43: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 20s 16ms/step - loss: 0.1131 - val_loss: 0.0649
# Epoch 44/100
# 1256/1257 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1167
# Epoch 44: val_loss did not improve from 0.06487
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.1151 - val_loss: 0.0883
# Epoch 45/100
# 1255/1257 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1137
# Epoch 45: val_loss did not improve from 0.06487
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.1190 - val_loss: 0.0915
# Epoch 46/100
# 1253/1257 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1225
# Epoch 46: val_loss did not improve from 0.06487
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.1144 - val_loss: 0.1007
# Epoch 47/100
# 1255/1257 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1090
# Epoch 47: val_loss did not improve from 0.06487
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 20s 15ms/step - loss: 0.1126 - val_loss: 0.0937
# Epoch 48/100
# 1254/1257 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1176
# Epoch 48: val_loss did not improve from 0.06487
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 20s 16ms/step - loss: 0.1080 - val_loss: 0.0708
# Epoch 49/100
# 1253/1257 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1145
# Epoch 49: val_loss did not improve from 0.06487
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.1185 - val_loss: 0.0763
# Epoch 50/100
# 1252/1257 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1123
# Epoch 50: val_loss did not improve from 0.06487
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 20s 16ms/step - loss: 0.1123 - val_loss: 0.0709
# Epoch 51/100
# 1256/1257 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0990
# Epoch 51: val_loss did not improve from 0.06487
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.1075 - val_loss: 0.1057
# Epoch 52/100
# 1256/1257 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1033
# Epoch 52: val_loss improved from 0.06487 to 0.05450, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras
#
# Epoch 52: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 22s 17ms/step - loss: 0.1036 - val_loss: 0.0545
# Epoch 53/100
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1056
# Epoch 53: val_loss did not improve from 0.05450
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 20s 16ms/step - loss: 0.1003 - val_loss: 0.0903
# Epoch 54/100
# 1253/1257 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0996
# Epoch 54: val_loss improved from 0.05450 to 0.05316, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras
#
# Epoch 54: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.0994 - val_loss: 0.0532
# Epoch 55/100
# 1256/1257 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0996
# Epoch 55: val_loss did not improve from 0.05316
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.0953 - val_loss: 0.1080
# Epoch 56/100
# 1253/1257 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1121
# Epoch 56: val_loss improved from 0.05316 to 0.04846, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras
#
# Epoch 56: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 21s 17ms/step - loss: 0.1111 - val_loss: 0.0485
# Epoch 57/100
# 1255/1257 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0972
# Epoch 57: val_loss did not improve from 0.04846
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.0959 - val_loss: 0.0710
# Epoch 58/100
# 1255/1257 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0949
# Epoch 58: val_loss did not improve from 0.04846
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.0964 - val_loss: 0.0577
# Epoch 59/100
# 1253/1257 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0912
# Epoch 59: val_loss did not improve from 0.04846
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.0981 - val_loss: 0.0606
# Epoch 60/100
# 1255/1257 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1014
# Epoch 60: val_loss did not improve from 0.04846
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 20s 16ms/step - loss: 0.0975 - val_loss: 0.0630
# Epoch 61/100
# 1256/1257 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0986
# Epoch 61: val_loss did not improve from 0.04846
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 22s 17ms/step - loss: 0.0977 - val_loss: 0.0893
# Epoch 62/100
# 1253/1257 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0932
# Epoch 62: val_loss did not improve from 0.04846
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 26s 21ms/step - loss: 0.0920 - val_loss: 0.0988
# Epoch 63/100
# 1253/1257 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0866
# Epoch 63: val_loss did not improve from 0.04846
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - loss: 0.0826 - val_loss: 0.0715
# Epoch 64/100
# 1254/1257 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0907
# Epoch 64: val_loss did not improve from 0.04846
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 26s 21ms/step - loss: 0.0925 - val_loss: 0.0487
# Epoch 65/100
# 1255/1257 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0800
# Epoch 65: val_loss did not improve from 0.04846
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 27s 22ms/step - loss: 0.0807 - val_loss: 0.0728
# Epoch 66/100
# 1256/1257 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0838
# Epoch 66: val_loss improved from 0.04846 to 0.04155, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras
#
# Epoch 66: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - loss: 0.0828 - val_loss: 0.0415
# Epoch 67/100
# 1254/1257 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0811
# Epoch 67: val_loss did not improve from 0.04155
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - loss: 0.0830 - val_loss: 0.0518
# Epoch 68/100
# 1254/1257 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0763
# Epoch 68: val_loss did not improve from 0.04155
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - loss: 0.0774 - val_loss: 0.0589
# Epoch 69/100
# 1255/1257 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0759
# Epoch 69: val_loss did not improve from 0.04155
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.0788 - val_loss: 0.0960
# Epoch 70/100
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0786
# Epoch 70: val_loss did not improve from 0.04155
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.0779 - val_loss: 0.0488
# Epoch 71/100
# 1255/1257 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0797
# Epoch 71: val_loss did not improve from 0.04155
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.0836 - val_loss: 0.0935
# Epoch 72/100
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0755
# Epoch 72: val_loss did not improve from 0.04155
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.0839 - val_loss: 0.0582
# Epoch 73/100
# 1256/1257 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0787
# Epoch 73: val_loss did not improve from 0.04155
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.0762 - val_loss: 0.0558
# Epoch 74/100
# 1252/1257 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0747
# Epoch 74: val_loss did not improve from 0.04155
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.0708 - val_loss: 0.0816
# Epoch 75/100
# 1253/1257 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0817
# Epoch 75: val_loss did not improve from 0.04155
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.0879 - val_loss: 0.0828
# Epoch 76/100
# 1253/1257 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0770
# Epoch 76: val_loss did not improve from 0.04155
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 20s 16ms/step - loss: 0.0770 - val_loss: 0.0675
# Epoch 77/100
# 1254/1257 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0704
# Epoch 77: val_loss did not improve from 0.04155
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 20s 16ms/step - loss: 0.0743 - val_loss: 0.0635
# Epoch 78/100
# 1254/1257 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0675
# Epoch 78: val_loss did not improve from 0.04155
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.0664 - val_loss: 0.0820
# Epoch 79/100
# 1254/1257 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0786
# Epoch 79: val_loss did not improve from 0.04155
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.0693 - val_loss: 0.0428
# Epoch 80/100
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0818
# Epoch 80: val_loss did not improve from 0.04155
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.0794 - val_loss: 0.0477
# Epoch 81/100
# 1253/1257 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0746
# Epoch 81: val_loss did not improve from 0.04155
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 20s 16ms/step - loss: 0.0711 - val_loss: 0.0532
# Epoch 82/100
# 1252/1257 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0706
# Epoch 82: val_loss improved from 0.04155 to 0.03375, saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras
#
# Epoch 82: finished saving model to /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 20s 16ms/step - loss: 0.0739 - val_loss: 0.0337
# Epoch 83/100
# 1254/1257 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0643
# Epoch 83: val_loss did not improve from 0.03375
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.0676 - val_loss: 0.0514
# Epoch 84/100
# 1256/1257 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0701
# Epoch 84: val_loss did not improve from 0.03375
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 20s 16ms/step - loss: 0.0700 - val_loss: 0.0702
# Epoch 85/100
# 1253/1257 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0673
# Epoch 85: val_loss did not improve from 0.03375
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 20s 16ms/step - loss: 0.0703 - val_loss: 0.0647
# Epoch 86/100
# 1253/1257 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0715
# Epoch 86: val_loss did not improve from 0.03375
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 20s 16ms/step - loss: 0.0652 - val_loss: 0.0520
# Epoch 87/100
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0547
# Epoch 87: val_loss did not improve from 0.03375
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.0649 - val_loss: 0.0671
# Epoch 88/100
# 1255/1257 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0715
# Epoch 88: val_loss did not improve from 0.03375
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 20s 16ms/step - loss: 0.0702 - val_loss: 0.0579
# Epoch 89/100
# 1255/1257 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0659
# Epoch 89: val_loss did not improve from 0.03375
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.0677 - val_loss: 0.0506
# Epoch 90/100
# 1255/1257 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0637
# Epoch 90: val_loss did not improve from 0.03375
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 20s 16ms/step - loss: 0.0653 - val_loss: 0.0515
# Epoch 91/100
# 1256/1257 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0624
# Epoch 91: val_loss did not improve from 0.03375
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 20s 16ms/step - loss: 0.0592 - val_loss: 0.0549
# Epoch 92/100
# 1254/1257 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0601
# Epoch 92: val_loss did not improve from 0.03375
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 20s 16ms/step - loss: 0.0642 - val_loss: 0.0408
# Epoch 93/100
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0786
# Epoch 93: val_loss did not improve from 0.03375
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.0706 - val_loss: 0.0427
# Epoch 94/100
# 1255/1257 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0719
# Epoch 94: val_loss did not improve from 0.03375
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - loss: 0.0707 - val_loss: 0.0487
# Epoch 95/100
# 1255/1257 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0665
# Epoch 95: val_loss did not improve from 0.03375
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 22s 17ms/step - loss: 0.0653 - val_loss: 0.0444
# Epoch 96/100
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0572
# Epoch 96: val_loss did not improve from 0.03375
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 21s 17ms/step - loss: 0.0603 - val_loss: 0.0389
# Epoch 97/100
# 1254/1257 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0595
# Epoch 97: val_loss did not improve from 0.03375
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 21s 16ms/step - loss: 0.0610 - val_loss: 0.0451
# Epoch 98/100
# 1256/1257 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0482
# Epoch 98: val_loss did not improve from 0.03375
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 21s 17ms/step - loss: 0.0570 - val_loss: 0.0783
# Epoch 99/100
# 1255/1257 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0544
# Epoch 99: val_loss did not improve from 0.03375
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 21s 17ms/step - loss: 0.0595 - val_loss: 0.0579
# Epoch 100/100
# 1256/1257 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0784
# Epoch 100: val_loss did not improve from 0.03375
# 1257/1257 ━━━━━━━━━━━━━━━━━━━━ 21s 16ms/step - loss: 0.0622 - val_loss: 0.0413
# Restoring model weights from the end of the best epoch: 82.
# 🏆 [TRAINING COMPLETE] Unified Graph successfully archived at: /mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential_25_5_04.keras

# %% [markdown]
# ### Evaluation Matrix

# %% [markdown]
# ### 📈 PHASE 1: SEGMENTATION LEARNING CURVES (TRAIN VS VALIDATION)

# %%
# ─────────────────────────────────────────────────────────────────────────────
# 📈 PHASE 1: SEGMENTATION LEARNING CURVES (TRAIN VS VALIDATION) - DYNAMIC FIX
# ─────────────────────────────────────────────────────────────────────────────
print("\n📈 [Visuals] Plotting Phase-1 Segmentation History (Train vs Val)...")
history_dict = history_p1.history 
epochs_range = range(1, len(history_dict['loss']) + 1)

dice_key = [k for k in history_dict.keys() if 'dice' in k and 'val' not in k][0]
val_dice_key = [k for k in history_dict.keys() if 'dice' in k and 'val' in k][0]

iou_key = [k for k in history_dict.keys() if 'iou' in k and 'val' not in k][0]
val_iou_key = [k for k in history_dict.keys() if 'iou' in k and 'val' in k][0]


acc_key = [k for k in history_dict.keys() if ('acc' in k or 'accuracy' in k) and 'val' not in k and 'dice' not in k and 'iou' not in k][0]
val_acc_key = [k for k in history_dict.keys() if ('acc' in k or 'accuracy' in k) and 'val' in k and 'dice' not in k and 'iou' not in k][0]

print(f"📊 Mapping Keys Automatically -> Dice: '{dice_key}', IoU: '{iou_key}', Accuracy: '{acc_key}'")

fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(18, 5), dpi=150)

# 1. Dice Coefficient Curve (Train vs Val)
axes[0].plot(epochs_range, history_dict[dice_key], color='teal', lw=2, label='Training Dice')
axes[0].plot(epochs_range, history_dict[val_dice_key], color='darkorange', lw=2, linestyle='--', label='Validation Dice')
axes[0].grid(True, linestyle=':', alpha=0.6)
axes[0].set_title('Segmentation Dice Coefficient', fontsize=12, fontweight='bold')
axes[0].set_xlabel('Epochs', fontsize=10)
axes[0].set_ylabel('Dice Score', fontsize=10)
axes[0].legend(loc='lower right')

# 2. IoU Metric Curve (Train vs Val)
axes[1].plot(epochs_range, history_dict[iou_key], color='purple', lw=2, label='Training IoU')
axes[1].plot(epochs_range, history_dict[val_iou_key], color='crimson', lw=2, linestyle='--', label='Validation IoU')
axes[1].grid(True, linestyle=':', alpha=0.6)
axes[1].set_title('Intersection over Union (IoU)', fontsize=12, fontweight='bold')
axes[1].set_xlabel('Epochs', fontsize=10)
axes[1].set_ylabel('IoU Score', fontsize=10)
axes[1].legend(loc='lower right')

# 3. Pixel Accuracy Curve (Train vs Val)
axes[2].plot(epochs_range, history_dict[acc_key], color='forestgreen', lw=2, label='Training Accuracy')
axes[2].plot(epochs_range, history_dict[val_acc_key], color='royalblue', lw=2, linestyle='--', label='Validation Accuracy')
axes[2].grid(True, linestyle=':', alpha=0.6)
axes[2].set_title('Segmentation Pixel Accuracy', fontsize=12, fontweight='bold')
axes[2].set_xlabel('Epochs', fontsize=10)
axes[2].set_ylabel('Accuracy Score', fontsize=10)
axes[2].legend(loc='lower right')

plt.tight_layout()
plt.show()
print("💾 Saved: segmentation_train_val_metrics04.png")
# Out:
# 📈 [Visuals] Plotting Phase-1 Segmentation History (Train vs Val)...
# 📊 Mapping Keys Automatically -> Dice: 'seg_output_dice_coef', IoU: 'seg_output_iou_metric', Accuracy: 'seg_output_accuracy'
# 💾 Saved: segmentation_train_val_metrics04.png

# %%
import matplotlib.pyplot as plt

print("\n📈 [Visuals] Plotting Phase-2 Classification Loss (Train vs Val)...")
h2_dict = history_p2.history
epochs_p2 = range(1, len(h2_dict['loss']) + 1)

p2_loss = [k for k in h2_dict.keys() if 'loss' in k and 'val' not in k][0]
p2_val_loss = [k for k in h2_dict.keys() if 'loss' in k and 'val' in k][0]


plt.figure(figsize=(8, 5), dpi=100)
plt.plot(epochs_p2, h2_dict[p2_loss], color='crimson', lw=2.5, label='Training Loss')
plt.plot(epochs_p2, h2_dict[p2_val_loss], color='midnightblue', lw=2.5, linestyle='--', label='Validation Loss')

# গ্রাফের সৌন্দর্য ও লেবেলিং
plt.title('Classification Cross-Entropy Loss Learning Curve', fontsize=12, fontweight='bold', pad=12)
plt.xlabel('Epochs', fontsize=10)
plt.ylabel('Loss Value', fontsize=10)
plt.grid(True, linestyle=':', alpha=0.6)
plt.legend(loc='upper right', fontsize=10)

plt.tight_layout()
plt.show()

print("💾 Saved: classification_train_val_loss.png")
# Out:
# 📈 [Visuals] Plotting Phase-2 Classification Loss (Train vs Val)...
# 💾 Saved: classification_train_val_loss.png

# %%
print(list(history_p2.history.keys()))
# Out:
# ['loss', 'val_loss']

# %% [markdown]
# ### Testing the Model Phase 1 + Phase 2

# %%
# %matplotlib inline

import os
import cv2
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# ─────────────────────────────────────────────────────────────────────────────
# ⚙️ GLOBAL INFERENCE CONFIGURATIONS
# ─────────────────────────────────────────────────────────────────────────────
IMG_SIZE = 256

# Define your exact paths here
MODEL_PATH = "/mnt/c/development/Thesis/PolypSegmentationBasedClassification/models/SC/unified_net/thesis_v3_sequential.keras"
TEST_POSITIVE_IMAGE_PATH = "/mnt/c/development/Thesis/PolypSegmentationBasedClassification/DataSets/PolypGen2021_MultiCenterData_v2/data_C4/images_C4/16_endocv2021_positive_557.jpg"
TEST_NEG_IMAGE_PATH = "/mnt/c/development/Thesis/PolypSegmentationBasedClassification/DataSets/PolypGen2021_MultiCenterData_v2/sequenceData/negativeOnly/seq10_neg/EndoCV2021_seq10_neg_40_endocv2021_negative_754.jpg"
TEST_POSITIVE_IMAGE_PATH_2 = "/mnt/c/development/Thesis/PolypSegmentationBasedClassification/DataSets/PolypGen2021_MultiCenterData_v2/imagesAll_positive/176OLCV1_100H0890.jpg"
TEST_NEG2_IMAGE_PATH = "/mnt/c/development/Thesis/PolypSegmentationBasedClassification/DataSets/PolypGen2021_MultiCenterData_v2/sequenceData/negativeOnly/seq13_neg/EndoCV2021_C5_seq3_246.jpg"
# ─────────────────────────────────────────────────────────────────────────────
# 🎨 REFINED IMAGE LABELED LOCALIZATION ENGINE
# ─────────────────────────────────────────────────────────────────────────────
def draw_bounding_box(image, mask):
    """
    Draws a clean bounding box around the predicted polyp region with 
    high-contrast paper-grade typography and dimension mapping.
    """
    res_img = image.copy()
    mask_uint8 = (mask > 0.5).astype(np.uint8) * 255
    contours, _ = cv2.findContours(mask_uint8, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    
    # Calibration ratio: mapping image pixels to physical centimeters
    pixel_to_cm_ratio = 50 
    
    for cnt in contours:
        # Filter out minor noise elements or artifacts
        if cv2.contourArea(cnt) < 10:
            continue
            
        x, y, w, h = cv2.boundingRect(cnt)
        
        # Calculate real-world scale approximations
        width_cm = w / pixel_to_cm_ratio
        height_cm = h / pixel_to_cm_ratio
        size_text = f"Polyp: {width_cm:.1f}cm x {height_cm:.1f}cm"
        
        # 1. Draw High-Visibility Bounding Box (Green)
        cv2.rectangle(res_img, (x, y), (x + w, y + h), (0, 255, 0), 2)
        
        # 2. Advanced Typography: Dynamic Text Positioning with Background Shadow
        text_y = y - 10 if y - 10 > 20 else y + h + 20
        
        # Draw a clean black backdrop shadow for ultra-clear readability in papers
        cv2.putText(res_img, size_text, (x + 1, text_y + 1), 
                    cv2.FONT_HERSHEY_SIMPLEX, 0.45, (0, 0, 0), 2, cv2.LINE_AA)
        # Draw the primary text layer
        cv2.putText(res_img, size_text, (x, text_y), 
                    cv2.FONT_HERSHEY_SIMPLEX, 0.45, (0, 255, 0), 1, cv2.LINE_AA)
        
    return res_img

# ─────────────────────────────────────────────────────────────────────────────
# 🔮 MULTI-TASK INFERENCE CORE PIPELINE (SEGMENTATION + CLASSIFICATION)
# ─────────────────────────────────────────────────────────────────────────────
def test_and_display(model, image_path, output_filename='result.png'):
    """
    Executes a joint multi-task prediction, extracting both pixel-level 
    segmentation masks and categorical classification diagnostic boundaries.
    """
    # 1. Read and pre-process target frame
    img = cv2.imread(image_path)
    if img is None:
        raise FileNotFoundError(f"❌ Target frame could not be loaded at: {image_path}")
        
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img_res = cv2.resize(img_rgb, (IMG_SIZE, IMG_SIZE))
    inp = np.expand_dims(img_res / 255.0, axis=0).astype(np.float32)

    # 2. Target forward pass prediction (Extracting multi-head lists)
    pred_outputs = model.predict(inp, verbose=0)
    
    # Check if the model returns a multi-head list [seg_output, clf_output]
    if isinstance(pred_outputs, list) and len(pred_outputs) >= 2:
        pred_mask_spatial = pred_outputs[0][0]  # Output Index 0: Segmentation Mask [256, 256, 1]
        clf_prediction = pred_outputs[1][0][0]  # Output Index 1: Classification Score (Scalar)
        has_classification = True
    else:
        # Fallback if model architecture is only predicting masks in this state
        pred_mask_spatial = pred_outputs[0] if isinstance(pred_outputs, list) else pred_outputs[0]
        clf_prediction = 0.0
        has_classification = False

    # 3. Geometric extraction mappings
    mask_bin = (pred_mask_spatial > 0.5).astype(np.uint8)
    mask_3d = np.concatenate([mask_bin] * 3, axis=-1)
    extracted = (img_res * mask_3d).astype(np.uint8)
    detected_img = draw_bounding_box(img_res, pred_mask_spatial)

    # 4. Generate Dynamically Labeled Classification Title
    if has_classification:
        if clf_prediction >= 0.5:
            diagnostic_text = f"DIAGNOSIS: POLYP DETECTED ({clf_prediction * 100:.2f}% Confidence)"
            title_color = '#1faa00' # Vibrant Green
        else:
            diagnostic_text = f"DIAGNOSIS: NON-POLYP ({(1.0 - clf_prediction) * 100:.2f}% Confidence)"
            title_color = '#dd0000' # Deep Red
    else:
        diagnostic_text = "DIAGNOSIS: Segmentation Mode Active (No Classification Head Found)"
        title_color = 'orange'

    # 5. Generate Professional 4-Column Presentation Graph
    titles = ['(a) Original Frame', '(b) Predicted Mask', '(c) Extracted Region', '(d) Localization View']
    display_images = [img_res, pred_mask_spatial.squeeze(), extracted, detected_img]
    
    fig, axes = plt.subplots(1, 4, figsize=(20, 5))
    
    for i in range(4):
        axes[i].imshow(display_images[i], cmap='gray' if i == 1 else None)
        axes[i].set_title(titles[i], fontsize=13, fontweight='bold', pad=12)
        axes[i].axis('off')
    
    # High-level overview structural description super-title with live diagnosis
    plt.suptitle(diagnostic_text, fontsize=16, fontweight='bold', color=title_color, y=1.04)
    
    plt.tight_layout()
    
    # Save the polished output image to disk
    plt.savefig(output_filename, dpi=300, bbox_inches='tight')
    print(f"🏆 Qualitative evaluation plot successfully saved to: {output_filename}")
    plt.show()

# ─────────────────────────────────────────────────────────────────────────────
# 🏃‍♂️ EXECUTION STEP
# ─────────────────────────────────────────────────────────────────────────────
if __name__ == '__main__':
    print("⏳ Loading Keras Architecture Graph into Memory (Shared Nodes)...")
    # Load model once outside the function to optimize execution loop
    shared_model = tf.keras.models.load_model(MODEL_PATH, compile=False)
    print("✅ Multi-Task Graph successfully initialized.\n")
    
    print("🎬 Processing Positive Dataset Specimen...")
    test_and_display(shared_model, TEST_POSITIVE_IMAGE_PATH, 'thesis_positive_result.png')
    
    print("\n🎬 Processing Negative Dataset Specimen...")
    test_and_display(shared_model, TEST_NEG_IMAGE_PATH, 'thesis_negative_result.png')

    print("\n🎬 Processing Negative Dataset Specimen...")
    test_and_display(shared_model, TEST_POSITIVE_IMAGE_PATH_2,'Neg3.png')

    print("\n🎬 Processing Negative Dataset Specimen...")
    test_and_display(shared_model, TEST_NEG2_IMAGE_PATH,'Neg4.png')
# Out:
# ⏳ Loading Keras Architecture Graph into Memory (Shared Nodes)...
# ✅ Multi-Task Graph successfully initialized.
#
# 🎬 Processing Positive Dataset Specimen...
# 🏆 Qualitative evaluation plot successfully saved to: thesis_positive_result.png
# 🎬 Processing Negative Dataset Specimen...
# 🏆 Qualitative evaluation plot successfully saved to: thesis_negative_result.png
# 🎬 Processing Negative Dataset Specimen...
# 🏆 Qualitative evaluation plot successfully saved to: Neg3.png
# 🎬 Processing Negative Dataset Specimen...
# 🏆 Qualitative evaluation plot successfully saved to: Neg4.png

# %% [markdown]
# #### Performance Matrix

# %%
# =============================================================================
# 📊 PRINT PEAK PERFORMANCE METRICS FOR THESIS REPORT
# =============================================================================
print("=====================================================================")
print("🏆 Unified Model: Peak Performance Metrics (Phase 1 & Phase 2)")
print("=====================================================================")

# 🧠 1. PHASE 1: SEMANTIC SEGMENTATION PERFORMANCE
h1 = history_p1.history

dice_key = [k for k in h1.keys() if 'dice' in k and 'val' not in k][0]
val_dice_key = [k for k in h1.keys() if 'dice' in k and 'val' in k][0]
iou_key = [k for k in h1.keys() if 'iou' in k and 'val' not in k][0]
val_iou_key = [k for k in h1.keys() if 'iou' in k and 'val' in k][0]


best_p1_idx = np.argmax(h1[val_dice_key])

print(f"\n📍 [PHASE 1: SEGMENTATION (Best Epoch: {best_p1_idx + 1})]")
print(f"   • Best Training Dice Score : {h1[dice_key][best_p1_idx]:.4f}")
print(f"   • Best Validation Dice Score : {h1[val_dice_key][best_p1_idx]:.4f} 🌟")
print(f"   • Associated Training IoU  : {h1[iou_key][best_p1_idx]:.4f}")
print(f"   • Associated Validation IoU: {h1[val_iou_key][best_p1_idx]:.4f}")


# 🧠 2. PHASE 2: CLASSIFICATION PERFORMANCE
h2 = history_p2.history
best_p2_idx = np.argmin(h2['val_loss'])

print(f"\n📍 [PHASE 2: CLASSIFICATION (Best Epoch: {best_p2_idx + 1})]")
print(f"   • Minimum Training Loss    : {h2['loss'][best_p2_idx]:.4f}")
print(f"   • Minimum Validation Loss  : {h2['val_loss'][best_p2_idx]:.4f} 🌟")


p2_acc_keys = [k for k in h2.keys() if 'acc' in k or 'accuracy' in k]
if p2_acc_keys:
    acc_k = [k for k in p2_acc_keys if 'val' not in k][0]
    val_acc_k = [k for k in p2_acc_keys if 'val' in k][0]
    print(f"   • Peak Training Accuracy   : {h2[acc_k][best_p2_idx]:.4f}")
    print(f"   • Peak Validation Accuracy : {h2[val_acc_k][best_p2_idx]:.4f}")
else:
    print("   • Note: Accuracy metrics were dropped in Phase 2 compile for this run.")

print("=====================================================================")
# Out:
# =====================================================================
# 🏆 Unified Model: Peak Performance Metrics (Phase 1 & Phase 2)
# =====================================================================
#
# 📍 [PHASE 1: SEGMENTATION (Best Epoch: 92)]
#    • Best Training Dice Score : 0.8116
#    • Best Validation Dice Score : 0.7871 🌟
#    • Associated Training IoU  : 0.7022
#    • Associated Validation IoU: 0.6750
#
# 📍 [PHASE 2: CLASSIFICATION (Best Epoch: 82)]
#    • Minimum Training Loss    : 0.0739
#    • Minimum Validation Loss  : 0.0337 🌟
#    • Note: Accuracy metrics were dropped in Phase 2 compile for this run.
# =====================================================================

# %% [markdown]
# #### Model Summary

# %%
model.summary()
# Out:
# Model: "Thesis_Unified_YNet"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ shared_input_image  │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_c1_3x3          │ (None, 256, 256,  │         51 │ shared_input_ima… │
# │ (SeparableConv2D)   │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_c1_5x5          │ (None, 256, 256,  │         99 │ shared_input_ima… │
# │ (SeparableConv2D)   │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_c1_7x7          │ (None, 256, 256,  │        171 │ shared_input_ima… │
# │ (SeparableConv2D)   │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_c1_1x1          │ (None, 256, 256,  │         27 │ shared_input_ima… │
# │ (SeparableConv2D)   │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         32 │ enc_c1_3x3[0][0]  │
# │ (BatchNormalizatio… │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         32 │ enc_c1_5x5[0][0]  │
# │ (BatchNormalizatio… │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         32 │ enc_c1_7x7[0][0]  │
# │ (BatchNormalizatio… │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         32 │ enc_c1_1x1[0][0]  │
# │ (BatchNormalizatio… │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_36       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_37       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_38       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_39       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_c1_concat       │ (None, 256, 256,  │          0 │ activation_36[0]… │
# │ (Concatenate)       │ 32)               │            │ activation_37[0]… │
# │                     │                   │            │ activation_38[0]… │
# │                     │                   │            │ activation_39[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 32)        │          0 │ enc_c1_concat[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_18 (Dense)    │ (None, 2)         │         64 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_19 (Dense)    │ (None, 32)        │         64 │ dense_18[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_9 (Reshape) │ (None, 1, 1, 32)  │          0 │ dense_19[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_9          │ (None, 256, 256,  │          0 │ enc_c1_concat[0]… │
# │ (Multiply)          │ 32)               │            │ reshape_9[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_p1              │ (None, 128, 128,  │          0 │ multiply_9[0][0]  │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_c2_3x3          │ (None, 128, 128,  │        800 │ enc_p1[0][0]      │
# │ (SeparableConv2D)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_c2_5x5          │ (None, 128, 128,  │      1,312 │ enc_p1[0][0]      │
# │ (SeparableConv2D)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_c2_7x7          │ (None, 128, 128,  │      2,080 │ enc_p1[0][0]      │
# │ (SeparableConv2D)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_c2_1x1          │ (None, 128, 128,  │        544 │ enc_p1[0][0]      │
# │ (SeparableConv2D)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ enc_c2_3x3[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ enc_c2_5x5[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ enc_c2_7x7[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ enc_c2_1x1[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_40       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_41       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_42       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_43       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_c2_concat       │ (None, 128, 128,  │          0 │ activation_40[0]… │
# │ (Concatenate)       │ 64)               │            │ activation_41[0]… │
# │                     │                   │            │ activation_42[0]… │
# │                     │                   │            │ activation_43[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 64)        │          0 │ enc_c2_concat[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_20 (Dense)    │ (None, 4)         │        256 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_21 (Dense)    │ (None, 64)        │        256 │ dense_20[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_10          │ (None, 1, 1, 64)  │          0 │ dense_21[0][0]    │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_10         │ (None, 128, 128,  │          0 │ enc_c2_concat[0]… │
# │ (Multiply)          │ 64)               │            │ reshape_10[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_p2              │ (None, 64, 64,    │          0 │ multiply_10[0][0] │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_c3_3x3          │ (None, 64, 64,    │      2,624 │ enc_p2[0][0]      │
# │ (SeparableConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_c3_5x5          │ (None, 64, 64,    │      3,648 │ enc_p2[0][0]      │
# │ (SeparableConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_c3_7x7          │ (None, 64, 64,    │      5,184 │ enc_p2[0][0]      │
# │ (SeparableConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_c3_1x1          │ (None, 64, 64,    │      2,112 │ enc_p2[0][0]      │
# │ (SeparableConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ enc_c3_3x3[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ enc_c3_5x5[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ enc_c3_7x7[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ enc_c3_1x1[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_44       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_45       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_46       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_47       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_c3_concat       │ (None, 64, 64,    │          0 │ activation_44[0]… │
# │ (Concatenate)       │ 128)              │            │ activation_45[0]… │
# │                     │                   │            │ activation_46[0]… │
# │                     │                   │            │ activation_47[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ enc_c3_concat[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_22 (Dense)    │ (None, 8)         │      1,024 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_23 (Dense)    │ (None, 128)       │      1,024 │ dense_22[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_11          │ (None, 1, 1, 128) │          0 │ dense_23[0][0]    │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_11         │ (None, 64, 64,    │          0 │ enc_c3_concat[0]… │
# │ (Multiply)          │ 128)              │            │ reshape_11[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_c3_dropout      │ (None, 64, 64,    │          0 │ multiply_11[0][0] │
# │ (SpatialDropout2D)  │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_p3              │ (None, 32, 32,    │          0 │ enc_c3_dropout[0… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_c4_3x3          │ (None, 32, 32,    │      9,344 │ enc_p3[0][0]      │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_c4_5x5          │ (None, 32, 32,    │     11,392 │ enc_p3[0][0]      │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_c4_7x7          │ (None, 32, 32,    │     14,464 │ enc_p3[0][0]      │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_c4_1x1          │ (None, 32, 32,    │      8,320 │ enc_p3[0][0]      │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ enc_c4_3x3[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ enc_c4_5x5[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ enc_c4_7x7[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ enc_c4_1x1[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_48       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_49       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_50       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_51       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_c4_concat       │ (None, 32, 32,    │          0 │ activation_48[0]… │
# │ (Concatenate)       │ 256)              │            │ activation_49[0]… │
# │                     │                   │            │ activation_50[0]… │
# │                     │                   │            │ activation_51[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 256)       │          0 │ enc_c4_concat[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_24 (Dense)    │ (None, 16)        │      4,096 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_25 (Dense)    │ (None, 256)       │      4,096 │ dense_24[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_12          │ (None, 1, 1, 256) │          0 │ dense_25[0][0]    │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_12         │ (None, 32, 32,    │          0 │ enc_c4_concat[0]… │
# │ (Multiply)          │ 256)              │            │ reshape_12[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_c4_dropout      │ (None, 32, 32,    │          0 │ multiply_12[0][0] │
# │ (SpatialDropout2D)  │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_p4              │ (None, 16, 16,    │          0 │ enc_c4_dropout[0… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ shared_bottleneck_… │ (None, 16, 16,    │     35,072 │ enc_p4[0][0]      │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ shared_bottleneck_… │ (None, 16, 16,    │     39,168 │ enc_p4[0][0]      │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ shared_bottleneck_… │ (None, 16, 16,    │     45,312 │ enc_p4[0][0]      │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ shared_bottleneck_… │ (None, 16, 16,    │     33,024 │ enc_p4[0][0]      │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ shared_bottlenec… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ shared_bottlenec… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ shared_bottlenec… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ shared_bottlenec… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_52       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_53       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_54       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_55       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ shared_bottleneck_… │ (None, 16, 16,    │          0 │ activation_52[0]… │
# │ (Concatenate)       │ 512)              │            │ activation_53[0]… │
# │                     │                   │            │ activation_54[0]… │
# │                     │                   │            │ activation_55[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 512)       │          0 │ shared_bottlenec… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_26 (Dense)    │ (None, 32)        │     16,384 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_27 (Dense)    │ (None, 512)       │     16,384 │ dense_26[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_13          │ (None, 1, 1, 512) │          0 │ dense_27[0][0]    │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_13         │ (None, 16, 16,    │          0 │ shared_bottlenec… │
# │ (Multiply)          │ 512)              │            │ reshape_13[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ shared_bottleneck_… │ (None, 16, 16,    │          0 │ multiply_13[0][0] │
# │ (SpatialDropout2D)  │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_u4              │ (None, 32, 32,    │    524,544 │ shared_bottlenec… │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_concat_4        │ (None, 32, 32,    │          0 │ dec_u4[0][0],     │
# │ (Concatenate)       │ 512)              │            │ enc_c4_dropout[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_c5_3x3          │ (None, 32, 32,    │     37,376 │ dec_concat_4[0][… │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_c5_5x5          │ (None, 32, 32,    │     45,568 │ dec_concat_4[0][… │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_c5_7x7          │ (None, 32, 32,    │     57,856 │ dec_concat_4[0][… │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_c5_1x1          │ (None, 32, 32,    │     33,280 │ dec_concat_4[0][… │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ dec_c5_3x3[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ dec_c5_5x5[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ dec_c5_7x7[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ dec_c5_1x1[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_56       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_57       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_58       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_59       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_c5_concat       │ (None, 32, 32,    │          0 │ activation_56[0]… │
# │ (Concatenate)       │ 256)              │            │ activation_57[0]… │
# │                     │                   │            │ activation_58[0]… │
# │                     │                   │            │ activation_59[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 256)       │          0 │ dec_c5_concat[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_28 (Dense)    │ (None, 16)        │      4,096 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_29 (Dense)    │ (None, 256)       │      4,096 │ dense_28[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_14          │ (None, 1, 1, 256) │          0 │ dense_29[0][0]    │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_14         │ (None, 32, 32,    │          0 │ dec_c5_concat[0]… │
# │ (Multiply)          │ 256)              │            │ reshape_14[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_c5_dropout      │ (None, 32, 32,    │          0 │ multiply_14[0][0] │
# │ (SpatialDropout2D)  │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_u3              │ (None, 64, 64,    │    131,200 │ dec_c5_dropout[0… │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_concat_3        │ (None, 64, 64,    │          0 │ dec_u3[0][0],     │
# │ (Concatenate)       │ 256)              │            │ enc_c3_dropout[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_c6_3x3          │ (None, 64, 64,    │     10,496 │ dec_concat_3[0][… │
# │ (SeparableConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_c6_5x5          │ (None, 64, 64,    │     14,592 │ dec_concat_3[0][… │
# │ (SeparableConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_c6_7x7          │ (None, 64, 64,    │     20,736 │ dec_concat_3[0][… │
# │ (SeparableConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_c6_1x1          │ (None, 64, 64,    │      8,448 │ dec_concat_3[0][… │
# │ (SeparableConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ dec_c6_3x3[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ dec_c6_5x5[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ dec_c6_7x7[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ dec_c6_1x1[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_60       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_61       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_62       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_63       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_c6_concat       │ (None, 64, 64,    │          0 │ activation_60[0]… │
# │ (Concatenate)       │ 128)              │            │ activation_61[0]… │
# │                     │                   │            │ activation_62[0]… │
# │                     │                   │            │ activation_63[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ dec_c6_concat[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_30 (Dense)    │ (None, 8)         │      1,024 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_31 (Dense)    │ (None, 128)       │      1,024 │ dense_30[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_15          │ (None, 1, 1, 128) │          0 │ dense_31[0][0]    │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_15         │ (None, 64, 64,    │          0 │ dec_c6_concat[0]… │
# │ (Multiply)          │ 128)              │            │ reshape_15[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_c6_dropout      │ (None, 64, 64,    │          0 │ multiply_15[0][0] │
# │ (SpatialDropout2D)  │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_u2              │ (None, 128, 128,  │     32,832 │ dec_c6_dropout[0… │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_concat_2        │ (None, 128, 128,  │          0 │ dec_u2[0][0],     │
# │ (Concatenate)       │ 128)              │            │ multiply_10[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_c7_3x3          │ (None, 128, 128,  │      3,200 │ dec_concat_2[0][… │
# │ (SeparableConv2D)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_c7_5x5          │ (None, 128, 128,  │      5,248 │ dec_concat_2[0][… │
# │ (SeparableConv2D)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_c7_7x7          │ (None, 128, 128,  │      8,320 │ dec_concat_2[0][… │
# │ (SeparableConv2D)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_c7_1x1          │ (None, 128, 128,  │      2,176 │ dec_concat_2[0][… │
# │ (SeparableConv2D)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ dec_c7_3x3[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ dec_c7_5x5[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ dec_c7_7x7[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ dec_c7_1x1[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_64       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_65       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_66       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_67       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_c7_concat       │ (None, 128, 128,  │          0 │ activation_64[0]… │
# │ (Concatenate)       │ 64)               │            │ activation_65[0]… │
# │                     │                   │            │ activation_66[0]… │
# │                     │                   │            │ activation_67[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 64)        │          0 │ dec_c7_concat[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_32 (Dense)    │ (None, 4)         │        256 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_33 (Dense)    │ (None, 64)        │        256 │ dense_32[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_16          │ (None, 1, 1, 64)  │          0 │ dense_33[0][0]    │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_16         │ (None, 128, 128,  │          0 │ dec_c7_concat[0]… │
# │ (Multiply)          │ 64)               │            │ reshape_16[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_u1              │ (None, 256, 256,  │      8,224 │ multiply_16[0][0] │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_concat_1        │ (None, 256, 256,  │          0 │ dec_u1[0][0],     │
# │ (Concatenate)       │ 64)               │            │ multiply_9[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_c8_3x3          │ (None, 256, 256,  │      1,088 │ dec_concat_1[0][… │
# │ (SeparableConv2D)   │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_c8_5x5          │ (None, 256, 256,  │      2,112 │ dec_concat_1[0][… │
# │ (SeparableConv2D)   │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_c8_7x7          │ (None, 256, 256,  │      3,648 │ dec_concat_1[0][… │
# │ (SeparableConv2D)   │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_c8_1x1          │ (None, 256, 256,  │        576 │ dec_concat_1[0][… │
# │ (SeparableConv2D)   │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         32 │ dec_c8_3x3[0][0]  │
# │ (BatchNormalizatio… │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         32 │ dec_c8_5x5[0][0]  │
# │ (BatchNormalizatio… │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         32 │ dec_c8_7x7[0][0]  │
# │ (BatchNormalizatio… │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │         32 │ dec_c8_1x1[0][0]  │
# │ (BatchNormalizatio… │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_68       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_69       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_70       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_71       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 8)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ clf_pd_cnn          │ (None, 16, 16,    │     21,024 │ shared_bottlenec… │
# │ (SeparableConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dec_c8_concat       │ (None, 256, 256,  │          0 │ activation_68[0]… │
# │ (Concatenate)       │ 32)               │            │ activation_69[0]… │
# │                     │                   │            │ activation_70[0]… │
# │                     │                   │            │ activation_71[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ clf_maxpool         │ (None, 8, 8, 32)  │          0 │ clf_pd_cnn[0][0]  │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 32)        │          0 │ dec_c8_concat[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ clf_gap             │ (None, 32)        │          0 │ clf_maxpool[0][0] │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_34 (Dense)    │ (None, 2)         │         64 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ clf_pcc_layer       │ (None, 1024)      │          0 │ clf_gap[0][0]     │
# │ (KerasPCCLayer)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_35 (Dense)    │ (None, 32)        │         64 │ dense_34[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ clf_zscore_bn       │ (None, 1024)      │      4,096 │ clf_pcc_layer[0]… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_17          │ (None, 1, 1, 32)  │          0 │ dense_35[0][0]    │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ clf_dense1 (Dense)  │ (None, 64)        │     65,600 │ clf_zscore_bn[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_17         │ (None, 256, 256,  │          0 │ dec_c8_concat[0]… │
# │ (Multiply)          │ 32)               │            │ reshape_17[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ clf_dropout         │ (None, 64)        │          0 │ clf_dense1[0][0]  │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ seg_output (Conv2D) │ (None, 256, 256,  │         33 │ multiply_17[0][0] │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ clf_output (Dense)  │ (None, 1)         │         65 │ clf_dropout[0][0] │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,494,982 (5.70 MB)
#  Trainable params: 88,737 (346.63 KB)
#  Non-trainable params: 1,228,765 (4.69 MB)
#  Optimizer params: 177,480 (693.29 KB)

# %% [markdown]
# #### Image Segmentation Time

# %%
import time
import numpy as np
import tensorflow as tf

sample_images, _ = next(iter(val_seg_ds.take(1))) 
sample_images = sample_images[:5] 

print("⚡ Running GPU Warm-up iterations...")
for _ in range(2):
    _ = model.predict(sample_images[0:1], verbose=0)

print("⏱️ Measuring exact inference time per image...")
execution_times = []

for i in range(len(sample_images)):
    single_img = tf.expand_dims(sample_images[i], axis=0) # Shape: (1, 256, 256, 3)
    
    start_time = time.perf_counter()
    

    outputs = model.predict(single_img, verbose=0)
    

    _ = tf.cast(outputs[0], tf.float32) 
    
    end_time = time.perf_counter()
    
    elapsed_time = (end_time - start_time) * 1000 
    execution_times.append(elapsed_time)
    print(f"   • Image {i+1}: {elapsed_time:.2f} ms")


avg_time_ms = np.mean(execution_times)
avg_time_sec = avg_time_ms / 1000
fps = 1 / avg_time_sec

print("\n=======================================================")
print("📊 FINAL COMPUTATIONAL EFFICIENCY REPORT")
print("=======================================================")
print(f"🚀 Average Inference Time : {avg_time_ms:.2f} ms per image")
print(f"⏰ In Seconds              : {avg_time_sec:.4f} seconds")
print(f"🎬 Frames Per Second (FPS) : {fps:.2f} FPS 🌟")
print("=======================================================")
# Out:
# ⚡ Running GPU Warm-up iterations...
# ⏱️ Measuring exact inference time per image...
#    • Image 1: 89.76 ms
#    • Image 2: 101.91 ms
#    • Image 3: 109.70 ms
#    • Image 4: 117.68 ms
#
# =======================================================
# 📊 FINAL COMPUTATIONAL EFFICIENCY REPORT
# =======================================================
# 🚀 Average Inference Time : 104.76 ms per image
# ⏰ In Seconds              : 0.1048 seconds
# 🎬 Frames Per Second (FPS) : 9.55 FPS 🌟
# =======================================================
